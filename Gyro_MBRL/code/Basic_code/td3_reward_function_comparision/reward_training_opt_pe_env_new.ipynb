# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeNewEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=100,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_new_env_100', exp_name='td3_pe_opt_ing_20000')
                   )
# Out:
# Warning: Log dir td3_pe_opt_ing_new_100 already exists! Storing info there anyway.
# Logging data to td3_pe_opt_ing_new_100/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f1821dec8c8>, 'GyroscopeNewEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	100,
#     "exp_name":	"td3_pe_opt_ing_20000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f1821dfa320>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_20000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_new_100",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_new_100/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_20000",
#         "output_dir":	"td3_pe_opt_ing_new_100"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            5.46 |
# |          MaxEpRet |            -479 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -485 |
# |      StdTestEpRet |               4 |
# |      MaxTestEpRet |            -479 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.04 |
# |         StdQ1Vals |            1.97 |
# |         MaxQ1Vals |         -0.0117 |
# |         MinQ1Vals |           -9.95 |
# |     AverageQ2Vals |           -6.11 |
# |         StdQ2Vals |            1.86 |
# |         MaxQ2Vals |          0.0311 |
# |         MinQ2Vals |            -9.9 |
# |            LossPi |            5.81 |
# |             LossQ |            3.43 |
# |              Time |            2.83 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |             7.6 |
# |          MaxEpRet |            -473 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            7.69 |
# |      MaxTestEpRet |            -471 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.7 |
# |         StdQ1Vals |            3.84 |
# |         MaxQ1Vals |           -7.17 |
# |         MinQ1Vals |           -23.6 |
# |     AverageQ2Vals |           -14.7 |
# |         StdQ2Vals |            3.84 |
# |         MaxQ2Vals |           -7.19 |
# |         MinQ2Vals |           -23.8 |
# |            LossPi |            14.5 |
# |             LossQ |           0.141 |
# |              Time |            7.64 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            8.45 |
# |      MaxTestEpRet |            -469 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.7 |
# |         StdQ1Vals |            3.71 |
# |         MaxQ1Vals |           -19.8 |
# |         MinQ1Vals |           -36.4 |
# |     AverageQ2Vals |           -27.7 |
# |         StdQ2Vals |            3.71 |
# |         MaxQ2Vals |           -19.9 |
# |         MinQ2Vals |           -36.4 |
# |            LossPi |            27.6 |
# |             LossQ |           0.161 |
# |              Time |            12.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            3.72 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -488 |
# |      StdTestEpRet |            7.59 |
# |      MaxTestEpRet |            -473 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.5 |
# |         StdQ1Vals |            3.23 |
# |         MaxQ1Vals |           -31.8 |
# |         MinQ1Vals |             -48 |
# |     AverageQ2Vals |           -39.5 |
# |         StdQ2Vals |            3.23 |
# |         MaxQ2Vals |           -31.8 |
# |         MinQ2Vals |           -47.5 |
# |            LossPi |            39.3 |
# |             LossQ |           0.216 |
# |              Time |            17.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            4.98 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -485 |
# |      StdTestEpRet |            13.1 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |            -502 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.4 |
# |         StdQ1Vals |            2.75 |
# |         MaxQ1Vals |           -42.4 |
# |         MinQ1Vals |           -56.9 |
# |     AverageQ2Vals |           -49.4 |
# |         StdQ2Vals |            2.75 |
# |         MaxQ2Vals |           -42.3 |
# |         MinQ2Vals |           -56.5 |
# |            LossPi |            49.3 |
# |             LossQ |           0.261 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            6.23 |
# |          MaxEpRet |            -469 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -486 |
# |      StdTestEpRet |            7.12 |
# |      MaxTestEpRet |            -473 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.7 |
# |         StdQ1Vals |            2.34 |
# |         MaxQ1Vals |             -51 |
# |         MinQ1Vals |           -64.1 |
# |     AverageQ2Vals |           -57.7 |
# |         StdQ2Vals |            2.34 |
# |         MaxQ2Vals |           -50.8 |
# |         MinQ2Vals |           -64.7 |
# |            LossPi |            57.6 |
# |             LossQ |            0.29 |
# |              Time |            27.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             8.4 |
# |          MaxEpRet |            -463 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            18.5 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.7 |
# |         StdQ1Vals |            2.02 |
# |         MaxQ1Vals |           -58.6 |
# |         MinQ1Vals |           -70.8 |
# |     AverageQ2Vals |           -64.7 |
# |         StdQ2Vals |            2.02 |
# |         MaxQ2Vals |           -58.5 |
# |         MinQ2Vals |           -70.9 |
# |            LossPi |            64.5 |
# |             LossQ |           0.316 |
# |              Time |              32 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -447 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            7.35 |
# |      MaxTestEpRet |            -469 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.4 |
# |         StdQ1Vals |            1.74 |
# |         MaxQ1Vals |           -64.7 |
# |         MinQ1Vals |           -76.1 |
# |     AverageQ2Vals |           -70.4 |
# |         StdQ2Vals |            1.74 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |           -76.4 |
# |            LossPi |            70.3 |
# |             LossQ |           0.319 |
# |              Time |            37.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            12.4 |
# |          MaxEpRet |            -453 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -468 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -423 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.2 |
# |         StdQ1Vals |            1.56 |
# |         MaxQ1Vals |           -70.1 |
# |         MinQ1Vals |           -80.6 |
# |     AverageQ2Vals |           -75.2 |
# |         StdQ2Vals |            1.56 |
# |         MaxQ2Vals |           -69.9 |
# |         MinQ2Vals |           -80.8 |
# |            LossPi |            75.1 |
# |             LossQ |           0.318 |
# |              Time |              42 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -433 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -476 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -418 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.1 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |           -74.4 |
# |         MinQ1Vals |           -84.3 |
# |     AverageQ2Vals |           -79.1 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |           -74.4 |
# |         MinQ2Vals |           -84.5 |
# |            LossPi |              79 |
# |             LossQ |           0.339 |
# |              Time |            47.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -464 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -398 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -459 |
# |      StdTestEpRet |            40.2 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.2 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |           -77.6 |
# |         MinQ1Vals |           -87.9 |
# |     AverageQ2Vals |           -82.2 |
# |         StdQ2Vals |            1.43 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |           -87.9 |
# |            LossPi |            82.1 |
# |             LossQ |           0.358 |
# |              Time |            52.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -460 |
# |          StdEpRet |            21.6 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -460 |
# |      StdTestEpRet |              43 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -84.8 |
# |         StdQ1Vals |            1.48 |
# |         MaxQ1Vals |           -79.6 |
# |         MinQ1Vals |           -90.5 |
# |     AverageQ2Vals |           -84.8 |
# |         StdQ2Vals |            1.48 |
# |         MaxQ2Vals |           -79.5 |
# |         MinQ2Vals |           -90.8 |
# |            LossPi |            84.7 |
# |             LossQ |           0.377 |
# |              Time |            57.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -459 |
# |          StdEpRet |            23.6 |
# |          MaxEpRet |            -394 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -432 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -86.8 |
# |         StdQ1Vals |             1.6 |
# |         MaxQ1Vals |           -80.9 |
# |         MinQ1Vals |           -92.6 |
# |     AverageQ2Vals |           -86.8 |
# |         StdQ2Vals |             1.6 |
# |         MaxQ2Vals |           -80.9 |
# |         MinQ2Vals |           -93.3 |
# |            LossPi |            86.7 |
# |             LossQ |            0.42 |
# |              Time |            62.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -463 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -416 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -456 |
# |      StdTestEpRet |            22.4 |
# |      MaxTestEpRet |            -427 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -88.5 |
# |         StdQ1Vals |            1.76 |
# |         MaxQ1Vals |           -82.1 |
# |         MinQ1Vals |             -95 |
# |     AverageQ2Vals |           -88.5 |
# |         StdQ2Vals |            1.75 |
# |         MaxQ2Vals |           -82.1 |
# |         MinQ2Vals |           -95.1 |
# |            LossPi |            88.4 |
# |             LossQ |           0.465 |
# |              Time |            67.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -467 |
# |          StdEpRet |            18.9 |
# |          MaxEpRet |            -421 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            29.4 |
# |      MaxTestEpRet |            -377 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -89.8 |
# |         StdQ1Vals |            1.91 |
# |         MaxQ1Vals |           -83.2 |
# |         MinQ1Vals |           -97.5 |
# |     AverageQ2Vals |           -89.9 |
# |         StdQ2Vals |             1.9 |
# |         MaxQ2Vals |           -83.2 |
# |         MinQ2Vals |           -96.9 |
# |            LossPi |            89.7 |
# |             LossQ |           0.498 |
# |              Time |            72.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -434 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |            -382 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -440 |
# |      StdTestEpRet |            36.5 |
# |      MaxTestEpRet |            -393 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -90.9 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |           -83.9 |
# |         MinQ1Vals |           -99.6 |
# |     AverageQ2Vals |           -90.9 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -83.8 |
# |         MinQ2Vals |           -98.5 |
# |            LossPi |            90.7 |
# |             LossQ |           0.536 |
# |              Time |            77.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -445 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -389 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -425 |
# |      StdTestEpRet |            58.3 |
# |      MaxTestEpRet |            -330 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -91.7 |
# |         StdQ1Vals |            2.29 |
# |         MaxQ1Vals |             -84 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -91.7 |
# |         StdQ2Vals |            2.28 |
# |         MaxQ2Vals |           -84.2 |
# |         MinQ2Vals |           -99.8 |
# |            LossPi |            91.5 |
# |             LossQ |           0.589 |
# |              Time |            82.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -453 |
# |          StdEpRet |            20.7 |
# |          MaxEpRet |            -405 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |              50 |
# |      MaxTestEpRet |            -334 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -92.2 |
# |         StdQ1Vals |            2.46 |
# |         MaxQ1Vals |           -83.8 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -92.2 |
# |         StdQ2Vals |            2.46 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |            -101 |
# |            LossPi |              92 |
# |             LossQ |           0.627 |
# |              Time |            87.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -423 |
# |          StdEpRet |            36.8 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -431 |
# |      StdTestEpRet |              31 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -468 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -92.6 |
# |         StdQ1Vals |            2.61 |
# |         MaxQ1Vals |           -83.5 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -92.6 |
# |         StdQ2Vals |            2.61 |
# |         MaxQ2Vals |           -83.7 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            92.4 |
# |             LossQ |           0.668 |
# |              Time |            92.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |            37.8 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            34.3 |
# |      MaxTestEpRet |            -362 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -92.8 |
# |         StdQ1Vals |            2.85 |
# |         MaxQ1Vals |           -83.6 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -92.8 |
# |         StdQ2Vals |            2.84 |
# |         MaxQ2Vals |           -83.8 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            92.6 |
# |             LossQ |           0.745 |
# |              Time |              97 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -407 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -385 |
# |      StdTestEpRet |            66.5 |
# |      MaxTestEpRet |            -237 |
# |      MinTestEpRet |            -463 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |             -93 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |           -83.3 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |             -93 |
# |         StdQ2Vals |            3.01 |
# |         MaxQ2Vals |           -83.7 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            92.8 |
# |             LossQ |           0.806 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -446 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -393 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -431 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -480 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            3.19 |
# |         MaxQ1Vals |           -82.9 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            3.18 |
# |         MaxQ2Vals |           -83.4 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            92.9 |
# |             LossQ |           0.835 |
# |              Time |             107 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -445 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -426 |
# |      StdTestEpRet |            65.7 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            3.34 |
# |         MaxQ1Vals |           -82.4 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            3.33 |
# |         MaxQ2Vals |           -83.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              93 |
# |             LossQ |           0.869 |
# |              Time |             113 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -433 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -386 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -434 |
# |      StdTestEpRet |            39.5 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            3.48 |
# |         MaxQ1Vals |           -82.1 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            3.48 |
# |         MaxQ2Vals |           -82.5 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            92.9 |
# |             LossQ |           0.897 |
# |              Time |             118 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -438 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -386 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            55.1 |
# |      MaxTestEpRet |            -300 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            3.67 |
# |         MaxQ1Vals |           -81.7 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            3.66 |
# |         MaxQ2Vals |           -82.4 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.8 |
# |             LossQ |           0.928 |
# |              Time |             124 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -440 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |            -383 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            46.7 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |             -93 |
# |         StdQ1Vals |            3.81 |
# |         MaxQ1Vals |           -81.4 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |             -93 |
# |         StdQ2Vals |            3.81 |
# |         MaxQ2Vals |           -82.1 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            92.8 |
# |             LossQ |           0.943 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -423 |
# |          StdEpRet |            33.3 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -463 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -92.9 |
# |         StdQ1Vals |            3.93 |
# |         MaxQ1Vals |           -81.1 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -92.9 |
# |         StdQ2Vals |            3.93 |
# |         MaxQ2Vals |           -81.9 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.6 |
# |             LossQ |           0.971 |
# |              Time |             134 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -423 |
# |          StdEpRet |            34.5 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -409 |
# |      StdTestEpRet |            44.2 |
# |      MaxTestEpRet |            -287 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -92.7 |
# |         StdQ1Vals |            4.04 |
# |         MaxQ1Vals |           -80.7 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.7 |
# |         StdQ2Vals |            4.04 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.5 |
# |             LossQ |           0.981 |
# |              Time |             139 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -416 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -457 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            53.2 |
# |      MaxTestEpRet |            -298 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -92.5 |
# |         StdQ1Vals |            4.19 |
# |         MaxQ1Vals |           -80.4 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.5 |
# |         StdQ2Vals |            4.19 |
# |         MaxQ2Vals |           -81.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.2 |
# |             LossQ |           0.989 |
# |              Time |             144 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -411 |
# |      StdTestEpRet |            45.3 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -459 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -92.3 |
# |         StdQ1Vals |            4.34 |
# |         MaxQ1Vals |           -79.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.3 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              92 |
# |             LossQ |            1.02 |
# |              Time |             150 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            -333 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            46.2 |
# |      MaxTestEpRet |            -294 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -92.1 |
# |         StdQ1Vals |            4.45 |
# |         MaxQ1Vals |             -80 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.1 |
# |         StdQ2Vals |            4.45 |
# |         MaxQ2Vals |           -80.5 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            91.8 |
# |             LossQ |            1.04 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            36.3 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |              37 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -91.8 |
# |         StdQ1Vals |            4.59 |
# |         MaxQ1Vals |           -79.4 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.8 |
# |         StdQ2Vals |            4.58 |
# |         MaxQ2Vals |           -80.1 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.6 |
# |             LossQ |            1.06 |
# |              Time |             160 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -428 |
# |          StdEpRet |            34.7 |
# |          MaxEpRet |            -351 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -428 |
# |      StdTestEpRet |            27.2 |
# |      MaxTestEpRet |            -383 |
# |      MinTestEpRet |            -483 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -91.6 |
# |         StdQ1Vals |            4.71 |
# |         MaxQ1Vals |           -79.4 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.6 |
# |         StdQ2Vals |             4.7 |
# |         MaxQ2Vals |           -79.8 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            91.3 |
# |             LossQ |            1.08 |
# |              Time |             165 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -416 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -458 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            37.3 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -462 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -91.4 |
# |         StdQ1Vals |            4.82 |
# |         MaxQ1Vals |           -79.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -91.4 |
# |         StdQ2Vals |            4.81 |
# |         MaxQ2Vals |           -79.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.1 |
# |             LossQ |             1.1 |
# |              Time |             170 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -386 |
# |      StdTestEpRet |            53.2 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -91.2 |
# |         StdQ1Vals |            4.94 |
# |         MaxQ1Vals |           -78.6 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -91.2 |
# |         StdQ2Vals |            4.93 |
# |         MaxQ2Vals |           -79.2 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            90.9 |
# |             LossQ |            1.12 |
# |              Time |             175 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -427 |
# |          StdEpRet |            30.3 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -376 |
# |      StdTestEpRet |              51 |
# |      MaxTestEpRet |            -275 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -90.9 |
# |         StdQ1Vals |            5.01 |
# |         MaxQ1Vals |           -78.5 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -90.9 |
# |         StdQ2Vals |            5.01 |
# |         MaxQ2Vals |             -79 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            90.6 |
# |             LossQ |            1.11 |
# |              Time |             180 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            35.7 |
# |          MaxEpRet |            -348 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            39.8 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -448 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -90.7 |
# |         StdQ1Vals |            5.09 |
# |         MaxQ1Vals |             -78 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -90.7 |
# |         StdQ2Vals |            5.09 |
# |         MaxQ2Vals |           -78.4 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            90.4 |
# |             LossQ |            1.14 |
# |              Time |             184 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -424 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -382 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            37.8 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -90.5 |
# |         StdQ1Vals |            5.17 |
# |         MaxQ1Vals |           -77.9 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -90.5 |
# |         StdQ2Vals |            5.17 |
# |         MaxQ2Vals |           -78.2 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            90.2 |
# |             LossQ |            1.15 |
# |              Time |             189 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            37.1 |
# |          MaxEpRet |            -351 |
# |          MinEpRet |            -464 |
# |  AverageTestEpRet |            -380 |
# |      StdTestEpRet |            58.7 |
# |      MaxTestEpRet |            -308 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -90.3 |
# |         StdQ1Vals |            5.21 |
# |         MaxQ1Vals |           -77.7 |
# |         MinQ1Vals |            -113 |
# |     AverageQ2Vals |           -90.3 |
# |         StdQ2Vals |            5.21 |
# |         MaxQ2Vals |             -78 |
# |         MinQ2Vals |            -110 |
# |            LossPi |              90 |
# |             LossQ |            1.14 |
# |              Time |             194 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -415 |
# |          StdEpRet |            39.3 |
# |          MaxEpRet |            -334 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |              36 |
# |      MaxTestEpRet |            -308 |
# |      MinTestEpRet |            -437 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -90.1 |
# |         StdQ1Vals |            5.24 |
# |         MaxQ1Vals |           -77.3 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -90.1 |
# |         StdQ2Vals |            5.24 |
# |         MaxQ2Vals |           -77.3 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            89.8 |
# |             LossQ |            1.15 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -427 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -386 |
# |      StdTestEpRet |            41.3 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -436 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -89.9 |
# |         StdQ1Vals |            5.32 |
# |         MaxQ1Vals |           -77.1 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -89.9 |
# |         StdQ2Vals |            5.32 |
# |         MaxQ2Vals |           -77.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            89.6 |
# |             LossQ |            1.17 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -384 |
# |      StdTestEpRet |            50.8 |
# |      MaxTestEpRet |            -278 |
# |      MinTestEpRet |            -480 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -89.7 |
# |         StdQ1Vals |            5.37 |
# |         MaxQ1Vals |           -77.2 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -89.7 |
# |         StdQ2Vals |            5.37 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            89.4 |
# |             LossQ |            1.17 |
# |              Time |             210 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            48.5 |
# |      MaxTestEpRet |            -302 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -89.5 |
# |         StdQ1Vals |            5.42 |
# |         MaxQ1Vals |           -76.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -89.5 |
# |         StdQ2Vals |            5.42 |
# |         MaxQ2Vals |           -77.3 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            89.2 |
# |             LossQ |            1.18 |
# |              Time |             215 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |            -329 |
# |          MinEpRet |            -462 |
# |  AverageTestEpRet |            -379 |
# |      StdTestEpRet |            44.6 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -89.3 |
# |         StdQ1Vals |            5.45 |
# |         MaxQ1Vals |           -76.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -89.3 |
# |         StdQ2Vals |            5.46 |
# |         MaxQ2Vals |           -76.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |              89 |
# |             LossQ |            1.18 |
# |              Time |             221 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            39.7 |
# |          MaxEpRet |            -318 |
# |          MinEpRet |            -458 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            20.2 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -419 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -89.1 |
# |         StdQ1Vals |             5.5 |
# |         MaxQ1Vals |           -76.6 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -89.1 |
# |         StdQ2Vals |             5.5 |
# |         MaxQ2Vals |           -76.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.8 |
# |             LossQ |            1.18 |
# |              Time |             226 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |              44 |
# |          MaxEpRet |            -338 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -382 |
# |      StdTestEpRet |            48.5 |
# |      MaxTestEpRet |            -265 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -88.9 |
# |         StdQ1Vals |            5.54 |
# |         MaxQ1Vals |           -76.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.9 |
# |         StdQ2Vals |            5.54 |
# |         MaxQ2Vals |           -76.4 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            88.6 |
# |             LossQ |            1.18 |
# |              Time |             231 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |            26.1 |
# |          MaxEpRet |            -364 |
# ...
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |              37 |
# |          MaxEpRet |            -331 |
# |          MinEpRet |            -457 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            33.4 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -431 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.65e+04 |
# |     AverageQ1Vals |             -88 |
# |         StdQ1Vals |            5.73 |
# |         MaxQ1Vals |             -75 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |             -88 |
# |         StdQ2Vals |            5.73 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            87.8 |
# |             LossQ |            1.19 |
# |              Time |             257 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |            38.9 |
# |          MaxEpRet |            -320 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -381 |
# |      StdTestEpRet |            42.7 |
# |      MaxTestEpRet |            -323 |
# |      MinTestEpRet |            -471 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.8e+04 |
# |     AverageQ1Vals |           -87.9 |
# |         StdQ1Vals |            5.75 |
# |         MaxQ1Vals |           -74.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -87.9 |
# |         StdQ2Vals |            5.74 |
# |         MaxQ2Vals |           -74.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            87.6 |
# |             LossQ |            1.18 |
# |              Time |             262 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            45.7 |
# |          MaxEpRet |            -318 |
# |          MinEpRet |            -457 |
# |  AverageTestEpRet |            -364 |
# |      StdTestEpRet |            54.1 |
# |      MaxTestEpRet |            -276 |
# |      MinTestEpRet |            -468 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.95e+04 |
# |     AverageQ1Vals |           -87.7 |
# |         StdQ1Vals |            5.81 |
# |         MaxQ1Vals |           -74.6 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -87.7 |
# |         StdQ2Vals |             5.8 |
# |         MaxQ2Vals |           -74.8 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            87.5 |
# |             LossQ |            1.16 |
# |              Time |             268 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |            37.4 |
# |          MaxEpRet |            -315 |
# |          MinEpRet |            -452 |
# |  AverageTestEpRet |            -367 |
# |      StdTestEpRet |            45.4 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         8.1e+04 |
# |     AverageQ1Vals |           -87.5 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |           -74.5 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -87.5 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |           -74.4 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            87.3 |
# |             LossQ |            1.18 |
# |              Time |             273 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -350 |
# |          MinEpRet |            -435 |
# |  AverageTestEpRet |            -359 |
# |      StdTestEpRet |            31.3 |
# |      MaxTestEpRet |            -296 |
# |      MinTestEpRet |            -402 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        8.25e+04 |
# |     AverageQ1Vals |           -87.4 |
# |         StdQ1Vals |            5.91 |
# |         MaxQ1Vals |           -74.3 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -87.4 |
# |         StdQ2Vals |             5.9 |
# |         MaxQ2Vals |           -74.5 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            87.1 |
# |             LossQ |            1.16 |
# |              Time |             278 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            31.1 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -385 |
# |      StdTestEpRet |            38.9 |
# |      MaxTestEpRet |            -342 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |           -87.2 |
# |         StdQ1Vals |            5.92 |
# |         MaxQ1Vals |           -74.2 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -87.2 |
# |         StdQ2Vals |            5.91 |
# |         MaxQ2Vals |           -74.4 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            86.9 |
# |             LossQ |            1.16 |
# |              Time |             284 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              57 |
# |      AverageEpRet |            -399 |
# |          StdEpRet |            33.9 |
# |          MaxEpRet |            -320 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -336 |
# |      StdTestEpRet |            46.6 |
# |      MaxTestEpRet |            -282 |
# |      MinTestEpRet |            -407 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        8.55e+04 |
# |     AverageQ1Vals |             -87 |
# |         StdQ1Vals |            5.95 |
# |         MaxQ1Vals |             -74 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |             -87 |
# |         StdQ2Vals |            5.95 |
# |         MaxQ2Vals |           -74.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            86.8 |
# |             LossQ |            1.17 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              58 |
# |      AverageEpRet |            -394 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -387 |
# |      StdTestEpRet |            42.2 |
# |      MaxTestEpRet |            -330 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         8.7e+04 |
# |     AverageQ1Vals |           -86.8 |
# |         StdQ1Vals |            5.98 |
# |         MaxQ1Vals |           -73.9 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -86.8 |
# |         StdQ2Vals |            5.98 |
# |         MaxQ2Vals |             -74 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            86.6 |
# |             LossQ |            1.16 |
# |              Time |             294 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              59 |
# |      AverageEpRet |            -380 |
# |          StdEpRet |            50.6 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -449 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            45.7 |
# |      MaxTestEpRet |            -298 |
# |      MinTestEpRet |            -428 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        8.85e+04 |
# |     AverageQ1Vals |           -86.7 |
# |         StdQ1Vals |            6.03 |
# |         MaxQ1Vals |             -73 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -86.7 |
# |         StdQ2Vals |            6.03 |
# |         MaxQ2Vals |           -73.4 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            86.4 |
# |             LossQ |            1.16 |
# |              Time |             300 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              60 |
# |      AverageEpRet |            -417 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -456 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            35.6 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -477 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+04 |
# |     AverageQ1Vals |           -86.5 |
# |         StdQ1Vals |            6.08 |
# |         MaxQ1Vals |           -72.6 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -86.5 |
# |         StdQ2Vals |            6.08 |
# |         MaxQ2Vals |           -72.6 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            86.2 |
# |             LossQ |            1.19 |
# |              Time |             306 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              61 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |              42 |
# |          MaxEpRet |            -300 |
# |          MinEpRet |            -448 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            41.7 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        9.15e+04 |
# |     AverageQ1Vals |           -86.4 |
# |         StdQ1Vals |            6.11 |
# |         MaxQ1Vals |           -72.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -86.4 |
# |         StdQ2Vals |            6.11 |
# |         MaxQ2Vals |           -72.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            86.1 |
# |             LossQ |            1.18 |
# |              Time |             311 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              62 |
# |      AverageEpRet |            -387 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |            -327 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -347 |
# |      StdTestEpRet |            45.3 |
# |      MaxTestEpRet |            -268 |
# |      MinTestEpRet |            -412 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         9.3e+04 |
# |     AverageQ1Vals |           -86.2 |
# |         StdQ1Vals |            6.12 |
# |         MaxQ1Vals |           -72.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -86.2 |
# |         StdQ2Vals |            6.11 |
# |         MaxQ2Vals |           -72.3 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            85.9 |
# |             LossQ |            1.19 |
# |              Time |             316 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              63 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |            32.8 |
# |          MaxEpRet |            -351 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -361 |
# |      StdTestEpRet |            34.3 |
# |      MaxTestEpRet |            -304 |
# |      MinTestEpRet |            -422 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        9.45e+04 |
# |     AverageQ1Vals |           -86.1 |
# |         StdQ1Vals |            6.16 |
# |         MaxQ1Vals |           -71.9 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -86.1 |
# |         StdQ2Vals |            6.16 |
# |         MaxQ2Vals |             -72 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            85.8 |
# |             LossQ |            1.18 |
# |              Time |             322 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              64 |
# |      AverageEpRet |            -382 |
# |          StdEpRet |              50 |
# |          MaxEpRet |            -298 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -367 |
# |      StdTestEpRet |            57.9 |
# |      MaxTestEpRet |            -262 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |           -85.9 |
# |         StdQ1Vals |            6.17 |
# |         MaxQ1Vals |           -71.7 |
# |         MinQ1Vals |            -113 |
# |     AverageQ2Vals |           -85.9 |
# |         StdQ2Vals |            6.16 |
# |         MaxQ2Vals |           -71.8 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            85.6 |
# |             LossQ |            1.19 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              65 |
# |      AverageEpRet |            -397 |
# |          StdEpRet |              35 |
# |          MaxEpRet |            -318 |
# |          MinEpRet |            -441 |
# |  AverageTestEpRet |            -370 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |            -315 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        9.75e+04 |
# |     AverageQ1Vals |           -85.8 |
# |         StdQ1Vals |            6.18 |
# |         MaxQ1Vals |           -71.5 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -85.8 |
# |         StdQ2Vals |            6.18 |
# |         MaxQ2Vals |           -71.7 |
# |         MinQ2Vals |            -112 |
# |            LossPi |            85.5 |
# |             LossQ |            1.18 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              66 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |            -330 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -355 |
# |      StdTestEpRet |            28.2 |
# |      MaxTestEpRet |            -319 |
# |      MinTestEpRet |            -397 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         9.9e+04 |
# |     AverageQ1Vals |           -85.7 |
# |         StdQ1Vals |            6.19 |
# |         MaxQ1Vals |           -71.3 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -85.7 |
# |         StdQ2Vals |            6.18 |
# |         MaxQ2Vals |           -71.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            85.4 |
# |             LossQ |            1.19 |
# |              Time |             338 |
# ---------------------------------------
