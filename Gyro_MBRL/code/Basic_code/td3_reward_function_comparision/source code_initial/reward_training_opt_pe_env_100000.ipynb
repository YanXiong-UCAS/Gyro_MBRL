# %% [markdown]
# # TD3
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1 & GyroscopeEnvNew4Paper-v0

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnvNew4Paper-v0'   # GyroscopeEnvNew4Paper-v0; GyroscopeEnv-v1
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=100000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_100000', exp_name='td3_pe_opt_ing_100000')
                   )
# Out:
# Warning: Log dir td3_pe_opt_ing_100000 already exists! Storing info there anyway.
# Logging data to td3_pe_opt_ing_100000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f810e46a8c8>, 'GyroscopeEnvNew4Paper-v0', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	100000,
#     "exp_name":	"td3_pe_opt_ing_100000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f80f89a2e48>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_100000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_100000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_100000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_100000",
#         "output_dir":	"td3_pe_opt_ing_100000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            7.15 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            8.85 |
# |      MaxTestEpRet |            -472 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.12 |
# |         StdQ1Vals |            2.02 |
# |         MaxQ1Vals |          0.0431 |
# |         MinQ1Vals |             -11 |
# |     AverageQ2Vals |           -6.17 |
# |         StdQ2Vals |            1.91 |
# |         MaxQ2Vals |         -0.0604 |
# |         MinQ2Vals |           -10.8 |
# |            LossPi |            5.92 |
# |             LossQ |            3.42 |
# |              Time |            2.95 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -494 |
# |          StdEpRet |            8.09 |
# |          MaxEpRet |            -478 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -490 |
# |      StdTestEpRet |            5.31 |
# |      MaxTestEpRet |            -481 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.8 |
# |         StdQ1Vals |            3.83 |
# |         MaxQ1Vals |           -7.18 |
# |         MinQ1Vals |           -24.8 |
# |     AverageQ2Vals |           -14.8 |
# |         StdQ2Vals |            3.83 |
# |         MaxQ2Vals |           -7.32 |
# |         MinQ2Vals |           -24.6 |
# |            LossPi |            14.7 |
# |             LossQ |           0.127 |
# |              Time |               8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            10.2 |
# |          MaxEpRet |            -468 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |              10 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.8 |
# |         StdQ1Vals |            3.69 |
# |         MaxQ1Vals |           -19.6 |
# |         MinQ1Vals |           -37.4 |
# |     AverageQ2Vals |           -27.8 |
# |         StdQ2Vals |            3.69 |
# |         MaxQ2Vals |           -19.4 |
# |         MinQ2Vals |           -37.1 |
# |            LossPi |            27.7 |
# |             LossQ |           0.156 |
# |              Time |            13.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            5.29 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |              35 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.5 |
# |         StdQ1Vals |            3.24 |
# |         MaxQ1Vals |           -31.7 |
# |         MinQ1Vals |           -48.5 |
# |     AverageQ2Vals |           -39.5 |
# |         StdQ2Vals |            3.24 |
# |         MaxQ2Vals |           -31.6 |
# |         MinQ2Vals |           -48.6 |
# |            LossPi |            39.4 |
# |             LossQ |           0.215 |
# |              Time |            19.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            7.14 |
# |          MaxEpRet |            -478 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            14.8 |
# |      MaxTestEpRet |            -449 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.5 |
# |         StdQ1Vals |            2.78 |
# |         MaxQ1Vals |             -42 |
# |         MinQ1Vals |           -57.7 |
# |     AverageQ2Vals |           -49.5 |
# |         StdQ2Vals |            2.78 |
# |         MaxQ2Vals |             -42 |
# |         MinQ2Vals |           -57.5 |
# |            LossPi |            49.3 |
# |             LossQ |           0.259 |
# |              Time |            25.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             7.1 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            23.2 |
# |      MaxTestEpRet |            -421 |
# |      MinTestEpRet |            -504 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.8 |
# |         StdQ1Vals |            2.41 |
# |         MaxQ1Vals |           -51.3 |
# |         MinQ1Vals |             -65 |
# |     AverageQ2Vals |           -57.8 |
# |         StdQ2Vals |            2.41 |
# |         MaxQ2Vals |             -51 |
# |         MinQ2Vals |             -65 |
# |            LossPi |            57.7 |
# |             LossQ |           0.292 |
# |              Time |            32.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -488 |
# |          StdEpRet |            12.6 |
# |          MaxEpRet |            -459 |
# |          MinEpRet |            -507 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            8.76 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.8 |
# |         StdQ1Vals |            2.08 |
# |         MaxQ1Vals |           -58.8 |
# |         MinQ1Vals |           -71.8 |
# |     AverageQ2Vals |           -64.8 |
# |         StdQ2Vals |            2.08 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |           -71.4 |
# |            LossPi |            64.7 |
# |             LossQ |           0.323 |
# |              Time |            38.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -484 |
# |          StdEpRet |            12.3 |
# |          MaxEpRet |            -463 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -466 |
# |      StdTestEpRet |            25.4 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.6 |
# |         StdQ1Vals |             1.8 |
# |         MaxQ1Vals |           -64.9 |
# |         MinQ1Vals |             -77 |
# |     AverageQ2Vals |           -70.6 |
# |         StdQ2Vals |             1.8 |
# |         MaxQ2Vals |           -64.7 |
# |         MinQ2Vals |           -76.8 |
# |            LossPi |            70.5 |
# |             LossQ |           0.321 |
# |              Time |            44.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -469 |
# |          StdEpRet |            16.7 |
# |          MaxEpRet |            -433 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -483 |
# |      StdTestEpRet |            8.45 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.3 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |           -69.9 |
# |         MinQ1Vals |           -81.2 |
# |     AverageQ2Vals |           -75.3 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |           -69.9 |
# |         MinQ2Vals |           -81.2 |
# |            LossPi |            75.2 |
# |             LossQ |           0.335 |
# |              Time |            50.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -422 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |              17 |
# |      MaxTestEpRet |            -439 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.2 |
# |         StdQ1Vals |            1.57 |
# |         MaxQ1Vals |           -74.2 |
# |         MinQ1Vals |           -85.5 |
# |     AverageQ2Vals |           -79.2 |
# |         StdQ2Vals |            1.57 |
# |         MaxQ2Vals |           -74.2 |
# |         MinQ2Vals |           -84.8 |
# |            LossPi |            79.1 |
# |             LossQ |           0.355 |
# |              Time |            57.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |            -445 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -475 |
# |      StdTestEpRet |            22.9 |
# |      MaxTestEpRet |            -430 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.4 |
# |         StdQ1Vals |            1.58 |
# |         MaxQ1Vals |           -77.2 |
# |         MinQ1Vals |           -88.7 |
# |     AverageQ2Vals |           -82.4 |
# |         StdQ2Vals |            1.58 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |           -88.4 |
# |            LossPi |            82.3 |
# |             LossQ |           0.373 |
# |              Time |            63.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |              19 |
# |          MaxEpRet |            -419 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -85.1 |
# |         StdQ1Vals |            1.63 |
# |         MaxQ1Vals |           -79.4 |
# |         MinQ1Vals |           -91.6 |
# |     AverageQ2Vals |           -85.1 |
# |         StdQ2Vals |            1.63 |
# |         MaxQ2Vals |           -79.5 |
# |         MinQ2Vals |           -91.4 |
# |            LossPi |              85 |
# |             LossQ |           0.403 |
# |              Time |            69.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -440 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -470 |
# |      StdTestEpRet |            36.7 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -500 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -87.3 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |           -81.5 |
# |         MinQ1Vals |           -93.9 |
# |     AverageQ2Vals |           -87.3 |
# |         StdQ2Vals |             1.7 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |           -93.7 |
# |            LossPi |            87.1 |
# |             LossQ |           0.424 |
# |              Time |              76 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            10.2 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -476 |
# |      StdTestEpRet |            17.7 |
# |      MaxTestEpRet |            -438 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -89.1 |
# |         StdQ1Vals |            1.76 |
# |         MaxQ1Vals |           -83.1 |
# |         MinQ1Vals |           -96.2 |
# |     AverageQ2Vals |           -89.1 |
# |         StdQ2Vals |            1.76 |
# |         MaxQ2Vals |           -83.1 |
# |         MinQ2Vals |           -95.6 |
# |            LossPi |            88.9 |
# |             LossQ |           0.443 |
# |              Time |            82.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            11.7 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -471 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |            -408 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -90.6 |
# |         StdQ1Vals |            1.79 |
# |         MaxQ1Vals |           -84.3 |
# |         MinQ1Vals |           -98.1 |
# |     AverageQ2Vals |           -90.6 |
# |         StdQ2Vals |             1.8 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |           -97.6 |
# |            LossPi |            90.4 |
# |             LossQ |            0.46 |
# |              Time |            89.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |            -434 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            15.6 |
# |      MaxTestEpRet |            -430 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -91.8 |
# |         StdQ1Vals |            1.83 |
# |         MaxQ1Vals |           -85.2 |
# |         MinQ1Vals |           -98.8 |
# |     AverageQ2Vals |           -91.8 |
# |         StdQ2Vals |            1.83 |
# |         MaxQ2Vals |           -85.1 |
# |         MinQ2Vals |           -99.1 |
# |            LossPi |            91.6 |
# |             LossQ |           0.465 |
# |              Time |            95.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -465 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |            -415 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -464 |
# |      StdTestEpRet |            41.9 |
# |      MaxTestEpRet |            -362 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -92.7 |
# |         StdQ1Vals |            1.89 |
# |         MaxQ1Vals |             -86 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -92.7 |
# |         StdQ2Vals |             1.9 |
# |         MaxQ2Vals |             -86 |
# |         MinQ2Vals |           -99.8 |
# |            LossPi |            92.6 |
# |             LossQ |            0.47 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -436 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -467 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |            -428 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -93.5 |
# |         StdQ1Vals |            1.96 |
# |         MaxQ1Vals |           -86.3 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -93.5 |
# |         StdQ2Vals |            1.96 |
# |         MaxQ2Vals |           -86.5 |
# |         MinQ2Vals |            -100 |
# |            LossPi |            93.4 |
# |             LossQ |           0.482 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |            -430 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -467 |
# |      StdTestEpRet |            19.8 |
# |      MaxTestEpRet |            -426 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -94.1 |
# |         StdQ1Vals |            2.04 |
# |         MaxQ1Vals |             -87 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -94.1 |
# |         StdQ2Vals |            2.05 |
# |         MaxQ2Vals |             -87 |
# |         MinQ2Vals |            -101 |
# |            LossPi |              94 |
# |             LossQ |           0.489 |
# |              Time |             115 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -454 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -453 |
# |      StdTestEpRet |            33.7 |
# |      MaxTestEpRet |            -384 |
# |      MinTestEpRet |            -500 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -94.6 |
# |         StdQ1Vals |            2.09 |
# |         MaxQ1Vals |           -87.2 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -94.6 |
# |         StdQ2Vals |             2.1 |
# |         MaxQ2Vals |           -87.2 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            94.5 |
# |             LossQ |           0.498 |
# |              Time |             122 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -469 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |            -437 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -448 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |            -389 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |             -95 |
# |         StdQ1Vals |            2.15 |
# |         MaxQ1Vals |           -87.7 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |             -95 |
# |         StdQ2Vals |            2.16 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            94.9 |
# |             LossQ |           0.505 |
# |              Time |             130 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |            -400 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -448 |
# |      StdTestEpRet |            34.6 |
# |      MaxTestEpRet |            -388 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -95.3 |
# |         StdQ1Vals |            2.22 |
# |         MaxQ1Vals |           -87.8 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -95.3 |
# |         StdQ2Vals |            2.23 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.2 |
# |             LossQ |           0.514 |
# |              Time |             136 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            13.2 |
# |          MaxEpRet |            -444 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -464 |
# |      StdTestEpRet |            15.5 |
# |      MaxTestEpRet |            -428 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -95.6 |
# |         StdQ1Vals |            2.28 |
# |         MaxQ1Vals |           -87.6 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -95.6 |
# |         StdQ2Vals |            2.29 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.4 |
# |             LossQ |           0.541 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -466 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |            -424 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -453 |
# |      StdTestEpRet |            33.4 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -95.8 |
# |         StdQ1Vals |            2.36 |
# |         MaxQ1Vals |           -87.4 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -95.8 |
# |         StdQ2Vals |            2.36 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.7 |
# |             LossQ |           0.548 |
# |              Time |             150 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -460 |
# |      StdTestEpRet |            18.4 |
# |      MaxTestEpRet |            -421 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -95.9 |
# |         StdQ1Vals |            2.44 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -95.9 |
# |         StdQ2Vals |            2.45 |
# |         MaxQ2Vals |           -87.3 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            95.8 |
# |             LossQ |           0.569 |
# |              Time |             156 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -464 |
# |          StdEpRet |              16 |
# |          MaxEpRet |            -442 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            20.8 |
# |      MaxTestEpRet |            -424 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |             -96 |
# |         StdQ1Vals |            2.52 |
# |         MaxQ1Vals |           -87.2 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |             -96 |
# |         StdQ2Vals |            2.53 |
# |         MaxQ2Vals |           -87.2 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            95.9 |
# |             LossQ |           0.579 |
# |              Time |             164 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -466 |
# |          StdEpRet |              14 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -464 |
# |      StdTestEpRet |            27.1 |
# |      MaxTestEpRet |            -398 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -96.1 |
# |         StdQ1Vals |            2.58 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -96.1 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              96 |
# |             LossQ |           0.596 |
# |              Time |             171 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -462 |
# |          StdEpRet |            17.1 |
# |          MaxEpRet |            -436 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -444 |
# |      StdTestEpRet |            28.5 |
# |      MaxTestEpRet |            -389 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -96.2 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -96.2 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              96 |
# |             LossQ |           0.603 |
# |              Time |             177 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |            -370 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -467 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |            -434 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -96.2 |
# |         StdQ1Vals |            2.67 |
# |         MaxQ1Vals |           -87.2 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.2 |
# |         StdQ2Vals |            2.67 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              96 |
# |             LossQ |           0.613 |
# |              Time |             184 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -467 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |            -434 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -455 |
# |      StdTestEpRet |            29.2 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -96.1 |
# |         StdQ1Vals |            2.75 |
# |         MaxQ1Vals |           -86.9 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.1 |
# |         StdQ2Vals |            2.75 |
# |         MaxQ2Vals |             -87 |
# |         MinQ2Vals |            -106 |
# |            LossPi |              96 |
# |             LossQ |           0.625 |
# |              Time |             191 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -467 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -440 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -441 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |            -352 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -96.1 |
# |         StdQ1Vals |            2.79 |
# |         MaxQ1Vals |           -86.9 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.1 |
# |         StdQ2Vals |             2.8 |
# |         MaxQ2Vals |           -86.8 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            95.9 |
# |             LossQ |           0.627 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -470 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -429 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -453 |
# |      StdTestEpRet |            27.7 |
# |      MaxTestEpRet |            -400 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -96.1 |
# |         StdQ1Vals |            2.82 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -96.1 |
# |         StdQ2Vals |            2.83 |
# |         MaxQ2Vals |           -86.8 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            95.9 |
# |             LossQ |           0.632 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -459 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -416 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -447 |
# |      StdTestEpRet |            33.3 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |             -96 |
# |         StdQ1Vals |            2.84 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |             -96 |
# |         StdQ2Vals |            2.85 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            95.9 |
# |             LossQ |           0.636 |
# |              Time |             212 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -460 |
# |          StdEpRet |            27.4 |
# |          MaxEpRet |            -389 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            58.3 |
# |      MaxTestEpRet |            -276 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |             -96 |
# |         StdQ1Vals |            2.88 |
# |         MaxQ1Vals |           -86.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             -96 |
# |         StdQ2Vals |            2.89 |
# |         MaxQ2Vals |           -86.5 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            95.8 |
# |             LossQ |           0.633 |
# |              Time |             218 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -460 |
# |          StdEpRet |              20 |
# |          MaxEpRet |            -413 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -453 |
# |      StdTestEpRet |            33.5 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -95.9 |
# |         StdQ1Vals |            2.92 |
# |         MaxQ1Vals |           -86.1 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.9 |
# |         StdQ2Vals |            2.93 |
# |         MaxQ2Vals |           -86.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.8 |
# |             LossQ |           0.637 |
# |              Time |             224 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |            -387 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -459 |
# |      StdTestEpRet |            16.2 |
# |      MaxTestEpRet |            -418 |
# |      MinTestEpRet |            -477 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -95.9 |
# |         StdQ1Vals |            2.96 |
# |         MaxQ1Vals |             -86 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.9 |
# |         StdQ2Vals |            2.96 |
# |         MaxQ2Vals |           -86.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.7 |
# |             LossQ |           0.634 |
# |              Time |             230 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -460 |
# |          StdEpRet |            15.2 |
# |          MaxEpRet |            -424 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -447 |
# |      StdTestEpRet |            32.2 |
# |      MaxTestEpRet |            -372 |
# |      MinTestEpRet |            -483 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -95.8 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |             -86 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.8 |
# |         StdQ2Vals |            3.02 |
# |         MaxQ2Vals |           -86.2 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            95.7 |
# |             LossQ |           0.649 |
# |              Time |             236 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -470 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |            -444 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -441 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |            -404 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -95.7 |
# |         StdQ1Vals |            3.05 |
# |         MaxQ1Vals |             -86 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.7 |
# |         StdQ2Vals |            3.06 |
# |         MaxQ2Vals |             -86 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.6 |
# |             LossQ |           0.655 |
# |              Time |             241 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -463 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -417 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -429 |
# |      StdTestEpRet |            48.3 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -95.7 |
# |         StdQ1Vals |            3.07 |
# |         MaxQ1Vals |           -85.4 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.7 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |           -85.7 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.5 |
# |             LossQ |            0.65 |
# |              Time |             247 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            22.7 |
# |          MaxEpRet |            -405 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -444 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -95.6 |
# |         StdQ1Vals |            3.12 |
# |         MaxQ1Vals |           -85.4 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.6 |
# |         StdQ2Vals |            3.13 |
# |         MaxQ2Vals |           -85.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.5 |
# |             LossQ |           0.657 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -462 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -400 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -451 |
# |      StdTestEpRet |            29.8 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -95.5 |
# |         StdQ1Vals |            3.14 |
# |         MaxQ1Vals |           -85.1 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.5 |
# |         StdQ2Vals |            3.15 |
# |         MaxQ2Vals |           -85.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.4 |
# |             LossQ |           0.656 |
# |              Time |             260 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -449 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -392 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -449 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -95.4 |
# |         StdQ1Vals |            3.17 |
# |         MaxQ1Vals |           -84.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.4 |
# |         StdQ2Vals |            3.18 |
# |         MaxQ2Vals |             -85 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.3 |
# |             LossQ |           0.662 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            22.1 |
# |          MaxEpRet |            -392 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -452 |
# |      StdTestEpRet |              39 |
# |      MaxTestEpRet |            -343 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -95.4 |
# |         StdQ1Vals |            3.21 |
# |         MaxQ1Vals |           -84.5 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.4 |
# |         StdQ2Vals |            3.21 |
# |         MaxQ2Vals |           -84.6 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.2 |
# |             LossQ |            0.67 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -453 |
# |          StdEpRet |            36.3 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            40.5 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -95.3 |
# |         StdQ1Vals |            3.24 |
# |         MaxQ1Vals |           -84.6 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.3 |
# |         StdQ2Vals |            3.25 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            95.1 |
# |             LossQ |            0.67 |
# |              Time |             281 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -458 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |            -416 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            39.5 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -485 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -95.2 |
# |         StdQ1Vals |            3.27 |
# |         MaxQ1Vals |           -84.3 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -95.2 |
# |         StdQ2Vals |            3.27 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              95 |
# |             LossQ |           0.674 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -407 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -435 |
# |      StdTestEpRet |              18 |
# |      MaxTestEpRet |            -401 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -95.1 |
# |         StdQ1Vals |             3.3 |
# |         MaxQ1Vals |           -84.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -95.1 |
# |         StdQ2Vals |             3.3 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            94.9 |
# |             LossQ |           0.682 |
# |              Time |             294 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -458 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |            -429 |
# ...
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.08e+05 |
# |     AverageQ1Vals |           -79.7 |
# |         StdQ1Vals |            9.04 |
# |         MaxQ1Vals |           -58.7 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.7 |
# |         StdQ2Vals |            9.04 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            79.4 |
# |             LossQ |            1.34 |
# |              Time |        1.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             273 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |            38.4 |
# |          MaxEpRet |            -320 |
# |          MinEpRet |            -458 |
# |  AverageTestEpRet |            -388 |
# |      StdTestEpRet |            30.5 |
# |      MaxTestEpRet |            -319 |
# |      MinTestEpRet |            -425 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.09e+05 |
# |     AverageQ1Vals |           -79.7 |
# |         StdQ1Vals |            9.07 |
# |         MaxQ1Vals |           -58.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -79.7 |
# |         StdQ2Vals |            9.07 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            79.4 |
# |             LossQ |            1.34 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             274 |
# |      AverageEpRet |            -365 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |            -299 |
# |          MinEpRet |            -407 |
# |  AverageTestEpRet |            -310 |
# |      StdTestEpRet |            57.6 |
# |      MaxTestEpRet |            -217 |
# |      MinTestEpRet |            -408 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.11e+05 |
# |     AverageQ1Vals |           -79.7 |
# |         StdQ1Vals |            9.06 |
# |         MaxQ1Vals |           -58.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -79.7 |
# |         StdQ2Vals |            9.06 |
# |         MaxQ2Vals |           -58.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            79.4 |
# |             LossQ |            1.34 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             275 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            37.1 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |            -406 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            67.2 |
# |      MaxTestEpRet |            -244 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.12e+05 |
# |     AverageQ1Vals |           -79.7 |
# |         StdQ1Vals |            9.06 |
# |         MaxQ1Vals |           -58.7 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.7 |
# |         StdQ2Vals |            9.07 |
# |         MaxQ2Vals |           -58.6 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            79.4 |
# |             LossQ |            1.31 |
# |              Time |        1.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             276 |
# |      AverageEpRet |            -351 |
# |          StdEpRet |            42.4 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |            -405 |
# |  AverageTestEpRet |            -345 |
# |      StdTestEpRet |            64.3 |
# |      MaxTestEpRet |            -217 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.14e+05 |
# |     AverageQ1Vals |           -79.6 |
# |         StdQ1Vals |            9.06 |
# |         MaxQ1Vals |           -58.8 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.6 |
# |         StdQ2Vals |            9.07 |
# |         MaxQ2Vals |           -58.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            79.3 |
# |             LossQ |            1.32 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             277 |
# |      AverageEpRet |            -357 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |            -302 |
# |          MinEpRet |            -425 |
# |  AverageTestEpRet |            -349 |
# |      StdTestEpRet |            59.9 |
# |      MaxTestEpRet |            -275 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.15e+05 |
# |     AverageQ1Vals |           -79.5 |
# |         StdQ1Vals |             9.1 |
# |         MaxQ1Vals |           -58.8 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.5 |
# |         StdQ2Vals |            9.11 |
# |         MaxQ2Vals |           -58.9 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            79.2 |
# |             LossQ |            1.31 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             278 |
# |      AverageEpRet |            -364 |
# |          StdEpRet |            33.6 |
# |          MaxEpRet |            -306 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -339 |
# |      StdTestEpRet |            63.7 |
# |      MaxTestEpRet |            -239 |
# |      MinTestEpRet |            -419 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.17e+05 |
# |     AverageQ1Vals |           -79.5 |
# |         StdQ1Vals |            9.08 |
# |         MaxQ1Vals |           -58.7 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -79.5 |
# |         StdQ2Vals |            9.09 |
# |         MaxQ2Vals |           -58.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            79.2 |
# |             LossQ |            1.34 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             279 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            40.2 |
# |          MaxEpRet |            -262 |
# |          MinEpRet |            -417 |
# |  AverageTestEpRet |            -309 |
# |      StdTestEpRet |            78.7 |
# |      MaxTestEpRet |            -220 |
# |      MinTestEpRet |            -511 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.18e+05 |
# |     AverageQ1Vals |           -79.4 |
# |         StdQ1Vals |            9.09 |
# |         MaxQ1Vals |           -59.2 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -79.4 |
# |         StdQ2Vals |             9.1 |
# |         MaxQ2Vals |             -59 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            79.1 |
# |             LossQ |            1.33 |
# |              Time |        1.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             280 |
# |      AverageEpRet |            -367 |
# |          StdEpRet |            51.2 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            -317 |
# |      StdTestEpRet |            53.8 |
# |      MaxTestEpRet |            -238 |
# |      MinTestEpRet |            -435 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+05 |
# |     AverageQ1Vals |           -79.4 |
# |         StdQ1Vals |            9.12 |
# |         MaxQ1Vals |             -59 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -79.4 |
# |         StdQ2Vals |            9.13 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            79.1 |
# |             LossQ |            1.36 |
# |              Time |        1.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             281 |
# |      AverageEpRet |            -358 |
# |          StdEpRet |            52.1 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |            -458 |
# |  AverageTestEpRet |            -267 |
# |      StdTestEpRet |            42.5 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.21e+05 |
# |     AverageQ1Vals |           -79.4 |
# |         StdQ1Vals |            9.16 |
# |         MaxQ1Vals |           -58.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -79.4 |
# |         StdQ2Vals |            9.17 |
# |         MaxQ2Vals |           -58.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            79.1 |
# |             LossQ |            1.34 |
# |              Time |        1.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             282 |
# |      AverageEpRet |            -368 |
# |          StdEpRet |            45.5 |
# |          MaxEpRet |            -315 |
# |          MinEpRet |            -445 |
# |  AverageTestEpRet |            -346 |
# |      StdTestEpRet |            52.3 |
# |      MaxTestEpRet |            -235 |
# |      MinTestEpRet |            -438 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.23e+05 |
# |     AverageQ1Vals |           -79.4 |
# |         StdQ1Vals |            9.14 |
# |         MaxQ1Vals |           -58.8 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.4 |
# |         StdQ2Vals |            9.15 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            79.1 |
# |             LossQ |            1.31 |
# |              Time |        1.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             283 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |            42.2 |
# |          MaxEpRet |            -315 |
# |          MinEpRet |            -430 |
# |  AverageTestEpRet |            -351 |
# |      StdTestEpRet |            63.3 |
# |      MaxTestEpRet |            -233 |
# |      MinTestEpRet |            -429 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.24e+05 |
# |     AverageQ1Vals |           -79.3 |
# |         StdQ1Vals |            9.16 |
# |         MaxQ1Vals |           -58.9 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.3 |
# |         StdQ2Vals |            9.16 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |              79 |
# |             LossQ |            1.33 |
# |              Time |        1.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             284 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            58.5 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -353 |
# |      StdTestEpRet |            67.4 |
# |      MaxTestEpRet |            -260 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.26e+05 |
# |     AverageQ1Vals |           -79.3 |
# |         StdQ1Vals |            9.16 |
# |         MaxQ1Vals |           -59.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -79.3 |
# |         StdQ2Vals |            9.16 |
# |         MaxQ2Vals |           -58.9 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              79 |
# |             LossQ |            1.33 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             285 |
# |      AverageEpRet |            -382 |
# |          StdEpRet |            39.9 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -364 |
# |      StdTestEpRet |            42.6 |
# |      MaxTestEpRet |            -298 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.27e+05 |
# |     AverageQ1Vals |           -79.2 |
# |         StdQ1Vals |            9.14 |
# |         MaxQ1Vals |           -58.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -79.2 |
# |         StdQ2Vals |            9.15 |
# |         MaxQ2Vals |           -58.7 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            78.9 |
# |             LossQ |            1.36 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             286 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            47.9 |
# |          MaxEpRet |            -284 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -310 |
# |      StdTestEpRet |            63.8 |
# |      MaxTestEpRet |            -229 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.29e+05 |
# |     AverageQ1Vals |           -79.2 |
# |         StdQ1Vals |            9.15 |
# |         MaxQ1Vals |           -58.7 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -79.2 |
# |         StdQ2Vals |            9.16 |
# |         MaxQ2Vals |           -58.6 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            78.8 |
# |             LossQ |            1.36 |
# |              Time |        1.99e+03 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1fd9b148b5ad> in <module>
#      40                    num_test_episodes=10,
#      41                    max_ep_len=100,   # 不能太大，大于100不收敛
# ---> 42                    logger_kwargs=dict(output_dir='td3_pe_opt_ing_100000', exp_name='td3_pe_opt_ing_100000')
#      43                    )
#      44
#
# ~/spinningup/spinup/algos/pytorch/td3/td3.py in td3(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, target_noise, noise_clip, policy_delay, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     320         if t >= update_after and t % update_every == 0:
#     321             for j in range(update_every):
# --> 322                 batch = replay_buffer.sample_batch(batch_size)
#     323                 update(data=batch, timer=j)
#     324
#
# ~/spinningup/spinup/algos/pytorch/td3/td3.py in sample_batch(self, batch_size)
#      35         idxs = np.random.randint(0, self.size, size=batch_size)
#      36         batch = dict(obs=self.obs_buf[idxs],
# ---> 37                      obs2=self.obs2_buf[idxs],
#      38                      act=self.act_buf[idxs],
#      39                      rew=self.rew_buf[idxs],
#
# KeyboardInterrupt:
