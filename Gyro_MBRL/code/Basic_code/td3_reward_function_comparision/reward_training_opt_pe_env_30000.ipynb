# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=30000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_30000', exp_name='td3_pe_opt_ing_30000')
                   )
# Out:
# Logging data to td3_pe_opt_ing_30000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fead59c39d8>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	30000,
#     "exp_name":	"td3_pe_opt_ing_30000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fead59c5b38>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_30000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_30000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_30000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_30000",
#         "output_dir":	"td3_pe_opt_ing_30000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            6.13 |
# |          MaxEpRet |            -477 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.05 |
# |         StdQ1Vals |            1.97 |
# |         MaxQ1Vals |          0.0123 |
# |         MinQ1Vals |           -9.98 |
# |     AverageQ2Vals |            -6.1 |
# |         StdQ2Vals |            1.86 |
# |         MaxQ2Vals |         -0.0224 |
# |         MinQ2Vals |             -10 |
# |            LossPi |            5.81 |
# |             LossQ |            3.35 |
# |              Time |            4.87 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            6.28 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            8.35 |
# |      MaxTestEpRet |            -470 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.9 |
# |         StdQ1Vals |            3.96 |
# |         MaxQ1Vals |           -7.15 |
# |         MinQ1Vals |           -25.3 |
# |     AverageQ2Vals |           -14.9 |
# |         StdQ2Vals |            3.96 |
# |         MaxQ2Vals |           -7.12 |
# |         MinQ2Vals |           -25.3 |
# |            LossPi |            14.7 |
# |             LossQ |           0.147 |
# |              Time |            13.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |             5.6 |
# |          MaxEpRet |            -475 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            12.7 |
# |      MaxTestEpRet |            -455 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |             -28 |
# |         StdQ1Vals |            3.71 |
# |         MaxQ1Vals |           -19.7 |
# |         MinQ1Vals |           -37.4 |
# |     AverageQ2Vals |             -28 |
# |         StdQ2Vals |            3.71 |
# |         MaxQ2Vals |           -19.5 |
# |         MinQ2Vals |           -37.4 |
# |            LossPi |            27.8 |
# |             LossQ |           0.172 |
# |              Time |            21.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             4.9 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            11.9 |
# |      MaxTestEpRet |            -457 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.6 |
# |         StdQ1Vals |            3.21 |
# |         MaxQ1Vals |           -31.4 |
# |         MinQ1Vals |           -47.9 |
# |     AverageQ2Vals |           -39.6 |
# |         StdQ2Vals |            3.21 |
# |         MaxQ2Vals |           -31.6 |
# |         MinQ2Vals |           -48.1 |
# |            LossPi |            39.5 |
# |             LossQ |           0.212 |
# |              Time |            30.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -495 |
# |          StdEpRet |            2.66 |
# |          MaxEpRet |            -491 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.5 |
# |         StdQ1Vals |            2.75 |
# |         MaxQ1Vals |           -42.3 |
# |         MinQ1Vals |           -57.3 |
# |     AverageQ2Vals |           -49.5 |
# |         StdQ2Vals |            2.75 |
# |         MaxQ2Vals |           -42.5 |
# |         MinQ2Vals |           -57.1 |
# |            LossPi |            49.4 |
# |             LossQ |           0.247 |
# |              Time |            38.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            4.61 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            6.69 |
# |      MaxTestEpRet |            -472 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.8 |
# |         StdQ1Vals |            2.36 |
# |         MaxQ1Vals |           -51.5 |
# |         MinQ1Vals |           -64.6 |
# |     AverageQ2Vals |           -57.8 |
# |         StdQ2Vals |            2.36 |
# |         MaxQ2Vals |           -51.4 |
# |         MinQ2Vals |           -64.5 |
# |            LossPi |            57.7 |
# |             LossQ |           0.282 |
# |              Time |            46.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |            11.1 |
# |          MaxEpRet |            -458 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -459 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.8 |
# |         StdQ1Vals |            2.04 |
# |         MaxQ1Vals |           -59.2 |
# |         MinQ1Vals |           -72.8 |
# |     AverageQ2Vals |           -64.8 |
# |         StdQ2Vals |            2.04 |
# |         MaxQ2Vals |           -59.1 |
# |         MinQ2Vals |           -72.9 |
# |            LossPi |            64.7 |
# |             LossQ |           0.303 |
# |              Time |              55 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |            -448 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -464 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |            -420 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.6 |
# |         StdQ1Vals |            1.77 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |           -77.6 |
# |     AverageQ2Vals |           -70.6 |
# |         StdQ2Vals |            1.76 |
# |         MaxQ2Vals |           -65.1 |
# |         MinQ2Vals |           -77.7 |
# |            LossPi |            70.5 |
# |             LossQ |           0.299 |
# |              Time |            63.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -469 |
# |          StdEpRet |            23.6 |
# |          MaxEpRet |            -404 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -471 |
# |      StdTestEpRet |              23 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -502 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.2 |
# |         StdQ1Vals |            1.62 |
# |         MaxQ1Vals |             -70 |
# |         MinQ1Vals |           -81.8 |
# |     AverageQ2Vals |           -75.2 |
# |         StdQ2Vals |            1.62 |
# |         MaxQ2Vals |             -70 |
# |         MinQ2Vals |           -81.4 |
# |            LossPi |            75.1 |
# |             LossQ |           0.309 |
# |              Time |            71.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |            -431 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |            -402 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.1 |
# |         StdQ1Vals |             1.6 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |           -85.5 |
# |     AverageQ2Vals |           -79.1 |
# |         StdQ2Vals |            1.59 |
# |         MaxQ2Vals |           -73.4 |
# |         MinQ2Vals |           -85.6 |
# |            LossPi |              79 |
# |             LossQ |           0.341 |
# |              Time |            80.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -470 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -418 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -455 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |            -399 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.3 |
# |         StdQ1Vals |             1.6 |
# |         MaxQ1Vals |           -76.1 |
# |         MinQ1Vals |           -88.2 |
# |     AverageQ2Vals |           -82.3 |
# |         StdQ2Vals |             1.6 |
# |         MaxQ2Vals |           -76.1 |
# |         MinQ2Vals |             -89 |
# |            LossPi |            82.2 |
# |             LossQ |            0.37 |
# |              Time |            88.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            9.34 |
# |          MaxEpRet |            -452 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |              31 |
# |      MaxTestEpRet |            -389 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -84.9 |
# |         StdQ1Vals |            1.63 |
# |         MaxQ1Vals |           -78.3 |
# |         MinQ1Vals |             -91 |
# |     AverageQ2Vals |           -84.9 |
# |         StdQ2Vals |            1.63 |
# |         MaxQ2Vals |           -78.3 |
# |         MinQ2Vals |           -90.9 |
# |            LossPi |            84.8 |
# |             LossQ |           0.397 |
# |              Time |            97.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -466 |
# |          StdEpRet |            21.5 |
# |          MaxEpRet |            -416 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -463 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |            -415 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |             -87 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |           -80.3 |
# |         MinQ1Vals |           -93.1 |
# |     AverageQ2Vals |             -87 |
# |         StdQ2Vals |            1.69 |
# |         MaxQ2Vals |           -80.3 |
# |         MinQ2Vals |           -92.9 |
# |            LossPi |            86.8 |
# |             LossQ |            0.42 |
# |              Time |             106 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -435 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -464 |
# |      StdTestEpRet |            23.9 |
# |      MaxTestEpRet |            -412 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -88.7 |
# |         StdQ1Vals |            1.74 |
# |         MaxQ1Vals |           -81.6 |
# |         MinQ1Vals |           -94.8 |
# |     AverageQ2Vals |           -88.7 |
# |         StdQ2Vals |            1.73 |
# |         MaxQ2Vals |           -81.6 |
# |         MinQ2Vals |           -94.5 |
# |            LossPi |            88.6 |
# |             LossQ |           0.435 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -461 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -453 |
# |      StdTestEpRet |            27.6 |
# |      MaxTestEpRet |            -401 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -90.1 |
# |         StdQ1Vals |            1.82 |
# |         MaxQ1Vals |           -83.1 |
# |         MinQ1Vals |           -96.3 |
# |     AverageQ2Vals |           -90.1 |
# |         StdQ2Vals |            1.82 |
# |         MaxQ2Vals |           -83.1 |
# |         MinQ2Vals |           -96.1 |
# |            LossPi |            89.9 |
# |             LossQ |           0.452 |
# |              Time |             122 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -422 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -439 |
# |      StdTestEpRet |            32.1 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -91.2 |
# |         StdQ1Vals |            1.92 |
# |         MaxQ1Vals |           -84.3 |
# |         MinQ1Vals |           -98.5 |
# |     AverageQ2Vals |           -91.2 |
# |         StdQ2Vals |            1.91 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |           -98.4 |
# |            LossPi |              91 |
# |             LossQ |           0.464 |
# |              Time |             131 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -458 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |            -388 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -460 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -427 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |             -92 |
# |         StdQ1Vals |            2.04 |
# |         MaxQ1Vals |             -85 |
# |         MinQ1Vals |           -99.1 |
# |     AverageQ2Vals |             -92 |
# |         StdQ2Vals |            2.03 |
# |         MaxQ2Vals |           -85.1 |
# |         MinQ2Vals |           -98.8 |
# |            LossPi |            91.9 |
# |             LossQ |           0.492 |
# |              Time |             140 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -459 |
# |          StdEpRet |            22.6 |
# |          MaxEpRet |            -414 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            46.5 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -92.7 |
# |         StdQ1Vals |            2.13 |
# |         MaxQ1Vals |           -85.5 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -92.7 |
# |         StdQ2Vals |            2.12 |
# |         MaxQ2Vals |           -85.6 |
# |         MinQ2Vals |           -99.8 |
# |            LossPi |            92.5 |
# |             LossQ |           0.519 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -447 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |            -375 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -434 |
# |      StdTestEpRet |            47.4 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            2.24 |
# |         MaxQ1Vals |           -86.1 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            2.24 |
# |         MaxQ2Vals |           -85.9 |
# |         MinQ2Vals |            -101 |
# |            LossPi |              93 |
# |             LossQ |           0.546 |
# |              Time |             157 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -448 |
# |          StdEpRet |            29.5 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -467 |
# |      StdTestEpRet |            10.7 |
# |      MaxTestEpRet |            -448 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -93.5 |
# |         StdQ1Vals |            2.36 |
# |         MaxQ1Vals |           -86.4 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -93.5 |
# |         StdQ2Vals |            2.36 |
# |         MaxQ2Vals |           -86.4 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            93.4 |
# |             LossQ |           0.588 |
# |              Time |             165 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |            -430 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -454 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -417 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            2.49 |
# |         MaxQ1Vals |           -86.6 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            2.48 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            93.6 |
# |             LossQ |           0.613 |
# |              Time |             174 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -458 |
# |          StdEpRet |            12.4 |
# |          MaxEpRet |            -437 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -425 |
# |      StdTestEpRet |            38.4 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            2.59 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -86.8 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            93.9 |
# |             LossQ |           0.633 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |            -412 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |              26 |
# |      MaxTestEpRet |            -391 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -94.1 |
# |         StdQ1Vals |            2.66 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -94.1 |
# |         StdQ2Vals |            2.65 |
# |         MaxQ2Vals |           -86.9 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              94 |
# |             LossQ |           0.649 |
# |              Time |             191 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -446 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |            -410 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -432 |
# |      StdTestEpRet |              36 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            2.72 |
# |         MaxQ1Vals |             -87 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            2.72 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.1 |
# |             LossQ |           0.658 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -461 |
# |          StdEpRet |            18.9 |
# |          MaxEpRet |            -424 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            44.2 |
# |      MaxTestEpRet |            -302 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |            2.79 |
# |         MaxQ1Vals |             -87 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |            2.78 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            94.1 |
# |             LossQ |           0.668 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -443 |
# |          StdEpRet |              27 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -478 |
# |  AverageTestEpRet |            -426 |
# |      StdTestEpRet |              30 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |            2.82 |
# |         MaxQ1Vals |           -86.9 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |            2.82 |
# |         MaxQ2Vals |           -87.2 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.1 |
# |             LossQ |           0.676 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -446 |
# |          StdEpRet |            30.1 |
# |          MaxEpRet |            -385 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -426 |
# |      StdTestEpRet |            24.9 |
# |      MaxTestEpRet |            -373 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |             2.9 |
# |         MaxQ1Vals |             -87 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |             2.9 |
# |         MaxQ2Vals |             -87 |
# |         MinQ2Vals |            -106 |
# |            LossPi |              94 |
# |             LossQ |           0.678 |
# |              Time |             227 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -447 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |            -399 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            31.3 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -94.1 |
# |         StdQ1Vals |            2.97 |
# |         MaxQ1Vals |           -86.7 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -94.1 |
# |         StdQ2Vals |            2.97 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              94 |
# |             LossQ |           0.699 |
# |              Time |             236 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            20.4 |
# |          MaxEpRet |            -408 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            40.3 |
# |      MaxTestEpRet |            -325 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            3.04 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            3.05 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            93.8 |
# |             LossQ |           0.713 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -445 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |            -409 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -414 |
# |      StdTestEpRet |            36.7 |
# |      MaxTestEpRet |            -307 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            3.11 |
# |         MaxQ1Vals |           -86.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            3.11 |
# |         MaxQ2Vals |           -86.3 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            93.8 |
# |             LossQ |           0.713 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |            32.7 |
# |          MaxEpRet |            -344 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            34.2 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            3.15 |
# |         MaxQ1Vals |           -86.2 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            3.15 |
# |         MaxQ2Vals |             -86 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            93.6 |
# |             LossQ |           0.711 |
# |              Time |             262 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |              26 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -409 |
# |      StdTestEpRet |            27.2 |
# |      MaxTestEpRet |            -351 |
# |      MinTestEpRet |            -454 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -93.6 |
# |         StdQ1Vals |            3.22 |
# |         MaxQ1Vals |           -85.9 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -93.6 |
# |         StdQ2Vals |            3.22 |
# |         MaxQ2Vals |           -85.5 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            93.4 |
# |             LossQ |           0.725 |
# |              Time |             271 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -438 |
# |          StdEpRet |            29.1 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -472 |
# |  AverageTestEpRet |            -390 |
# |      StdTestEpRet |            36.8 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -93.4 |
# |         StdQ1Vals |             3.3 |
# |         MaxQ1Vals |           -85.6 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -93.4 |
# |         StdQ2Vals |             3.3 |
# |         MaxQ2Vals |           -85.3 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            93.2 |
# |             LossQ |           0.755 |
# |              Time |             279 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -440 |
# |          StdEpRet |            17.2 |
# |          MaxEpRet |            -407 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            47.7 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            3.36 |
# |         MaxQ1Vals |           -85.3 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            3.36 |
# |         MaxQ2Vals |           -85.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              93 |
# |             LossQ |           0.758 |
# |              Time |             288 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -441 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -389 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -418 |
# |      StdTestEpRet |            27.7 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            3.42 |
# |         MaxQ1Vals |           -84.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            3.42 |
# |         MaxQ2Vals |           -84.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.8 |
# |             LossQ |           0.775 |
# |              Time |             297 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            34.5 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -417 |
# |      StdTestEpRet |            34.1 |
# |      MaxTestEpRet |            -339 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -92.9 |
# |         StdQ1Vals |            3.48 |
# |         MaxQ1Vals |           -84.2 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -92.9 |
# |         StdQ2Vals |            3.48 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.6 |
# |             LossQ |           0.792 |
# |              Time |             306 |
# ---------------------------------------
