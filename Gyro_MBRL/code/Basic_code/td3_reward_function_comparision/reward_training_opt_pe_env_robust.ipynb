# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeRobustEnv-v0'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2,
    'obs_noise': 0.001
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=2000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_robust_2000', exp_name='td3_pe_opt_ing_robust_2000')
                   )
# Out:
# Warning: Log dir td3_pe_opt_ing_robust_2000 already exists! Storing info there anyway.
# Logging data to td3_pe_opt_ing_robust_2000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fb86a17c9d8>, 'GyroscopeRobustEnv-v0', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2, 'obs_noise': 0.001}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	2000,
#     "exp_name":	"td3_pe_opt_ing_robust_2000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fb86a181b00>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_robust_2000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_robust_2000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_robust_2000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_robust_2000",
#         "output_dir":	"td3_pe_opt_ing_robust_2000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            8.25 |
# |          MaxEpRet |            -469 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |            -454 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -5.92 |
# |         StdQ1Vals |            1.91 |
# |         MaxQ1Vals |          0.0351 |
# |         MinQ1Vals |           -9.46 |
# |     AverageQ2Vals |           -5.97 |
# |         StdQ2Vals |            1.81 |
# |         MaxQ2Vals |          -0.112 |
# |         MinQ2Vals |           -9.51 |
# |            LossPi |            5.64 |
# |             LossQ |            3.44 |
# |              Time |             268 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -487 |
# |          StdEpRet |            8.82 |
# |          MaxEpRet |            -469 |
# |          MinEpRet |            -509 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |            -460 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.5 |
# |         StdQ1Vals |            3.78 |
# |         MaxQ1Vals |           -7.02 |
# |         MinQ1Vals |           -22.9 |
# |     AverageQ2Vals |           -14.5 |
# |         StdQ2Vals |            3.78 |
# |         MaxQ2Vals |           -6.99 |
# |         MinQ2Vals |             -23 |
# |            LossPi |            14.3 |
# |             LossQ |           0.115 |
# |              Time |             507 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -484 |
# |          StdEpRet |            10.5 |
# |          MaxEpRet |            -466 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -461 |
# |      StdTestEpRet |            34.3 |
# |      MaxTestEpRet |            -372 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.4 |
# |         StdQ1Vals |            3.66 |
# |         MaxQ1Vals |           -18.5 |
# |         MinQ1Vals |           -36.6 |
# |     AverageQ2Vals |           -27.4 |
# |         StdQ2Vals |            3.66 |
# |         MaxQ2Vals |           -18.4 |
# |         MinQ2Vals |           -36.5 |
# |            LossPi |            27.2 |
# |             LossQ |           0.137 |
# |              Time |             874 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            7.32 |
# |          MaxEpRet |            -475 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -466 |
# |      StdTestEpRet |            22.4 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |             -39 |
# |         StdQ1Vals |            3.28 |
# |         MaxQ1Vals |           -28.9 |
# |         MinQ1Vals |           -48.1 |
# |     AverageQ2Vals |             -39 |
# |         StdQ2Vals |            3.28 |
# |         MaxQ2Vals |             -29 |
# |         MinQ2Vals |           -47.9 |
# |            LossPi |            38.8 |
# |             LossQ |            0.21 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -484 |
# |          StdEpRet |            9.84 |
# |          MaxEpRet |            -464 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -458 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -430 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -48.8 |
# |         StdQ1Vals |            2.84 |
# |         MaxQ1Vals |           -38.8 |
# |         MinQ1Vals |           -57.2 |
# |     AverageQ2Vals |           -48.8 |
# |         StdQ2Vals |            2.85 |
# |         MaxQ2Vals |           -38.6 |
# |         MinQ2Vals |             -57 |
# |            LossPi |            48.6 |
# |             LossQ |           0.251 |
# |              Time |        1.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            7.89 |
# |          MaxEpRet |            -474 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -431 |
# |      StdTestEpRet |            21.7 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -56.9 |
# |         StdQ1Vals |            2.53 |
# |         MaxQ1Vals |           -47.6 |
# |         MinQ1Vals |           -65.1 |
# |     AverageQ2Vals |           -56.9 |
# |         StdQ2Vals |            2.54 |
# |         MaxQ2Vals |           -47.2 |
# |         MinQ2Vals |             -65 |
# |            LossPi |            56.7 |
# |             LossQ |           0.299 |
# |              Time |        2.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -442 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |            -405 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -63.7 |
# |         StdQ1Vals |            2.24 |
# |         MaxQ1Vals |             -55 |
# |         MinQ1Vals |           -71.4 |
# |     AverageQ2Vals |           -63.7 |
# |         StdQ2Vals |            2.25 |
# |         MaxQ2Vals |           -54.5 |
# |         MinQ2Vals |           -72.1 |
# |            LossPi |            63.5 |
# |             LossQ |           0.333 |
# |              Time |        3.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |            -424 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            41.1 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |             -69 |
# |         StdQ1Vals |            2.18 |
# |         MaxQ1Vals |             -61 |
# |         MinQ1Vals |           -76.9 |
# |     AverageQ2Vals |             -69 |
# |         StdQ2Vals |            2.19 |
# |         MaxQ2Vals |           -60.6 |
# |         MinQ2Vals |           -77.2 |
# |            LossPi |            68.8 |
# |             LossQ |           0.355 |
# |              Time |        4.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -444 |
# |          StdEpRet |            30.3 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            23.9 |
# |      MaxTestEpRet |            -405 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -73.2 |
# |         StdQ1Vals |            2.25 |
# |         MaxQ1Vals |           -64.2 |
# |         MinQ1Vals |           -81.5 |
# |     AverageQ2Vals |           -73.2 |
# |         StdQ2Vals |            2.26 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |           -81.6 |
# |            LossPi |              73 |
# |             LossQ |           0.387 |
# |              Time |        5.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -442 |
# |          StdEpRet |            30.3 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -428 |
# |      StdTestEpRet |            37.1 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -76.6 |
# |         StdQ1Vals |            2.41 |
# |         MaxQ1Vals |           -67.1 |
# |         MinQ1Vals |           -85.1 |
# |     AverageQ2Vals |           -76.6 |
# |         StdQ2Vals |            2.42 |
# |         MaxQ2Vals |             -67 |
# |         MinQ2Vals |           -84.9 |
# |            LossPi |            76.4 |
# |             LossQ |           0.417 |
# |              Time |        6.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -449 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -405 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -440 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |            -394 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -79.4 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -69.4 |
# |         MinQ1Vals |           -87.6 |
# |     AverageQ2Vals |           -79.4 |
# |         StdQ2Vals |            2.65 |
# |         MaxQ2Vals |           -69.4 |
# |         MinQ2Vals |             -88 |
# |            LossPi |            79.1 |
# |             LossQ |           0.461 |
# |              Time |        7.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -437 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -370 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -418 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -81.5 |
# |         StdQ1Vals |            2.81 |
# |         MaxQ1Vals |           -71.4 |
# |         MinQ1Vals |           -90.6 |
# |     AverageQ2Vals |           -81.5 |
# |         StdQ2Vals |            2.82 |
# |         MaxQ2Vals |           -71.5 |
# |         MinQ2Vals |           -90.4 |
# |            LossPi |            81.3 |
# |             LossQ |           0.499 |
# |              Time |        8.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -446 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -407 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |            31.8 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -83.3 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |           -72.9 |
# |         MinQ1Vals |           -92.4 |
# |     AverageQ2Vals |           -83.3 |
# |         StdQ2Vals |            3.01 |
# |         MaxQ2Vals |           -72.8 |
# |         MinQ2Vals |             -93 |
# |            LossPi |              83 |
# |             LossQ |           0.523 |
# |              Time |        9.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -433 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            35.5 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -84.7 |
# |         StdQ1Vals |            3.15 |
# |         MaxQ1Vals |           -74.2 |
# |         MinQ1Vals |           -94.1 |
# |     AverageQ2Vals |           -84.7 |
# |         StdQ2Vals |            3.16 |
# |         MaxQ2Vals |           -74.1 |
# |         MinQ2Vals |           -94.8 |
# |            LossPi |            84.4 |
# |             LossQ |           0.554 |
# |              Time |        1.02e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -438 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |            -397 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -403 |
# |      StdTestEpRet |            41.5 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -85.8 |
# |         StdQ1Vals |            3.31 |
# |         MaxQ1Vals |           -75.2 |
# |         MinQ1Vals |           -96.5 |
# |     AverageQ2Vals |           -85.8 |
# |         StdQ2Vals |            3.32 |
# |         MaxQ2Vals |           -75.1 |
# |         MinQ2Vals |           -96.1 |
# |            LossPi |            85.6 |
# |             LossQ |           0.583 |
# |              Time |        1.14e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -436 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            30.1 |
# |      MaxTestEpRet |            -334 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -86.7 |
# |         StdQ1Vals |             3.4 |
# |         MaxQ1Vals |             -76 |
# |         MinQ1Vals |           -97.9 |
# |     AverageQ2Vals |           -86.7 |
# |         StdQ2Vals |            3.41 |
# |         MaxQ2Vals |           -75.8 |
# |         MinQ2Vals |           -97.2 |
# |            LossPi |            86.5 |
# |             LossQ |           0.593 |
# |              Time |        1.24e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            31.4 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -429 |
# |      StdTestEpRet |              28 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -483 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -87.3 |
# |         StdQ1Vals |            3.57 |
# |         MaxQ1Vals |           -76.7 |
# |         MinQ1Vals |           -98.7 |
# |     AverageQ2Vals |           -87.3 |
# |         StdQ2Vals |            3.59 |
# |         MaxQ2Vals |           -76.4 |
# |         MinQ2Vals |           -98.7 |
# |            LossPi |            87.1 |
# |             LossQ |           0.615 |
# |              Time |        1.33e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -430 |
# |          StdEpRet |            34.3 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |            51.4 |
# |      MaxTestEpRet |            -279 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -87.8 |
# |         StdQ1Vals |             3.7 |
# |         MaxQ1Vals |           -76.8 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -87.8 |
# |         StdQ2Vals |            3.71 |
# |         MaxQ2Vals |             -77 |
# |         MinQ2Vals |           -99.7 |
# |            LossPi |            87.6 |
# |             LossQ |           0.625 |
# |              Time |         1.4e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -429 |
# |          StdEpRet |            41.9 |
# |          MaxEpRet |            -346 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            54.3 |
# |      MaxTestEpRet |            -293 |
# |      MinTestEpRet |            -477 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            3.83 |
# |         MaxQ1Vals |           -76.9 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            3.85 |
# |         MaxQ2Vals |           -76.8 |
# |         MinQ2Vals |            -101 |
# |            LossPi |              88 |
# |             LossQ |            0.65 |
# |              Time |        1.47e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -433 |
# |          StdEpRet |            36.3 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -478 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            41.8 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -88.5 |
# |         StdQ1Vals |            3.98 |
# |         MaxQ1Vals |           -76.9 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -88.5 |
# |         StdQ2Vals |            3.99 |
# |         MaxQ2Vals |           -76.8 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            88.3 |
# |             LossQ |           0.675 |
# |              Time |        1.57e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            29.2 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -456 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            51.7 |
# |      MaxTestEpRet |            -289 |
# |      MinTestEpRet |            -466 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -88.7 |
# |         StdQ1Vals |             4.1 |
# |         MaxQ1Vals |           -76.8 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -88.7 |
# |         StdQ2Vals |            4.12 |
# |         MaxQ2Vals |           -76.7 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            88.5 |
# |             LossQ |           0.694 |
# |              Time |        1.63e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -435 |
# |          StdEpRet |              29 |
# |          MaxEpRet |            -380 |
# |          MinEpRet |            -472 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            25.8 |
# |      MaxTestEpRet |            -372 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -88.9 |
# |         StdQ1Vals |            4.18 |
# |         MaxQ1Vals |           -76.5 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -88.9 |
# |         StdQ2Vals |            4.19 |
# |         MaxQ2Vals |           -76.5 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            88.6 |
# |             LossQ |           0.716 |
# |              Time |         1.7e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -427 |
# |          StdEpRet |            27.4 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -472 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            41.4 |
# |      MaxTestEpRet |            -327 |
# |      MinTestEpRet |            -472 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |             -89 |
# |         StdQ1Vals |            4.27 |
# |         MaxQ1Vals |           -76.4 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |             -89 |
# |         StdQ2Vals |            4.28 |
# |         MaxQ2Vals |           -76.4 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            88.8 |
# |             LossQ |           0.727 |
# |              Time |        1.83e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |            -346 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            35.5 |
# |      MaxTestEpRet |            -327 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -88.9 |
# |         StdQ1Vals |            4.37 |
# |         MaxQ1Vals |           -76.4 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -88.9 |
# |         StdQ2Vals |            4.38 |
# |         MaxQ2Vals |           -76.3 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            88.7 |
# |             LossQ |           0.738 |
# |              Time |        1.98e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |            -337 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |              36 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -88.9 |
# |         StdQ1Vals |            4.44 |
# |         MaxQ1Vals |           -76.3 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -88.9 |
# |         StdQ2Vals |            4.45 |
# |         MaxQ2Vals |           -76.2 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            88.7 |
# |             LossQ |           0.763 |
# |              Time |        2.08e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -468 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            17.7 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -88.9 |
# |         StdQ1Vals |            4.51 |
# |         MaxQ1Vals |           -76.3 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.9 |
# |         StdQ2Vals |            4.52 |
# |         MaxQ2Vals |           -76.2 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            88.7 |
# |             LossQ |           0.768 |
# |              Time |        2.22e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |            30.3 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -414 |
# |      StdTestEpRet |            21.4 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -88.8 |
# |         StdQ1Vals |            4.59 |
# |         MaxQ1Vals |           -76.2 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.8 |
# |         StdQ2Vals |             4.6 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            88.6 |
# |             LossQ |           0.783 |
# |              Time |        2.32e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            34.4 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            37.4 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -466 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -88.7 |
# |         StdQ1Vals |            4.68 |
# |         MaxQ1Vals |           -76.3 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.7 |
# |         StdQ2Vals |            4.69 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            88.5 |
# |             LossQ |           0.782 |
# |              Time |        2.41e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            34.8 |
# |          MaxEpRet |            -333 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            43.2 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -88.6 |
# |         StdQ1Vals |            4.76 |
# |         MaxQ1Vals |           -76.2 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -88.6 |
# |         StdQ2Vals |            4.78 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            88.4 |
# |             LossQ |           0.786 |
# |              Time |        2.55e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -417 |
# |          StdEpRet |            25.5 |
# |          MaxEpRet |            -370 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            59.9 |
# |      MaxTestEpRet |            -268 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -88.5 |
# |         StdQ1Vals |            4.83 |
# |         MaxQ1Vals |             -76 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -88.5 |
# |         StdQ2Vals |            4.85 |
# |         MaxQ2Vals |           -75.9 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            88.2 |
# |             LossQ |           0.785 |
# |              Time |        2.63e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -424 |
# |          StdEpRet |            27.6 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            29.5 |
# |      MaxTestEpRet |            -362 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            4.88 |
# |         MaxQ1Vals |           -75.7 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            4.89 |
# |         MaxQ2Vals |           -75.7 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            88.1 |
# |             LossQ |            0.78 |
# |              Time |        2.71e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            39.6 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            37.5 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -471 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            4.97 |
# |         MaxQ1Vals |           -75.7 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            4.99 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |            -105 |
# |            LossPi |              88 |
# |             LossQ |           0.793 |
# |              Time |        2.81e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            29.6 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |            -329 |
# |      MinTestEpRet |            -477 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -88.1 |
# |         StdQ1Vals |            5.05 |
# |         MaxQ1Vals |           -75.7 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -88.1 |
# |         StdQ2Vals |            5.06 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            87.8 |
# |             LossQ |             0.8 |
# |              Time |        2.91e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -420 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            26.9 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |            -435 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -87.9 |
# |         StdQ1Vals |             5.1 |
# |         MaxQ1Vals |           -75.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -87.9 |
# |         StdQ2Vals |            5.12 |
# |         MaxQ2Vals |           -75.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            87.6 |
# |             LossQ |           0.797 |
# |              Time |        3.06e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |            -321 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -87.7 |
# |         StdQ1Vals |            5.16 |
# |         MaxQ1Vals |           -75.4 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -87.7 |
# |         StdQ2Vals |            5.18 |
# |         MaxQ2Vals |             -75 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            87.5 |
# |             LossQ |           0.796 |
# |              Time |        3.13e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            42.8 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -476 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            49.4 |
# |      MaxTestEpRet |            -312 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -87.6 |
# |         StdQ1Vals |            5.22 |
# |         MaxQ1Vals |           -75.3 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -87.6 |
# |         StdQ2Vals |            5.24 |
# |         MaxQ2Vals |           -74.8 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            87.3 |
# |             LossQ |           0.805 |
# |              Time |        3.23e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -417 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -366 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            48.2 |
# |      MaxTestEpRet |            -299 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -87.4 |
# |         StdQ1Vals |            5.26 |
# |         MaxQ1Vals |             -75 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -87.4 |
# |         StdQ2Vals |            5.28 |
# |         MaxQ2Vals |           -74.6 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            87.2 |
# |             LossQ |           0.815 |
# |              Time |        3.37e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            46.8 |
# |          MaxEpRet |            -295 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -414 |
# |      StdTestEpRet |            38.5 |
# |      MaxTestEpRet |            -327 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -87.3 |
# |         StdQ1Vals |            5.32 |
# |         MaxQ1Vals |             -75 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -87.3 |
# |         StdQ2Vals |            5.33 |
# |         MaxQ2Vals |           -74.4 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            87.1 |
# |             LossQ |           0.826 |
# |              Time |        3.45e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -424 |
# |          StdEpRet |            36.2 |
# |          MaxEpRet |            -351 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            43.3 |
# |      MaxTestEpRet |            -334 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -87.2 |
# |         StdQ1Vals |            5.38 |
# |         MaxQ1Vals |           -74.7 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -87.2 |
# |         StdQ2Vals |            5.39 |
# |         MaxQ2Vals |           -74.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            86.9 |
# |             LossQ |           0.825 |
# |              Time |        3.59e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |            -347 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            40.9 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -87.1 |
# |         StdQ1Vals |            5.44 |
# |         MaxQ1Vals |           -74.2 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -87.1 |
# |         StdQ2Vals |            5.46 |
# |         MaxQ2Vals |           -74.1 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            86.9 |
# |             LossQ |           0.844 |
# |              Time |        3.73e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            45.6 |
# |          MaxEpRet |            -296 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -444 |
# |      StdTestEpRet |            25.1 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -86.9 |
# |         StdQ1Vals |            5.47 |
# |         MaxQ1Vals |           -73.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -86.9 |
# |         StdQ2Vals |            5.49 |
# |         MaxQ2Vals |           -73.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            86.7 |
# |             LossQ |           0.853 |
# |              Time |        3.78e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            39.8 |
# |          MaxEpRet |            -343 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -86.7 |
# |         StdQ1Vals |            5.52 |
# |         MaxQ1Vals |           -73.5 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -86.7 |
# |         StdQ2Vals |            5.53 |
# |         MaxQ2Vals |           -73.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            86.5 |
# |             LossQ |           0.851 |
# |              Time |         3.9e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -426 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -463 |
# |  AverageTestEpRet |            -379 |
# |      StdTestEpRet |            56.1 |
# |      MaxTestEpRet |            -286 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -86.6 |
# |         StdQ1Vals |            5.55 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -86.6 |
# |         StdQ2Vals |            5.56 |
# |         MaxQ2Vals |           -73.2 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            86.4 |
# |             LossQ |           0.851 |
# |              Time |        4.02e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            39.3 |
# |          MaxEpRet |            -318 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            49.5 |
# |      MaxTestEpRet |            -331 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -86.5 |
# |         StdQ1Vals |            5.57 |
# |         MaxQ1Vals |           -72.9 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -86.5 |
# |         StdQ2Vals |            5.59 |
# |         MaxQ2Vals |           -72.9 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            86.3 |
# |             LossQ |           0.847 |
# |              Time |        4.13e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            45.1 |
# |          MaxEpRet |            -275 |
# |          MinEpRet |            -468 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            32.3 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -86.4 |
# |         StdQ1Vals |            5.61 |
# |         MaxQ1Vals |           -72.6 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -86.4 |
# |         StdQ2Vals |            5.62 |
# |         MaxQ2Vals |           -72.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            86.1 |
# |             LossQ |           0.863 |
# |              Time |        4.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -415 |
# |          StdEpRet |            24.5 |
# |          MaxEpRet |            -366 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -387 |
# |      StdTestEpRet |            61.6 |
# |      MaxTestEpRet |            -239 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -86.2 |
# |         StdQ1Vals |            5.64 |
# |         MaxQ1Vals |           -72.7 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -86.2 |
# |         StdQ2Vals |            5.66 |
# |         MaxQ2Vals |           -72.4 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              86 |
# |             LossQ |           0.857 |
# |              Time |        4.33e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            36.1 |
# ...
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/__init__.py", line 48, in <module>
#     from tensorflow.contrib.distributions.python.ops.inverse_gamma import *
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 894, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1157, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1129, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1241, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 82, in _path_stat
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-600b55314969>", line 43, in <module>
#     logger_kwargs=dict(output_dir='td3_pe_opt_ing_robust_2000', exp_name='td3_pe_opt_ing_robust_2000')
#   File "/Users/yan/spinningup/spinup/algos/pytorch/td3/td3.py", line 334, in td3
#     test_agent()
#   File "/Users/yan/spinningup/spinup/algos/pytorch/td3/td3.py", line 276, in test_agent
#     o, r, d, _ = test_env.step(get_action(o, 0))
#   File "/Users/yan/Documents/Project_code/Gyro_MBRL/Gyro_MBRL/lib/gym_gyroscope_env/gym_gyroscope_env/envs/gyroscope_robust_env.py", line 229, in step
#     args = (u1, u2)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/ivp.py", line 576, in solve_ivp
#     message = solver.step()
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 181, in step
#     success, message = self._step_impl()
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/rk.py", line 145, in _step_impl
#     self.B, self.C, self.K)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/rk.py", line 64, in rk_step
#     K[s] = fun(t + c * h, y + dy)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 138, in fun
#     return self.fun_single(t, y)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 20, in fun_wrapped
#     return np.asarray(fun(t, y), dtype=dtype)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/ivp.py", line 514, in <lambda>
#     fun = lambda t, x, fun=fun: fun(t, x, *args)
#   File "/Users/yan/Documents/Project_code/Gyro_MBRL/Gyro_MBRL/lib/gym_gyroscope_env/gym_gyroscope_env/envs/gyroscope_robust_env.py", line 318, in dxdt
#     dx_dt[1] = ((J1)*np.sin(2*x[2])*x[1]*x[3]+2*(T1-T3*np.sin(x[2])-Jdx3*np.cos(x[2])*x[3]*x[5]))/(J2+(J3)*np.cos(2*x[2]))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-600b55314969>", line 43, in <module>
#     logger_kwargs=dict(output_dir='td3_pe_opt_ing_robust_2000', exp_name='td3_pe_opt_ing_robust_2000')
#   File "/Users/yan/spinningup/spinup/algos/pytorch/td3/td3.py", line 334, in td3
#     test_agent()
#   File "/Users/yan/spinningup/spinup/algos/pytorch/td3/td3.py", line 276, in test_agent
#     o, r, d, _ = test_env.step(get_action(o, 0))
#   File "/Users/yan/Documents/Project_code/Gyro_MBRL/Gyro_MBRL/lib/gym_gyroscope_env/gym_gyroscope_env/envs/gyroscope_robust_env.py", line 229, in step
#     args = (u1, u2)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/ivp.py", line 576, in solve_ivp
#     message = solver.step()
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 181, in step
#     success, message = self._step_impl()
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/rk.py", line 145, in _step_impl
#     self.B, self.C, self.K)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/rk.py", line 64, in rk_step
#     K[s] = fun(t + c * h, y + dy)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 138, in fun
#     return self.fun_single(t, y)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/base.py", line 20, in fun_wrapped
#     return np.asarray(fun(t, y), dtype=dtype)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/scipy/integrate/_ivp/ivp.py", line 514, in <lambda>
#     fun = lambda t, x, fun=fun: fun(t, x, *args)
#   File "/Users/yan/Documents/Project_code/Gyro_MBRL/Gyro_MBRL/lib/gym_gyroscope_env/gym_gyroscope_env/envs/gyroscope_robust_env.py", line 318, in dxdt
#     dx_dt[1] = ((J1)*np.sin(2*x[2])*x[1]*x[3]+2*(T1-T3*np.sin(x[2])-Jdx3*np.cos(x[2])*x[3]*x[5]))/(J2+(J3)*np.cos(2*x[2]))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 428, in _joinrealpath
#     newpath = join(path, name)
#   File "/Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/posixpath.py", line 89, in join
#     elif not path or path.endswith(sep):
# KeyboardInterrupt
