# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=5000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_5000', exp_name='td3_pe_opt_ing_5000')
                   )
# Out:
# Logging data to td3_pe_opt_ing_5000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fce895fca60>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	5000,
#     "exp_name":	"td3_pe_opt_ing_5000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fce89600a20>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_5000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_5000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_5000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_5000",
#         "output_dir":	"td3_pe_opt_ing_5000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -494 |
# |          StdEpRet |            6.42 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            3.81 |
# |      MaxTestEpRet |            -473 |
# |      MinTestEpRet |            -485 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |            -6.1 |
# |         StdQ1Vals |            1.99 |
# |         MaxQ1Vals |          0.0111 |
# |         MinQ1Vals |           -10.5 |
# |     AverageQ2Vals |           -6.15 |
# |         StdQ2Vals |            1.88 |
# |         MaxQ2Vals |         0.00505 |
# |         MinQ2Vals |           -10.5 |
# |            LossPi |            5.87 |
# |             LossQ |            3.37 |
# |              Time |            4.95 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            6.06 |
# |          MaxEpRet |            -479 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |            -446 |
# |      MinTestEpRet |            -485 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.9 |
# |         StdQ1Vals |            3.85 |
# |         MaxQ1Vals |           -6.83 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |           -14.9 |
# |         StdQ2Vals |            3.85 |
# |         MaxQ2Vals |           -6.67 |
# |         MinQ2Vals |           -23.6 |
# |            LossPi |            14.7 |
# |             LossQ |           0.144 |
# |              Time |            13.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             8.3 |
# |          MaxEpRet |            -470 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -470 |
# |      StdTestEpRet |            23.2 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.8 |
# |         StdQ1Vals |            3.68 |
# |         MaxQ1Vals |           -19.4 |
# |         MinQ1Vals |           -38.5 |
# |     AverageQ2Vals |           -27.8 |
# |         StdQ2Vals |            3.68 |
# |         MaxQ2Vals |           -19.3 |
# |         MinQ2Vals |           -38.7 |
# |            LossPi |            27.7 |
# |             LossQ |           0.163 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -495 |
# |          StdEpRet |            5.37 |
# |          MaxEpRet |            -487 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            8.88 |
# |      MaxTestEpRet |            -463 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.4 |
# |         StdQ1Vals |            3.25 |
# |         MaxQ1Vals |           -31.7 |
# |         MinQ1Vals |           -48.8 |
# |     AverageQ2Vals |           -39.4 |
# |         StdQ2Vals |            3.25 |
# |         MaxQ2Vals |           -31.7 |
# |         MinQ2Vals |           -48.9 |
# |            LossPi |            39.3 |
# |             LossQ |           0.216 |
# |              Time |            31.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            5.24 |
# |          MaxEpRet |            -482 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |            -448 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.3 |
# |         StdQ1Vals |            2.79 |
# |         MaxQ1Vals |           -42.1 |
# |         MinQ1Vals |           -57.4 |
# |     AverageQ2Vals |           -49.3 |
# |         StdQ2Vals |            2.79 |
# |         MaxQ2Vals |           -42.2 |
# |         MinQ2Vals |           -57.3 |
# |            LossPi |            49.2 |
# |             LossQ |            0.25 |
# |              Time |            40.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            5.12 |
# |          MaxEpRet |            -479 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            15.8 |
# |      MaxTestEpRet |            -436 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.6 |
# |         StdQ1Vals |            2.42 |
# |         MaxQ1Vals |           -50.6 |
# |         MinQ1Vals |           -64.5 |
# |     AverageQ2Vals |           -57.6 |
# |         StdQ2Vals |            2.42 |
# |         MaxQ2Vals |           -50.9 |
# |         MinQ2Vals |           -64.7 |
# |            LossPi |            57.5 |
# |             LossQ |           0.273 |
# |              Time |              50 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -485 |
# |          StdEpRet |            11.7 |
# |          MaxEpRet |            -459 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            14.3 |
# |      MaxTestEpRet |            -452 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.7 |
# |         StdQ1Vals |             2.1 |
# |         MaxQ1Vals |           -58.2 |
# |         MinQ1Vals |           -70.9 |
# |     AverageQ2Vals |           -64.7 |
# |         StdQ2Vals |             2.1 |
# |         MaxQ2Vals |           -58.2 |
# |         MinQ2Vals |           -70.9 |
# |            LossPi |            64.5 |
# |             LossQ |           0.289 |
# |              Time |            58.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            12.3 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -470 |
# |      StdTestEpRet |            32.4 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.4 |
# |         StdQ1Vals |            1.81 |
# |         MaxQ1Vals |           -64.5 |
# |         MinQ1Vals |           -76.2 |
# |     AverageQ2Vals |           -70.4 |
# |         StdQ2Vals |            1.82 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |           -76.6 |
# |            LossPi |            70.3 |
# |             LossQ |           0.281 |
# |              Time |              68 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -465 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |            -435 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            11.4 |
# |      MaxTestEpRet |            -462 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.1 |
# |         StdQ1Vals |            1.64 |
# |         MaxQ1Vals |           -69.5 |
# |         MinQ1Vals |           -80.7 |
# |     AverageQ2Vals |           -75.1 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |           -69.8 |
# |         MinQ2Vals |             -81 |
# |            LossPi |              75 |
# |             LossQ |           0.298 |
# |              Time |              77 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            12.4 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -461 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |            -425 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -78.9 |
# |         StdQ1Vals |            1.64 |
# |         MaxQ1Vals |           -73.4 |
# |         MinQ1Vals |           -84.8 |
# |     AverageQ2Vals |           -78.9 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |           -73.5 |
# |         MinQ2Vals |           -84.8 |
# |            LossPi |            78.8 |
# |             LossQ |            0.32 |
# |              Time |            85.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -411 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -448 |
# |      StdTestEpRet |            33.7 |
# |      MaxTestEpRet |            -387 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.1 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |           -76.1 |
# |         MinQ1Vals |           -87.9 |
# |     AverageQ2Vals |           -82.1 |
# |         StdQ2Vals |            1.66 |
# |         MaxQ2Vals |           -76.2 |
# |         MinQ2Vals |           -88.4 |
# |            LossPi |              82 |
# |             LossQ |           0.346 |
# |              Time |              94 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -444 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -458 |
# |      StdTestEpRet |            34.6 |
# |      MaxTestEpRet |            -384 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -84.7 |
# |         StdQ1Vals |            1.73 |
# |         MaxQ1Vals |           -78.4 |
# |         MinQ1Vals |           -90.7 |
# |     AverageQ2Vals |           -84.7 |
# |         StdQ2Vals |            1.74 |
# |         MaxQ2Vals |           -78.4 |
# |         MinQ2Vals |           -90.9 |
# |            LossPi |            84.6 |
# |             LossQ |           0.364 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -469 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |            -379 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |            -436 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -86.8 |
# |         StdQ1Vals |            1.85 |
# |         MaxQ1Vals |           -80.7 |
# |         MinQ1Vals |           -92.9 |
# |     AverageQ2Vals |           -86.8 |
# |         StdQ2Vals |            1.86 |
# |         MaxQ2Vals |           -80.6 |
# |         MinQ2Vals |           -93.1 |
# |            LossPi |            86.7 |
# |             LossQ |           0.399 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            15.2 |
# |          MaxEpRet |            -432 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -446 |
# |      StdTestEpRet |              30 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -88.5 |
# |         StdQ1Vals |            1.98 |
# |         MaxQ1Vals |           -82.3 |
# |         MinQ1Vals |           -94.9 |
# |     AverageQ2Vals |           -88.5 |
# |         StdQ2Vals |            1.99 |
# |         MaxQ2Vals |           -82.2 |
# |         MinQ2Vals |           -95.4 |
# |            LossPi |            88.4 |
# |             LossQ |           0.423 |
# |              Time |             120 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -466 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -401 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -446 |
# |      StdTestEpRet |            42.2 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -89.9 |
# |         StdQ1Vals |             2.1 |
# |         MaxQ1Vals |           -83.2 |
# |         MinQ1Vals |           -96.6 |
# |     AverageQ2Vals |           -89.9 |
# |         StdQ2Vals |            2.11 |
# |         MaxQ2Vals |           -83.3 |
# |         MinQ2Vals |           -96.8 |
# |            LossPi |            89.8 |
# |             LossQ |           0.442 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |            -420 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |              45 |
# |      MaxTestEpRet |            -345 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |             -91 |
# |         StdQ1Vals |            2.25 |
# |         MaxQ1Vals |           -83.8 |
# |         MinQ1Vals |           -97.7 |
# |     AverageQ2Vals |             -91 |
# |         StdQ2Vals |            2.26 |
# |         MaxQ2Vals |           -83.9 |
# |         MinQ2Vals |           -97.7 |
# |            LossPi |            90.9 |
# |             LossQ |           0.465 |
# |              Time |             138 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -461 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -404 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -449 |
# |      StdTestEpRet |            27.1 |
# |      MaxTestEpRet |            -406 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -91.9 |
# |         StdQ1Vals |            2.42 |
# |         MaxQ1Vals |           -84.1 |
# |         MinQ1Vals |           -99.1 |
# |     AverageQ2Vals |           -91.9 |
# |         StdQ2Vals |            2.43 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |           -99.2 |
# |            LossPi |            91.7 |
# |             LossQ |           0.497 |
# |              Time |             146 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -441 |
# |          StdEpRet |            35.7 |
# |          MaxEpRet |            -335 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -441 |
# |      StdTestEpRet |            23.6 |
# |      MaxTestEpRet |            -408 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -92.5 |
# |         StdQ1Vals |            2.55 |
# |         MaxQ1Vals |           -84.2 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -92.5 |
# |         StdQ2Vals |            2.56 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |           -99.8 |
# |            LossPi |            92.4 |
# |             LossQ |           0.524 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -436 |
# |          StdEpRet |            37.9 |
# |          MaxEpRet |            -340 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -426 |
# |      StdTestEpRet |            43.6 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -92.9 |
# |         StdQ1Vals |            2.72 |
# |         MaxQ1Vals |           -84.6 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -92.9 |
# |         StdQ2Vals |            2.73 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            92.8 |
# |             LossQ |           0.565 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -451 |
# |          StdEpRet |            40.8 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -456 |
# |      StdTestEpRet |            30.1 |
# |      MaxTestEpRet |            -392 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |             2.9 |
# |         MaxQ1Vals |           -84.2 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            2.92 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            93.1 |
# |             LossQ |           0.617 |
# |              Time |             172 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -438 |
# |          StdEpRet |            31.3 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -441 |
# |      StdTestEpRet |            31.7 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -93.4 |
# |         StdQ1Vals |            3.12 |
# |         MaxQ1Vals |           -83.6 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -93.4 |
# |         StdQ2Vals |            3.13 |
# |         MaxQ2Vals |           -83.5 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            93.3 |
# |             LossQ |           0.663 |
# |              Time |             181 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -445 |
# |          StdEpRet |            29.2 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -423 |
# |      StdTestEpRet |            39.3 |
# |      MaxTestEpRet |            -362 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -93.5 |
# |         StdQ1Vals |            3.32 |
# |         MaxQ1Vals |           -83.1 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -93.5 |
# |         StdQ2Vals |            3.33 |
# |         MaxQ2Vals |             -83 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            93.3 |
# |             LossQ |           0.697 |
# |              Time |             190 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            18.5 |
# |          MaxEpRet |            -429 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -424 |
# |      StdTestEpRet |            31.8 |
# |      MaxTestEpRet |            -352 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -93.6 |
# |         StdQ1Vals |            3.48 |
# |         MaxQ1Vals |           -82.7 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -93.6 |
# |         StdQ2Vals |            3.49 |
# |         MaxQ2Vals |           -82.5 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            93.5 |
# |             LossQ |           0.728 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            40.7 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -411 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -93.6 |
# |         StdQ1Vals |            3.62 |
# |         MaxQ1Vals |           -82.4 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -93.6 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |           -82.1 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            93.5 |
# |             LossQ |            0.76 |
# |              Time |             207 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -438 |
# |          StdEpRet |            33.7 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -434 |
# |      StdTestEpRet |              22 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -477 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -93.6 |
# |         StdQ1Vals |            3.79 |
# |         MaxQ1Vals |           -82.2 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -93.6 |
# |         StdQ2Vals |             3.8 |
# |         MaxQ2Vals |             -82 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            93.4 |
# |             LossQ |           0.794 |
# |              Time |             215 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            22.7 |
# |          MaxEpRet |            -406 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            33.6 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -454 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -93.5 |
# |         StdQ1Vals |            3.91 |
# |         MaxQ1Vals |           -82.1 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -93.5 |
# |         StdQ2Vals |            3.92 |
# |         MaxQ2Vals |           -81.9 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            93.2 |
# |             LossQ |           0.815 |
# |              Time |             224 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |            27.5 |
# |          MaxEpRet |            -386 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            46.9 |
# |      MaxTestEpRet |            -352 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -93.4 |
# |         StdQ1Vals |            4.02 |
# |         MaxQ1Vals |           -81.9 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -93.4 |
# |         StdQ2Vals |            4.03 |
# |         MaxQ2Vals |           -81.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            93.1 |
# |             LossQ |           0.837 |
# |              Time |             233 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -437 |
# |          StdEpRet |            28.7 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -427 |
# |      StdTestEpRet |            29.8 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            4.19 |
# |         MaxQ1Vals |           -81.7 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |             4.2 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              93 |
# |             LossQ |           0.846 |
# |              Time |             241 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -440 |
# |          StdEpRet |              27 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -476 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |             -93 |
# |         StdQ1Vals |            4.32 |
# |         MaxQ1Vals |           -81.4 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |             -93 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            92.8 |
# |             LossQ |           0.861 |
# |              Time |             250 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |            30.7 |
# |          MaxEpRet |            -381 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            47.5 |
# |      MaxTestEpRet |            -291 |
# |      MinTestEpRet |            -454 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -92.9 |
# |         StdQ1Vals |            4.44 |
# |         MaxQ1Vals |           -81.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.9 |
# |         StdQ2Vals |            4.45 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            92.7 |
# |             LossQ |            0.89 |
# |              Time |             258 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -430 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            45.7 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -468 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -92.7 |
# |         StdQ1Vals |            4.54 |
# |         MaxQ1Vals |           -80.8 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.7 |
# |         StdQ2Vals |            4.55 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.5 |
# |             LossQ |           0.897 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -435 |
# |          StdEpRet |            24.5 |
# |          MaxEpRet |            -397 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -384 |
# |      StdTestEpRet |            71.9 |
# |      MaxTestEpRet |            -238 |
# |      MinTestEpRet |            -452 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -92.5 |
# |         StdQ1Vals |            4.64 |
# |         MaxQ1Vals |           -80.4 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.5 |
# |         StdQ2Vals |            4.65 |
# |         MaxQ2Vals |           -80.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.3 |
# |             LossQ |           0.916 |
# |              Time |             275 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -430 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            -338 |
# |          MinEpRet |            -468 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            51.8 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -92.3 |
# |         StdQ1Vals |            4.74 |
# |         MaxQ1Vals |           -79.9 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -92.3 |
# |         StdQ2Vals |            4.76 |
# |         MaxQ2Vals |           -80.3 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            92.1 |
# |             LossQ |           0.929 |
# |              Time |             284 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -430 |
# |          StdEpRet |            36.6 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            40.2 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -92.1 |
# |         StdQ1Vals |            4.83 |
# |         MaxQ1Vals |           -79.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.1 |
# |         StdQ2Vals |            4.84 |
# |         MaxQ2Vals |           -79.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            91.8 |
# |             LossQ |           0.931 |
# |              Time |             293 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |              35 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -417 |
# |      StdTestEpRet |            54.6 |
# |      MaxTestEpRet |            -301 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -91.9 |
# |         StdQ1Vals |            4.92 |
# |         MaxQ1Vals |           -79.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -91.9 |
# |         StdQ2Vals |            4.93 |
# |         MaxQ2Vals |           -79.3 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            91.6 |
# |             LossQ |           0.963 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -416 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -91.6 |
# |         StdQ1Vals |            5.03 |
# |         MaxQ1Vals |           -78.9 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -91.6 |
# |         StdQ2Vals |            5.04 |
# |         MaxQ2Vals |           -79.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            91.4 |
# |             LossQ |            0.97 |
# |              Time |             310 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -426 |
# |          StdEpRet |            36.1 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |            -325 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -91.4 |
# |         StdQ1Vals |            5.08 |
# |         MaxQ1Vals |           -78.4 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -91.4 |
# |         StdQ2Vals |            5.09 |
# |         MaxQ2Vals |           -78.3 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            91.1 |
# |             LossQ |           0.985 |
# |              Time |             319 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            40.4 |
# |          MaxEpRet |            -326 |
# |          MinEpRet |            -462 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |              26 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -459 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -91.1 |
# |         StdQ1Vals |            5.17 |
# |         MaxQ1Vals |             -78 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -91.1 |
# |         StdQ2Vals |            5.18 |
# |         MaxQ2Vals |           -77.7 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            90.9 |
# |             LossQ |            1.01 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            32.5 |
# |          MaxEpRet |            -349 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -387 |
# |      StdTestEpRet |              48 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -90.9 |
# |         StdQ1Vals |            5.23 |
# |         MaxQ1Vals |           -77.5 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.9 |
# |         StdQ2Vals |            5.25 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            90.6 |
# |             LossQ |            1.03 |
# |              Time |             336 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            49.3 |
# |          MaxEpRet |            -304 |
# |          MinEpRet |            -472 |
# |  AverageTestEpRet |            -376 |
# |      StdTestEpRet |            61.8 |
# |      MaxTestEpRet |            -226 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -90.6 |
# |         StdQ1Vals |             5.3 |
# |         MaxQ1Vals |             -77 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.6 |
# |         StdQ2Vals |            5.32 |
# |         MaxQ2Vals |           -77.1 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            90.4 |
# |             LossQ |            1.05 |
# |              Time |             345 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -449 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |            30.5 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -472 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -90.4 |
# |         StdQ1Vals |            5.37 |
# |         MaxQ1Vals |           -76.4 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -90.4 |
# |         StdQ2Vals |            5.38 |
# |         MaxQ2Vals |           -76.6 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            90.1 |
# |             LossQ |            1.06 |
# |              Time |             354 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -415 |
# |          StdEpRet |            38.6 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -393 |
# |      StdTestEpRet |              48 |
# |      MaxTestEpRet |            -287 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -90.1 |
# |         StdQ1Vals |            5.43 |
# |         MaxQ1Vals |             -76 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.1 |
# |         StdQ2Vals |            5.44 |
# |         MaxQ2Vals |           -76.1 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            89.9 |
# |             LossQ |            1.06 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |              35 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -380 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |            -311 |
# |      MinTestEpRet |            -414 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -89.9 |
# |         StdQ1Vals |            5.47 |
# |         MaxQ1Vals |           -75.6 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -89.9 |
# |         StdQ2Vals |            5.49 |
# |         MaxQ2Vals |           -75.6 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            89.6 |
# |             LossQ |            1.09 |
# |              Time |             370 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -428 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |            -384 |
# |          MinEpRet |            -468 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            66.7 |
# |      MaxTestEpRet |            -272 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -89.7 |
# |         StdQ1Vals |             5.5 |
# |         MaxQ1Vals |           -75.2 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -89.7 |
# |         StdQ2Vals |            5.52 |
# |         MaxQ2Vals |           -75.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            89.4 |
# |             LossQ |             1.1 |
# |              Time |             379 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -457 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            52.1 |
# |      MaxTestEpRet |            -277 |
# |      MinTestEpRet |            -452 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -89.4 |
# |         StdQ1Vals |            5.56 |
# |         MaxQ1Vals |           -75.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -89.4 |
# |         StdQ2Vals |            5.57 |
# |         MaxQ2Vals |           -75.1 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            89.1 |
# |             LossQ |            1.11 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |            -384 |
# |          MinEpRet |            -446 |
# |  AverageTestEpRet |            -385 |
# |      StdTestEpRet |            72.5 |
# |      MaxTestEpRet |            -258 |
# |      MinTestEpRet |            -485 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -89.2 |
# |         StdQ1Vals |            5.59 |
# |         MaxQ1Vals |           -74.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -89.2 |
# |         StdQ2Vals |             5.6 |
# |         MaxQ2Vals |           -74.9 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.9 |
# |             LossQ |            1.13 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -360 |
# |      StdTestEpRet |              32 |
# ...
# ---------------------------------------
# |             Epoch |              80 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            41.3 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            34.1 |
# |      MaxTestEpRet |            -346 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |           -85.7 |
# |         StdQ1Vals |            5.84 |
# |         MaxQ1Vals |           -73.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.7 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |             -73 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.4 |
# |             LossQ |            1.03 |
# |              Time |             692 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              81 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |            29.3 |
# |          MaxEpRet |            -336 |
# |          MinEpRet |            -448 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            38.2 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.21e+05 |
# |     AverageQ1Vals |           -85.6 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -85.6 |
# |         StdQ2Vals |            5.86 |
# |         MaxQ2Vals |             -73 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            85.4 |
# |             LossQ |            1.04 |
# |              Time |             701 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            31.7 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |            -476 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -402 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.23e+05 |
# |     AverageQ1Vals |           -85.6 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |           -73.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.6 |
# |         StdQ2Vals |            5.87 |
# |         MaxQ2Vals |           -73.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.3 |
# |             LossQ |            1.03 |
# |              Time |             709 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |              39 |
# |          MaxEpRet |            -315 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |           -85.6 |
# |         StdQ1Vals |            5.84 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.6 |
# |         StdQ2Vals |            5.86 |
# |         MaxQ2Vals |           -72.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.3 |
# |             LossQ |            1.04 |
# |              Time |             717 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -430 |
# |          StdEpRet |            26.6 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -392 |
# |      StdTestEpRet |            55.3 |
# |      MaxTestEpRet |            -277 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.26e+05 |
# |     AverageQ1Vals |           -85.6 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.6 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |           -73.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.3 |
# |             LossQ |            1.02 |
# |              Time |             726 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -416 |
# |          StdEpRet |            26.4 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            54.8 |
# |      MaxTestEpRet |            -254 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.27e+05 |
# |     AverageQ1Vals |           -85.5 |
# |         StdQ1Vals |            5.82 |
# |         MaxQ1Vals |           -73.3 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.5 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |           -73.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.3 |
# |             LossQ |            1.01 |
# |              Time |             734 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            24.7 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |            -453 |
# |  AverageTestEpRet |            -339 |
# |      StdTestEpRet |            31.9 |
# |      MaxTestEpRet |            -295 |
# |      MinTestEpRet |            -389 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.29e+05 |
# |     AverageQ1Vals |           -85.5 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |           -73.2 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -85.5 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |             -73 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.2 |
# |             LossQ |            1.01 |
# |              Time |             743 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -346 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -383 |
# |      StdTestEpRet |            35.1 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |            -428 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.3e+05 |
# |     AverageQ1Vals |           -85.4 |
# |         StdQ1Vals |            5.81 |
# |         MaxQ1Vals |           -73.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -85.4 |
# |         StdQ2Vals |            5.83 |
# |         MaxQ2Vals |           -72.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            85.2 |
# |             LossQ |            1.01 |
# |              Time |             752 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -417 |
# |          StdEpRet |            32.1 |
# |          MaxEpRet |            -344 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -361 |
# |      StdTestEpRet |            34.7 |
# |      MaxTestEpRet |            -303 |
# |      MinTestEpRet |            -430 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |           -85.4 |
# |         StdQ1Vals |             5.8 |
# |         MaxQ1Vals |             -73 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -85.4 |
# |         StdQ2Vals |            5.82 |
# |         MaxQ2Vals |           -72.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.2 |
# |             LossQ |           0.999 |
# |              Time |             761 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |            32.1 |
# |          MaxEpRet |            -349 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -385 |
# |      StdTestEpRet |            48.6 |
# |      MaxTestEpRet |            -314 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.33e+05 |
# |     AverageQ1Vals |           -85.4 |
# |         StdQ1Vals |            5.82 |
# |         MaxQ1Vals |             -73 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -85.4 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |           -72.9 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.2 |
# |             LossQ |               1 |
# |              Time |             769 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -428 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -383 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -375 |
# |      StdTestEpRet |            25.3 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -415 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+05 |
# |     AverageQ1Vals |           -85.4 |
# |         StdQ1Vals |             5.8 |
# |         MaxQ1Vals |           -72.9 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.4 |
# |         StdQ2Vals |            5.82 |
# |         MaxQ2Vals |           -72.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.1 |
# |             LossQ |           0.985 |
# |              Time |             778 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -348 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -388 |
# |      StdTestEpRet |              44 |
# |      MaxTestEpRet |            -291 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |           -85.3 |
# |         StdQ1Vals |            5.82 |
# |         MaxQ1Vals |           -72.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.3 |
# |         StdQ2Vals |            5.83 |
# |         MaxQ2Vals |           -72.6 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            85.1 |
# |             LossQ |           0.986 |
# |              Time |             787 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            33.7 |
# |          MaxEpRet |            -340 |
# |          MinEpRet |            -456 |
# |  AverageTestEpRet |            -387 |
# |      StdTestEpRet |            38.5 |
# |      MaxTestEpRet |            -306 |
# |      MinTestEpRet |            -437 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.38e+05 |
# |     AverageQ1Vals |           -85.3 |
# |         StdQ1Vals |            5.82 |
# |         MaxQ1Vals |           -72.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -85.3 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |             -72 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              85 |
# |             LossQ |           0.985 |
# |              Time |             796 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -323 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |            48.4 |
# |      MaxTestEpRet |            -261 |
# |      MinTestEpRet |            -434 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.39e+05 |
# |     AverageQ1Vals |           -85.2 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |           -72.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.2 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |           -72.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            84.9 |
# |             LossQ |           0.986 |
# |              Time |             805 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |            -339 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -381 |
# |      StdTestEpRet |            45.3 |
# |      MaxTestEpRet |            -311 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.41e+05 |
# |     AverageQ1Vals |           -85.1 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |             -72 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -85.1 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |           -71.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            84.9 |
# |             LossQ |           0.998 |
# |              Time |             814 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -352 |
# |      StdTestEpRet |            38.3 |
# |      MaxTestEpRet |            -288 |
# |      MinTestEpRet |            -408 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.42e+05 |
# |     AverageQ1Vals |             -85 |
# |         StdQ1Vals |            5.81 |
# |         MaxQ1Vals |           -71.7 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |             -85 |
# |         StdQ2Vals |            5.83 |
# |         MaxQ2Vals |           -71.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            84.8 |
# |             LossQ |           0.985 |
# |              Time |             823 |
# ---------------------------------------
