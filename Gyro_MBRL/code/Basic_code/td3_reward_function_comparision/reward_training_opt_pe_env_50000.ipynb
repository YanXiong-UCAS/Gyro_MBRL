# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=50000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_50000', exp_name='td3_pe_opt_ing_50000')
                   )
# Out:
# Logging data to td3_pe_opt_ing_50000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fe41b4b21e0>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	50000,
#     "exp_name":	"td3_pe_opt_ing_50000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fe41b4bcbe0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_50000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_50000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_50000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_50000",
#         "output_dir":	"td3_pe_opt_ing_50000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -490 |
# |          StdEpRet |            8.74 |
# |          MaxEpRet |            -466 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -483 |
# |      StdTestEpRet |            6.93 |
# |      MaxTestEpRet |            -472 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -5.98 |
# |         StdQ1Vals |            1.93 |
# |         MaxQ1Vals |          0.0127 |
# |         MinQ1Vals |           -11.5 |
# |     AverageQ2Vals |           -6.03 |
# |         StdQ2Vals |            1.83 |
# |         MaxQ2Vals |          0.0567 |
# |         MinQ2Vals |           -10.1 |
# |            LossPi |            5.74 |
# |             LossQ |            3.39 |
# |              Time |            6.74 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            7.95 |
# |          MaxEpRet |            -475 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -486 |
# |      StdTestEpRet |            6.03 |
# |      MaxTestEpRet |            -474 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.7 |
# |         StdQ1Vals |            3.88 |
# |         MaxQ1Vals |           -7.01 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |           -14.7 |
# |         StdQ2Vals |            3.88 |
# |         MaxQ2Vals |           -7.18 |
# |         MinQ2Vals |             -24 |
# |            LossPi |            14.5 |
# |             LossQ |           0.141 |
# |              Time |            19.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            6.53 |
# |          MaxEpRet |            -478 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            14.4 |
# |      MaxTestEpRet |            -447 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.7 |
# |         StdQ1Vals |            3.69 |
# |         MaxQ1Vals |           -19.6 |
# |         MinQ1Vals |             -38 |
# |     AverageQ2Vals |           -27.7 |
# |         StdQ2Vals |            3.69 |
# |         MaxQ2Vals |           -19.8 |
# |         MinQ2Vals |           -37.9 |
# |            LossPi |            27.6 |
# |             LossQ |           0.174 |
# |              Time |            33.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            6.83 |
# |          MaxEpRet |            -474 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -471 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -424 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.3 |
# |         StdQ1Vals |            3.23 |
# |         MaxQ1Vals |           -31.5 |
# |         MinQ1Vals |           -48.7 |
# |     AverageQ2Vals |           -39.3 |
# |         StdQ2Vals |            3.23 |
# |         MaxQ2Vals |           -31.4 |
# |         MinQ2Vals |           -48.4 |
# |            LossPi |            39.2 |
# |             LossQ |           0.239 |
# |              Time |            47.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            7.18 |
# |          MaxEpRet |            -471 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -474 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |            -415 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.2 |
# |         StdQ1Vals |            2.84 |
# |         MaxQ1Vals |           -41.6 |
# |         MinQ1Vals |             -58 |
# |     AverageQ2Vals |           -49.2 |
# |         StdQ2Vals |            2.84 |
# |         MaxQ2Vals |           -41.5 |
# |         MinQ2Vals |           -58.2 |
# |            LossPi |            49.1 |
# |             LossQ |           0.297 |
# |              Time |            62.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            5.37 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            14.9 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.5 |
# |         StdQ1Vals |            2.49 |
# |         MaxQ1Vals |           -50.3 |
# |         MinQ1Vals |           -65.1 |
# |     AverageQ2Vals |           -57.5 |
# |         StdQ2Vals |            2.49 |
# |         MaxQ2Vals |           -50.6 |
# |         MinQ2Vals |           -65.9 |
# |            LossPi |            57.4 |
# |             LossQ |           0.329 |
# |              Time |            76.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -490 |
# |          StdEpRet |            8.14 |
# |          MaxEpRet |            -470 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -468 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |            -410 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.5 |
# |         StdQ1Vals |            2.16 |
# |         MaxQ1Vals |           -57.5 |
# |         MinQ1Vals |           -71.3 |
# |     AverageQ2Vals |           -64.5 |
# |         StdQ2Vals |            2.16 |
# |         MaxQ2Vals |           -57.6 |
# |         MinQ2Vals |           -71.4 |
# |            LossPi |            64.3 |
# |             LossQ |           0.344 |
# |              Time |            90.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |            -451 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -451 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |            -392 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.2 |
# |         StdQ1Vals |            1.87 |
# |         MaxQ1Vals |           -63.9 |
# |         MinQ1Vals |           -76.9 |
# |     AverageQ2Vals |           -70.2 |
# |         StdQ2Vals |            1.87 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |           -77.6 |
# |            LossPi |              70 |
# |             LossQ |           0.337 |
# |              Time |             104 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -475 |
# |          StdEpRet |            10.8 |
# |          MaxEpRet |            -449 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            30.3 |
# |      MaxTestEpRet |            -404 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -74.9 |
# |         StdQ1Vals |            1.71 |
# |         MaxQ1Vals |           -69.1 |
# |         MinQ1Vals |           -80.8 |
# |     AverageQ2Vals |           -74.9 |
# |         StdQ2Vals |            1.71 |
# |         MaxQ2Vals |           -68.6 |
# |         MinQ2Vals |           -81.4 |
# |            LossPi |            74.7 |
# |             LossQ |           0.337 |
# |              Time |             117 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            16.1 |
# |          MaxEpRet |            -427 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -428 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -78.8 |
# |         StdQ1Vals |             1.6 |
# |         MaxQ1Vals |           -73.2 |
# |         MinQ1Vals |           -84.7 |
# |     AverageQ2Vals |           -78.8 |
# |         StdQ2Vals |             1.6 |
# |         MaxQ2Vals |           -73.2 |
# |         MinQ2Vals |           -84.8 |
# |            LossPi |            78.6 |
# |             LossQ |           0.359 |
# |              Time |             132 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            14.1 |
# |          MaxEpRet |            -449 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -455 |
# |      StdTestEpRet |            28.9 |
# |      MaxTestEpRet |            -417 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |             -82 |
# |         StdQ1Vals |            1.55 |
# |         MaxQ1Vals |           -76.5 |
# |         MinQ1Vals |           -87.8 |
# |     AverageQ2Vals |             -82 |
# |         StdQ2Vals |            1.55 |
# |         MaxQ2Vals |           -76.3 |
# |         MinQ2Vals |           -88.5 |
# |            LossPi |            81.8 |
# |             LossQ |            0.38 |
# |              Time |             146 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -462 |
# |          StdEpRet |            17.1 |
# |          MaxEpRet |            -421 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -457 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -84.5 |
# |         StdQ1Vals |            1.54 |
# |         MaxQ1Vals |           -79.3 |
# |         MinQ1Vals |           -91.4 |
# |     AverageQ2Vals |           -84.5 |
# |         StdQ2Vals |            1.55 |
# |         MaxQ2Vals |           -79.3 |
# |         MinQ2Vals |           -90.8 |
# |            LossPi |            84.4 |
# |             LossQ |           0.401 |
# |              Time |             161 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -459 |
# |          StdEpRet |            34.5 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -440 |
# |      StdTestEpRet |            42.9 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -86.6 |
# |         StdQ1Vals |             1.6 |
# |         MaxQ1Vals |           -80.9 |
# |         MinQ1Vals |           -93.2 |
# |     AverageQ2Vals |           -86.6 |
# |         StdQ2Vals |            1.61 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |           -93.2 |
# |            LossPi |            86.5 |
# |             LossQ |           0.422 |
# |              Time |             175 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -453 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |            -384 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |            -444 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            1.76 |
# |         MaxQ1Vals |           -81.9 |
# |         MinQ1Vals |           -95.1 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            1.77 |
# |         MaxQ2Vals |           -81.8 |
# |         MinQ2Vals |           -95.8 |
# |            LossPi |            88.1 |
# |             LossQ |            0.45 |
# |              Time |             188 |
# ---------------------------------------
