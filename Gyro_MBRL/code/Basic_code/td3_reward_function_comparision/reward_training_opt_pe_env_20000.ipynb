# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=20000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_20000', exp_name='td3_pe_opt_ing_20000')
                   )
# Out:
# Warning: Log dir td3_pe_opt_ing_20000 already exists! Storing info there anyway.
# Logging data to td3_pe_opt_ing_20000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fe564ca4a60>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	20000,
#     "exp_name":	"td3_pe_opt_ing_20000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fe564cb4a90>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_20000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_20000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_20000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_20000",
#         "output_dir":	"td3_pe_opt_ing_20000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |               6 |
# |          MaxEpRet |            -473 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -463 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |            -411 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.06 |
# |         StdQ1Vals |            1.99 |
# |         MaxQ1Vals |          0.0332 |
# |         MinQ1Vals |             -11 |
# |     AverageQ2Vals |           -6.12 |
# |         StdQ2Vals |            1.88 |
# |         MaxQ2Vals |         -0.0245 |
# |         MinQ2Vals |           -10.9 |
# |            LossPi |            5.83 |
# |             LossQ |            3.36 |
# |              Time |            5.06 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            6.36 |
# |          MaxEpRet |            -480 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -483 |
# |      StdTestEpRet |            9.28 |
# |      MaxTestEpRet |            -469 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.7 |
# |         StdQ1Vals |            3.84 |
# |         MaxQ1Vals |           -7.09 |
# |         MinQ1Vals |           -24.2 |
# |     AverageQ2Vals |           -14.7 |
# |         StdQ2Vals |            3.84 |
# |         MaxQ2Vals |           -7.07 |
# |         MinQ2Vals |           -24.1 |
# |            LossPi |            14.5 |
# |             LossQ |           0.156 |
# |              Time |            13.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            4.17 |
# |          MaxEpRet |            -477 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            7.56 |
# |      MaxTestEpRet |            -471 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.6 |
# |         StdQ1Vals |            3.69 |
# |         MaxQ1Vals |           -19.5 |
# |         MinQ1Vals |           -37.2 |
# |     AverageQ2Vals |           -27.7 |
# |         StdQ2Vals |            3.69 |
# |         MaxQ2Vals |           -19.3 |
# |         MinQ2Vals |             -37 |
# |            LossPi |            27.5 |
# |             LossQ |           0.184 |
# |              Time |            21.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            5.17 |
# |          MaxEpRet |            -480 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -486 |
# |      StdTestEpRet |            9.72 |
# |      MaxTestEpRet |            -471 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.3 |
# |         StdQ1Vals |            3.22 |
# |         MaxQ1Vals |           -31.2 |
# |         MinQ1Vals |           -47.6 |
# |     AverageQ2Vals |           -39.3 |
# |         StdQ2Vals |            3.22 |
# |         MaxQ2Vals |           -31.2 |
# |         MinQ2Vals |           -47.8 |
# |            LossPi |            39.1 |
# |             LossQ |            0.24 |
# |              Time |            30.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -495 |
# |          StdEpRet |            5.57 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |            -506 |
# |  AverageTestEpRet |            -488 |
# |      StdTestEpRet |            5.69 |
# |      MaxTestEpRet |            -481 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.2 |
# |         StdQ1Vals |            2.77 |
# |         MaxQ1Vals |           -41.4 |
# |         MinQ1Vals |           -57.2 |
# |     AverageQ2Vals |           -49.2 |
# |         StdQ2Vals |            2.78 |
# |         MaxQ2Vals |           -41.6 |
# |         MinQ2Vals |           -56.7 |
# |            LossPi |              49 |
# |             LossQ |           0.267 |
# |              Time |            38.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            5.66 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -486 |
# |      StdTestEpRet |            7.04 |
# |      MaxTestEpRet |            -473 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.6 |
# |         StdQ1Vals |             2.4 |
# |         MaxQ1Vals |           -50.2 |
# |         MinQ1Vals |           -65.1 |
# |     AverageQ2Vals |           -57.6 |
# |         StdQ2Vals |             2.4 |
# |         MaxQ2Vals |           -50.4 |
# |         MinQ2Vals |           -66.1 |
# |            LossPi |            57.4 |
# |             LossQ |           0.306 |
# |              Time |              47 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |             6.8 |
# |          MaxEpRet |            -473 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            14.9 |
# |      MaxTestEpRet |            -458 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.5 |
# |         StdQ1Vals |            2.11 |
# |         MaxQ1Vals |           -57.7 |
# |         MinQ1Vals |           -71.6 |
# |     AverageQ2Vals |           -64.5 |
# |         StdQ2Vals |            2.11 |
# |         MaxQ2Vals |           -57.7 |
# |         MinQ2Vals |           -72.3 |
# |            LossPi |            64.4 |
# |             LossQ |           0.326 |
# |              Time |            56.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -484 |
# |          StdEpRet |            11.4 |
# |          MaxEpRet |            -465 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |            -468 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.3 |
# |         StdQ1Vals |            1.84 |
# |         MaxQ1Vals |             -64 |
# |         MinQ1Vals |             -77 |
# |     AverageQ2Vals |           -70.3 |
# |         StdQ2Vals |            1.84 |
# |         MaxQ2Vals |             -64 |
# |         MinQ2Vals |           -77.2 |
# |            LossPi |            70.2 |
# |             LossQ |           0.315 |
# |              Time |            65.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            10.9 |
# |      MaxTestEpRet |            -457 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.1 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |           -69.2 |
# |         MinQ1Vals |           -81.4 |
# |     AverageQ2Vals |           -75.1 |
# |         StdQ2Vals |            1.66 |
# |         MaxQ2Vals |           -69.4 |
# |         MinQ2Vals |           -81.5 |
# |            LossPi |            75.1 |
# |             LossQ |           0.314 |
# |              Time |            75.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            10.8 |
# |          MaxEpRet |            -459 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            11.4 |
# |      MaxTestEpRet |            -465 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.1 |
# |         StdQ1Vals |            1.52 |
# |         MaxQ1Vals |             -74 |
# |         MinQ1Vals |           -85.2 |
# |     AverageQ2Vals |           -79.1 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |           -74.2 |
# |         MinQ2Vals |           -85.2 |
# |            LossPi |              79 |
# |             LossQ |           0.327 |
# |              Time |            85.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -480 |
# |          StdEpRet |            9.56 |
# |          MaxEpRet |            -461 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -474 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -431 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.4 |
# |         StdQ1Vals |            1.41 |
# |         MaxQ1Vals |           -77.2 |
# |         MinQ1Vals |           -87.9 |
# |     AverageQ2Vals |           -82.4 |
# |         StdQ2Vals |            1.42 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |           -88.2 |
# |            LossPi |            82.3 |
# |             LossQ |           0.332 |
# |              Time |            94.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |            -435 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            23.8 |
# |      MaxTestEpRet |            -424 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -85.1 |
# |         StdQ1Vals |            1.34 |
# |         MaxQ1Vals |           -80.7 |
# |         MinQ1Vals |           -90.9 |
# |     AverageQ2Vals |           -85.1 |
# |         StdQ2Vals |            1.35 |
# |         MaxQ2Vals |           -80.7 |
# |         MinQ2Vals |           -91.4 |
# |            LossPi |              85 |
# |             LossQ |           0.333 |
# |              Time |             104 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -469 |
# |          StdEpRet |              18 |
# |          MaxEpRet |            -431 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -448 |
# |      StdTestEpRet |            35.5 |
# |      MaxTestEpRet |            -384 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -87.3 |
# |         StdQ1Vals |            1.36 |
# |         MaxQ1Vals |           -82.6 |
# |         MinQ1Vals |           -92.7 |
# |     AverageQ2Vals |           -87.3 |
# |         StdQ2Vals |            1.37 |
# |         MaxQ2Vals |           -82.8 |
# |         MinQ2Vals |           -93.5 |
# |            LossPi |            87.2 |
# |             LossQ |           0.352 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            9.53 |
# |      MaxTestEpRet |            -466 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |             -89 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |           -84.4 |
# |         MinQ1Vals |           -94.7 |
# |     AverageQ2Vals |             -89 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |           -84.3 |
# |         MinQ2Vals |           -95.6 |
# |            LossPi |            88.9 |
# |             LossQ |           0.372 |
# |              Time |             123 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            8.48 |
# |          MaxEpRet |            -454 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            20.4 |
# |      MaxTestEpRet |            -431 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -90.5 |
# |         StdQ1Vals |            1.52 |
# |         MaxQ1Vals |           -85.5 |
# |         MinQ1Vals |           -96.6 |
# |     AverageQ2Vals |           -90.5 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |           -85.5 |
# |         MinQ2Vals |           -97.1 |
# |            LossPi |            90.3 |
# |             LossQ |           0.394 |
# |              Time |             132 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |            -397 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -439 |
# |      StdTestEpRet |            55.4 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -91.6 |
# |         StdQ1Vals |            1.62 |
# |         MaxQ1Vals |           -85.6 |
# |         MinQ1Vals |           -97.9 |
# |     AverageQ2Vals |           -91.6 |
# |         StdQ2Vals |            1.63 |
# |         MaxQ2Vals |           -85.2 |
# |         MinQ2Vals |           -98.1 |
# |            LossPi |            91.5 |
# |             LossQ |            0.42 |
# |              Time |             142 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -450 |
# |      StdTestEpRet |            34.9 |
# |      MaxTestEpRet |            -397 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -92.5 |
# |         StdQ1Vals |            1.71 |
# |         MaxQ1Vals |           -85.6 |
# |         MinQ1Vals |           -99.2 |
# |     AverageQ2Vals |           -92.5 |
# |         StdQ2Vals |            1.72 |
# |         MaxQ2Vals |           -85.4 |
# |         MinQ2Vals |           -99.8 |
# |            LossPi |            92.4 |
# |             LossQ |           0.443 |
# |              Time |             151 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            27.6 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -438 |
# |      StdTestEpRet |            30.4 |
# |      MaxTestEpRet |            -392 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -93.2 |
# |         StdQ1Vals |            1.82 |
# |         MaxQ1Vals |           -85.7 |
# |         MinQ1Vals |           -99.7 |
# |     AverageQ2Vals |           -93.2 |
# |         StdQ2Vals |            1.83 |
# |         MaxQ2Vals |           -85.4 |
# |         MinQ2Vals |            -100 |
# |            LossPi |            93.1 |
# |             LossQ |           0.472 |
# |              Time |             160 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            22.2 |
# |          MaxEpRet |            -417 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -450 |
# |      StdTestEpRet |            29.4 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -93.7 |
# |         StdQ1Vals |            1.97 |
# |         MaxQ1Vals |           -85.7 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -93.7 |
# |         StdQ2Vals |            1.98 |
# |         MaxQ2Vals |           -85.4 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            93.6 |
# |             LossQ |           0.488 |
# |              Time |             169 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |            -398 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -449 |
# |      StdTestEpRet |              22 |
# |      MaxTestEpRet |            -411 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            2.08 |
# |         MaxQ1Vals |           -85.4 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            2.09 |
# |         MaxQ2Vals |           -85.3 |
# |         MinQ2Vals |            -102 |
# |            LossPi |              94 |
# |             LossQ |           0.514 |
# |              Time |             178 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            31.1 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -445 |
# |      StdTestEpRet |            34.6 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |            -480 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |            2.21 |
# |         MaxQ1Vals |             -85 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |            2.23 |
# |         MaxQ2Vals |           -84.8 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            94.3 |
# |             LossQ |           0.543 |
# |              Time |             188 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |            -401 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -445 |
# |      StdTestEpRet |            36.9 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -94.6 |
# |         StdQ1Vals |            2.36 |
# |         MaxQ1Vals |           -84.7 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -94.6 |
# |         StdQ2Vals |            2.37 |
# |         MaxQ2Vals |           -84.3 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            94.5 |
# |             LossQ |           0.572 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |            21.8 |
# |          MaxEpRet |            -412 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -433 |
# |      StdTestEpRet |            42.9 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -94.8 |
# |         StdQ1Vals |            2.49 |
# |         MaxQ1Vals |           -84.2 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -94.8 |
# |         StdQ2Vals |            2.51 |
# |         MaxQ2Vals |             -84 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            94.6 |
# |             LossQ |           0.595 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -448 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |            -391 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -443 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -94.9 |
# |         StdQ1Vals |            2.57 |
# |         MaxQ1Vals |           -83.8 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -94.9 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -83.7 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            94.7 |
# |             LossQ |           0.614 |
# |              Time |             215 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -451 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -398 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            53.7 |
# |      MaxTestEpRet |            -281 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -94.9 |
# |         StdQ1Vals |            2.72 |
# |         MaxQ1Vals |           -83.6 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.9 |
# |         StdQ2Vals |            2.73 |
# |         MaxQ2Vals |           -83.3 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            94.7 |
# |             LossQ |           0.645 |
# |              Time |             225 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -439 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |            -384 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -388 |
# |      StdTestEpRet |            49.9 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -94.9 |
# |         StdQ1Vals |            2.86 |
# |         MaxQ1Vals |           -83.1 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.9 |
# |         StdQ2Vals |            2.88 |
# |         MaxQ2Vals |           -82.8 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.7 |
# |             LossQ |           0.666 |
# |              Time |             235 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -447 |
# |          StdEpRet |            13.2 |
# |          MaxEpRet |            -422 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -415 |
# |      StdTestEpRet |            32.9 |
# |      MaxTestEpRet |            -363 |
# |      MinTestEpRet |            -462 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -94.8 |
# |         StdQ1Vals |               3 |
# |         MaxQ1Vals |           -82.8 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.8 |
# |         StdQ2Vals |            3.01 |
# |         MaxQ2Vals |           -82.5 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.6 |
# |             LossQ |           0.695 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -426 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |            -383 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -438 |
# |      StdTestEpRet |              41 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -94.6 |
# |         StdQ1Vals |            3.12 |
# |         MaxQ1Vals |           -82.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.6 |
# |         StdQ2Vals |            3.14 |
# |         MaxQ2Vals |           -82.3 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            94.4 |
# |             LossQ |           0.715 |
# |              Time |             254 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -437 |
# |          StdEpRet |            27.1 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |            55.4 |
# |      MaxTestEpRet |            -304 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |            3.31 |
# |         MaxQ1Vals |           -82.2 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |            3.32 |
# |         MaxQ2Vals |           -82.1 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            94.2 |
# |             LossQ |           0.731 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -444 |
# |          StdEpRet |            26.4 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            44.9 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |            -483 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            3.46 |
# |         MaxQ1Vals |           -81.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            3.48 |
# |         MaxQ2Vals |           -81.6 |
# |         MinQ2Vals |            -106 |
# |            LossPi |              94 |
# |             LossQ |           0.758 |
# |              Time |             275 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |              47 |
# |          MaxEpRet |            -299 |
# |          MinEpRet |            -479 |
# |  AverageTestEpRet |            -381 |
# |      StdTestEpRet |            37.8 |
# |      MaxTestEpRet |            -338 |
# |      MinTestEpRet |            -449 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -93.9 |
# |         StdQ1Vals |            3.61 |
# |         MaxQ1Vals |           -81.4 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -93.9 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |           -81.4 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            93.7 |
# |             LossQ |           0.778 |
# |              Time |             286 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            27.4 |
# |          MaxEpRet |            -335 |
# |          MinEpRet |            -446 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            49.7 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -93.7 |
# |         StdQ1Vals |            3.75 |
# |         MaxQ1Vals |           -81.2 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -93.7 |
# |         StdQ2Vals |            3.76 |
# |         MaxQ2Vals |           -81.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            93.4 |
# |             LossQ |           0.811 |
# |              Time |             295 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |            34.8 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -392 |
# |      StdTestEpRet |            43.5 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -93.4 |
# |         StdQ1Vals |            3.88 |
# |         MaxQ1Vals |           -80.8 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -93.4 |
# |         StdQ2Vals |            3.89 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            93.2 |
# |             LossQ |           0.829 |
# |              Time |             304 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            33.6 |
# |          MaxEpRet |            -317 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -426 |
# |      StdTestEpRet |            41.8 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            4.04 |
# |         MaxQ1Vals |           -80.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            4.05 |
# |         MaxQ2Vals |           -80.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            92.9 |
# |             LossQ |           0.839 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |            -344 |
# |          MinEpRet |            -457 |
# |  AverageTestEpRet |            -356 |
# |      StdTestEpRet |            46.4 |
# |      MaxTestEpRet |            -295 |
# |      MinTestEpRet |            -411 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -92.8 |
# |         StdQ1Vals |            4.17 |
# |         MaxQ1Vals |           -80.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -92.8 |
# |         StdQ2Vals |            4.18 |
# |         MaxQ2Vals |             -80 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            92.6 |
# |             LossQ |           0.876 |
# |              Time |             323 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -412 |
# |          StdEpRet |            44.6 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |            -392 |
# |      StdTestEpRet |            44.3 |
# |      MaxTestEpRet |            -338 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -92.5 |
# |         StdQ1Vals |            4.32 |
# |         MaxQ1Vals |           -79.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -92.5 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |           -79.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            92.2 |
# |             LossQ |           0.886 |
# |              Time |             334 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -382 |
# |      StdTestEpRet |            39.1 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |            -429 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -92.2 |
# |         StdQ1Vals |            4.49 |
# |         MaxQ1Vals |           -79.5 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -92.2 |
# |         StdQ2Vals |             4.5 |
# |         MaxQ2Vals |           -79.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.9 |
# |             LossQ |           0.918 |
# |              Time |             343 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            27.3 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -381 |
# |      StdTestEpRet |            36.1 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -91.8 |
# |         StdQ1Vals |            4.61 |
# |         MaxQ1Vals |           -78.9 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -91.8 |
# |         StdQ2Vals |            4.62 |
# |         MaxQ2Vals |             -79 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.6 |
# |             LossQ |           0.966 |
# |              Time |             352 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            33.1 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -370 |
# |      StdTestEpRet |            50.1 |
# |      MaxTestEpRet |            -291 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -91.5 |
# |         StdQ1Vals |            4.73 |
# |         MaxQ1Vals |           -78.6 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.5 |
# |         StdQ2Vals |            4.73 |
# |         MaxQ2Vals |           -78.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.2 |
# |             LossQ |            0.98 |
# |              Time |             361 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -368 |
# |      StdTestEpRet |            54.2 |
# |      MaxTestEpRet |            -267 |
# |      MinTestEpRet |            -449 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -91.2 |
# |         StdQ1Vals |            4.82 |
# |         MaxQ1Vals |           -78.4 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.2 |
# |         StdQ2Vals |            4.82 |
# |         MaxQ2Vals |           -78.3 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            90.9 |
# |             LossQ |           0.992 |
# |              Time |             370 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -410 |
# |          StdEpRet |            36.4 |
# |          MaxEpRet |            -344 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -349 |
# |      StdTestEpRet |            41.9 |
# |      MaxTestEpRet |            -246 |
# |      MinTestEpRet |            -405 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -90.9 |
# |         StdQ1Vals |            4.93 |
# |         MaxQ1Vals |           -78.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.9 |
# |         StdQ2Vals |            4.93 |
# |         MaxQ2Vals |           -78.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            90.6 |
# |             LossQ |            1.02 |
# |              Time |             379 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -402 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |            -350 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -364 |
# |      StdTestEpRet |            32.4 |
# |      MaxTestEpRet |            -289 |
# |      MinTestEpRet |            -403 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -90.6 |
# |         StdQ1Vals |            5.02 |
# |         MaxQ1Vals |           -77.9 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.6 |
# |         StdQ2Vals |            5.01 |
# |         MaxQ2Vals |           -77.8 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            90.3 |
# |             LossQ |            1.04 |
# |              Time |             389 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            35.9 |
# |          MaxEpRet |            -315 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -375 |
# |      StdTestEpRet |            29.4 |
# |      MaxTestEpRet |            -340 |
# |      MinTestEpRet |            -421 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -90.2 |
# |         StdQ1Vals |            5.16 |
# |         MaxQ1Vals |           -77.2 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.2 |
# |         StdQ2Vals |            5.16 |
# |         MaxQ2Vals |           -77.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            89.9 |
# |             LossQ |            1.06 |
# |              Time |             399 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            34.9 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -375 |
# |      StdTestEpRet |            43.6 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -89.8 |
# |         StdQ1Vals |            5.23 |
# |         MaxQ1Vals |           -76.5 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -89.8 |
# |         StdQ2Vals |            5.23 |
# |         MaxQ2Vals |           -76.8 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            89.5 |
# |             LossQ |            1.07 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -415 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -343 |
# |          MinEpRet |            -456 |
# |  AverageTestEpRet |            -364 |
# |      StdTestEpRet |            48.5 |
# |      MaxTestEpRet |            -292 |
# |      MinTestEpRet |            -421 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -89.5 |
# |         StdQ1Vals |            5.32 |
# |         MaxQ1Vals |           -76.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -89.5 |
# |         StdQ2Vals |            5.32 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            89.2 |
# |             LossQ |            1.07 |
# |              Time |             417 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |            -330 |
# |          MinEpRet |            -464 |
# |  AverageTestEpRet |            -390 |
# |      StdTestEpRet |            20.4 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -416 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -89.2 |
# |         StdQ1Vals |            5.39 |
# |         MaxQ1Vals |           -76.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -89.2 |
# |         StdQ2Vals |            5.39 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.9 |
# |             LossQ |            1.08 |
# |              Time |             426 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -419 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -451 |
# ...
# ---------------------------------------
# |             Epoch |             960 |
# |      AverageEpRet |            -297 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |            -232 |
# |          MinEpRet |            -344 |
# |  AverageTestEpRet |            -253 |
# |      StdTestEpRet |            28.5 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -295 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.44e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.6 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.79 |
# |         MaxQ2Vals |           -52.8 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.7 |
# |             LossQ |           0.999 |
# |              Time |        8.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             961 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -278 |
# |          MinEpRet |            -357 |
# |  AverageTestEpRet |            -268 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |            -216 |
# |      MinTestEpRet |            -317 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.44e+06 |
# |     AverageQ1Vals |             -62 |
# |         StdQ1Vals |            7.82 |
# |         MaxQ1Vals |           -52.5 |
# |         MinQ1Vals |           -99.9 |
# |     AverageQ2Vals |             -62 |
# |         StdQ2Vals |            7.81 |
# |         MaxQ2Vals |           -52.5 |
# |         MinQ2Vals |           -99.3 |
# |            LossPi |            61.8 |
# |             LossQ |            1.01 |
# |              Time |        8.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             962 |
# |      AverageEpRet |            -296 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |            -263 |
# |          MinEpRet |            -344 |
# |  AverageTestEpRet |            -249 |
# |      StdTestEpRet |            25.2 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -282 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.44e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.6 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.79 |
# |         MaxQ2Vals |           -52.8 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            61.8 |
# |             LossQ |               1 |
# |              Time |        8.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             963 |
# |      AverageEpRet |            -299 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -248 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |            -272 |
# |      StdTestEpRet |            43.1 |
# |      MaxTestEpRet |            -215 |
# |      MinTestEpRet |            -371 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.44e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.4 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.7 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.7 |
# |             LossQ |           0.983 |
# |              Time |        8.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             964 |
# |      AverageEpRet |            -294 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -254 |
# |          MinEpRet |            -345 |
# |  AverageTestEpRet |            -273 |
# |      StdTestEpRet |              46 |
# |      MaxTestEpRet |            -192 |
# |      MinTestEpRet |            -354 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |             -62 |
# |         StdQ1Vals |            7.83 |
# |         MaxQ1Vals |           -52.3 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             -62 |
# |         StdQ2Vals |            7.82 |
# |         MaxQ2Vals |           -52.5 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            61.8 |
# |             LossQ |           0.998 |
# |              Time |        8.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             965 |
# |      AverageEpRet |            -295 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |            -258 |
# |          MinEpRet |            -341 |
# |  AverageTestEpRet |            -269 |
# |      StdTestEpRet |            47.5 |
# |      MaxTestEpRet |            -205 |
# |      MinTestEpRet |            -348 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |             -62 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.6 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |             -62 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.7 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            61.8 |
# |             LossQ |           0.991 |
# |              Time |        8.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             966 |
# |      AverageEpRet |            -297 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -242 |
# |          MinEpRet |            -346 |
# |  AverageTestEpRet |            -290 |
# |      StdTestEpRet |            62.4 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -388 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |             -62 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.4 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |             -62 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.4 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            61.8 |
# |             LossQ |           0.992 |
# |              Time |           9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             967 |
# |      AverageEpRet |            -300 |
# |          StdEpRet |            27.6 |
# |          MaxEpRet |            -266 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |            -243 |
# |      StdTestEpRet |            27.2 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -275 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |            7.78 |
# |         MaxQ1Vals |           -52.5 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.77 |
# |         MaxQ2Vals |           -52.7 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.7 |
# |             LossQ |           0.986 |
# |              Time |        9.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             968 |
# |      AverageEpRet |            -298 |
# |          StdEpRet |            25.7 |
# |          MaxEpRet |            -267 |
# |          MinEpRet |            -351 |
# |  AverageTestEpRet |            -254 |
# |      StdTestEpRet |            29.8 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -308 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.4 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.79 |
# |         MaxQ2Vals |           -52.6 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.7 |
# |             LossQ |           0.999 |
# |              Time |        9.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             969 |
# |      AverageEpRet |            -302 |
# |          StdEpRet |            29.6 |
# |          MaxEpRet |            -254 |
# |          MinEpRet |            -352 |
# |  AverageTestEpRet |            -284 |
# |      StdTestEpRet |            48.2 |
# |      MaxTestEpRet |            -223 |
# |      MinTestEpRet |            -402 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.6 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.79 |
# |         MaxQ2Vals |           -52.6 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            61.8 |
# |             LossQ |           0.981 |
# |              Time |        9.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             970 |
# |      AverageEpRet |            -320 |
# |          StdEpRet |            36.5 |
# |          MaxEpRet |            -259 |
# |          MinEpRet |            -395 |
# |  AverageTestEpRet |            -260 |
# |      StdTestEpRet |              25 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -293 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |            7.81 |
# |         MaxQ1Vals |           -52.3 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.81 |
# |         MaxQ2Vals |           -52.5 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.8 |
# |             LossQ |               1 |
# |              Time |        9.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             971 |
# |      AverageEpRet |            -311 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |            -263 |
# |          MinEpRet |            -368 |
# |  AverageTestEpRet |            -269 |
# |      StdTestEpRet |            45.3 |
# |      MaxTestEpRet |            -214 |
# |      MinTestEpRet |            -384 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.46e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |            7.81 |
# |         MaxQ1Vals |           -52.5 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.6 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            61.7 |
# |             LossQ |           0.991 |
# |              Time |        9.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             972 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |            -276 |
# |          MinEpRet |            -407 |
# |  AverageTestEpRet |            -241 |
# |      StdTestEpRet |            20.1 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -275 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.46e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |            7.83 |
# |         MaxQ1Vals |           -52.5 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.83 |
# |         MaxQ2Vals |           -52.6 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            61.7 |
# |             LossQ |           0.996 |
# |              Time |        9.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             973 |
# |      AverageEpRet |            -310 |
# |          StdEpRet |            38.4 |
# |          MaxEpRet |            -244 |
# |          MinEpRet |            -405 |
# |  AverageTestEpRet |            -257 |
# |      StdTestEpRet |            29.9 |
# |      MaxTestEpRet |            -215 |
# |      MinTestEpRet |            -303 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.46e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.5 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            61.7 |
# |             LossQ |            0.99 |
# |              Time |        9.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             974 |
# |      AverageEpRet |            -303 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |            -342 |
# |  AverageTestEpRet |            -255 |
# |      StdTestEpRet |            59.5 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |            -388 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.46e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |            7.84 |
# |         MaxQ1Vals |           -52.6 |
# |         MinQ1Vals |           -99.7 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |            7.84 |
# |         MaxQ2Vals |           -52.6 |
# |         MinQ2Vals |            -100 |
# |            LossPi |            61.7 |
# |             LossQ |           0.974 |
# |              Time |        9.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             975 |
# |      AverageEpRet |            -298 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -253 |
# |          MinEpRet |            -342 |
# |  AverageTestEpRet |            -278 |
# |      StdTestEpRet |            64.8 |
# |      MaxTestEpRet |            -208 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.46e+06 |
# |     AverageQ1Vals |           -61.9 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |           -52.4 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -61.9 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |           -52.5 |
# |         MinQ2Vals |            -100 |
# |            LossPi |            61.7 |
# |             LossQ |           0.982 |
# |              Time |        9.09e+03 |
# ---------------------------------------
