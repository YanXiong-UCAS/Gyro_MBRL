# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yan/opt/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=35000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_opt_ing_35000', exp_name='td3_pe_opt_ing_35000')
                   )
# Out:
# Logging data to td3_pe_opt_ing_35000/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ffbb886a9d8>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	35000,
#     "exp_name":	"td3_pe_opt_ing_35000",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7ffbb8877ac8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_opt_ing_35000",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_opt_ing_35000",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_opt_ing_35000/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_opt_ing_35000",
#         "output_dir":	"td3_pe_opt_ing_35000"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            3.51 |
# |          MaxEpRet |            -485 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -462 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.07 |
# |         StdQ1Vals |            1.97 |
# |         MaxQ1Vals |          0.0452 |
# |         MinQ1Vals |           -10.6 |
# |     AverageQ2Vals |           -6.13 |
# |         StdQ2Vals |            1.87 |
# |         MaxQ2Vals |        -0.00769 |
# |         MinQ2Vals |             -11 |
# |            LossPi |            5.85 |
# |             LossQ |            3.39 |
# |              Time |            5.49 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             6.3 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -486 |
# |      StdTestEpRet |            7.97 |
# |      MaxTestEpRet |            -468 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.8 |
# |         StdQ1Vals |            3.85 |
# |         MaxQ1Vals |              -7 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |           -14.8 |
# |         StdQ2Vals |            3.85 |
# |         MaxQ2Vals |           -7.22 |
# |         MinQ2Vals |           -24.1 |
# |            LossPi |            14.6 |
# |             LossQ |           0.135 |
# |              Time |            13.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            5.98 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -475 |
# |      StdTestEpRet |            20.2 |
# |      MaxTestEpRet |            -434 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.8 |
# |         StdQ1Vals |            3.72 |
# |         MaxQ1Vals |           -19.7 |
# |         MinQ1Vals |           -37.5 |
# |     AverageQ2Vals |           -27.8 |
# |         StdQ2Vals |            3.72 |
# |         MaxQ2Vals |           -19.7 |
# |         MinQ2Vals |           -37.4 |
# |            LossPi |            27.7 |
# |             LossQ |           0.174 |
# |              Time |            22.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            6.55 |
# |          MaxEpRet |            -474 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -448 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.5 |
# |         StdQ1Vals |            3.23 |
# |         MaxQ1Vals |           -31.7 |
# |         MinQ1Vals |           -49.8 |
# |     AverageQ2Vals |           -39.5 |
# |         StdQ2Vals |            3.22 |
# |         MaxQ2Vals |           -31.6 |
# |         MinQ2Vals |           -49.3 |
# |            LossPi |            39.4 |
# |             LossQ |           0.218 |
# |              Time |            30.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            3.96 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -489 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |            -464 |
# |      MinTestEpRet |            -500 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.4 |
# |         StdQ1Vals |             2.8 |
# |         MaxQ1Vals |           -42.6 |
# |         MinQ1Vals |           -60.1 |
# |     AverageQ2Vals |           -49.4 |
# |         StdQ2Vals |             2.8 |
# |         MaxQ2Vals |           -42.5 |
# |         MinQ2Vals |           -59.8 |
# |            LossPi |            49.3 |
# |             LossQ |           0.251 |
# |              Time |            40.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            5.73 |
# |          MaxEpRet |            -482 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            12.3 |
# |      MaxTestEpRet |            -451 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -57.8 |
# |         StdQ1Vals |            2.41 |
# |         MaxQ1Vals |           -51.6 |
# |         MinQ1Vals |           -67.3 |
# |     AverageQ2Vals |           -57.8 |
# |         StdQ2Vals |            2.41 |
# |         MaxQ2Vals |           -51.5 |
# |         MinQ2Vals |           -67.5 |
# |            LossPi |            57.6 |
# |             LossQ |           0.273 |
# |              Time |            49.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            8.11 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -489 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -465 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -64.8 |
# |         StdQ1Vals |            2.06 |
# |         MaxQ1Vals |           -59.2 |
# |         MinQ1Vals |           -73.4 |
# |     AverageQ2Vals |           -64.8 |
# |         StdQ2Vals |            2.06 |
# |         MaxQ2Vals |           -58.9 |
# |         MinQ2Vals |           -74.4 |
# |            LossPi |            64.7 |
# |             LossQ |           0.287 |
# |              Time |            57.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |             4.9 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -487 |
# |      StdTestEpRet |            5.63 |
# |      MaxTestEpRet |            -475 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.7 |
# |         StdQ1Vals |            1.78 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |             -79 |
# |     AverageQ2Vals |           -70.7 |
# |         StdQ2Vals |            1.78 |
# |         MaxQ2Vals |           -65.8 |
# |         MinQ2Vals |           -79.4 |
# |            LossPi |            70.5 |
# |             LossQ |           0.295 |
# |              Time |            66.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -485 |
# |          StdEpRet |            8.44 |
# |          MaxEpRet |            -466 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -460 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.6 |
# |         StdQ1Vals |            1.55 |
# |         MaxQ1Vals |             -71 |
# |         MinQ1Vals |           -82.6 |
# |     AverageQ2Vals |           -75.6 |
# |         StdQ2Vals |            1.55 |
# |         MaxQ2Vals |           -71.1 |
# |         MinQ2Vals |           -83.5 |
# |            LossPi |            75.4 |
# |             LossQ |           0.294 |
# |              Time |              77 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -480 |
# |          StdEpRet |            9.91 |
# |          MaxEpRet |            -463 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |              13 |
# |      MaxTestEpRet |            -447 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.5 |
# |         StdQ1Vals |            1.36 |
# |         MaxQ1Vals |           -75.2 |
# |         MinQ1Vals |           -85.8 |
# |     AverageQ2Vals |           -79.5 |
# |         StdQ2Vals |            1.37 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |           -86.8 |
# |            LossPi |            79.4 |
# |             LossQ |           0.297 |
# |              Time |            86.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -458 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            18.5 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.8 |
# |         StdQ1Vals |            1.24 |
# |         MaxQ1Vals |           -78.7 |
# |         MinQ1Vals |           -89.3 |
# |     AverageQ2Vals |           -82.8 |
# |         StdQ2Vals |            1.24 |
# |         MaxQ2Vals |           -78.8 |
# |         MinQ2Vals |           -89.2 |
# |            LossPi |            82.7 |
# |             LossQ |            0.31 |
# |              Time |              95 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            10.7 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -434 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -85.5 |
# |         StdQ1Vals |            1.18 |
# |         MaxQ1Vals |           -81.6 |
# |         MinQ1Vals |           -91.8 |
# |     AverageQ2Vals |           -85.5 |
# |         StdQ2Vals |            1.19 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |           -92.2 |
# |            LossPi |            85.4 |
# |             LossQ |            0.32 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            9.64 |
# |          MaxEpRet |            -459 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |              18 |
# |      MaxTestEpRet |            -422 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -87.7 |
# |         StdQ1Vals |            1.18 |
# |         MaxQ1Vals |           -83.6 |
# |         MinQ1Vals |           -94.1 |
# |     AverageQ2Vals |           -87.7 |
# |         StdQ2Vals |            1.18 |
# |         MaxQ2Vals |           -83.4 |
# |         MinQ2Vals |           -94.3 |
# |            LossPi |            87.6 |
# |             LossQ |           0.335 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |            -452 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            29.9 |
# |      MaxTestEpRet |            -404 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -89.5 |
# |         StdQ1Vals |            1.18 |
# |         MaxQ1Vals |           -85.6 |
# |         MinQ1Vals |           -95.4 |
# |     AverageQ2Vals |           -89.5 |
# |         StdQ2Vals |            1.19 |
# |         MaxQ2Vals |           -85.5 |
# |         MinQ2Vals |           -95.7 |
# |            LossPi |            89.4 |
# |             LossQ |           0.345 |
# |              Time |             124 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            10.7 |
# |          MaxEpRet |            -453 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -470 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -428 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |             -91 |
# |         StdQ1Vals |            1.21 |
# |         MaxQ1Vals |           -86.6 |
# |         MinQ1Vals |           -97.3 |
# |     AverageQ2Vals |             -91 |
# |         StdQ2Vals |            1.22 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |           -97.4 |
# |            LossPi |            90.9 |
# |             LossQ |            0.35 |
# |              Time |             132 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -474 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            11.6 |
# |      MaxTestEpRet |            -454 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -92.2 |
# |         StdQ1Vals |            1.25 |
# |         MaxQ1Vals |           -87.8 |
# |         MinQ1Vals |           -98.3 |
# |     AverageQ2Vals |           -92.2 |
# |         StdQ2Vals |            1.26 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |           -98.6 |
# |            LossPi |            92.1 |
# |             LossQ |           0.365 |
# |              Time |             141 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -464 |
# |          StdEpRet |            17.2 |
# |          MaxEpRet |            -431 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -456 |
# |      StdTestEpRet |            33.6 |
# |      MaxTestEpRet |            -384 |
# |      MinTestEpRet |            -502 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            1.32 |
# |         MaxQ1Vals |           -88.4 |
# |         MinQ1Vals |           -99.1 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |           -88.4 |
# |         MinQ2Vals |           -98.9 |
# |            LossPi |              93 |
# |             LossQ |           0.374 |
# |              Time |             149 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -464 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -432 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -459 |
# |      StdTestEpRet |            25.3 |
# |      MaxTestEpRet |            -402 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            1.41 |
# |         MaxQ1Vals |           -88.8 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            1.42 |
# |         MaxQ2Vals |           -88.7 |
# |         MinQ2Vals |           -99.7 |
# |            LossPi |            93.7 |
# |             LossQ |            0.39 |
# |              Time |             158 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            16.8 |
# |          MaxEpRet |            -417 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -452 |
# |      StdTestEpRet |            19.2 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |            1.54 |
# |         MaxQ1Vals |           -88.8 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |            1.54 |
# |         MaxQ2Vals |           -88.8 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            94.2 |
# |             LossQ |           0.413 |
# |              Time |             167 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -460 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |            -400 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -451 |
# |      StdTestEpRet |              29 |
# |      MaxTestEpRet |            -394 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -94.7 |
# |         StdQ1Vals |            1.67 |
# |         MaxQ1Vals |           -88.6 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -94.7 |
# |         StdQ2Vals |            1.68 |
# |         MaxQ2Vals |           -88.7 |
# |         MinQ2Vals |            -101 |
# |            LossPi |            94.6 |
# |             LossQ |           0.438 |
# |              Time |             175 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -461 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |            -399 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -438 |
# |      StdTestEpRet |            35.2 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -479 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |             -95 |
# |         StdQ1Vals |            1.77 |
# |         MaxQ1Vals |           -88.8 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |             -95 |
# |         StdQ2Vals |            1.78 |
# |         MaxQ2Vals |           -88.8 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            94.9 |
# |             LossQ |           0.466 |
# |              Time |             184 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -391 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            16.7 |
# |      MaxTestEpRet |            -429 |
# |      MinTestEpRet |            -483 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -95.2 |
# |         StdQ1Vals |            1.87 |
# |         MaxQ1Vals |           -88.8 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -95.2 |
# |         StdQ2Vals |            1.88 |
# |         MaxQ2Vals |           -88.8 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.1 |
# |             LossQ |           0.489 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |            21.8 |
# |          MaxEpRet |            -419 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -422 |
# |      StdTestEpRet |            64.4 |
# |      MaxTestEpRet |            -266 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -95.3 |
# |         StdQ1Vals |            2.01 |
# |         MaxQ1Vals |           -88.6 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -95.3 |
# |         StdQ2Vals |            2.02 |
# |         MaxQ2Vals |           -88.6 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.2 |
# |             LossQ |           0.509 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -428 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -445 |
# |      StdTestEpRet |            25.5 |
# |      MaxTestEpRet |            -408 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -95.3 |
# |         StdQ1Vals |            2.11 |
# |         MaxQ1Vals |           -88.6 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -95.3 |
# |         StdQ2Vals |            2.12 |
# |         MaxQ2Vals |           -88.6 |
# |         MinQ2Vals |            -104 |
# |            LossPi |            95.2 |
# |             LossQ |           0.534 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -439 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -434 |
# |      StdTestEpRet |            31.1 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -95.3 |
# |         StdQ1Vals |            2.22 |
# |         MaxQ1Vals |           -88.4 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -95.3 |
# |         StdQ2Vals |            2.23 |
# |         MaxQ2Vals |           -88.4 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            95.1 |
# |             LossQ |           0.553 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -449 |
# |          StdEpRet |            21.5 |
# |          MaxEpRet |            -405 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -452 |
# |      StdTestEpRet |            37.7 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -95.2 |
# |         StdQ1Vals |            2.35 |
# |         MaxQ1Vals |           -88.1 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -95.2 |
# |         StdQ2Vals |            2.35 |
# |         MaxQ2Vals |             -88 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            95.1 |
# |             LossQ |           0.583 |
# |              Time |             226 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |            -427 |
# |          MinEpRet |            -481 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            40.6 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -95.1 |
# |         StdQ1Vals |            2.46 |
# |         MaxQ1Vals |           -87.7 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -95.1 |
# |         StdQ2Vals |            2.47 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.9 |
# |             LossQ |           0.608 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -447 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -430 |
# |      StdTestEpRet |            33.2 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |             -95 |
# |         StdQ1Vals |            2.59 |
# |         MaxQ1Vals |           -87.4 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             -95 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -87.2 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            94.8 |
# |             LossQ |           0.621 |
# |              Time |             243 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -421 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -428 |
# |      StdTestEpRet |            42.4 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -94.8 |
# |         StdQ1Vals |            2.69 |
# |         MaxQ1Vals |             -87 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -94.8 |
# |         StdQ2Vals |            2.69 |
# |         MaxQ2Vals |           -86.7 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            94.7 |
# |             LossQ |           0.649 |
# |              Time |             251 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            44.8 |
# |          MaxEpRet |            -344 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -430 |
# |      StdTestEpRet |            32.6 |
# |      MaxTestEpRet |            -389 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -94.7 |
# |         StdQ1Vals |            2.83 |
# |         MaxQ1Vals |           -86.6 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -94.7 |
# |         StdQ2Vals |            2.83 |
# |         MaxQ2Vals |           -86.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            94.5 |
# |             LossQ |           0.669 |
# |              Time |             259 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -382 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            53.9 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |            2.98 |
# |         MaxQ1Vals |           -86.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |            2.98 |
# |         MaxQ2Vals |             -86 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            94.2 |
# |             LossQ |           0.697 |
# |              Time |             268 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -439 |
# |          StdEpRet |            35.2 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            44.3 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -463 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            3.12 |
# |         MaxQ1Vals |           -85.2 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            3.12 |
# |         MaxQ2Vals |           -85.2 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              94 |
# |             LossQ |           0.727 |
# |              Time |             276 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -442 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -386 |
# |          MinEpRet |            -482 |
# |  AverageTestEpRet |            -413 |
# |      StdTestEpRet |            47.3 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            3.27 |
# |         MaxQ1Vals |           -83.7 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            3.27 |
# |         MaxQ2Vals |           -83.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            93.8 |
# |             LossQ |           0.746 |
# |              Time |             285 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -445 |
# |          StdEpRet |            32.5 |
# |          MaxEpRet |            -378 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            35.5 |
# |      MaxTestEpRet |            -329 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            3.44 |
# |         MaxQ1Vals |           -82.3 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            3.44 |
# |         MaxQ2Vals |           -82.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            93.5 |
# |             LossQ |           0.764 |
# |              Time |             293 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            18.1 |
# |          MaxEpRet |            -402 |
# |          MinEpRet |            -476 |
# |  AverageTestEpRet |            -422 |
# |      StdTestEpRet |            41.4 |
# |      MaxTestEpRet |            -327 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -93.6 |
# |         StdQ1Vals |            3.58 |
# |         MaxQ1Vals |           -81.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -93.6 |
# |         StdQ2Vals |            3.59 |
# |         MaxQ2Vals |           -81.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            93.4 |
# |             LossQ |           0.779 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            33.7 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -93.3 |
# |         StdQ1Vals |            3.72 |
# |         MaxQ1Vals |           -80.9 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -93.3 |
# |         StdQ2Vals |            3.73 |
# |         MaxQ2Vals |             -81 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            93.1 |
# |             LossQ |           0.783 |
# |              Time |             310 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -431 |
# |          StdEpRet |            43.7 |
# |          MaxEpRet |            -343 |
# |          MinEpRet |            -491 |
# |  AverageTestEpRet |            -413 |
# |      StdTestEpRet |            16.7 |
# |      MaxTestEpRet |            -383 |
# |      MinTestEpRet |            -435 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -93.1 |
# |         StdQ1Vals |            3.85 |
# |         MaxQ1Vals |           -80.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -93.1 |
# |         StdQ2Vals |            3.85 |
# |         MaxQ2Vals |           -80.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            92.8 |
# |             LossQ |           0.793 |
# |              Time |             318 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -432 |
# |          StdEpRet |            39.3 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            36.2 |
# |      MaxTestEpRet |            -343 |
# |      MinTestEpRet |            -449 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -92.8 |
# |         StdQ1Vals |            4.03 |
# |         MaxQ1Vals |           -79.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.8 |
# |         StdQ2Vals |            4.03 |
# |         MaxQ2Vals |           -79.4 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            92.6 |
# |             LossQ |           0.828 |
# |              Time |             326 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -427 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -419 |
# |      StdTestEpRet |            33.6 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -484 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -92.6 |
# |         StdQ1Vals |            4.17 |
# |         MaxQ1Vals |           -78.8 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.6 |
# |         StdQ2Vals |            4.17 |
# |         MaxQ2Vals |           -78.6 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            92.4 |
# |             LossQ |           0.824 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -435 |
# |          StdEpRet |            40.8 |
# |          MaxEpRet |            -321 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -376 |
# |      StdTestEpRet |            50.9 |
# |      MaxTestEpRet |            -292 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -92.4 |
# |         StdQ1Vals |             4.3 |
# |         MaxQ1Vals |           -77.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.4 |
# |         StdQ2Vals |            4.29 |
# |         MaxQ2Vals |             -78 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            92.1 |
# |             LossQ |           0.843 |
# |              Time |             343 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -424 |
# |          StdEpRet |            23.7 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            35.3 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -92.1 |
# |         StdQ1Vals |            4.45 |
# |         MaxQ1Vals |           -77.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -92.1 |
# |         StdQ2Vals |            4.45 |
# |         MaxQ2Vals |           -77.4 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.8 |
# |             LossQ |           0.856 |
# |              Time |             351 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -412 |
# |          StdEpRet |            33.9 |
# |          MaxEpRet |            -342 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -377 |
# |      StdTestEpRet |            60.2 |
# |      MaxTestEpRet |            -274 |
# |      MinTestEpRet |            -451 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -91.8 |
# |         StdQ1Vals |             4.6 |
# |         MaxQ1Vals |           -76.8 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.8 |
# |         StdQ2Vals |             4.6 |
# |         MaxQ2Vals |           -76.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            91.5 |
# |             LossQ |           0.871 |
# |              Time |             360 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |            36.1 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            43.4 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -451 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -91.5 |
# |         StdQ1Vals |             4.7 |
# |         MaxQ1Vals |           -76.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -91.5 |
# |         StdQ2Vals |             4.7 |
# |         MaxQ2Vals |             -76 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            91.2 |
# |             LossQ |           0.866 |
# |              Time |             368 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |              34 |
# |          MaxEpRet |            -321 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -388 |
# |      StdTestEpRet |            41.5 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -91.2 |
# |         StdQ1Vals |             4.8 |
# |         MaxQ1Vals |           -75.5 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -91.2 |
# |         StdQ2Vals |             4.8 |
# |         MaxQ2Vals |           -75.7 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            90.9 |
# |             LossQ |           0.875 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            43.7 |
# |          MaxEpRet |            -319 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |            -335 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -90.8 |
# |         StdQ1Vals |            4.92 |
# |         MaxQ1Vals |           -75.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -90.8 |
# |         StdQ2Vals |            4.92 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            90.6 |
# |             LossQ |           0.881 |
# |              Time |             385 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            35.6 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            53.4 |
# |      MaxTestEpRet |            -289 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -90.5 |
# |         StdQ1Vals |            5.06 |
# |         MaxQ1Vals |           -74.5 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -90.5 |
# |         StdQ2Vals |            5.06 |
# |         MaxQ2Vals |           -74.3 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            90.2 |
# |             LossQ |           0.887 |
# |              Time |             393 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            47.9 |
# |          MaxEpRet |            -303 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -360 |
# |      StdTestEpRet |            63.3 |
# ...
# ---------------------------------------
# |             Epoch |             115 |
# |      AverageEpRet |            -382 |
# |          StdEpRet |            48.4 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -363 |
# |      StdTestEpRet |            39.6 |
# |      MaxTestEpRet |            -285 |
# |      MinTestEpRet |            -419 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |           -81.3 |
# |         StdQ1Vals |            7.12 |
# |         MaxQ1Vals |           -65.2 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -81.3 |
# |         StdQ2Vals |            7.13 |
# |         MaxQ2Vals |             -65 |
# |         MinQ2Vals |            -111 |
# |            LossPi |              81 |
# |             LossQ |            1.06 |
# |              Time |             981 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             116 |
# |      AverageEpRet |            -372 |
# |          StdEpRet |            45.9 |
# |          MaxEpRet |            -293 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -353 |
# |      StdTestEpRet |            65.2 |
# |      MaxTestEpRet |            -251 |
# |      MinTestEpRet |            -428 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.74e+05 |
# |     AverageQ1Vals |           -81.2 |
# |         StdQ1Vals |             7.1 |
# |         MaxQ1Vals |           -65.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -81.2 |
# |         StdQ2Vals |             7.1 |
# |         MaxQ2Vals |           -64.9 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.9 |
# |             LossQ |            1.05 |
# |              Time |             989 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             117 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |              37 |
# |          MaxEpRet |            -335 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -374 |
# |      StdTestEpRet |            69.1 |
# |      MaxTestEpRet |            -274 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.75e+05 |
# |     AverageQ1Vals |           -81.1 |
# |         StdQ1Vals |            7.11 |
# |         MaxQ1Vals |           -64.9 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -81.1 |
# |         StdQ2Vals |            7.11 |
# |         MaxQ2Vals |             -65 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            80.8 |
# |             LossQ |            1.04 |
# |              Time |             998 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             118 |
# |      AverageEpRet |            -393 |
# |          StdEpRet |            46.7 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -323 |
# |      StdTestEpRet |            59.8 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -426 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.77e+05 |
# |     AverageQ1Vals |           -81.1 |
# |         StdQ1Vals |            7.16 |
# |         MaxQ1Vals |           -64.8 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -81.1 |
# |         StdQ2Vals |            7.16 |
# |         MaxQ2Vals |           -64.9 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            80.8 |
# |             LossQ |            1.07 |
# |              Time |        1.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             119 |
# |      AverageEpRet |            -380 |
# |          StdEpRet |            43.9 |
# |          MaxEpRet |            -298 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -337 |
# |      StdTestEpRet |            56.2 |
# |      MaxTestEpRet |            -264 |
# |      MinTestEpRet |            -417 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.78e+05 |
# |     AverageQ1Vals |           -81.1 |
# |         StdQ1Vals |            7.13 |
# |         MaxQ1Vals |           -64.6 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -81.1 |
# |         StdQ2Vals |            7.13 |
# |         MaxQ2Vals |           -64.7 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.8 |
# |             LossQ |            1.07 |
# |              Time |        1.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             120 |
# |      AverageEpRet |            -376 |
# |          StdEpRet |            34.5 |
# |          MaxEpRet |            -323 |
# |          MinEpRet |            -436 |
# |  AverageTestEpRet |            -383 |
# |      StdTestEpRet |            31.7 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             -81 |
# |         StdQ1Vals |            7.15 |
# |         MaxQ1Vals |           -64.7 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |             -81 |
# |         StdQ2Vals |            7.15 |
# |         MaxQ2Vals |           -64.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            80.7 |
# |             LossQ |            1.08 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             121 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            44.3 |
# |          MaxEpRet |            -314 |
# |          MinEpRet |            -453 |
# |  AverageTestEpRet |            -353 |
# |      StdTestEpRet |            47.3 |
# |      MaxTestEpRet |            -283 |
# |      MinTestEpRet |            -462 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.81e+05 |
# |     AverageQ1Vals |             -81 |
# |         StdQ1Vals |            7.12 |
# |         MaxQ1Vals |           -64.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |             -81 |
# |         StdQ2Vals |            7.12 |
# |         MaxQ2Vals |           -64.7 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            80.7 |
# |             LossQ |            1.06 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             122 |
# |      AverageEpRet |            -387 |
# |          StdEpRet |            43.9 |
# |          MaxEpRet |            -304 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -352 |
# |      StdTestEpRet |              22 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |            -401 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.83e+05 |
# |     AverageQ1Vals |           -80.9 |
# |         StdQ1Vals |            7.15 |
# |         MaxQ1Vals |           -64.4 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -80.9 |
# |         StdQ2Vals |            7.16 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.6 |
# |             LossQ |            1.07 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             123 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |            39.3 |
# |          MaxEpRet |            -326 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -361 |
# |      StdTestEpRet |            50.7 |
# |      MaxTestEpRet |            -268 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |           -80.8 |
# |         StdQ1Vals |            7.17 |
# |         MaxQ1Vals |           -64.6 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -80.8 |
# |         StdQ2Vals |            7.17 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            80.6 |
# |             LossQ |            1.08 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             124 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |            40.7 |
# |          MaxEpRet |            -309 |
# |          MinEpRet |            -445 |
# |  AverageTestEpRet |            -370 |
# |      StdTestEpRet |            31.6 |
# |      MaxTestEpRet |            -311 |
# |      MinTestEpRet |            -415 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.86e+05 |
# |     AverageQ1Vals |           -80.8 |
# |         StdQ1Vals |            7.18 |
# |         MaxQ1Vals |           -64.5 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -80.8 |
# |         StdQ2Vals |            7.18 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |            -112 |
# |            LossPi |            80.4 |
# |             LossQ |            1.08 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             125 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            36.8 |
# |          MaxEpRet |            -323 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -374 |
# |      StdTestEpRet |            45.9 |
# |      MaxTestEpRet |            -306 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.87e+05 |
# |     AverageQ1Vals |           -80.7 |
# |         StdQ1Vals |            7.18 |
# |         MaxQ1Vals |           -64.4 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -80.7 |
# |         StdQ2Vals |            7.18 |
# |         MaxQ2Vals |           -64.4 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            80.4 |
# |             LossQ |            1.08 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             126 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |            36.1 |
# |          MaxEpRet |            -316 |
# |          MinEpRet |            -469 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            63.9 |
# |      MaxTestEpRet |            -250 |
# |      MinTestEpRet |            -452 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.89e+05 |
# |     AverageQ1Vals |           -80.7 |
# |         StdQ1Vals |            7.19 |
# |         MaxQ1Vals |           -64.3 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -80.7 |
# |         StdQ2Vals |            7.19 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.4 |
# |             LossQ |            1.06 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             127 |
# |      AverageEpRet |            -393 |
# |          StdEpRet |            40.3 |
# |          MaxEpRet |            -317 |
# |          MinEpRet |            -456 |
# |  AverageTestEpRet |            -334 |
# |      StdTestEpRet |            58.3 |
# |      MaxTestEpRet |            -232 |
# |      MinTestEpRet |            -436 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.9e+05 |
# |     AverageQ1Vals |           -80.7 |
# |         StdQ1Vals |            7.19 |
# |         MaxQ1Vals |           -64.3 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -80.7 |
# |         StdQ2Vals |             7.2 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.4 |
# |             LossQ |            1.08 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             128 |
# |      AverageEpRet |            -385 |
# |          StdEpRet |            36.6 |
# |          MaxEpRet |            -332 |
# |          MinEpRet |            -444 |
# |  AverageTestEpRet |            -345 |
# |      StdTestEpRet |            37.2 |
# |      MaxTestEpRet |            -271 |
# |      MinTestEpRet |            -396 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |           -80.6 |
# |         StdQ1Vals |             7.2 |
# |         MaxQ1Vals |           -64.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -80.6 |
# |         StdQ2Vals |             7.2 |
# |         MaxQ2Vals |           -63.9 |
# |         MinQ2Vals |            -111 |
# |            LossPi |            80.3 |
# |             LossQ |            1.08 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             129 |
# |      AverageEpRet |            -394 |
# |          StdEpRet |            33.2 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -352 |
# |      StdTestEpRet |              53 |
# |      MaxTestEpRet |            -303 |
# |      MinTestEpRet |            -451 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.93e+05 |
# |     AverageQ1Vals |           -80.6 |
# |         StdQ1Vals |            7.19 |
# |         MaxQ1Vals |           -64.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -80.6 |
# |         StdQ2Vals |            7.19 |
# |         MaxQ2Vals |           -64.1 |
# |         MinQ2Vals |            -112 |
# |            LossPi |            80.3 |
# |             LossQ |            1.08 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             130 |
# |      AverageEpRet |            -380 |
# |          StdEpRet |            39.8 |
# |          MaxEpRet |            -307 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -379 |
# |      StdTestEpRet |            50.5 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -468 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+05 |
# |     AverageQ1Vals |           -80.5 |
# |         StdQ1Vals |            7.19 |
# |         MaxQ1Vals |           -64.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -80.5 |
# |         StdQ2Vals |             7.2 |
# |         MaxQ2Vals |           -64.1 |
# |         MinQ2Vals |            -113 |
# |            LossPi |            80.2 |
# |             LossQ |            1.07 |
# |              Time |        1.11e+03 |
# ---------------------------------------
