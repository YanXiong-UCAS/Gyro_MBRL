# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnvNew4Paper-v0'   # 该环境专为本研究设计

simu_args = {
    'dt': 0.02,   # Real system的sampling time是0.02s，后期应该予以更正！！！
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.td3_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=500,   # 最佳效果大致分布在30000-50000之间
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   pi_lr=1e-3,
                   q_lr=1e-3,
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   act_noise=0.1,
                   target_noise=0.2,
                   noise_clip=0.5,
                   policy_delay=2,
                   num_test_episodes=10,
                   max_ep_len=100,   # 不能太大，大于100不收敛
                   logger_kwargs=dict(output_dir='td3_pe_new4paper500', exp_name='td3_pe_new4paper500')
                   )
# Out:
# Warning: Log dir td3_pe_new4paper500 already exists! Storing info there anyway.
# Logging data to td3_pe_new4paper500/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fde71bf28c8>, 'GyroscopeEnvNew4Paper-v0', simu_args={'dt': 0.02, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	500,
#     "exp_name":	"td3_pe_new4paper500",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fde71bff2b0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_pe_new4paper500",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_pe_new4paper500",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_pe_new4paper500/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_pe_new4paper500",
#         "output_dir":	"td3_pe_new4paper500"
#     },
#     "max_ep_len":	100,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -496 |
# |          StdEpRet |            5.14 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -492 |
# |      StdTestEpRet |            5.37 |
# |      MaxTestEpRet |            -482 |
# |      MinTestEpRet |            -500 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -6.02 |
# |         StdQ1Vals |            1.94 |
# |         MaxQ1Vals |          0.0082 |
# |         MinQ1Vals |           -9.25 |
# |     AverageQ2Vals |           -6.08 |
# |         StdQ2Vals |            1.85 |
# |         MaxQ2Vals |         -0.0794 |
# |         MinQ2Vals |           -9.36 |
# |            LossPi |            5.78 |
# |             LossQ |            3.47 |
# |              Time |             2.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -493 |
# |          StdEpRet |            9.91 |
# |          MaxEpRet |            -465 |
# |          MinEpRet |            -507 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |            -396 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -14.8 |
# |         StdQ1Vals |            3.89 |
# |         MaxQ1Vals |           -6.86 |
# |         MinQ1Vals |           -23.6 |
# |     AverageQ2Vals |           -14.8 |
# |         StdQ2Vals |            3.89 |
# |         MaxQ2Vals |           -7.02 |
# |         MinQ2Vals |           -23.3 |
# |            LossPi |            14.7 |
# |             LossQ |          0.0927 |
# |              Time |            6.97 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -494 |
# |          StdEpRet |            5.29 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -488 |
# |      StdTestEpRet |             7.9 |
# |      MaxTestEpRet |            -476 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -27.9 |
# |         StdQ1Vals |            3.73 |
# |         MaxQ1Vals |           -19.2 |
# |         MinQ1Vals |           -37.6 |
# |     AverageQ2Vals |           -27.9 |
# |         StdQ2Vals |            3.73 |
# |         MaxQ2Vals |           -19.2 |
# |         MinQ2Vals |           -37.9 |
# |            LossPi |            27.8 |
# |             LossQ |          0.0985 |
# |              Time |            11.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            9.96 |
# |          MaxEpRet |            -470 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            11.9 |
# |      MaxTestEpRet |            -461 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -39.7 |
# |         StdQ1Vals |            3.29 |
# |         MaxQ1Vals |           -30.9 |
# |         MinQ1Vals |           -48.7 |
# |     AverageQ2Vals |           -39.7 |
# |         StdQ2Vals |            3.29 |
# |         MaxQ2Vals |           -30.8 |
# |         MinQ2Vals |           -48.6 |
# |            LossPi |            39.6 |
# |             LossQ |            0.14 |
# |              Time |            16.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |            9.93 |
# |          MaxEpRet |            -469 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            16.2 |
# |      MaxTestEpRet |            -448 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -49.7 |
# |         StdQ1Vals |            2.83 |
# |         MaxQ1Vals |           -41.1 |
# |         MinQ1Vals |           -57.8 |
# |     AverageQ2Vals |           -49.7 |
# |         StdQ2Vals |            2.84 |
# |         MaxQ2Vals |             -41 |
# |         MinQ2Vals |             -58 |
# |            LossPi |            49.6 |
# |             LossQ |           0.172 |
# |              Time |              21 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -490 |
# |          StdEpRet |            14.6 |
# |          MaxEpRet |            -449 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            34.3 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -58.1 |
# |         StdQ1Vals |            2.52 |
# |         MaxQ1Vals |           -50.1 |
# |         MinQ1Vals |           -65.5 |
# |     AverageQ2Vals |           -58.1 |
# |         StdQ2Vals |            2.53 |
# |         MaxQ2Vals |           -49.7 |
# |         MinQ2Vals |             -66 |
# |            LossPi |              58 |
# |             LossQ |           0.199 |
# |              Time |            25.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            8.85 |
# |          MaxEpRet |            -471 |
# |          MinEpRet |            -505 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |             -65 |
# |         StdQ1Vals |            2.26 |
# |         MaxQ1Vals |           -57.3 |
# |         MinQ1Vals |           -71.9 |
# |     AverageQ2Vals |             -65 |
# |         StdQ2Vals |            2.27 |
# |         MaxQ2Vals |           -57.1 |
# |         MinQ2Vals |           -72.5 |
# |            LossPi |            64.9 |
# |             LossQ |           0.219 |
# |              Time |            30.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            14.9 |
# |          MaxEpRet |            -434 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            8.68 |
# |      MaxTestEpRet |            -466 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -70.7 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |           -63.2 |
# |         MinQ1Vals |           -77.4 |
# |     AverageQ2Vals |           -70.7 |
# |         StdQ2Vals |            2.08 |
# |         MaxQ2Vals |           -62.9 |
# |         MinQ2Vals |           -77.9 |
# |            LossPi |            70.7 |
# |             LossQ |           0.237 |
# |              Time |            35.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |            -468 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            22.6 |
# |      MaxTestEpRet |            -414 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -75.5 |
# |         StdQ1Vals |            1.97 |
# |         MaxQ1Vals |           -67.9 |
# |         MinQ1Vals |           -82.4 |
# |     AverageQ2Vals |           -75.5 |
# |         StdQ2Vals |            1.98 |
# |         MaxQ2Vals |           -67.9 |
# |         MinQ2Vals |           -82.2 |
# |            LossPi |            75.4 |
# |             LossQ |           0.247 |
# |              Time |            40.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -482 |
# |          StdEpRet |            20.6 |
# |          MaxEpRet |            -428 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            14.3 |
# |      MaxTestEpRet |            -453 |
# |      MinTestEpRet |            -502 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -79.5 |
# |         StdQ1Vals |             1.9 |
# |         MaxQ1Vals |           -71.7 |
# |         MinQ1Vals |           -85.9 |
# |     AverageQ2Vals |           -79.5 |
# |         StdQ2Vals |            1.91 |
# |         MaxQ2Vals |           -71.5 |
# |         MinQ2Vals |           -86.2 |
# |            LossPi |            79.4 |
# |             LossQ |           0.261 |
# |              Time |              45 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -480 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            9.62 |
# |      MaxTestEpRet |            -462 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -82.8 |
# |         StdQ1Vals |            1.88 |
# |         MaxQ1Vals |           -75.1 |
# |         MinQ1Vals |           -89.7 |
# |     AverageQ2Vals |           -82.8 |
# |         StdQ2Vals |            1.89 |
# |         MaxQ2Vals |           -75.1 |
# |         MinQ2Vals |           -89.2 |
# |            LossPi |            82.7 |
# |             LossQ |           0.275 |
# |              Time |            49.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |            -404 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -476 |
# |      StdTestEpRet |            16.1 |
# |      MaxTestEpRet |            -446 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -85.5 |
# |         StdQ1Vals |             1.9 |
# |         MaxQ1Vals |           -77.7 |
# |         MinQ1Vals |           -92.2 |
# |     AverageQ2Vals |           -85.5 |
# |         StdQ2Vals |            1.91 |
# |         MaxQ2Vals |           -77.8 |
# |         MinQ2Vals |           -92.6 |
# |            LossPi |            85.4 |
# |             LossQ |           0.281 |
# |              Time |            54.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |            -460 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -476 |
# |      StdTestEpRet |            7.21 |
# |      MaxTestEpRet |            -469 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -87.8 |
# |         StdQ1Vals |            1.96 |
# |         MaxQ1Vals |             -80 |
# |         MinQ1Vals |           -94.5 |
# |     AverageQ2Vals |           -87.8 |
# |         StdQ2Vals |            1.97 |
# |         MaxQ2Vals |           -79.6 |
# |         MinQ2Vals |           -94.6 |
# |            LossPi |            87.7 |
# |             LossQ |           0.287 |
# |              Time |            59.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -487 |
# |          StdEpRet |            9.64 |
# |          MaxEpRet |            -464 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |            19.7 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -89.7 |
# |         StdQ1Vals |            2.01 |
# |         MaxQ1Vals |           -81.4 |
# |         MinQ1Vals |           -96.8 |
# |     AverageQ2Vals |           -89.7 |
# |         StdQ2Vals |            2.03 |
# |         MaxQ2Vals |           -81.5 |
# |         MinQ2Vals |           -96.2 |
# |            LossPi |            89.6 |
# |             LossQ |             0.3 |
# |              Time |            64.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -485 |
# |          StdEpRet |              12 |
# |          MaxEpRet |            -453 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            13.5 |
# |      MaxTestEpRet |            -449 |
# |      MinTestEpRet |            -499 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -91.3 |
# |         StdQ1Vals |            2.05 |
# |         MaxQ1Vals |           -82.8 |
# |         MinQ1Vals |           -98.6 |
# |     AverageQ2Vals |           -91.3 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -82.7 |
# |         MinQ2Vals |           -98.1 |
# |            LossPi |            91.2 |
# |             LossQ |           0.312 |
# |              Time |            69.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -485 |
# |          StdEpRet |             8.7 |
# |          MaxEpRet |            -468 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            14.7 |
# |      MaxTestEpRet |            -458 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -92.6 |
# |         StdQ1Vals |            2.05 |
# |         MaxQ1Vals |             -84 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -92.6 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -84.1 |
# |         MinQ2Vals |           -99.7 |
# |            LossPi |            92.5 |
# |             LossQ |           0.307 |
# |              Time |            74.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -475 |
# |          StdEpRet |              17 |
# |          MaxEpRet |            -438 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            8.74 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -93.7 |
# |         StdQ1Vals |            2.04 |
# |         MaxQ1Vals |           -84.4 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -93.7 |
# |         StdQ2Vals |            2.06 |
# |         MaxQ2Vals |           -84.4 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            93.6 |
# |             LossQ |           0.323 |
# |              Time |            79.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            16.8 |
# |          MaxEpRet |            -448 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -503 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -94.5 |
# |         StdQ1Vals |            2.06 |
# |         MaxQ1Vals |           -84.8 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -94.5 |
# |         StdQ2Vals |            2.08 |
# |         MaxQ2Vals |           -84.9 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            94.4 |
# |             LossQ |           0.322 |
# |              Time |            84.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |            -493 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -432 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -95.2 |
# |         StdQ1Vals |             2.1 |
# |         MaxQ1Vals |           -85.3 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -95.2 |
# |         StdQ2Vals |            2.12 |
# |         MaxQ2Vals |           -85.3 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            95.1 |
# |             LossQ |           0.327 |
# |              Time |            89.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            19.1 |
# |      MaxTestEpRet |            -427 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -95.7 |
# |         StdQ1Vals |            2.18 |
# |         MaxQ1Vals |           -85.7 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -95.7 |
# |         StdQ2Vals |             2.2 |
# |         MaxQ2Vals |           -85.8 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            95.6 |
# |             LossQ |           0.333 |
# |              Time |            94.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -488 |
# |          StdEpRet |            9.51 |
# |          MaxEpRet |            -472 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |            16.2 |
# |      MaxTestEpRet |            -435 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -96.2 |
# |         StdQ1Vals |            2.23 |
# |         MaxQ1Vals |           -86.2 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.2 |
# |         StdQ2Vals |            2.24 |
# |         MaxQ2Vals |           -86.1 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            96.1 |
# |             LossQ |           0.335 |
# |              Time |            99.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -460 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |              13 |
# |      MaxTestEpRet |            -444 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -96.6 |
# |         StdQ1Vals |            2.24 |
# |         MaxQ1Vals |           -86.3 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.6 |
# |         StdQ2Vals |            2.25 |
# |         MaxQ2Vals |           -86.1 |
# |         MinQ2Vals |            -105 |
# |            LossPi |            96.5 |
# |             LossQ |           0.337 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            15.5 |
# |          MaxEpRet |            -450 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |            8.21 |
# |      MaxTestEpRet |            -471 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -96.9 |
# |         StdQ1Vals |            2.26 |
# |         MaxQ1Vals |           -86.6 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -96.9 |
# |         StdQ2Vals |            2.28 |
# |         MaxQ2Vals |           -86.6 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            96.8 |
# |             LossQ |           0.339 |
# |              Time |             110 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            15.1 |
# |          MaxEpRet |            -451 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |            -414 |
# |      MinTestEpRet |            -500 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -97.1 |
# |         StdQ1Vals |             2.3 |
# |         MaxQ1Vals |           -86.7 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -97.1 |
# |         StdQ2Vals |            2.31 |
# |         MaxQ2Vals |           -86.6 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              97 |
# |             LossQ |           0.347 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -485 |
# |          StdEpRet |            10.2 |
# |          MaxEpRet |            -471 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -444 |
# |      MinTestEpRet |            -503 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -97.3 |
# |         StdQ1Vals |            2.34 |
# |         MaxQ1Vals |           -86.7 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -97.3 |
# |         StdQ2Vals |            2.35 |
# |         MaxQ2Vals |           -86.9 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            97.2 |
# |             LossQ |           0.338 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -447 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -468 |
# |      StdTestEpRet |            20.4 |
# |      MaxTestEpRet |            -422 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -97.5 |
# |         StdQ1Vals |            2.37 |
# |         MaxQ1Vals |           -86.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -97.5 |
# |         StdQ2Vals |            2.38 |
# |         MaxQ2Vals |           -86.8 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            97.3 |
# |             LossQ |           0.341 |
# |              Time |             124 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -487 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -456 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |            19.3 |
# |      MaxTestEpRet |            -443 |
# |      MinTestEpRet |            -503 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -97.6 |
# |         StdQ1Vals |             2.4 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -97.6 |
# |         StdQ2Vals |            2.42 |
# |         MaxQ2Vals |             -87 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.5 |
# |             LossQ |           0.336 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -466 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |            -405 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -479 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.45 |
# |         MaxQ1Vals |           -87.2 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |            2.47 |
# |         MaxQ2Vals |           -86.9 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.6 |
# |             LossQ |           0.339 |
# |              Time |             134 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -471 |
# |          StdEpRet |            13.9 |
# |          MaxEpRet |            -443 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |            12.6 |
# |      MaxTestEpRet |            -455 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.48 |
# |         MaxQ1Vals |           -87.3 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |             2.5 |
# |         MaxQ2Vals |             -87 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.6 |
# |             LossQ |           0.345 |
# |              Time |             139 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -450 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            16.2 |
# |      MaxTestEpRet |            -438 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.51 |
# |         MaxQ1Vals |           -87.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |            2.52 |
# |         MaxQ2Vals |           -87.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.6 |
# |             LossQ |           0.348 |
# |              Time |             144 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            14.6 |
# |          MaxEpRet |            -449 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -488 |
# |      StdTestEpRet |            4.57 |
# |      MaxTestEpRet |            -480 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.52 |
# |         MaxQ1Vals |           -87.6 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |            2.54 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.6 |
# |             LossQ |           0.347 |
# |              Time |             149 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -470 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |            -439 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            9.99 |
# |      MaxTestEpRet |            -464 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.55 |
# |         MaxQ1Vals |           -87.6 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |            2.56 |
# |         MaxQ2Vals |           -87.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.6 |
# |             LossQ |           0.355 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -480 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -455 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |            -449 |
# |      MinTestEpRet |            -498 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -97.7 |
# |         StdQ1Vals |            2.58 |
# |         MaxQ1Vals |           -87.5 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.7 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -87.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.6 |
# |             LossQ |           0.345 |
# |              Time |             159 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -475 |
# |          StdEpRet |            14.5 |
# |          MaxEpRet |            -437 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -413 |
# |      MinTestEpRet |            -504 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -97.6 |
# |         StdQ1Vals |             2.6 |
# |         MaxQ1Vals |           -87.8 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -97.6 |
# |         StdQ2Vals |            2.61 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.5 |
# |             LossQ |           0.344 |
# |              Time |             164 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -470 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |            -444 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -474 |
# |      StdTestEpRet |            16.2 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -97.6 |
# |         StdQ1Vals |            2.62 |
# |         MaxQ1Vals |           -87.9 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -97.6 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            97.5 |
# |             LossQ |           0.339 |
# |              Time |             169 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -391 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -480 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -432 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -97.5 |
# |         StdQ1Vals |            2.65 |
# |         MaxQ1Vals |           -87.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.5 |
# |         StdQ2Vals |            2.66 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.4 |
# |             LossQ |           0.336 |
# |              Time |             174 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |            -417 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |            -459 |
# |      StdTestEpRet |            27.7 |
# |      MaxTestEpRet |            -387 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -97.5 |
# |         StdQ1Vals |            2.69 |
# |         MaxQ1Vals |           -88.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.5 |
# |         StdQ2Vals |             2.7 |
# |         MaxQ2Vals |           -87.7 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            97.4 |
# |             LossQ |           0.341 |
# |              Time |             179 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |              16 |
# |          MaxEpRet |            -442 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -458 |
# |      StdTestEpRet |            35.8 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |            -505 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -97.5 |
# |         StdQ1Vals |            2.72 |
# |         MaxQ1Vals |           -88.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.5 |
# |         StdQ2Vals |            2.73 |
# |         MaxQ2Vals |           -87.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.4 |
# |             LossQ |           0.341 |
# |              Time |             184 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -464 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |            -419 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -463 |
# |      StdTestEpRet |            29.5 |
# |      MaxTestEpRet |            -403 |
# |      MinTestEpRet |            -501 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -97.5 |
# |         StdQ1Vals |            2.76 |
# |         MaxQ1Vals |           -88.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.5 |
# |         StdQ2Vals |            2.77 |
# |         MaxQ2Vals |           -87.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.4 |
# |             LossQ |            0.34 |
# |              Time |             189 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            18.8 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -97.4 |
# |         StdQ1Vals |            2.82 |
# |         MaxQ1Vals |           -88.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.4 |
# |         StdQ2Vals |            2.83 |
# |         MaxQ2Vals |             -88 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.3 |
# |             LossQ |           0.348 |
# |              Time |             194 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |            -449 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            27.8 |
# |      MaxTestEpRet |            -405 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |     AverageQ1Vals |           -97.4 |
# |         StdQ1Vals |            2.85 |
# |         MaxQ1Vals |             -88 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.4 |
# |         StdQ2Vals |            2.86 |
# |         MaxQ2Vals |             -88 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            97.3 |
# |             LossQ |           0.355 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -467 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |            -436 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -459 |
# |      StdTestEpRet |            24.1 |
# |      MaxTestEpRet |            -400 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |     AverageQ1Vals |           -97.3 |
# |         StdQ1Vals |             2.9 |
# |         MaxQ1Vals |             -88 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -97.3 |
# |         StdQ2Vals |            2.91 |
# |         MaxQ2Vals |           -87.9 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            97.2 |
# |             LossQ |           0.353 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -468 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |            -399 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -468 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |     AverageQ1Vals |           -97.3 |
# |         StdQ1Vals |            2.93 |
# |         MaxQ1Vals |           -87.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.3 |
# |         StdQ2Vals |            2.94 |
# |         MaxQ2Vals |           -87.6 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            97.2 |
# |             LossQ |            0.36 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -467 |
# |          StdEpRet |            30.7 |
# |          MaxEpRet |            -391 |
# |          MinEpRet |            -508 |
# |  AverageTestEpRet |            -468 |
# |      StdTestEpRet |            22.2 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |            -503 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -97.2 |
# |         StdQ1Vals |            2.98 |
# |         MaxQ1Vals |           -87.2 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.2 |
# |         StdQ2Vals |            2.99 |
# |         MaxQ2Vals |           -87.4 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            97.1 |
# |             LossQ |           0.374 |
# |              Time |             214 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            14.9 |
# |          MaxEpRet |            -447 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |            17.9 |
# |      MaxTestEpRet |            -432 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |     AverageQ1Vals |           -97.2 |
# |         StdQ1Vals |               3 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -97.2 |
# |         StdQ2Vals |            3.01 |
# |         MaxQ2Vals |           -87.3 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            97.1 |
# |             LossQ |           0.378 |
# |              Time |             219 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -472 |
# |          StdEpRet |            22.6 |
# |          MaxEpRet |            -412 |
# |          MinEpRet |            -496 |
# |  AverageTestEpRet |            -465 |
# |      StdTestEpRet |            16.6 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |     AverageQ1Vals |           -97.1 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |           -87.1 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -97.1 |
# |         StdQ2Vals |            3.03 |
# |         MaxQ2Vals |           -87.1 |
# |         MinQ2Vals |            -110 |
# |            LossPi |              97 |
# |             LossQ |           0.388 |
# |              Time |             225 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -476 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -439 |
# |          MinEpRet |            -498 |
# ...
# ---------------------------------------
# |             Epoch |             358 |
# |      AverageEpRet |            -434 |
# |          StdEpRet |            40.9 |
# |          MaxEpRet |            -338 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            33.7 |
# |      MaxTestEpRet |            -356 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.37e+05 |
# |     AverageQ1Vals |           -88.4 |
# |         StdQ1Vals |            7.69 |
# |         MaxQ1Vals |             -64 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |           -88.4 |
# |         StdQ2Vals |            7.69 |
# |         MaxQ2Vals |           -64.1 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.2 |
# |             LossQ |           0.614 |
# |              Time |        1.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             359 |
# |      AverageEpRet |            -434 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |            34.6 |
# |      MaxTestEpRet |            -372 |
# |      MinTestEpRet |            -478 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.38e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            7.69 |
# |         MaxQ1Vals |           -63.8 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            7.69 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |            -107 |
# |            LossPi |            88.1 |
# |             LossQ |           0.616 |
# |              Time |        1.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             360 |
# |      AverageEpRet |            -428 |
# |          StdEpRet |              31 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            61.4 |
# |      MaxTestEpRet |            -272 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            7.68 |
# |         MaxQ1Vals |           -63.7 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            7.68 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            88.1 |
# |             LossQ |           0.611 |
# |              Time |        1.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             361 |
# |      AverageEpRet |            -424 |
# |          StdEpRet |            36.8 |
# |          MaxEpRet |            -372 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -411 |
# |      StdTestEpRet |            49.4 |
# |      MaxTestEpRet |            -288 |
# |      MinTestEpRet |            -466 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.41e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |             7.7 |
# |         MaxQ1Vals |           -63.7 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |             7.7 |
# |         MaxQ2Vals |           -64.3 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            88.1 |
# |             LossQ |           0.626 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             362 |
# |      AverageEpRet |            -420 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -433 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.43e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            7.68 |
# |         MaxQ1Vals |           -63.4 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            7.68 |
# |         MaxQ2Vals |             -64 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.1 |
# |             LossQ |           0.603 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             363 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -393 |
# |      StdTestEpRet |              43 |
# |      MaxTestEpRet |            -317 |
# |      MinTestEpRet |            -466 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.44e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            7.71 |
# |         MaxQ1Vals |           -63.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            7.71 |
# |         MaxQ2Vals |           -64.5 |
# |         MinQ2Vals |            -109 |
# |            LossPi |            88.1 |
# |             LossQ |           0.633 |
# |              Time |        1.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             364 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            44.9 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.46e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.72 |
# |         MaxQ1Vals |           -63.6 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            7.72 |
# |         MaxQ2Vals |           -63.8 |
# |         MinQ2Vals |            -110 |
# |            LossPi |            88.1 |
# |             LossQ |           0.607 |
# |              Time |        1.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             365 |
# |      AverageEpRet |            -441 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -425 |
# |      StdTestEpRet |            42.8 |
# |      MaxTestEpRet |            -335 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.47e+05 |
# |     AverageQ1Vals |           -88.3 |
# |         StdQ1Vals |            7.71 |
# |         MaxQ1Vals |           -63.8 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -88.3 |
# |         StdQ2Vals |            7.71 |
# |         MaxQ2Vals |           -64.7 |
# |         MinQ2Vals |            -108 |
# |            LossPi |            88.1 |
# |             LossQ |           0.608 |
# |              Time |        1.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             366 |
# |      AverageEpRet |            -434 |
# |          StdEpRet |              45 |
# |          MaxEpRet |            -343 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            38.6 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.49e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.71 |
# |         MaxQ1Vals |           -63.9 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            7.71 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              88 |
# |             LossQ |           0.616 |
# |              Time |        1.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             367 |
# |      AverageEpRet |            -425 |
# |          StdEpRet |            35.8 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -464 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |            37.5 |
# |      MaxTestEpRet |            -365 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.5e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.73 |
# |         MaxQ1Vals |           -63.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            7.73 |
# |         MaxQ2Vals |           -64.1 |
# |         MinQ2Vals |            -107 |
# |            LossPi |              88 |
# |             LossQ |           0.617 |
# |              Time |        1.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             368 |
# |      AverageEpRet |            -434 |
# |          StdEpRet |            38.8 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -424 |
# |      StdTestEpRet |            36.2 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -466 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.52e+05 |
# |     AverageQ1Vals |           -88.1 |
# |         StdQ1Vals |            7.75 |
# |         MaxQ1Vals |           -63.4 |
# |         MinQ1Vals |            -108 |
# |     AverageQ2Vals |           -88.1 |
# |         StdQ2Vals |            7.75 |
# |         MaxQ2Vals |           -64.2 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              88 |
# |             LossQ |           0.604 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             369 |
# |      AverageEpRet |            -422 |
# |          StdEpRet |            43.2 |
# |          MaxEpRet |            -342 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -419 |
# |      StdTestEpRet |            34.4 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.53e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.69 |
# |         MaxQ1Vals |           -63.8 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |             7.7 |
# |         MaxQ2Vals |           -64.1 |
# |         MinQ2Vals |            -109 |
# |            LossPi |              88 |
# |             LossQ |            0.62 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             370 |
# |      AverageEpRet |            -436 |
# |          StdEpRet |            37.4 |
# |          MaxEpRet |            -337 |
# |          MinEpRet |            -472 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            34.9 |
# |      MaxTestEpRet |            -356 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.75 |
# |         MaxQ1Vals |           -63.5 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            7.75 |
# |         MaxQ2Vals |           -63.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              88 |
# |             LossQ |           0.613 |
# |              Time |        1.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             371 |
# |      AverageEpRet |            -440 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            56.2 |
# |      MaxTestEpRet |            -325 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.56e+05 |
# |     AverageQ1Vals |           -88.1 |
# |         StdQ1Vals |            7.75 |
# |         MaxQ1Vals |           -63.6 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |           -88.1 |
# |         StdQ2Vals |            7.75 |
# |         MaxQ2Vals |           -64.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |              88 |
# |             LossQ |           0.612 |
# |              Time |        1.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             372 |
# |      AverageEpRet |            -423 |
# |          StdEpRet |            38.5 |
# |          MaxEpRet |            -370 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -429 |
# |      StdTestEpRet |            39.3 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |            -471 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.58e+05 |
# |     AverageQ1Vals |           -88.2 |
# |         StdQ1Vals |            7.73 |
# |         MaxQ1Vals |           -63.3 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -88.2 |
# |         StdQ2Vals |            7.73 |
# |         MaxQ2Vals |           -63.5 |
# |         MinQ2Vals |            -110 |
# |            LossPi |              88 |
# |             LossQ |           0.604 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             373 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            37.9 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -412 |
# |      StdTestEpRet |            43.3 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |            -465 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.59e+05 |
# |     AverageQ1Vals |           -88.1 |
# |         StdQ1Vals |            7.75 |
# |         MaxQ1Vals |           -63.7 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |           -88.1 |
# |         StdQ2Vals |            7.75 |
# |         MaxQ2Vals |           -63.9 |
# |         MinQ2Vals |            -109 |
# |            LossPi |              88 |
# |             LossQ |           0.614 |
# |              Time |        1.92e+03 |
# ---------------------------------------
