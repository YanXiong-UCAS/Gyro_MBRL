# %% [markdown]
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### Quadratic reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_q', exp_name='ddpg_q'))
# Out:
# Warning: Log dir ddpg_q already exists! Storing info there anyway.
# Logging data to ddpg_q/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f438205c400>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='Quadratic', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0})",
#     "epochs":	500,
#     "exp_name":	"ddpg_q",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f4381d99390>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q",
#         "output_dir":	"ddpg_q"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -66.7 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |             -42 |
# |          MinEpRet |            -107 |
# |  AverageTestEpRet |           -64.6 |
# |      StdTestEpRet |            17.6 |
# |      MaxTestEpRet |           -39.2 |
# |      MinTestEpRet |            -103 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |      AverageQVals |           -1.36 |
# |          StdQVals |           0.643 |
# |          MaxQVals |          0.0291 |
# |          MinQVals |           -4.58 |
# |            LossPi |            1.28 |
# |             LossQ |          0.0621 |
# |              Time |            3.81 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -66.3 |
# |          StdEpRet |            13.2 |
# |          MaxEpRet |           -37.5 |
# |          MinEpRet |           -98.9 |
# |  AverageTestEpRet |           -69.3 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |           -10.8 |
# |      MinTestEpRet |            -100 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |      AverageQVals |           -3.69 |
# |          StdQVals |            1.76 |
# |          MaxQVals |          -0.329 |
# |          MinQVals |             -12 |
# |            LossPi |            3.51 |
# |             LossQ |          0.0936 |
# |              Time |            9.96 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -64.1 |
# |          StdEpRet |            9.22 |
# |          MaxEpRet |           -46.7 |
# |          MinEpRet |           -82.4 |
# |  AverageTestEpRet |           -48.8 |
# |      StdTestEpRet |            20.8 |
# |      MaxTestEpRet |           -1.74 |
# |      MinTestEpRet |           -77.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |      AverageQVals |           -6.13 |
# |          StdQVals |            2.15 |
# |          MaxQVals |          -0.914 |
# |          MinQVals |           -15.8 |
# |            LossPi |            5.79 |
# |             LossQ |           0.222 |
# |              Time |            14.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |           -67.1 |
# |          StdEpRet |            15.1 |
# |          MaxEpRet |           -39.3 |
# |          MinEpRet |             -95 |
# |  AverageTestEpRet |           -31.3 |
# |      StdTestEpRet |            24.7 |
# |      MaxTestEpRet |           -5.62 |
# |      MinTestEpRet |           -93.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |      AverageQVals |           -7.85 |
# |          StdQVals |            2.51 |
# |          MaxQVals |          -0.749 |
# |          MinQVals |           -18.8 |
# |            LossPi |            7.44 |
# |             LossQ |           0.297 |
# |              Time |            19.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -61.3 |
# |          StdEpRet |            9.16 |
# |          MaxEpRet |           -39.3 |
# |          MinEpRet |           -72.2 |
# |  AverageTestEpRet |           -37.8 |
# |      StdTestEpRet |            17.6 |
# |      MaxTestEpRet |           -9.17 |
# |      MinTestEpRet |           -68.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |      AverageQVals |           -9.05 |
# |          StdQVals |            2.92 |
# |          MaxQVals |          -0.551 |
# |          MinQVals |           -19.4 |
# |            LossPi |            8.58 |
# |             LossQ |           0.383 |
# |              Time |            24.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -62.1 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |           -38.6 |
# |          MinEpRet |             -97 |
# |  AverageTestEpRet |           -35.4 |
# |      StdTestEpRet |            11.9 |
# |      MaxTestEpRet |           -13.8 |
# |      MinTestEpRet |           -57.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |      AverageQVals |           -9.83 |
# |          StdQVals |            3.19 |
# |          MaxQVals |           -0.19 |
# |          MinQVals |           -21.9 |
# |            LossPi |            9.34 |
# |             LossQ |             0.4 |
# |              Time |            28.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -54.6 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |           -12.6 |
# |          MinEpRet |             -84 |
# |  AverageTestEpRet |           -29.9 |
# |      StdTestEpRet |            11.4 |
# |      MaxTestEpRet |             -12 |
# |      MinTestEpRet |           -50.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |      AverageQVals |           -10.3 |
# |          StdQVals |             3.5 |
# |          MaxQVals |          -0.212 |
# |          MinQVals |           -22.7 |
# |            LossPi |             9.8 |
# |             LossQ |           0.442 |
# |              Time |            33.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -20.2 |
# |          StdEpRet |            10.9 |
# |          MaxEpRet |           -3.57 |
# |          MinEpRet |           -40.4 |
# |  AverageTestEpRet |             -25 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |            -7.9 |
# |      MinTestEpRet |           -42.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |      AverageQVals |           -10.3 |
# |          StdQVals |             3.9 |
# |          MaxQVals |           -0.19 |
# |          MinQVals |           -24.4 |
# |            LossPi |            9.78 |
# |             LossQ |           0.422 |
# |              Time |            38.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |           -19.1 |
# |          StdEpRet |              15 |
# |          MaxEpRet |           -2.74 |
# |          MinEpRet |           -54.3 |
# |  AverageTestEpRet |           -15.3 |
# |      StdTestEpRet |            9.99 |
# |      MaxTestEpRet |              -5 |
# |      MinTestEpRet |           -35.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |      AverageQVals |           -10.1 |
# |          StdQVals |            4.23 |
# |          MaxQVals |          -0.171 |
# |          MinQVals |           -25.1 |
# |            LossPi |            9.58 |
# |             LossQ |           0.394 |
# |              Time |              43 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -27.5 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |           -5.74 |
# |          MinEpRet |           -65.2 |
# |  AverageTestEpRet |             -19 |
# |      StdTestEpRet |             9.2 |
# |      MaxTestEpRet |           -5.61 |
# |      MinTestEpRet |           -37.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |      AverageQVals |           -9.79 |
# |          StdQVals |            4.55 |
# |          MaxQVals |         -0.0833 |
# |          MinQVals |           -25.2 |
# |            LossPi |            9.34 |
# |             LossQ |           0.382 |
# |              Time |            47.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -18.7 |
# |          StdEpRet |            11.4 |
# |          MaxEpRet |           -5.89 |
# |          MinEpRet |           -46.1 |
# |  AverageTestEpRet |             -11 |
# |      StdTestEpRet |            5.69 |
# |      MaxTestEpRet |           -1.48 |
# |      MinTestEpRet |             -20 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |           -9.57 |
# |          StdQVals |            4.89 |
# |          MaxQVals |          0.0558 |
# |          MinQVals |           -25.5 |
# |            LossPi |            9.12 |
# |             LossQ |           0.385 |
# |              Time |            52.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -13.9 |
# |          StdEpRet |            8.79 |
# |          MaxEpRet |           -2.34 |
# |          MinEpRet |           -39.9 |
# |  AverageTestEpRet |           -12.5 |
# |      StdTestEpRet |            10.9 |
# |      MaxTestEpRet |           -2.15 |
# |      MinTestEpRet |           -40.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |      AverageQVals |           -8.99 |
# |          StdQVals |            5.22 |
# |          MaxQVals |           0.209 |
# |          MinQVals |           -26.1 |
# |            LossPi |            8.55 |
# |             LossQ |           0.382 |
# |              Time |            57.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             -14 |
# |          StdEpRet |            8.61 |
# |          MaxEpRet |           -1.32 |
# |          MinEpRet |           -33.3 |
# |  AverageTestEpRet |           -12.3 |
# |      StdTestEpRet |            7.43 |
# |      MaxTestEpRet |          -0.579 |
# |      MinTestEpRet |           -26.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |      AverageQVals |           -8.39 |
# |          StdQVals |            5.45 |
# |          MaxQVals |           0.363 |
# |          MinQVals |           -27.2 |
# |            LossPi |            7.96 |
# |             LossQ |           0.367 |
# |              Time |              62 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -15.8 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |           -3.41 |
# |          MinEpRet |           -50.8 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            7.45 |
# |      MaxTestEpRet |            -1.7 |
# |      MinTestEpRet |           -27.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |      AverageQVals |           -7.65 |
# |          StdQVals |             5.8 |
# |          MaxQVals |           0.547 |
# |          MinQVals |           -28.6 |
# |            LossPi |            7.23 |
# |             LossQ |           0.359 |
# |              Time |            66.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -20.3 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |           -6.68 |
# |          MinEpRet |           -48.8 |
# |  AverageTestEpRet |           -14.8 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |           -3.62 |
# |      MinTestEpRet |           -37.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |      AverageQVals |           -6.93 |
# |          StdQVals |            6.04 |
# |          MaxQVals |           0.684 |
# |          MinQVals |           -30.8 |
# |            LossPi |            6.52 |
# |             LossQ |           0.361 |
# |              Time |            71.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -12.8 |
# |          StdEpRet |            7.86 |
# |          MaxEpRet |           -1.36 |
# |          MinEpRet |             -25 |
# |  AverageTestEpRet |           -17.1 |
# |      StdTestEpRet |            13.5 |
# |      MaxTestEpRet |           -7.43 |
# |      MinTestEpRet |           -49.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |      AverageQVals |           -6.32 |
# |          StdQVals |            6.11 |
# |          MaxQVals |           0.811 |
# |          MinQVals |           -31.5 |
# |            LossPi |            5.94 |
# |             LossQ |           0.353 |
# |              Time |            76.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -16.9 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |           -2.36 |
# |          MinEpRet |           -56.7 |
# |  AverageTestEpRet |           -12.6 |
# |      StdTestEpRet |            8.88 |
# |      MaxTestEpRet |          -0.537 |
# |      MinTestEpRet |           -31.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |      AverageQVals |           -5.93 |
# |          StdQVals |            6.04 |
# |          MaxQVals |           0.784 |
# |          MinQVals |           -32.6 |
# |            LossPi |            5.57 |
# |             LossQ |           0.337 |
# |              Time |              81 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           -11.9 |
# |          StdEpRet |            7.35 |
# |          MaxEpRet |           -3.29 |
# |          MinEpRet |             -30 |
# |  AverageTestEpRet |           -14.4 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |           -4.26 |
# |      MinTestEpRet |           -40.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |      AverageQVals |           -5.36 |
# |          StdQVals |            5.84 |
# |          MaxQVals |           0.905 |
# |          MinQVals |           -33.1 |
# |            LossPi |            5.02 |
# |             LossQ |           0.301 |
# |              Time |            85.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           -16.5 |
# |          StdEpRet |            11.1 |
# |          MaxEpRet |           -3.22 |
# |          MinEpRet |           -45.7 |
# |  AverageTestEpRet |           -11.7 |
# |      StdTestEpRet |            7.99 |
# |      MaxTestEpRet |           -2.12 |
# |      MinTestEpRet |             -30 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |      AverageQVals |           -4.87 |
# |          StdQVals |            5.61 |
# |          MaxQVals |           0.805 |
# |          MinQVals |           -32.6 |
# |            LossPi |            4.54 |
# |             LossQ |           0.289 |
# |              Time |            90.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -12.8 |
# |          StdEpRet |            10.1 |
# |          MaxEpRet |           -1.49 |
# |          MinEpRet |           -36.9 |
# |  AverageTestEpRet |           -16.7 |
# |      StdTestEpRet |            9.22 |
# |      MaxTestEpRet |           -2.81 |
# |      MinTestEpRet |           -33.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |      AverageQVals |           -4.47 |
# |          StdQVals |            5.32 |
# |          MaxQVals |            0.79 |
# |          MinQVals |             -31 |
# |            LossPi |            4.16 |
# |             LossQ |           0.282 |
# |              Time |            95.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           -16.1 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |           -4.86 |
# |          MinEpRet |           -47.6 |
# |  AverageTestEpRet |           -8.83 |
# |      StdTestEpRet |            3.67 |
# |      MaxTestEpRet |            -2.9 |
# |      MinTestEpRet |           -15.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |      AverageQVals |           -4.11 |
# |          StdQVals |            5.01 |
# |          MaxQVals |           0.738 |
# |          MinQVals |             -29 |
# |            LossPi |            3.81 |
# |             LossQ |           0.267 |
# |              Time |             100 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -12.3 |
# |          StdEpRet |            6.46 |
# |          MaxEpRet |           -3.56 |
# |          MinEpRet |           -28.5 |
# |  AverageTestEpRet |           -12.6 |
# |      StdTestEpRet |            6.17 |
# |      MaxTestEpRet |           -4.24 |
# |      MinTestEpRet |             -23 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |           -3.75 |
# |          StdQVals |             4.7 |
# |          MaxQVals |            0.66 |
# |          MinQVals |           -26.9 |
# |            LossPi |            3.47 |
# |             LossQ |           0.263 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -11.4 |
# |          StdEpRet |            5.12 |
# |          MaxEpRet |           -6.01 |
# |          MinEpRet |           -26.6 |
# |  AverageTestEpRet |           -11.7 |
# |      StdTestEpRet |            7.47 |
# |      MaxTestEpRet |           -2.75 |
# |      MinTestEpRet |           -24.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |      AverageQVals |           -3.42 |
# |          StdQVals |             4.4 |
# |          MaxQVals |           0.562 |
# |          MinQVals |           -26.4 |
# |            LossPi |            3.15 |
# |             LossQ |           0.245 |
# |              Time |             110 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -14.9 |
# |          StdEpRet |            8.94 |
# |          MaxEpRet |           -1.35 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |             -14 |
# |      StdTestEpRet |            12.6 |
# |      MaxTestEpRet |           -3.54 |
# |      MinTestEpRet |           -42.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |      AverageQVals |           -3.13 |
# |          StdQVals |             4.1 |
# |          MaxQVals |           0.435 |
# |          MinQVals |           -24.9 |
# |            LossPi |            2.86 |
# |             LossQ |           0.228 |
# |              Time |             115 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             -12 |
# |          StdEpRet |            5.84 |
# |          MaxEpRet |           -2.83 |
# |          MinEpRet |           -26.7 |
# |  AverageTestEpRet |           -12.4 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -3.2 |
# |      MinTestEpRet |           -36.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |      AverageQVals |           -2.92 |
# |          StdQVals |             3.8 |
# |          MaxQVals |           0.294 |
# |          MinQVals |           -24.6 |
# |            LossPi |            2.67 |
# |             LossQ |           0.222 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -8.33 |
# |          StdEpRet |            4.85 |
# |          MaxEpRet |          -0.819 |
# |          MinEpRet |           -18.1 |
# |  AverageTestEpRet |           -6.05 |
# |      StdTestEpRet |            3.68 |
# |      MaxTestEpRet |           -1.06 |
# |      MinTestEpRet |           -14.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |      AverageQVals |           -2.72 |
# |          StdQVals |            3.51 |
# |          MaxQVals |           0.161 |
# |          MinQVals |           -23.8 |
# |            LossPi |            2.47 |
# |             LossQ |            0.21 |
# |              Time |             124 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |           -12.1 |
# |          StdEpRet |            8.83 |
# |          MaxEpRet |           -3.24 |
# |          MinEpRet |           -37.1 |
# |  AverageTestEpRet |             -16 |
# |      StdTestEpRet |             9.7 |
# |      MaxTestEpRet |           -4.84 |
# |      MinTestEpRet |           -34.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |      AverageQVals |           -2.59 |
# |          StdQVals |            3.33 |
# |          MaxQVals |          0.0208 |
# |          MinQVals |           -23.2 |
# |            LossPi |            2.36 |
# |             LossQ |           0.201 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -11.5 |
# |          StdEpRet |             6.3 |
# |          MaxEpRet |           -2.36 |
# |          MinEpRet |           -24.4 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            5.81 |
# |      MaxTestEpRet |           -2.85 |
# |      MinTestEpRet |           -21.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |      AverageQVals |           -2.47 |
# |          StdQVals |            3.11 |
# |          MaxQVals |           -0.14 |
# |          MinQVals |           -23.3 |
# |            LossPi |            2.24 |
# |             LossQ |           0.192 |
# |              Time |             134 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -14.1 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |           -2.48 |
# |          MinEpRet |           -34.5 |
# |  AverageTestEpRet |           -14.3 |
# |      StdTestEpRet |            10.3 |
# |      MaxTestEpRet |           -5.26 |
# |      MinTestEpRet |           -39.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |      AverageQVals |            -2.4 |
# |          StdQVals |            2.91 |
# |          MaxQVals |           0.145 |
# |          MinQVals |           -21.4 |
# |            LossPi |            2.19 |
# |             LossQ |           0.181 |
# |              Time |             138 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           -13.5 |
# |          StdEpRet |            10.4 |
# |          MaxEpRet |           -2.15 |
# |          MinEpRet |           -38.2 |
# |  AverageTestEpRet |           -8.15 |
# |      StdTestEpRet |            5.36 |
# |      MaxTestEpRet |           -1.47 |
# |      MinTestEpRet |           -20.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |      AverageQVals |           -2.43 |
# |          StdQVals |            2.76 |
# |          MaxQVals |           0.856 |
# |          MinQVals |           -20.9 |
# |            LossPi |            2.24 |
# |             LossQ |           0.167 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |           -8.32 |
# |          StdEpRet |            5.14 |
# |          MaxEpRet |           -1.26 |
# |          MinEpRet |           -19.3 |
# |  AverageTestEpRet |           -14.1 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |           -2.34 |
# |      MinTestEpRet |           -46.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |      AverageQVals |           -2.49 |
# |          StdQVals |            2.63 |
# |          MaxQVals |            0.68 |
# |          MinQVals |           -19.7 |
# |            LossPi |             2.3 |
# |             LossQ |            0.16 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -15.7 |
# |          StdEpRet |            7.15 |
# |          MaxEpRet |           -4.37 |
# |          MinEpRet |           -30.3 |
# |  AverageTestEpRet |            -7.9 |
# |      StdTestEpRet |            3.44 |
# |      MaxTestEpRet |           -2.48 |
# |      MinTestEpRet |           -12.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |            -2.6 |
# |          StdQVals |            2.52 |
# |          MaxQVals |            2.63 |
# |          MinQVals |           -19.1 |
# |            LossPi |            2.41 |
# |             LossQ |           0.154 |
# |              Time |             153 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -9.62 |
# |          StdEpRet |            8.12 |
# |          MaxEpRet |            -2.1 |
# |          MinEpRet |           -30.5 |
# |  AverageTestEpRet |           -9.71 |
# |      StdTestEpRet |            7.83 |
# |      MaxTestEpRet |           -1.71 |
# |      MinTestEpRet |           -26.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -2.72 |
# |          StdQVals |            2.45 |
# |          MaxQVals |           0.465 |
# |          MinQVals |           -19.1 |
# |            LossPi |            2.54 |
# |             LossQ |           0.148 |
# |              Time |             158 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |           -8.95 |
# |          StdEpRet |            4.57 |
# |          MaxEpRet |          -0.788 |
# |          MinEpRet |           -19.2 |
# |  AverageTestEpRet |              -7 |
# |      StdTestEpRet |            4.42 |
# |      MaxTestEpRet |           -2.78 |
# |      MinTestEpRet |           -16.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -2.83 |
# |          StdQVals |            2.41 |
# |          MaxQVals |          -0.825 |
# |          MinQVals |           -17.9 |
# |            LossPi |            2.66 |
# |             LossQ |           0.146 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |           -10.9 |
# |          StdEpRet |            8.25 |
# |          MaxEpRet |           -1.22 |
# |          MinEpRet |           -28.1 |
# |  AverageTestEpRet |           -12.5 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -2.3 |
# |      MinTestEpRet |           -40.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -2.94 |
# |          StdQVals |            2.33 |
# |          MaxQVals |            -1.2 |
# |          MinQVals |           -17.6 |
# |            LossPi |            2.77 |
# |             LossQ |           0.142 |
# |              Time |             168 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -10.4 |
# |          StdEpRet |             6.7 |
# |          MaxEpRet |           -2.47 |
# |          MinEpRet |           -25.6 |
# |  AverageTestEpRet |           -7.61 |
# |      StdTestEpRet |            5.08 |
# |      MaxTestEpRet |          -0.701 |
# |      MinTestEpRet |           -15.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -3.06 |
# |          StdQVals |            2.26 |
# |          MaxQVals |           -1.09 |
# |          MinQVals |           -18.5 |
# |            LossPi |             2.9 |
# |             LossQ |           0.141 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             -15 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |           -3.18 |
# |          MinEpRet |           -46.9 |
# |  AverageTestEpRet |           -9.87 |
# |      StdTestEpRet |            6.37 |
# |      MaxTestEpRet |           -3.03 |
# |      MinTestEpRet |           -23.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |           -3.21 |
# |          StdQVals |            2.23 |
# |          MaxQVals |           -1.69 |
# |          MinQVals |           -19.9 |
# |            LossPi |            3.05 |
# |             LossQ |           0.135 |
# |              Time |             178 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             -13 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |           -2.92 |
# |          MinEpRet |           -38.5 |
# |  AverageTestEpRet |           -17.8 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |           -6.98 |
# |      MinTestEpRet |           -43.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |            -3.4 |
# |          StdQVals |             2.2 |
# |          MaxQVals |           -1.48 |
# |          MinQVals |             -19 |
# |            LossPi |            3.25 |
# |             LossQ |           0.132 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -7.2 |
# |          StdEpRet |             5.5 |
# |          MaxEpRet |           -1.22 |
# |          MinEpRet |           -20.5 |
# |  AverageTestEpRet |           -16.3 |
# |      StdTestEpRet |            7.65 |
# |      MaxTestEpRet |           -2.83 |
# |      MinTestEpRet |           -27.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -3.57 |
# |          StdQVals |            2.16 |
# |          MaxQVals |           -2.01 |
# |          MinQVals |           -20.3 |
# |            LossPi |            3.42 |
# |             LossQ |           0.123 |
# |              Time |             187 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -12.4 |
# |          StdEpRet |            7.25 |
# |          MaxEpRet |           -2.05 |
# |          MinEpRet |           -29.2 |
# |  AverageTestEpRet |           -10.8 |
# |      StdTestEpRet |            8.35 |
# |      MaxTestEpRet |           -2.13 |
# |      MinTestEpRet |           -33.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -3.74 |
# |          StdQVals |            2.12 |
# |          MaxQVals |           -2.52 |
# |          MinQVals |           -20.7 |
# |            LossPi |             3.6 |
# |             LossQ |           0.118 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |           -15.3 |
# |          StdEpRet |            9.33 |
# |          MaxEpRet |           -1.71 |
# |          MinEpRet |           -36.5 |
# |  AverageTestEpRet |           -12.2 |
# |      StdTestEpRet |            5.17 |
# |      MaxTestEpRet |           -5.87 |
# |      MinTestEpRet |           -23.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -3.93 |
# |          StdQVals |            2.09 |
# |          MaxQVals |           -2.73 |
# |          MinQVals |           -23.7 |
# |            LossPi |            3.79 |
# |             LossQ |           0.115 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |           -7.09 |
# |          StdEpRet |            3.93 |
# |          MaxEpRet |           -1.24 |
# |          MinEpRet |             -14 |
# |  AverageTestEpRet |           -6.95 |
# |      StdTestEpRet |            4.68 |
# |      MaxTestEpRet |          -0.434 |
# |      MinTestEpRet |           -14.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |            -4.1 |
# |          StdQVals |            2.07 |
# |          MaxQVals |           -2.87 |
# |          MinQVals |           -21.7 |
# |            LossPi |            3.97 |
# |             LossQ |           0.115 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -9.6 |
# |          StdEpRet |             6.1 |
# |          MaxEpRet |           -2.17 |
# |          MinEpRet |             -24 |
# |  AverageTestEpRet |           -12.9 |
# |      StdTestEpRet |            6.78 |
# |      MaxTestEpRet |           -4.37 |
# |      MinTestEpRet |           -27.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -4.29 |
# |          StdQVals |            2.09 |
# |          MaxQVals |           -3.08 |
# |          MinQVals |           -21.9 |
# |            LossPi |            4.16 |
# |             LossQ |           0.114 |
# |              Time |             207 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -9.6 |
# |          StdEpRet |             8.6 |
# |          MaxEpRet |          -0.728 |
# |          MinEpRet |           -34.1 |
# |  AverageTestEpRet |           -6.13 |
# |      StdTestEpRet |            5.89 |
# |      MaxTestEpRet |           -0.27 |
# |      MinTestEpRet |           -16.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -4.47 |
# |          StdQVals |            2.06 |
# |          MaxQVals |            -3.2 |
# |          MinQVals |           -19.5 |
# |            LossPi |            4.33 |
# |             LossQ |           0.114 |
# |              Time |             212 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           -11.7 |
# |          StdEpRet |            4.81 |
# |          MaxEpRet |           -3.53 |
# |          MinEpRet |           -17.9 |
# |  AverageTestEpRet |           -12.7 |
# |      StdTestEpRet |            6.64 |
# |      MaxTestEpRet |           -7.04 |
# |      MinTestEpRet |           -27.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |           -4.63 |
# |          StdQVals |            2.04 |
# |          MaxQVals |           -3.52 |
# |          MinQVals |           -18.7 |
# |            LossPi |             4.5 |
# |             LossQ |            0.11 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -10.8 |
# |          StdEpRet |            7.67 |
# |          MaxEpRet |           -1.75 |
# |          MinEpRet |           -28.6 |
# |  AverageTestEpRet |           -10.4 |
# |      StdTestEpRet |            9.73 |
# |      MaxTestEpRet |           -1.14 |
# |      MinTestEpRet |           -34.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |           -4.79 |
# |          StdQVals |            2.02 |
# |          MaxQVals |           -3.34 |
# |          MinQVals |           -19.1 |
# |            LossPi |            4.66 |
# |             LossQ |           0.109 |
# |              Time |             222 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -9.36 |
# |          StdEpRet |             5.4 |
# |          MaxEpRet |           -1.85 |
# |          MinEpRet |           -17.6 |
# |  AverageTestEpRet |            -8.1 |
# |      StdTestEpRet |            5.42 |
# |      MaxTestEpRet |           -2.16 |
# |      MinTestEpRet |           -20.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -4.95 |
# |          StdQVals |            2.01 |
# |          MaxQVals |           -2.45 |
# |          MinQVals |           -20.6 |
# |            LossPi |            4.83 |
# |             LossQ |           0.106 |
# |              Time |             227 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |           -7.72 |
# |          StdEpRet |            5.33 |
# |          MaxEpRet |          -0.859 |
# |          MinEpRet |           -16.8 |
# |  AverageTestEpRet |           -12.7 |
# |      StdTestEpRet |            5.18 |
# |      MaxTestEpRet |              -5 |
# |      MinTestEpRet |           -22.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -5.11 |
# |          StdQVals |            1.97 |
# |          MaxQVals |           -1.61 |
# |          MinQVals |           -20.9 |
# |            LossPi |            4.99 |
# |             LossQ |           0.104 |
# |              Time |             232 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             -14 |
# |          StdEpRet |            10.4 |
# |          MaxEpRet |            -1.6 |
# |          MinEpRet |           -40.5 |
# |  AverageTestEpRet |           -9.51 |
# |      StdTestEpRet |             6.4 |
# |      MaxTestEpRet |           -2.17 |
# |      MinTestEpRet |           -21.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |           -5.29 |
# |          StdQVals |            1.97 |
# |          MaxQVals |           -2.06 |
# |          MinQVals |           -21.5 |
# |            LossPi |            5.17 |
# |             LossQ |           0.103 |
# |              Time |             237 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           -11.6 |
# |          StdEpRet |            6.56 |
# |          MaxEpRet |           -2.67 |
# |          MinEpRet |           -25.3 |
# |  AverageTestEpRet |           -13.5 |
# |      StdTestEpRet |            9.31 |
# |      MaxTestEpRet |           -2.46 |
# |      MinTestEpRet |           -27.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |           -5.46 |
# |          StdQVals |            1.95 |
# |          MaxQVals |          -0.787 |
# |          MinQVals |           -23.7 |
# |            LossPi |            5.34 |
# |             LossQ |          0.0988 |
# |              Time |             242 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |           -13.7 |
# |          StdEpRet |            9.08 |
# |          MaxEpRet |           -1.39 |
# |          MinEpRet |           -30.1 |
# |  AverageTestEpRet |           -9.78 |
# |      StdTestEpRet |            5.53 |
# |      MaxTestEpRet |           -2.69 |
# |      MinTestEpRet |             -23 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.65e+04 |
# |      AverageQVals |           -5.62 |
# |          StdQVals |            1.93 |
# |          MaxQVals |           -1.24 |
# |          MinQVals |           -21.3 |
# |            LossPi |             5.5 |
# |             LossQ |          0.0976 |
# |              Time |             247 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |           -9.49 |
# |          StdEpRet |            6.65 |
# |          MaxEpRet |           -2.15 |
# |          MinEpRet |           -23.3 |
# |  AverageTestEpRet |           -13.7 |
# |      StdTestEpRet |            10.9 |
# |      MaxTestEpRet |           -2.57 |
# |      MinTestEpRet |           -38.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.8e+04 |
# |      AverageQVals |           -5.77 |
# |          StdQVals |            1.92 |
# |          MaxQVals |           -4.41 |
# |          MinQVals |           -20.5 |
# |            LossPi |            5.66 |
# |             LossQ |           0.101 |
# |              Time |             252 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |             -17 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |          -0.941 |
# |          MinEpRet |           -47.4 |
# |  AverageTestEpRet |           -6.38 |
# |      StdTestEpRet |            3.45 |
# |      MaxTestEpRet |           -2.71 |
# |      MinTestEpRet |           -11.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.95e+04 |
# |      AverageQVals |           -5.95 |
# |          StdQVals |            1.93 |
# |          MaxQVals |           -4.24 |
# |          MinQVals |           -20.1 |
# |            LossPi |            5.84 |
# |             LossQ |           0.101 |
# |              Time |             257 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |           -11.7 |
# |          StdEpRet |            7.93 |
# |          MaxEpRet |           -1.81 |
# |          MinEpRet |           -34.7 |
# |  AverageTestEpRet |           -7.88 |
# |      StdTestEpRet |             4.6 |
# |      MaxTestEpRet |           -1.49 |
# |      MinTestEpRet |           -15.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         8.1e+04 |
# |      AverageQVals |           -6.11 |
# |          StdQVals |            1.93 |
# |          MaxQVals |           -3.95 |
# |          MinQVals |           -20.5 |
# |            LossPi |               6 |
# |             LossQ |           0.101 |
# |              Time |             262 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |           -10.9 |
# |          StdEpRet |            9.16 |
# |          MaxEpRet |           -2.34 |
# |          MinEpRet |           -28.5 |
# |  AverageTestEpRet |           -8.91 |
# |      StdTestEpRet |            3.89 |
# |      MaxTestEpRet |            -2.3 |
# |      MinTestEpRet |             -16 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |           -6.26 |
# |          StdQVals |            1.92 |
# |          MaxQVals |            -4.3 |
# |          MinQVals |           -20.8 |
# |            LossPi |            6.14 |
# |             LossQ |          0.0991 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |           -12.2 |
# |          StdEpRet |            6.87 |
# |          MaxEpRet |           -1.89 |
# |          MinEpRet |             -23 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             482 |
# |      AverageEpRet |            -7.7 |
# |          StdEpRet |            4.43 |
# |          MaxEpRet |            -1.3 |
# |          MinEpRet |           -17.5 |
# |  AverageTestEpRet |           -8.11 |
# |      StdTestEpRet |            4.65 |
# |      MaxTestEpRet |           -1.12 |
# |      MinTestEpRet |             -15 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.23e+05 |
# |      AverageQVals |            10.9 |
# |          StdQVals |            2.47 |
# |          MaxQVals |            18.6 |
# |          MinQVals |           -9.67 |
# |            LossPi |             -11 |
# |             LossQ |          0.0786 |
# |              Time |        2.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             483 |
# |      AverageEpRet |           -9.42 |
# |          StdEpRet |            7.79 |
# |          MaxEpRet |           -1.32 |
# |          MinEpRet |           -31.4 |
# |  AverageTestEpRet |           -7.92 |
# |      StdTestEpRet |            4.43 |
# |      MaxTestEpRet |           -1.52 |
# |      MinTestEpRet |           -13.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.24e+05 |
# |      AverageQVals |            10.9 |
# |          StdQVals |            2.47 |
# |          MaxQVals |            18.8 |
# |          MinQVals |           -10.6 |
# |            LossPi |             -11 |
# |             LossQ |          0.0792 |
# |              Time |        2.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             484 |
# |      AverageEpRet |           -7.83 |
# |          StdEpRet |            4.67 |
# |          MaxEpRet |           -1.04 |
# |          MinEpRet |           -17.7 |
# |  AverageTestEpRet |           -8.44 |
# |      StdTestEpRet |            3.75 |
# |      MaxTestEpRet |           -1.54 |
# |      MinTestEpRet |           -15.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.26e+05 |
# |      AverageQVals |            10.8 |
# |          StdQVals |            2.47 |
# |          MaxQVals |            18.8 |
# |          MinQVals |           -10.6 |
# |            LossPi |           -10.9 |
# |             LossQ |          0.0787 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             485 |
# |      AverageEpRet |            -6.7 |
# |          StdEpRet |             4.2 |
# |          MaxEpRet |          -0.545 |
# |          MinEpRet |           -17.4 |
# |  AverageTestEpRet |           -4.86 |
# |      StdTestEpRet |            2.65 |
# |      MaxTestEpRet |           -1.17 |
# |      MinTestEpRet |           -11.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.27e+05 |
# |      AverageQVals |            10.7 |
# |          StdQVals |            2.48 |
# |          MaxQVals |            18.4 |
# |          MinQVals |           -10.5 |
# |            LossPi |           -10.8 |
# |             LossQ |          0.0778 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             486 |
# |      AverageEpRet |           -9.79 |
# |          StdEpRet |             3.7 |
# |          MaxEpRet |           -2.94 |
# |          MinEpRet |           -14.1 |
# |  AverageTestEpRet |           -5.07 |
# |      StdTestEpRet |            2.25 |
# |      MaxTestEpRet |           -1.86 |
# |      MinTestEpRet |           -10.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.29e+05 |
# |      AverageQVals |            10.6 |
# |          StdQVals |            2.47 |
# |          MaxQVals |            18.5 |
# |          MinQVals |           -11.1 |
# |            LossPi |           -10.7 |
# |             LossQ |           0.074 |
# |              Time |        2.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             487 |
# |      AverageEpRet |            -9.2 |
# |          StdEpRet |            4.27 |
# |          MaxEpRet |           -1.69 |
# |          MinEpRet |           -17.4 |
# |  AverageTestEpRet |           -6.45 |
# |      StdTestEpRet |            3.28 |
# |      MaxTestEpRet |           -1.99 |
# |      MinTestEpRet |             -12 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.3e+05 |
# |      AverageQVals |            10.5 |
# |          StdQVals |            2.45 |
# |          MaxQVals |            18.3 |
# |          MinQVals |           -11.1 |
# |            LossPi |           -10.6 |
# |             LossQ |          0.0702 |
# |              Time |        2.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             488 |
# |      AverageEpRet |           -8.98 |
# |          StdEpRet |            5.92 |
# |          MaxEpRet |           -2.24 |
# |          MinEpRet |           -26.6 |
# |  AverageTestEpRet |           -6.25 |
# |      StdTestEpRet |            3.74 |
# |      MaxTestEpRet |           -0.18 |
# |      MinTestEpRet |           -11.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.32e+05 |
# |      AverageQVals |            10.4 |
# |          StdQVals |            2.43 |
# |          MaxQVals |              18 |
# |          MinQVals |           -13.1 |
# |            LossPi |           -10.5 |
# |             LossQ |          0.0735 |
# |              Time |        2.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             489 |
# |      AverageEpRet |           -6.29 |
# |          StdEpRet |            4.29 |
# |          MaxEpRet |          -0.394 |
# |          MinEpRet |           -16.8 |
# |  AverageTestEpRet |           -4.07 |
# |      StdTestEpRet |            1.95 |
# |      MaxTestEpRet |           -1.94 |
# |      MinTestEpRet |           -8.83 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.33e+05 |
# |      AverageQVals |            10.4 |
# |          StdQVals |            2.42 |
# |          MaxQVals |            17.9 |
# |          MinQVals |           -11.7 |
# |            LossPi |           -10.5 |
# |             LossQ |           0.071 |
# |              Time |        2.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             490 |
# |      AverageEpRet |           -7.37 |
# |          StdEpRet |            6.78 |
# |          MaxEpRet |           -1.29 |
# |          MinEpRet |             -31 |
# |  AverageTestEpRet |           -8.94 |
# |      StdTestEpRet |            5.51 |
# |      MaxTestEpRet |          -0.696 |
# |      MinTestEpRet |           -19.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+05 |
# |      AverageQVals |            10.3 |
# |          StdQVals |            2.43 |
# |          MaxQVals |            18.2 |
# |          MinQVals |           -12.1 |
# |            LossPi |           -10.4 |
# |             LossQ |           0.074 |
# |              Time |        2.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             491 |
# |      AverageEpRet |            -6.4 |
# |          StdEpRet |            3.79 |
# |          MaxEpRet |           -1.32 |
# |          MinEpRet |           -14.8 |
# |  AverageTestEpRet |            -7.2 |
# |      StdTestEpRet |             3.9 |
# |      MaxTestEpRet |           -1.69 |
# |      MinTestEpRet |           -12.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.36e+05 |
# |      AverageQVals |            10.2 |
# |          StdQVals |            2.46 |
# |          MaxQVals |            18.1 |
# |          MinQVals |           -13.5 |
# |            LossPi |           -10.3 |
# |             LossQ |           0.079 |
# |              Time |        2.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             492 |
# |      AverageEpRet |           -8.18 |
# |          StdEpRet |            6.42 |
# |          MaxEpRet |           -1.48 |
# |          MinEpRet |           -27.1 |
# |  AverageTestEpRet |           -6.51 |
# |      StdTestEpRet |            4.93 |
# |      MaxTestEpRet |           -2.29 |
# |      MinTestEpRet |           -19.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.38e+05 |
# |      AverageQVals |            10.2 |
# |          StdQVals |            2.46 |
# |          MaxQVals |              18 |
# |          MinQVals |           -14.2 |
# |            LossPi |           -10.2 |
# |             LossQ |          0.0768 |
# |              Time |        2.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             493 |
# |      AverageEpRet |           -5.02 |
# |          StdEpRet |            3.11 |
# |          MaxEpRet |          -0.751 |
# |          MinEpRet |           -10.6 |
# |  AverageTestEpRet |           -5.85 |
# |      StdTestEpRet |            3.54 |
# |      MaxTestEpRet |           -1.15 |
# |      MinTestEpRet |             -11 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.39e+05 |
# |      AverageQVals |            10.1 |
# |          StdQVals |            2.47 |
# |          MaxQVals |            17.8 |
# |          MinQVals |           -13.6 |
# |            LossPi |           -10.2 |
# |             LossQ |          0.0732 |
# |              Time |        2.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             494 |
# |      AverageEpRet |           -6.89 |
# |          StdEpRet |             4.7 |
# |          MaxEpRet |           -2.43 |
# |          MinEpRet |           -19.6 |
# |  AverageTestEpRet |           -6.12 |
# |      StdTestEpRet |            4.41 |
# |      MaxTestEpRet |           -1.89 |
# |      MinTestEpRet |             -18 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.41e+05 |
# |      AverageQVals |              10 |
# |          StdQVals |            2.49 |
# |          MaxQVals |            17.7 |
# |          MinQVals |           -10.8 |
# |            LossPi |           -10.1 |
# |             LossQ |          0.0791 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             495 |
# |      AverageEpRet |           -5.92 |
# |          StdEpRet |            3.86 |
# |          MaxEpRet |           -0.65 |
# |          MinEpRet |           -15.9 |
# |  AverageTestEpRet |           -7.03 |
# |      StdTestEpRet |            2.87 |
# |      MaxTestEpRet |           -3.33 |
# |      MinTestEpRet |           -13.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.42e+05 |
# |      AverageQVals |            9.98 |
# |          StdQVals |            2.52 |
# |          MaxQVals |            17.9 |
# |          MinQVals |           -10.8 |
# |            LossPi |           -10.1 |
# |             LossQ |          0.0757 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             496 |
# |      AverageEpRet |           -8.66 |
# |          StdEpRet |            4.44 |
# |          MaxEpRet |            -1.8 |
# |          MinEpRet |           -15.6 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            10.9 |
# |      MaxTestEpRet |          -0.804 |
# |      MinTestEpRet |           -40.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.44e+05 |
# |      AverageQVals |            9.93 |
# |          StdQVals |            2.53 |
# |          MaxQVals |            18.3 |
# |          MinQVals |             -13 |
# |            LossPi |             -10 |
# |             LossQ |          0.0741 |
# |              Time |         2.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             497 |
# |      AverageEpRet |           -8.69 |
# |          StdEpRet |            3.27 |
# |          MaxEpRet |           -4.18 |
# |          MinEpRet |           -15.8 |
# |  AverageTestEpRet |           -9.78 |
# |      StdTestEpRet |            6.16 |
# |      MaxTestEpRet |           -1.43 |
# |      MinTestEpRet |           -20.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.45e+05 |
# |      AverageQVals |            9.87 |
# |          StdQVals |            2.55 |
# |          MaxQVals |            18.1 |
# |          MinQVals |           -11.3 |
# |            LossPi |           -9.96 |
# |             LossQ |          0.0747 |
# |              Time |         2.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             498 |
# |      AverageEpRet |           -9.52 |
# |          StdEpRet |            5.85 |
# |          MaxEpRet |           -1.93 |
# |          MinEpRet |           -21.4 |
# |  AverageTestEpRet |           -5.67 |
# |      StdTestEpRet |            3.53 |
# |      MaxTestEpRet |           -1.62 |
# |      MinTestEpRet |           -14.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.47e+05 |
# |      AverageQVals |            9.78 |
# |          StdQVals |            2.56 |
# |          MaxQVals |            18.5 |
# |          MinQVals |           -9.98 |
# |            LossPi |           -9.88 |
# |             LossQ |          0.0733 |
# |              Time |        2.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             499 |
# |      AverageEpRet |           -7.57 |
# |          StdEpRet |            7.37 |
# |          MaxEpRet |          -0.822 |
# |          MinEpRet |           -30.6 |
# |  AverageTestEpRet |           -5.03 |
# |      StdTestEpRet |             2.2 |
# |      MaxTestEpRet |           -1.19 |
# |      MinTestEpRet |            -8.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.48e+05 |
# |      AverageQVals |            9.75 |
# |          StdQVals |            2.59 |
# |          MaxQVals |            18.1 |
# |          MinQVals |           -11.9 |
# |            LossPi |           -9.84 |
# |             LossQ |          0.0753 |
# |              Time |        2.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             500 |
# |      AverageEpRet |           -7.32 |
# |          StdEpRet |            4.26 |
# |          MaxEpRet |            -0.8 |
# |          MinEpRet |           -14.2 |
# |  AverageTestEpRet |           -5.32 |
# |      StdTestEpRet |             3.8 |
# |      MaxTestEpRet |          -0.594 |
# |      MinTestEpRet |           -14.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+05 |
# |      AverageQVals |            9.72 |
# |          StdQVals |            2.63 |
# |          MaxQVals |            18.4 |
# |          MinQVals |           -15.2 |
# |            LossPi |           -9.81 |
# |             LossQ |          0.0766 |
# |              Time |        2.52e+03 |
# ---------------------------------------

# %% [markdown]
# #### Absolute reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Absolute'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_a', exp_name='ddpg_a'))

# %% [markdown]
# #### Normalized reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Normalized'
reward_args = {
    'k': 1,
    'qx2': 1, 
    'qx4': 1, 
    'pu1': 0,
    'pu2': 0
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_n', exp_name='ddpg_n'))

# Following parameters are used in previous project
# startsteps_b = 20000
# pilr_b = 0.001
# qlr_b = 0.001

# %% [markdown]
# #### Quadratic reward with ending penalty

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic with ending penalty'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'sx1': 100, 
    'sx3': 100, 
    'end_horizon': 0
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_q_ep', exp_name='ddpg_q_ep'))

# %% [markdown]
# #### Quadratic reward with penalty

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic with penalty'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'bound': 0.2,
    'penalty': 10
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_q_p', exp_name='ddpg_q_p'))

# %% [markdown]
# #### Quadratic reward with exponential term

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic with exponential'
reward_args = {
    'qx1': 1,
    'qx2': 0,
    'qx3': 1,
    'qx4': 0,
    'pu1': 0,
    'pu2': 0,
    'eax1': 10,
    'ebx1': 10,
    'eax3': 10,
    'ebx3': 10
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_q_e', exp_name='ddpg_q_e'))

# %% [markdown]
# #### Quadratic reward with bonus

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic with bonus'
reward_args = {
    'qx1': 1,
    'qx2': 0,
    'qx3': 1,
    'qx4': 0,
    'pu1': 0,
    'pu2': 0,
    'bound': 0.05,
    'bonus': 2
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_q_b', exp_name='ddpg_q_b'))

# %% [markdown]
# #### Normalized reward with bonus

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Normalized with bonus'
reward_args = {
    'k': 1,
    'qx2': 1, 
    'qx4': 1, 
    'pu1': 0,
    'pu2': 0,
    'bound': 0.05, 
    'bonus': 2
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_n_b', exp_name='ddpg_n_b'))

# %% [markdown]
# #### Sparse reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Sparse'
reward_args = {
    'bx': 0.05,
    'rx': 1, 
    'bv': 0, 
    'rv': 0, 
    'bu': 0, 
    'ru': 0
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_s', exp_name='ddpg_s'))

# %% [markdown]
# #### Power function reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p005', exp_name='ddpg_p005'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.1
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p01', exp_name='ddpg_p01'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.5
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p05', exp_name='ddpg_p05'))

# %% [markdown]
# #### Exponential reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Exponential'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'e': 10
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_e10', exp_name='ddpg_e10'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Exponential'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'e': 20
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_e20', exp_name='ddpg_e20'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Exponential'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_e40', exp_name='ddpg_e40'))

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p01e40', exp_name='ddpg_p01e40'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.1,
    'e': 80
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.995, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p01e80', exp_name='ddpg_p01e80'))

# %% [markdown]
# #### further study on p = 0.05, why it doesnt learn

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 0.95, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p005_gamma095', exp_name='ddpg_p005_gamma095'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0, 
    'qx3': 1, 
    'qx4': 0, 
    'pu1': 0, 
    'pu2': 0,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 500, 
                    replay_size = 1000000, 
                    gamma = 1, 
                    polyak = 0.995, 
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100, 
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='ddpg_p005_gamma1', exp_name='ddpg_p005_gamma1'))
