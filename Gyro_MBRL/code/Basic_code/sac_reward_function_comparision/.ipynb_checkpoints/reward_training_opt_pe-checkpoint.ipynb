# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.1,
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.sac_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=2000,
                   replay_size=1000000,
                   gamma=0.95,
                   polyak=0.995,
                   lr=0.00125,
                   alpha=0.05,   # Entropy regularization coefficient. (Equivalent to inverse of reward scale in the original SAC paper.
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   num_test_episodes=10,
                   max_ep_len=100,
                   logger_kwargs=dict(output_dir='sac_pe_opt003', exp_name='sac_pe_opt003')
                   )
# Out:
# Warning: Log dir sac_pe_opt003 already exists! Storing info there anyway.
# Logging data to sac_pe_opt003/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.05,
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f7fe3b7e840>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.1, 'pu2': 0.1, 'p': 0.1, 'e': 40})",
#     "epochs":	200,
#     "exp_name":	"sac_pe_opt003",
#     "gamma":	0.95,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f7fe3b8f198>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_pe_opt003",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"sac_pe_opt003",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='sac_pe_opt003/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_pe_opt003",
#         "output_dir":	"sac_pe_opt003"
#     },
#     "lr":	0.00125,
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5540, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -491 |
# |          StdEpRet |             5.5 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |            6.75 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -7.73 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |           0.357 |
# |         MinQ1Vals |           -14.5 |
# |     AverageQ2Vals |           -7.81 |
# |         StdQ2Vals |            2.87 |
# |         MaxQ2Vals |        -0.00989 |
# |         MinQ2Vals |           -14.4 |
# |      AverageLogPi |         -0.0697 |
# |          StdLogPi |           0.937 |
# |          MaxLogPi |             2.8 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            7.68 |
# |             LossQ |            3.14 |
# |              Time |            5.48 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |            5.28 |
# |          MaxEpRet |            -477 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |            9.24 |
# |      MaxTestEpRet |            -460 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |             -25 |
# |         StdQ1Vals |            7.25 |
# |         MaxQ1Vals |           -10.8 |
# |         MinQ1Vals |           -39.8 |
# |     AverageQ2Vals |             -25 |
# |         StdQ2Vals |            7.25 |
# |         MaxQ2Vals |           -10.7 |
# |         MinQ2Vals |           -39.8 |
# |      AverageLogPi |          -0.223 |
# |          StdLogPi |           0.908 |
# |          MaxLogPi |             2.4 |
# |          MinLogPi |            -9.2 |
# |            LossPi |            24.9 |
# |             LossQ |           0.203 |
# |              Time |            16.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -492 |
# |          StdEpRet |             5.6 |
# |          MaxEpRet |            -481 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |            -449 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |             -47 |
# |         StdQ1Vals |            5.49 |
# |         MaxQ1Vals |           -34.8 |
# |         MinQ1Vals |           -60.7 |
# |     AverageQ2Vals |             -47 |
# |         StdQ2Vals |            5.49 |
# |         MaxQ2Vals |             -35 |
# |         MinQ2Vals |           -60.6 |
# |      AverageLogPi |          -0.402 |
# |          StdLogPi |           0.929 |
# |          MaxLogPi |            4.12 |
# |          MinLogPi |           -11.4 |
# |            LossPi |            46.9 |
# |             LossQ |           0.267 |
# |              Time |            27.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -490 |
# |          StdEpRet |            9.12 |
# |          MaxEpRet |            -468 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -477 |
# |      StdTestEpRet |            11.1 |
# |      MaxTestEpRet |            -461 |
# |      MinTestEpRet |            -491 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |           -62.7 |
# |         StdQ1Vals |            3.93 |
# |         MaxQ1Vals |           -53.2 |
# |         MinQ1Vals |           -76.3 |
# |     AverageQ2Vals |           -62.7 |
# |         StdQ2Vals |            3.93 |
# |         MaxQ2Vals |           -53.2 |
# |         MinQ2Vals |           -76.4 |
# |      AverageLogPi |          -0.562 |
# |          StdLogPi |           0.901 |
# |          MaxLogPi |            3.54 |
# |          MinLogPi |           -10.7 |
# |            LossPi |            62.7 |
# |             LossQ |           0.301 |
# |              Time |              38 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -489 |
# |          StdEpRet |            5.17 |
# |          MaxEpRet |            -480 |
# |          MinEpRet |            -500 |
# |  AverageTestEpRet |            -475 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |            -450 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -73.7 |
# |         StdQ1Vals |            2.85 |
# |         MaxQ1Vals |           -66.3 |
# |         MinQ1Vals |           -84.1 |
# |     AverageQ2Vals |           -73.7 |
# |         StdQ2Vals |            2.85 |
# |         MaxQ2Vals |           -66.3 |
# |         MinQ2Vals |             -84 |
# |      AverageLogPi |           -0.65 |
# |          StdLogPi |           0.875 |
# |          MaxLogPi |            3.14 |
# |          MinLogPi |           -9.34 |
# |            LossPi |            73.7 |
# |             LossQ |           0.326 |
# |              Time |            49.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -490 |
# |          StdEpRet |            5.73 |
# |          MaxEpRet |            -480 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |            -484 |
# |      StdTestEpRet |            7.86 |
# |      MaxTestEpRet |            -472 |
# |      MinTestEpRet |            -496 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |           -81.5 |
# |         StdQ1Vals |            2.17 |
# |         MaxQ1Vals |           -75.6 |
# |         MinQ1Vals |           -89.6 |
# |     AverageQ2Vals |           -81.5 |
# |         StdQ2Vals |            2.16 |
# |         MaxQ2Vals |           -75.2 |
# |         MinQ2Vals |           -89.8 |
# |      AverageLogPi |          -0.729 |
# |          StdLogPi |           0.844 |
# |          MaxLogPi |            3.33 |
# |          MinLogPi |           -9.04 |
# |            LossPi |            81.5 |
# |             LossQ |            0.33 |
# |              Time |            60.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |            6.93 |
# |          MaxEpRet |            -475 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -481 |
# |      StdTestEpRet |            7.71 |
# |      MaxTestEpRet |            -472 |
# |      MinTestEpRet |            -495 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -86.8 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |           -81.5 |
# |         MinQ1Vals |           -93.6 |
# |     AverageQ2Vals |           -86.8 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |           -81.7 |
# |         MinQ2Vals |           -93.8 |
# |      AverageLogPi |          -0.789 |
# |          StdLogPi |           0.831 |
# |          MaxLogPi |            3.32 |
# |          MinLogPi |             -10 |
# |            LossPi |            86.8 |
# |             LossQ |           0.329 |
# |              Time |              74 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |            9.14 |
# |          MaxEpRet |            -466 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -469 |
# |      StdTestEpRet |            18.6 |
# |      MaxTestEpRet |            -426 |
# |      MinTestEpRet |            -497 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -90.4 |
# |         StdQ1Vals |            1.33 |
# |         MaxQ1Vals |           -85.7 |
# |         MinQ1Vals |           -96.4 |
# |     AverageQ2Vals |           -90.4 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |             -86 |
# |         MinQ2Vals |           -96.3 |
# |      AverageLogPi |           -0.81 |
# |          StdLogPi |            0.84 |
# |          MaxLogPi |            3.48 |
# |          MinLogPi |           -11.4 |
# |            LossPi |            90.4 |
# |             LossQ |           0.331 |
# |              Time |            86.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -482 |
# |          StdEpRet |            9.77 |
# |          MaxEpRet |            -461 |
# |          MinEpRet |            -497 |
# |  AverageTestEpRet |            -467 |
# |      StdTestEpRet |            20.8 |
# |      MaxTestEpRet |            -412 |
# |      MinTestEpRet |            -490 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -92.8 |
# |         StdQ1Vals |             1.2 |
# |         MaxQ1Vals |           -88.8 |
# |         MinQ1Vals |           -98.7 |
# |     AverageQ2Vals |           -92.8 |
# |         StdQ2Vals |            1.19 |
# |         MaxQ2Vals |           -89.1 |
# |         MinQ2Vals |           -98.4 |
# |      AverageLogPi |           -0.84 |
# |          StdLogPi |           0.835 |
# |          MaxLogPi |            4.24 |
# |          MinLogPi |            -8.6 |
# |            LossPi |            92.8 |
# |             LossQ |           0.338 |
# |              Time |            97.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            8.16 |
# |          MaxEpRet |            -467 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |            -454 |
# |      StdTestEpRet |            27.6 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |            1.15 |
# |         MaxQ1Vals |           -90.8 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |            1.14 |
# |         MaxQ2Vals |           -90.8 |
# |         MinQ2Vals |            -100 |
# |      AverageLogPi |          -0.839 |
# |          StdLogPi |           0.845 |
# |          MaxLogPi |            4.51 |
# |          MinLogPi |           -7.66 |
# |            LossPi |            94.5 |
# |             LossQ |           0.344 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -440 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -462 |
# |      StdTestEpRet |            20.8 |
# |      MaxTestEpRet |            -416 |
# |      MinTestEpRet |            -488 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -95.6 |
# |         StdQ1Vals |            1.15 |
# |         MaxQ1Vals |           -91.7 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |           -95.6 |
# |         StdQ2Vals |            1.13 |
# |         MaxQ2Vals |           -91.8 |
# |         MinQ2Vals |            -101 |
# |      AverageLogPi |          -0.814 |
# |          StdLogPi |           0.871 |
# |          MaxLogPi |               4 |
# |          MinLogPi |           -10.8 |
# |            LossPi |            95.6 |
# |             LossQ |           0.359 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -473 |
# |          StdEpRet |            16.2 |
# |          MaxEpRet |            -440 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -456 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |            -407 |
# |      MinTestEpRet |            -492 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -96.3 |
# |         StdQ1Vals |            1.23 |
# |         MaxQ1Vals |           -92.3 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -96.3 |
# |         StdQ2Vals |            1.21 |
# |         MaxQ2Vals |           -92.3 |
# |         MinQ2Vals |            -102 |
# |      AverageLogPi |           -0.76 |
# |          StdLogPi |           0.924 |
# |          MaxLogPi |            4.73 |
# |          MinLogPi |           -8.96 |
# |            LossPi |            96.3 |
# |             LossQ |           0.371 |
# |              Time |             130 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -477 |
# |          StdEpRet |            10.9 |
# |          MaxEpRet |            -452 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -463 |
# |      StdTestEpRet |            24.9 |
# |      MaxTestEpRet |            -411 |
# |      MinTestEpRet |            -493 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -96.7 |
# |         StdQ1Vals |            1.35 |
# |         MaxQ1Vals |           -92.2 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |           -96.7 |
# |         StdQ2Vals |            1.33 |
# |         MaxQ2Vals |           -92.2 |
# |         MinQ2Vals |            -102 |
# |      AverageLogPi |          -0.665 |
# |          StdLogPi |           0.984 |
# |          MaxLogPi |            4.82 |
# |          MinLogPi |           -10.2 |
# |            LossPi |            96.7 |
# |             LossQ |           0.395 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -462 |
# |          StdEpRet |            20.2 |
# |          MaxEpRet |            -425 |
# |          MinEpRet |            -492 |
# |  AverageTestEpRet |            -451 |
# |      StdTestEpRet |            26.9 |
# |      MaxTestEpRet |            -410 |
# |      MinTestEpRet |            -494 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -96.8 |
# |         StdQ1Vals |            1.46 |
# |         MaxQ1Vals |             -92 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -96.8 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |           -92.1 |
# |         MinQ2Vals |            -103 |
# |      AverageLogPi |          -0.583 |
# |          StdLogPi |            1.05 |
# |          MaxLogPi |            5.32 |
# |          MinLogPi |           -9.91 |
# |            LossPi |            96.8 |
# |             LossQ |           0.416 |
# |              Time |             156 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -462 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |            -422 |
# |          MinEpRet |            -495 |
# |  AverageTestEpRet |            -429 |
# |      StdTestEpRet |            30.4 |
# |      MaxTestEpRet |            -345 |
# |      MinTestEpRet |            -462 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -96.8 |
# |         StdQ1Vals |            1.58 |
# |         MaxQ1Vals |           -91.9 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |           -96.8 |
# |         StdQ2Vals |            1.56 |
# |         MaxQ2Vals |           -91.8 |
# |         MinQ2Vals |            -103 |
# |      AverageLogPi |          -0.494 |
# |          StdLogPi |             1.1 |
# |          MaxLogPi |            5.69 |
# |          MinLogPi |           -7.68 |
# |            LossPi |            96.8 |
# |             LossQ |           0.444 |
# |              Time |             167 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |            -419 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -442 |
# |      StdTestEpRet |            36.6 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -96.6 |
# |         StdQ1Vals |            1.74 |
# |         MaxQ1Vals |           -91.5 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |           -96.6 |
# |         StdQ2Vals |            1.72 |
# |         MaxQ2Vals |           -91.3 |
# |         MinQ2Vals |            -104 |
# |      AverageLogPi |          -0.415 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            6.18 |
# |          MinLogPi |           -9.18 |
# |            LossPi |            96.6 |
# |             LossQ |           0.479 |
# |              Time |             178 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -456 |
# |          StdEpRet |            22.9 |
# |          MaxEpRet |            -404 |
# |          MinEpRet |            -499 |
# |  AverageTestEpRet |            -436 |
# |      StdTestEpRet |            24.6 |
# |      MaxTestEpRet |            -403 |
# |      MinTestEpRet |            -482 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -96.3 |
# |         StdQ1Vals |            1.93 |
# |         MaxQ1Vals |           -90.5 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -96.3 |
# |         StdQ2Vals |            1.92 |
# |         MaxQ2Vals |           -90.6 |
# |         MinQ2Vals |            -105 |
# |      AverageLogPi |          -0.353 |
# |          StdLogPi |            1.18 |
# |          MaxLogPi |            6.15 |
# |          MinLogPi |           -9.36 |
# |            LossPi |            96.3 |
# |             LossQ |           0.509 |
# |              Time |             190 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -450 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |            -381 |
# |          MinEpRet |            -484 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            45.4 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |             -96 |
# |         StdQ1Vals |            2.12 |
# |         MaxQ1Vals |           -89.5 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |             -96 |
# |         StdQ2Vals |            2.11 |
# |         MaxQ2Vals |           -89.8 |
# |         MinQ2Vals |            -105 |
# |      AverageLogPi |          -0.258 |
# |          StdLogPi |            1.23 |
# |          MaxLogPi |            5.88 |
# |          MinLogPi |            -8.4 |
# |            LossPi |              96 |
# |             LossQ |           0.549 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -449 |
# |          StdEpRet |            30.8 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -489 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |            39.1 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -95.7 |
# |         StdQ1Vals |             2.3 |
# |         MaxQ1Vals |           -88.7 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |           -95.7 |
# |         StdQ2Vals |            2.29 |
# |         MaxQ2Vals |           -88.5 |
# |         MinQ2Vals |            -106 |
# |      AverageLogPi |          -0.184 |
# |          StdLogPi |            1.27 |
# |          MaxLogPi |            6.82 |
# |          MinLogPi |           -8.29 |
# |            LossPi |            95.7 |
# |             LossQ |           0.598 |
# |              Time |             210 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-feaca5b9e508> in <module>
#      36                    num_test_episodes=10,
#      37                    max_ep_len=100,
# ---> 38                    logger_kwargs=dict(output_dir='sac_pe_opt003', exp_name='sac_pe_opt003')
#      39                    )
#
# ~/spinningup/spinup/algos/pytorch/sac/sac.py in sac(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, lr, alpha, batch_size, start_steps, update_after, update_every, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     320             for j in range(update_every):
#     321                 batch = replay_buffer.sample_batch(batch_size)
# --> 322                 update(data=batch)
#     323
#     324         # End of epoch handling
#
# ~/spinningup/spinup/algos/pytorch/sac/sac.py in update(data)
#     231         # First run one gradient descent step for Q1 and Q2
#     232         q_optimizer.zero_grad()
# --> 233         loss_q, q_info = compute_loss_q(data)
#     234         loss_q.backward()
#     235         q_optimizer.step()
#
# ~/spinningup/spinup/algos/pytorch/sac/sac.py in compute_loss_q(data)
#     180         o, a, r, o2, d = data['obs'], data['act'], data['rew'], data['obs2'], data['done']
#     181
# --> 182         q1 = ac.q1(o,a)
#     183         q2 = ac.q2(o,a)
#     184
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/spinningup/spinup/algos/pytorch/sac/core.py in forward(self, obs, act)
#      75
#      76     def forward(self, obs, act):
# ---> 77         q = self.q(torch.cat([obs, act], dim=-1))
#      78         return torch.squeeze(q, -1) # Critical to ensure q has right shape.
#      79
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# KeyboardInterrupt:
