# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %% [markdown]
# #### Quadratic reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Quadratic'
reward_args = {
    'qx1': 1,
    'qx2': 0.2,
    'qx3': 1,
    'qx4': 0.2,
    'pu1': 0.2,
    'pu2': 0.2
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.sac_pytorch(env_fn_,
                   ac_kwargs= dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                   seed=0,
                   steps_per_epoch=1500,
                   epochs=500,
                   replay_size=1000000,
                   gamma=0.995,
                   polyak=0.995,
                   lr=0.00125,
                   alpha=0.1,   # Entropy regularization coefficient. (Equivalent to inverse of reward scale in the original SAC paper.
                   batch_size=100,
                   start_steps=10000,
                   update_after=1000,
                   update_every=50,
                   num_test_episodes=10,
                   max_ep_len=100,
                   logger_kwargs=dict(output_dir='sac_q_opt_001', exp_name='sac_q_opt_001')
                   )
# Out:
# Logging data to sac_q_opt_001/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.1,
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f143751d8c8>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='Quadratic', reward_args={'qx1': 1, 'qx2': 0.2, 'qx3': 1, 'qx4': 0.2, 'pu1': 0.2, 'pu2': 0.2})",
#     "epochs":	500,
#     "exp_name":	"sac_q_opt_001",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f1437530940>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_q_opt_001",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"sac_q_opt_001",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='sac_q_opt_001/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_q_opt_001",
#         "output_dir":	"sac_q_opt_001"
#     },
#     "lr":	0.00125,
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5540, 	 q1: 5697, 	 q2: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -112 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |           -68.8 |
# |          MinEpRet |            -153 |
# |  AverageTestEpRet |           -77.7 |
# |      StdTestEpRet |            33.3 |
# |      MaxTestEpRet |           -39.8 |
# |      MinTestEpRet |            -135 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |     AverageQ1Vals |           -2.04 |
# |         StdQ1Vals |           0.913 |
# |         MaxQ1Vals |           0.353 |
# |         MinQ1Vals |           -8.33 |
# |     AverageQ2Vals |           -2.07 |
# |         StdQ2Vals |           0.882 |
# |         MaxQ2Vals |          -0.045 |
# |         MinQ2Vals |           -8.44 |
# |      AverageLogPi |          -0.947 |
# |          StdLogPi |           0.706 |
# |          MaxLogPi |            2.82 |
# |          MinLogPi |           -9.46 |
# |            LossPi |            1.92 |
# |             LossQ |           0.369 |
# |              Time |            6.21 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |           -78.1 |
# |          MinEpRet |            -186 |
# |  AverageTestEpRet |           -58.7 |
# |      StdTestEpRet |              28 |
# |      MaxTestEpRet |           -16.3 |
# |      MinTestEpRet |            -103 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |     AverageQ1Vals |           -6.33 |
# |         StdQ1Vals |            2.86 |
# |         MaxQ1Vals |          -0.632 |
# |         MinQ1Vals |           -23.1 |
# |     AverageQ2Vals |           -6.33 |
# |         StdQ2Vals |            2.87 |
# |         MaxQ2Vals |          -0.663 |
# |         MinQ2Vals |           -23.6 |
# |      AverageLogPi |          -0.221 |
# |          StdLogPi |            1.16 |
# |          MaxLogPi |            5.68 |
# |          MinLogPi |           -10.3 |
# |            LossPi |            6.03 |
# |             LossQ |           0.383 |
# |              Time |            17.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -132 |
# |          StdEpRet |            45.2 |
# |          MaxEpRet |           -85.9 |
# |          MinEpRet |            -283 |
# |  AverageTestEpRet |           -39.8 |
# |      StdTestEpRet |            8.83 |
# |      MaxTestEpRet |           -22.7 |
# |      MinTestEpRet |           -52.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |     AverageQ1Vals |           -12.2 |
# |         StdQ1Vals |            4.04 |
# |         MaxQ1Vals |            -2.1 |
# |         MinQ1Vals |           -39.3 |
# |     AverageQ2Vals |           -12.2 |
# |         StdQ2Vals |            4.05 |
# |         MaxQ2Vals |           -1.99 |
# |         MinQ2Vals |           -40.3 |
# |      AverageLogPi |           0.426 |
# |          StdLogPi |            1.45 |
# |          MaxLogPi |            7.38 |
# |          MinLogPi |           -9.57 |
# |            LossPi |            11.6 |
# |             LossQ |           0.741 |
# |              Time |            28.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -125 |
# |          StdEpRet |            36.4 |
# |          MaxEpRet |           -79.7 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |           -47.6 |
# |      StdTestEpRet |            36.1 |
# |      MaxTestEpRet |           -1.42 |
# |      MinTestEpRet |            -112 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |     AverageQ1Vals |             -17 |
# |         StdQ1Vals |            4.77 |
# |         MaxQ1Vals |           -3.43 |
# |         MinQ1Vals |           -49.5 |
# |     AverageQ2Vals |             -17 |
# |         StdQ2Vals |            4.79 |
# |         MaxQ2Vals |           -4.08 |
# |         MinQ2Vals |           -49.1 |
# |      AverageLogPi |           0.593 |
# |          StdLogPi |            1.53 |
# |          MaxLogPi |            6.91 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            16.4 |
# |             LossQ |            1.15 |
# |              Time |            41.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -181 |
# |          StdEpRet |             109 |
# |          MaxEpRet |           -63.5 |
# |          MinEpRet |            -436 |
# |  AverageTestEpRet |           -34.1 |
# |      StdTestEpRet |            13.4 |
# |      MaxTestEpRet |           -11.3 |
# |      MinTestEpRet |           -53.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |     AverageQ1Vals |           -21.5 |
# |         StdQ1Vals |             6.1 |
# |         MaxQ1Vals |            -5.6 |
# |         MinQ1Vals |           -72.1 |
# |     AverageQ2Vals |           -21.5 |
# |         StdQ2Vals |            6.12 |
# |         MaxQ2Vals |           -5.73 |
# |         MinQ2Vals |           -71.1 |
# |      AverageLogPi |            0.76 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |            10.4 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            20.9 |
# |             LossQ |            1.88 |
# |              Time |            53.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -166 |
# |          StdEpRet |            93.5 |
# |          MaxEpRet |           -50.7 |
# |          MinEpRet |            -399 |
# |  AverageTestEpRet |           -31.5 |
# |      StdTestEpRet |            13.6 |
# |      MaxTestEpRet |            -8.6 |
# |      MinTestEpRet |             -54 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |     AverageQ1Vals |             -26 |
# |         StdQ1Vals |            8.41 |
# |         MaxQ1Vals |           -7.25 |
# |         MinQ1Vals |           -89.2 |
# |     AverageQ2Vals |             -26 |
# |         StdQ2Vals |            8.42 |
# |         MaxQ2Vals |           -7.91 |
# |         MinQ2Vals |             -88 |
# |      AverageLogPi |            1.07 |
# |          StdLogPi |            1.79 |
# |          MaxLogPi |            11.1 |
# |          MinLogPi |             -11 |
# |            LossPi |            25.2 |
# |             LossQ |             2.8 |
# |              Time |            65.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -116 |
# |          StdEpRet |              54 |
# |          MaxEpRet |           -25.9 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |           -28.2 |
# |      StdTestEpRet |            13.2 |
# |      MaxTestEpRet |           -6.96 |
# |      MinTestEpRet |             -54 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |     AverageQ1Vals |           -29.4 |
# |         StdQ1Vals |            9.17 |
# |         MaxQ1Vals |           -8.74 |
# |         MinQ1Vals |           -96.6 |
# |     AverageQ2Vals |           -29.4 |
# |         StdQ2Vals |            9.17 |
# |         MaxQ2Vals |           -9.22 |
# |         MinQ2Vals |           -96.4 |
# |      AverageLogPi |            1.18 |
# |          StdLogPi |            1.84 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -9.87 |
# |            LossPi |            28.5 |
# |             LossQ |            3.06 |
# |              Time |            77.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -49.4 |
# |          StdEpRet |              19 |
# |          MaxEpRet |           -13.5 |
# |          MinEpRet |           -88.1 |
# |  AverageTestEpRet |           -36.5 |
# |      StdTestEpRet |            22.6 |
# |      MaxTestEpRet |           -8.46 |
# |      MinTestEpRet |           -69.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -31.6 |
# |         StdQ1Vals |            9.51 |
# |         MaxQ1Vals |           -10.4 |
# |         MinQ1Vals |            -100 |
# |     AverageQ2Vals |           -31.6 |
# |         StdQ2Vals |            9.51 |
# |         MaxQ2Vals |           -10.9 |
# |         MinQ2Vals |            -101 |
# |      AverageLogPi |            1.07 |
# |          StdLogPi |            1.85 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -10.7 |
# |            LossPi |            30.9 |
# |             LossQ |            2.96 |
# |              Time |            89.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             -44 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |             -15 |
# |          MinEpRet |           -81.6 |
# |  AverageTestEpRet |             -29 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |           -5.32 |
# |      MinTestEpRet |           -64.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |     AverageQ1Vals |           -34.1 |
# |         StdQ1Vals |            9.56 |
# |         MaxQ1Vals |           -12.5 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |           -34.1 |
# |         StdQ2Vals |            9.57 |
# |         MaxQ2Vals |           -12.8 |
# |         MinQ2Vals |            -107 |
# |      AverageLogPi |           0.888 |
# |          StdLogPi |             1.8 |
# |          MaxLogPi |            10.4 |
# |          MinLogPi |           -9.51 |
# |            LossPi |            33.4 |
# |             LossQ |             2.7 |
# |              Time |             101 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -36.6 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |             -13 |
# |          MinEpRet |           -56.8 |
# |  AverageTestEpRet |           -33.5 |
# |      StdTestEpRet |            19.1 |
# |      MaxTestEpRet |           -3.99 |
# |      MinTestEpRet |           -63.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |     AverageQ1Vals |           -36.3 |
# |         StdQ1Vals |            9.92 |
# |         MaxQ1Vals |           -14.2 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |           -36.3 |
# |         StdQ2Vals |            9.93 |
# |         MaxQ2Vals |           -13.8 |
# |         MinQ2Vals |            -110 |
# |      AverageLogPi |           0.785 |
# |          StdLogPi |            1.77 |
# |          MaxLogPi |            9.86 |
# |          MinLogPi |            -9.5 |
# |            LossPi |            35.7 |
# |             LossQ |            2.44 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -38.5 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |           -11.9 |
# |          MinEpRet |            -104 |
# |  AverageTestEpRet |             -27 |
# |      StdTestEpRet |            16.9 |
# |      MaxTestEpRet |           -7.47 |
# |      MinTestEpRet |           -56.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -38.4 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |           -14.4 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -38.4 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |           -14.2 |
# |         MinQ2Vals |            -112 |
# |      AverageLogPi |           0.719 |
# |          StdLogPi |            1.76 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -9.31 |
# |            LossPi |              38 |
# |             LossQ |            2.32 |
# |              Time |             126 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -22.9 |
# |          StdEpRet |            7.59 |
# |          MaxEpRet |           -12.8 |
# |          MinEpRet |           -39.9 |
# |  AverageTestEpRet |           -35.3 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |           -8.01 |
# |      MinTestEpRet |             -57 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |     AverageQ1Vals |           -40.3 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |           -15.1 |
# |         MinQ1Vals |            -113 |
# |     AverageQ2Vals |           -40.3 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |           -15.3 |
# |         MinQ2Vals |            -113 |
# |      AverageLogPi |           0.687 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            10.8 |
# |          MinLogPi |           -11.1 |
# |            LossPi |            39.8 |
# |             LossQ |             2.3 |
# |              Time |             140 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -29.1 |
# |          StdEpRet |              15 |
# |          MaxEpRet |           -13.2 |
# |          MinEpRet |           -65.4 |
# |  AverageTestEpRet |           -15.7 |
# |      StdTestEpRet |            10.5 |
# |      MaxTestEpRet |           -4.82 |
# |      MinTestEpRet |           -37.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |     AverageQ1Vals |           -41.9 |
# |         StdQ1Vals |            11.2 |
# |         MaxQ1Vals |           -16.2 |
# |         MinQ1Vals |            -117 |
# |     AverageQ2Vals |           -41.9 |
# |         StdQ2Vals |            11.2 |
# |         MaxQ2Vals |           -16.3 |
# |         MinQ2Vals |            -115 |
# |      AverageLogPi |           0.648 |
# |          StdLogPi |            1.74 |
# |          MaxLogPi |            9.41 |
# |          MinLogPi |           -9.42 |
# |            LossPi |            41.5 |
# |             LossQ |            2.31 |
# |              Time |             152 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -22.2 |
# |          StdEpRet |              11 |
# |          MaxEpRet |           -10.7 |
# |          MinEpRet |           -48.6 |
# |  AverageTestEpRet |           -13.4 |
# |      StdTestEpRet |            8.43 |
# |      MaxTestEpRet |           -4.17 |
# |      MinTestEpRet |           -31.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |     AverageQ1Vals |           -43.5 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |           -16.7 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |           -43.5 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |           -16.6 |
# |         MinQ2Vals |            -120 |
# |      AverageLogPi |           0.638 |
# |          StdLogPi |            1.74 |
# |          MaxLogPi |            9.98 |
# |          MinLogPi |           -10.9 |
# |            LossPi |            43.1 |
# |             LossQ |            2.32 |
# |              Time |             167 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -24.9 |
# |          StdEpRet |            7.88 |
# |          MaxEpRet |           -14.3 |
# |          MinEpRet |           -40.3 |
# |  AverageTestEpRet |             -15 |
# |      StdTestEpRet |            7.62 |
# |      MaxTestEpRet |           -4.96 |
# |      MinTestEpRet |           -32.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |     AverageQ1Vals |           -44.6 |
# |         StdQ1Vals |            12.4 |
# |         MaxQ1Vals |           -15.6 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |           -44.6 |
# |         StdQ2Vals |            12.4 |
# |         MaxQ2Vals |             -15 |
# |         MinQ2Vals |            -121 |
# |      AverageLogPi |           0.653 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            10.6 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            44.2 |
# |             LossQ |            2.33 |
# |              Time |             182 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -26.1 |
# |          StdEpRet |            12.1 |
# |          MaxEpRet |              -9 |
# |          MinEpRet |           -48.5 |
# |  AverageTestEpRet |           -15.8 |
# |      StdTestEpRet |            13.4 |
# |      MaxTestEpRet |           -2.24 |
# |      MinTestEpRet |           -40.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |           -45.5 |
# |         StdQ1Vals |              13 |
# |         MaxQ1Vals |           -13.3 |
# |         MinQ1Vals |            -126 |
# |     AverageQ2Vals |           -45.5 |
# |         StdQ2Vals |              13 |
# |         MaxQ2Vals |           -12.8 |
# |         MinQ2Vals |            -125 |
# |      AverageLogPi |           0.649 |
# |          StdLogPi |            1.76 |
# |          MaxLogPi |            11.7 |
# |          MinLogPi |           -11.3 |
# |            LossPi |            45.2 |
# |             LossQ |            2.37 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -29.4 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |           -13.6 |
# |          MinEpRet |           -64.2 |
# |  AverageTestEpRet |           -10.9 |
# |      StdTestEpRet |            7.49 |
# |      MaxTestEpRet |           -1.65 |
# |      MinTestEpRet |           -23.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |           -46.2 |
# |         StdQ1Vals |            13.5 |
# |         MaxQ1Vals |           -13.1 |
# |         MinQ1Vals |            -129 |
# |     AverageQ2Vals |           -46.2 |
# |         StdQ2Vals |            13.5 |
# |         MaxQ2Vals |           -13.6 |
# |         MinQ2Vals |            -128 |
# |      AverageLogPi |           0.651 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            10.6 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            45.8 |
# |             LossQ |            2.37 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           -26.7 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |           -13.4 |
# |          MinEpRet |           -58.9 |
# |  AverageTestEpRet |           -21.6 |
# |      StdTestEpRet |            18.5 |
# |      MaxTestEpRet |           -4.31 |
# |      MinTestEpRet |           -63.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |     AverageQ1Vals |           -46.8 |
# |         StdQ1Vals |            13.8 |
# |         MaxQ1Vals |           -14.4 |
# |         MinQ1Vals |            -130 |
# |     AverageQ2Vals |           -46.8 |
# |         StdQ2Vals |            13.8 |
# |         MaxQ2Vals |           -13.8 |
# |         MinQ2Vals |            -130 |
# |      AverageLogPi |           0.653 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -9.24 |
# |            LossPi |            46.4 |
# |             LossQ |             2.4 |
# |              Time |             218 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           -26.5 |
# |          StdEpRet |              14 |
# |          MaxEpRet |           -15.7 |
# |          MinEpRet |           -62.7 |
# |  AverageTestEpRet |           -13.4 |
# |      StdTestEpRet |             4.8 |
# |      MaxTestEpRet |           -5.05 |
# |      MinTestEpRet |           -21.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |     AverageQ1Vals |           -47.1 |
# |         StdQ1Vals |            14.3 |
# |         MaxQ1Vals |             -15 |
# |         MinQ1Vals |            -131 |
# |     AverageQ2Vals |           -47.1 |
# |         StdQ2Vals |            14.3 |
# |         MaxQ2Vals |           -15.3 |
# |         MinQ2Vals |            -130 |
# |      AverageLogPi |           0.651 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -9.57 |
# |            LossPi |            46.8 |
# |             LossQ |            2.43 |
# |              Time |             231 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -25.7 |
# |          StdEpRet |            8.15 |
# |          MaxEpRet |           -16.5 |
# |          MinEpRet |           -46.9 |
# |  AverageTestEpRet |           -15.2 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |           -3.58 |
# |      MinTestEpRet |           -40.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |     AverageQ1Vals |           -47.5 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |           -16.2 |
# |         MinQ1Vals |            -131 |
# |     AverageQ2Vals |           -47.5 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |           -15.7 |
# |         MinQ2Vals |            -130 |
# |      AverageLogPi |           0.627 |
# |          StdLogPi |            1.75 |
# |          MaxLogPi |            11.5 |
# |          MinLogPi |           -11.7 |
# |            LossPi |            47.2 |
# |             LossQ |            2.42 |
# |              Time |             244 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             -22 |
# |          StdEpRet |            10.5 |
# |          MaxEpRet |           -12.5 |
# |          MinEpRet |           -47.8 |
# |  AverageTestEpRet |           -21.2 |
# |      StdTestEpRet |            10.7 |
# |      MaxTestEpRet |           -4.91 |
# |      MinTestEpRet |           -34.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |     AverageQ1Vals |           -47.8 |
# |         StdQ1Vals |            14.7 |
# |         MaxQ1Vals |           -16.3 |
# |         MinQ1Vals |            -134 |
# |     AverageQ2Vals |           -47.8 |
# |         StdQ2Vals |            14.7 |
# |         MaxQ2Vals |           -16.2 |
# |         MinQ2Vals |            -132 |
# |      AverageLogPi |           0.615 |
# |          StdLogPi |            1.76 |
# |          MaxLogPi |              11 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            47.5 |
# |             LossQ |            2.41 |
# |              Time |             256 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -21.1 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |           -10.2 |
# |          MinEpRet |           -50.1 |
# |  AverageTestEpRet |           -12.4 |
# |      StdTestEpRet |            5.14 |
# |      MaxTestEpRet |            -6.1 |
# |      MinTestEpRet |           -24.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -47.9 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |           -15.7 |
# |         MinQ1Vals |            -136 |
# |     AverageQ2Vals |           -47.9 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |           -15.6 |
# |         MinQ2Vals |            -134 |
# |      AverageLogPi |           0.588 |
# |          StdLogPi |            1.74 |
# |          MaxLogPi |            11.5 |
# |          MinLogPi |           -9.62 |
# |            LossPi |            47.6 |
# |             LossQ |            2.37 |
# |              Time |             269 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -20.6 |
# |          StdEpRet |            5.11 |
# |          MaxEpRet |           -11.6 |
# |          MinEpRet |             -29 |
# |  AverageTestEpRet |           -11.3 |
# |      StdTestEpRet |            5.92 |
# |      MaxTestEpRet |           -4.17 |
# |      MinTestEpRet |           -24.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |     AverageQ1Vals |           -47.9 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |           -16.8 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -47.9 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |           -16.3 |
# |         MinQ2Vals |            -133 |
# |      AverageLogPi |           0.562 |
# |          StdLogPi |            1.73 |
# |          MaxLogPi |            11.2 |
# |          MinLogPi |             -12 |
# |            LossPi |            47.7 |
# |             LossQ |            2.34 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             -22 |
# |          StdEpRet |            6.39 |
# |          MaxEpRet |           -12.9 |
# |          MinEpRet |           -34.1 |
# |  AverageTestEpRet |           -11.6 |
# |      StdTestEpRet |            5.36 |
# |      MaxTestEpRet |           -3.06 |
# |      MinTestEpRet |             -21 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |           -48.1 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |           -16.4 |
# |         MinQ1Vals |            -134 |
# |     AverageQ2Vals |           -48.1 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |           -17.4 |
# |         MinQ2Vals |            -135 |
# |      AverageLogPi |           0.536 |
# |          StdLogPi |            1.73 |
# |          MaxLogPi |            11.1 |
# |          MinLogPi |           -10.7 |
# |            LossPi |            47.9 |
# |             LossQ |            2.29 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |           -18.8 |
# |          StdEpRet |            4.95 |
# |          MaxEpRet |           -10.5 |
# |          MinEpRet |           -28.6 |
# |  AverageTestEpRet |           -15.9 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |           -7.09 |
# |      MinTestEpRet |             -49 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |     AverageQ1Vals |           -48.2 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |           -18.6 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -48.2 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |           -18.5 |
# |         MinQ2Vals |            -136 |
# |      AverageLogPi |           0.527 |
# |          StdLogPi |            1.72 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -11.5 |
# |            LossPi |              48 |
# |             LossQ |            2.23 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -22.1 |
# |          StdEpRet |            10.6 |
# |          MaxEpRet |           -9.74 |
# |          MinEpRet |           -51.5 |
# |  AverageTestEpRet |           -8.27 |
# |      StdTestEpRet |            5.17 |
# |      MaxTestEpRet |            -4.3 |
# |      MinTestEpRet |           -21.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |             -20 |
# |         MinQ1Vals |            -136 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |           -19.2 |
# |         MinQ2Vals |            -137 |
# |      AverageLogPi |           0.502 |
# |          StdLogPi |             1.7 |
# |          MaxLogPi |            11.9 |
# |          MinLogPi |             -10 |
# |            LossPi |            48.1 |
# |             LossQ |            2.17 |
# |              Time |             315 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             -20 |
# |          StdEpRet |            6.79 |
# |          MaxEpRet |           -9.47 |
# |          MinEpRet |           -34.9 |
# |  AverageTestEpRet |           -10.7 |
# |      StdTestEpRet |            4.25 |
# |      MaxTestEpRet |           -6.19 |
# |      MinTestEpRet |             -21 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |     AverageQ1Vals |           -48.4 |
# |         StdQ1Vals |              15 |
# |         MaxQ1Vals |           -20.3 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.4 |
# |         StdQ2Vals |              15 |
# |         MaxQ2Vals |           -20.3 |
# |         MinQ2Vals |            -136 |
# |      AverageLogPi |           0.486 |
# |          StdLogPi |            1.71 |
# |          MaxLogPi |            10.8 |
# |          MinLogPi |           -10.2 |
# |            LossPi |            48.2 |
# |             LossQ |            2.13 |
# |              Time |             329 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -24.8 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |             -10 |
# |          MinEpRet |           -52.3 |
# |  AverageTestEpRet |           -14.7 |
# |      StdTestEpRet |            9.45 |
# |      MaxTestEpRet |            -5.5 |
# |      MinTestEpRet |             -37 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |           -20.7 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |           -21.5 |
# |         MinQ2Vals |            -136 |
# |      AverageLogPi |           0.466 |
# |          StdLogPi |            1.69 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -9.82 |
# |            LossPi |            48.1 |
# |             LossQ |            2.06 |
# |              Time |             345 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -18.4 |
# |          StdEpRet |            5.64 |
# |          MaxEpRet |           -8.23 |
# |          MinEpRet |           -28.7 |
# |  AverageTestEpRet |           -13.5 |
# |      StdTestEpRet |            8.24 |
# |      MaxTestEpRet |          -0.699 |
# |      MinTestEpRet |           -30.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |           -21.4 |
# |         MinQ1Vals |            -135 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |             -22 |
# |         MinQ2Vals |            -135 |
# |      AverageLogPi |           0.452 |
# |          StdLogPi |            1.69 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -9.86 |
# |            LossPi |            48.1 |
# |             LossQ |            2.06 |
# |              Time |             358 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           -23.3 |
# |          StdEpRet |            8.26 |
# |          MaxEpRet |           -13.6 |
# |          MinEpRet |           -41.3 |
# |  AverageTestEpRet |           -16.6 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |           -2.03 |
# |      MinTestEpRet |           -59.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |     AverageQ1Vals |           -48.2 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |             -22 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.2 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |           -22.6 |
# |         MinQ2Vals |            -138 |
# |      AverageLogPi |           0.436 |
# |          StdLogPi |            1.68 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            48.1 |
# |             LossQ |            2.02 |
# |              Time |             369 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |           -24.3 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |           -11.7 |
# |          MinEpRet |           -49.6 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            4.19 |
# |      MaxTestEpRet |           -5.25 |
# |      MinTestEpRet |           -19.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |     AverageQ1Vals |           -48.2 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |           -22.4 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.2 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |           -22.6 |
# |         MinQ2Vals |            -138 |
# |      AverageLogPi |           0.401 |
# |          StdLogPi |            1.66 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -10.5 |
# |            LossPi |              48 |
# |             LossQ |            1.95 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -18.3 |
# |          StdEpRet |            7.96 |
# |          MaxEpRet |           -10.2 |
# |          MinEpRet |           -37.9 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            7.87 |
# |      MaxTestEpRet |           -1.69 |
# |      MinTestEpRet |           -33.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |           -22.9 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |           -23.3 |
# |         MinQ2Vals |            -138 |
# |      AverageLogPi |           0.376 |
# |          StdLogPi |            1.67 |
# |          MaxLogPi |            10.8 |
# |          MinLogPi |           -9.27 |
# |            LossPi |            48.2 |
# |             LossQ |            1.94 |
# |              Time |             393 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -24.3 |
# |          StdEpRet |            8.17 |
# |          MaxEpRet |           -11.7 |
# |          MinEpRet |           -38.5 |
# |  AverageTestEpRet |           -16.1 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |           -3.51 |
# |      MinTestEpRet |           -48.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -48.4 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |           -23.3 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -48.4 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |             -24 |
# |         MinQ2Vals |            -137 |
# |      AverageLogPi |           0.361 |
# |          StdLogPi |            1.65 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            48.3 |
# |             LossQ |            1.89 |
# |              Time |             406 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |           -19.8 |
# |          StdEpRet |            6.21 |
# |          MaxEpRet |           -9.66 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |           -13.5 |
# |      StdTestEpRet |            5.75 |
# |      MaxTestEpRet |           -4.49 |
# |      MinTestEpRet |           -20.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |     AverageQ1Vals |           -48.5 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |             -24 |
# |         MinQ1Vals |            -141 |
# |     AverageQ2Vals |           -48.5 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |           -24.5 |
# |         MinQ2Vals |            -138 |
# |      AverageLogPi |           0.354 |
# |          StdLogPi |            1.64 |
# |          MaxLogPi |            10.4 |
# |          MinLogPi |            -9.7 |
# |            LossPi |            48.4 |
# |             LossQ |            1.82 |
# |              Time |             417 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             -27 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |           -14.2 |
# |          MinEpRet |           -68.2 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |            9.61 |
# |      MaxTestEpRet |          -0.803 |
# |      MinTestEpRet |           -29.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |     AverageQ1Vals |           -48.6 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |           -24.3 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -48.6 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |             -25 |
# |         MinQ2Vals |            -139 |
# |      AverageLogPi |           0.333 |
# |          StdLogPi |            1.63 |
# |          MaxLogPi |              11 |
# |          MinLogPi |           -9.97 |
# |            LossPi |            48.5 |
# |             LossQ |            1.83 |
# |              Time |             430 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -19.4 |
# |          StdEpRet |            6.37 |
# |          MaxEpRet |           -10.4 |
# |          MinEpRet |           -37.1 |
# |  AverageTestEpRet |           -10.1 |
# |      StdTestEpRet |            8.04 |
# |      MaxTestEpRet |           -3.52 |
# |      MinTestEpRet |             -30 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |     AverageQ1Vals |           -48.6 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |           -24.8 |
# |         MinQ1Vals |            -140 |
# |     AverageQ2Vals |           -48.6 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |           -25.5 |
# |         MinQ2Vals |            -140 |
# |      AverageLogPi |           0.323 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            48.5 |
# |             LossQ |            1.79 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |           -19.1 |
# |          StdEpRet |            4.43 |
# |          MaxEpRet |           -12.5 |
# |          MinEpRet |           -27.3 |
# |  AverageTestEpRet |           -11.8 |
# |      StdTestEpRet |            5.21 |
# |      MaxTestEpRet |           -6.92 |
# |      MinTestEpRet |           -21.6 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |     AverageQ1Vals |           -48.6 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |             -25 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.6 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |           -25.8 |
# |         MinQ2Vals |            -137 |
# |      AverageLogPi |           0.313 |
# |          StdLogPi |            1.63 |
# |          MaxLogPi |            10.4 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            48.5 |
# |             LossQ |            1.77 |
# |              Time |             454 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |           -19.5 |
# |          StdEpRet |            5.43 |
# |          MaxEpRet |             -12 |
# |          MinEpRet |           -32.1 |
# |  AverageTestEpRet |           -10.2 |
# |      StdTestEpRet |            5.38 |
# |      MaxTestEpRet |           -2.37 |
# |      MinTestEpRet |           -18.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |     AverageQ1Vals |           -48.5 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |           -25.5 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |           -48.5 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |           -26.1 |
# |         MinQ2Vals |            -135 |
# |      AverageLogPi |           0.313 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |            10.2 |
# |          MinLogPi |           -10.8 |
# |            LossPi |            48.4 |
# |             LossQ |            1.71 |
# |              Time |             466 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -18.2 |
# |          StdEpRet |            4.56 |
# |          MaxEpRet |           -12.4 |
# |          MinEpRet |           -25.6 |
# |  AverageTestEpRet |           -14.1 |
# |      StdTestEpRet |            8.79 |
# |      MaxTestEpRet |           -3.52 |
# |      MinTestEpRet |             -34 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |           -25.5 |
# |         MinQ1Vals |            -140 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |           -26.1 |
# |         MinQ2Vals |            -138 |
# |      AverageLogPi |           0.299 |
# |          StdLogPi |            1.61 |
# |          MaxLogPi |            10.6 |
# |          MinLogPi |           -9.16 |
# |            LossPi |            48.2 |
# |             LossQ |            1.69 |
# |              Time |             478 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -19.1 |
# |          StdEpRet |            7.34 |
# |          MaxEpRet |           -9.43 |
# |          MinEpRet |             -36 |
# |  AverageTestEpRet |           -11.6 |
# |      StdTestEpRet |            8.12 |
# |      MaxTestEpRet |           -1.81 |
# |      MinTestEpRet |           -28.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |           -48.1 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |           -25.6 |
# |         MinQ1Vals |            -138 |
# |     AverageQ2Vals |           -48.1 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |           -26.4 |
# |         MinQ2Vals |            -137 |
# |      AverageLogPi |           0.302 |
# |          StdLogPi |            1.61 |
# |          MaxLogPi |            10.9 |
# |          MinLogPi |           -9.95 |
# |            LossPi |              48 |
# |             LossQ |            1.71 |
# |              Time |             491 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# ...
# |  AverageTestEpRet |           -8.64 |
# |      StdTestEpRet |            4.87 |
# |      MaxTestEpRet |          -0.393 |
# |      MinTestEpRet |           -16.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.3e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.95 |
# |         MaxQ1Vals |           -13.4 |
# |         MinQ1Vals |            -122 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.94 |
# |         MaxQ2Vals |           -13.5 |
# |         MinQ2Vals |            -121 |
# |      AverageLogPi |          -0.411 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            11.6 |
# |          MinLogPi |           -8.71 |
# |            LossPi |            21.8 |
# |             LossQ |           0.345 |
# |              Time |        5.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             488 |
# |      AverageEpRet |           -17.8 |
# |          StdEpRet |            4.83 |
# |          MaxEpRet |           -12.7 |
# |          MinEpRet |             -30 |
# |  AverageTestEpRet |           -8.23 |
# |      StdTestEpRet |            2.72 |
# |      MaxTestEpRet |           -3.37 |
# |      MinTestEpRet |           -12.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.32e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.99 |
# |         MaxQ1Vals |           -13.6 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.99 |
# |         MaxQ2Vals |           -13.5 |
# |         MinQ2Vals |            -117 |
# |      AverageLogPi |           -0.39 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            15.9 |
# |          MinLogPi |           -10.3 |
# |            LossPi |            21.8 |
# |             LossQ |           0.345 |
# |              Time |        5.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             489 |
# |      AverageEpRet |           -18.9 |
# |          StdEpRet |             6.1 |
# |          MaxEpRet |           -10.7 |
# |          MinEpRet |           -31.6 |
# |  AverageTestEpRet |           -10.6 |
# |      StdTestEpRet |            4.61 |
# |      MaxTestEpRet |           -5.76 |
# |      MinTestEpRet |           -19.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.33e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.95 |
# |         MaxQ1Vals |           -13.5 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.95 |
# |         MaxQ2Vals |           -13.4 |
# |         MinQ2Vals |            -114 |
# |      AverageLogPi |          -0.405 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            13.6 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            21.8 |
# |             LossQ |           0.346 |
# |              Time |        5.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             490 |
# |      AverageEpRet |           -17.2 |
# |          StdEpRet |            3.58 |
# |          MaxEpRet |           -11.1 |
# |          MinEpRet |           -23.9 |
# |  AverageTestEpRet |           -10.9 |
# |      StdTestEpRet |            5.44 |
# |      MaxTestEpRet |           -3.02 |
# |      MinTestEpRet |           -20.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.97 |
# |         MaxQ1Vals |           -13.3 |
# |         MinQ1Vals |            -126 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.97 |
# |         MaxQ2Vals |           -13.5 |
# |         MinQ2Vals |            -125 |
# |      AverageLogPi |          -0.398 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            12.4 |
# |          MinLogPi |           -9.43 |
# |            LossPi |            21.8 |
# |             LossQ |           0.353 |
# |              Time |        5.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             491 |
# |      AverageEpRet |           -19.5 |
# |          StdEpRet |            5.63 |
# |          MaxEpRet |           -11.2 |
# |          MinEpRet |           -29.9 |
# |  AverageTestEpRet |           -11.1 |
# |      StdTestEpRet |            6.54 |
# |      MaxTestEpRet |           -4.98 |
# |      MinTestEpRet |           -29.7 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.36e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.97 |
# |         MaxQ1Vals |           -13.5 |
# |         MinQ1Vals |            -122 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.97 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -117 |
# |      AverageLogPi |          -0.406 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            11.5 |
# |          MinLogPi |           -10.1 |
# |            LossPi |            21.8 |
# |             LossQ |           0.335 |
# |              Time |        5.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             492 |
# |      AverageEpRet |           -16.9 |
# |          StdEpRet |            6.16 |
# |          MaxEpRet |           -10.4 |
# |          MinEpRet |           -35.1 |
# |  AverageTestEpRet |           -8.17 |
# |      StdTestEpRet |            5.26 |
# |      MaxTestEpRet |           -2.91 |
# |      MinTestEpRet |           -21.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.38e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.91 |
# |         MaxQ1Vals |           -13.7 |
# |         MinQ1Vals |            -115 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.91 |
# |         MaxQ2Vals |           -13.6 |
# |         MinQ2Vals |            -116 |
# |      AverageLogPi |          -0.411 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            11.4 |
# |          MinLogPi |           -9.48 |
# |            LossPi |            21.8 |
# |             LossQ |           0.336 |
# |              Time |        5.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             493 |
# |      AverageEpRet |           -17.4 |
# |          StdEpRet |             4.4 |
# |          MaxEpRet |           -12.6 |
# |          MinEpRet |           -27.8 |
# |  AverageTestEpRet |           -9.87 |
# |      StdTestEpRet |            8.27 |
# |      MaxTestEpRet |           -1.77 |
# |      MinTestEpRet |           -32.4 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.39e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.92 |
# |         MaxQ1Vals |           -13.6 |
# |         MinQ1Vals |            -117 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.92 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -124 |
# |      AverageLogPi |          -0.409 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            12.2 |
# |          MinLogPi |           -10.5 |
# |            LossPi |            21.8 |
# |             LossQ |           0.347 |
# |              Time |        5.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             494 |
# |      AverageEpRet |           -17.3 |
# |          StdEpRet |            3.15 |
# |          MaxEpRet |           -13.4 |
# |          MinEpRet |           -23.2 |
# |  AverageTestEpRet |           -7.78 |
# |      StdTestEpRet |            3.97 |
# |      MaxTestEpRet |           -3.04 |
# |      MinTestEpRet |           -17.8 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.41e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |               5 |
# |         MaxQ1Vals |           -13.5 |
# |         MinQ1Vals |            -120 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |               5 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -120 |
# |      AverageLogPi |          -0.391 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            13.7 |
# |          MinLogPi |           -10.6 |
# |            LossPi |            21.8 |
# |             LossQ |           0.346 |
# |              Time |        5.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             495 |
# |      AverageEpRet |           -19.1 |
# |          StdEpRet |            5.72 |
# |          MaxEpRet |           -11.8 |
# |          MinEpRet |           -29.9 |
# |  AverageTestEpRet |           -6.92 |
# |      StdTestEpRet |            4.43 |
# |      MaxTestEpRet |           -1.06 |
# |      MinTestEpRet |           -15.2 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.42e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.94 |
# |         MaxQ1Vals |           -13.6 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.95 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -123 |
# |      AverageLogPi |          -0.376 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            12.8 |
# |          MinLogPi |           -7.87 |
# |            LossPi |            21.8 |
# |             LossQ |           0.347 |
# |              Time |        5.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             496 |
# |      AverageEpRet |           -18.5 |
# |          StdEpRet |            4.46 |
# |          MaxEpRet |           -12.8 |
# |          MinEpRet |           -27.9 |
# |  AverageTestEpRet |           -12.6 |
# |      StdTestEpRet |            7.38 |
# |      MaxTestEpRet |           -5.27 |
# |      MinTestEpRet |           -30.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.44e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.93 |
# |         MaxQ1Vals |           -13.7 |
# |         MinQ1Vals |            -122 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.93 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -120 |
# |      AverageLogPi |          -0.397 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            14.5 |
# |          MinLogPi |           -9.03 |
# |            LossPi |            21.8 |
# |             LossQ |           0.357 |
# |              Time |        5.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             497 |
# |      AverageEpRet |           -17.8 |
# |          StdEpRet |            4.56 |
# |          MaxEpRet |           -12.2 |
# |          MinEpRet |           -25.5 |
# |  AverageTestEpRet |           -9.38 |
# |      StdTestEpRet |            4.22 |
# |      MaxTestEpRet |           -3.76 |
# |      MinTestEpRet |           -16.5 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.45e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.89 |
# |         MaxQ1Vals |           -13.6 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |             4.9 |
# |         MaxQ2Vals |           -13.6 |
# |         MinQ2Vals |            -120 |
# |      AverageLogPi |          -0.398 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            11.2 |
# |          MinLogPi |           -10.2 |
# |            LossPi |            21.8 |
# |             LossQ |           0.344 |
# |              Time |        5.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             498 |
# |      AverageEpRet |           -17.2 |
# |          StdEpRet |            3.71 |
# |          MaxEpRet |           -11.4 |
# |          MinEpRet |           -25.5 |
# |  AverageTestEpRet |           -13.2 |
# |      StdTestEpRet |             8.8 |
# |      MaxTestEpRet |           -2.35 |
# |      MinTestEpRet |           -28.9 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.47e+05 |
# |     AverageQ1Vals |           -21.7 |
# |         StdQ1Vals |            4.94 |
# |         MaxQ1Vals |           -13.3 |
# |         MinQ1Vals |            -130 |
# |     AverageQ2Vals |           -21.7 |
# |         StdQ2Vals |            4.94 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -128 |
# |      AverageLogPi |          -0.412 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            12.2 |
# |          MinLogPi |           -9.16 |
# |            LossPi |            21.8 |
# |             LossQ |           0.344 |
# |              Time |        5.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             499 |
# |      AverageEpRet |           -22.5 |
# |          StdEpRet |            8.54 |
# |          MaxEpRet |           -11.3 |
# |          MinEpRet |           -42.5 |
# |  AverageTestEpRet |           -7.23 |
# |      StdTestEpRet |            3.22 |
# |      MaxTestEpRet |           -1.61 |
# |      MinTestEpRet |           -11.3 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.48e+05 |
# |     AverageQ1Vals |           -21.7 |
# |         StdQ1Vals |             4.9 |
# |         MaxQ1Vals |           -13.7 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |           -21.7 |
# |         StdQ2Vals |             4.9 |
# |         MaxQ2Vals |           -13.6 |
# |         MinQ2Vals |            -121 |
# |      AverageLogPi |          -0.409 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            12.4 |
# |          MinLogPi |           -9.49 |
# |            LossPi |            21.8 |
# |             LossQ |            0.33 |
# |              Time |        5.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             500 |
# |      AverageEpRet |           -19.6 |
# |          StdEpRet |            4.57 |
# |          MaxEpRet |           -10.4 |
# |          MinEpRet |           -30.4 |
# |  AverageTestEpRet |             -12 |
# |      StdTestEpRet |             8.9 |
# |      MaxTestEpRet |            -4.1 |
# |      MinTestEpRet |           -33.1 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+05 |
# |     AverageQ1Vals |           -21.8 |
# |         StdQ1Vals |            4.98 |
# |         MaxQ1Vals |           -13.6 |
# |         MinQ1Vals |            -121 |
# |     AverageQ2Vals |           -21.8 |
# |         StdQ2Vals |            4.99 |
# |         MaxQ2Vals |           -13.7 |
# |         MinQ2Vals |            -125 |
# |      AverageLogPi |          -0.391 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            12.7 |
# |          MinLogPi |           -9.21 |
# |            LossPi |            21.8 |
# |             LossQ |           0.343 |
# |              Time |         5.4e+03 |
# ---------------------------------------
