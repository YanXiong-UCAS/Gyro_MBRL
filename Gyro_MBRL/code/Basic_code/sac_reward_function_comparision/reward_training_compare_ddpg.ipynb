# %% [markdown]
# # Soft Actor-Critic (SAC)
#
# # Model training with quadratic, exponential, and other reward functions on Env-v1

# %%
# trained in reward_training.py

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
# Out:
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/xiongyan/anaconda3/envs/spinningup/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# #### PE reward

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1,
    'qx2': 0,
    'qx3': 1,
    'qx4': 0,
    'pu1': 0,
    'pu2': 0,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_,
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU),
                    seed = 0,
                    steps_per_epoch = 1500,
                    epochs = 2000,
                    replay_size = 2000000,
                    gamma = 0.995,
                    polyak = 0.995,
                    pi_lr = 0.0025,
                    q_lr = 0.0025,
                    batch_size = 100,
                    start_steps = 10000,
                    act_noise = 0.1,
                    max_ep_len = 100,
                    logger_kwargs = dict(output_dir='ddpg_compare', exp_name='ddpg_compare')
                    )
# Out:
# Logging data to ddpg_compare/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fb3f78aa840>, 'GyroscopeEnv-v1', simu_args={'dt': 0.05, 'ep_len': 100, 'seed': 2}, reward_func='PE', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'p': 0.1, 'e': 40})",
#     "epochs":	2000,
#     "exp_name":	"ddpg_compare",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fb3f78bb940>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_compare",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_compare",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_compare/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_compare",
#         "output_dir":	"ddpg_compare"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	2000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1500,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5474, 	 q: 5697
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -378 |
# |          StdEpRet |            9.32 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            11.5 |
# |      MaxTestEpRet |            -347 |
# |      MinTestEpRet |            -388 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+03 |
# |      AverageQVals |           -6.53 |
# |          StdQVals |            2.13 |
# |          MaxQVals |           0.013 |
# |          MinQVals |           -11.8 |
# |            LossPi |            6.38 |
# |             LossQ |           0.458 |
# |              Time |            4.69 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |            4.68 |
# |          MaxEpRet |            -366 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -378 |
# |      StdTestEpRet |            4.97 |
# |      MaxTestEpRet |            -372 |
# |      MinTestEpRet |            -387 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+03 |
# |      AverageQVals |             -22 |
# |          StdQVals |            7.13 |
# |          MaxQVals |           -8.83 |
# |          MinQVals |           -37.8 |
# |            LossPi |            21.9 |
# |             LossQ |          0.0849 |
# |              Time |            11.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |            5.42 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -374 |
# |      StdTestEpRet |            14.5 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |            -392 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+03 |
# |      AverageQVals |           -46.5 |
# |          StdQVals |            7.16 |
# |          MaxQVals |           -31.1 |
# |          MinQVals |             -64 |
# |            LossPi |            46.3 |
# |             LossQ |           0.162 |
# |              Time |            18.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |             4.4 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -388 |
# |  AverageTestEpRet |            -375 |
# |      StdTestEpRet |            5.68 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -383 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+03 |
# |      AverageQVals |           -70.5 |
# |          StdQVals |            7.01 |
# |          MaxQVals |           -53.9 |
# |          MinQVals |             -89 |
# |            LossPi |            70.4 |
# |             LossQ |           0.233 |
# |              Time |            26.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -375 |
# |          StdEpRet |            8.27 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -369 |
# |      StdTestEpRet |              10 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -380 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+03 |
# |      AverageQVals |           -93.8 |
# |          StdQVals |            6.87 |
# |          MaxQVals |             -77 |
# |          MinQVals |            -114 |
# |            LossPi |            93.6 |
# |             LossQ |           0.301 |
# |              Time |            33.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -377 |
# |          StdEpRet |            5.72 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -372 |
# |      StdTestEpRet |            5.79 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |            -378 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           9e+03 |
# |      AverageQVals |            -116 |
# |          StdQVals |            6.75 |
# |          MaxQVals |           -99.3 |
# |          MinQVals |            -135 |
# |            LossPi |             116 |
# |             LossQ |           0.366 |
# |              Time |            40.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |            6.88 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -367 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |            -384 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.05e+04 |
# |      AverageQVals |            -138 |
# |          StdQVals |             6.6 |
# |          MaxQVals |            -120 |
# |          MinQVals |            -158 |
# |            LossPi |             138 |
# |             LossQ |           0.462 |
# |              Time |            47.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -371 |
# |          StdEpRet |            8.57 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -375 |
# |      StdTestEpRet |            4.63 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.2e+04 |
# |      AverageQVals |            -159 |
# |          StdQVals |            6.55 |
# |          MaxQVals |            -141 |
# |          MinQVals |            -178 |
# |            LossPi |             159 |
# |             LossQ |           0.483 |
# |              Time |            54.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -370 |
# |          StdEpRet |            8.82 |
# |          MaxEpRet |            -340 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -372 |
# |      StdTestEpRet |              12 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |            -385 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+04 |
# |      AverageQVals |            -179 |
# |          StdQVals |            6.44 |
# |          MaxQVals |            -159 |
# |          MinQVals |            -199 |
# |            LossPi |             179 |
# |             LossQ |           0.512 |
# |              Time |              62 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -369 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -337 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |            -372 |
# |      StdTestEpRet |            6.79 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |            -382 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.5e+04 |
# |      AverageQVals |            -198 |
# |          StdQVals |            6.37 |
# |          MaxQVals |            -178 |
# |          MinQVals |            -221 |
# |            LossPi |             198 |
# |             LossQ |           0.542 |
# |              Time |            69.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -370 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |            -343 |
# |      MinTestEpRet |            -388 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |            -217 |
# |          StdQVals |            6.32 |
# |          MaxQVals |            -195 |
# |          MinQVals |            -239 |
# |            LossPi |             217 |
# |             LossQ |           0.614 |
# |              Time |            76.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |            9.92 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -388 |
# |  AverageTestEpRet |            -373 |
# |      StdTestEpRet |            4.66 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.8e+04 |
# |      AverageQVals |            -235 |
# |          StdQVals |            6.22 |
# |          MaxQVals |            -212 |
# |          MinQVals |            -257 |
# |            LossPi |             235 |
# |             LossQ |           0.596 |
# |              Time |            83.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -375 |
# |          StdEpRet |            5.94 |
# |          MaxEpRet |            -363 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |            -368 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |            -343 |
# |      MinTestEpRet |            -382 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.95e+04 |
# |      AverageQVals |            -253 |
# |          StdQVals |            6.21 |
# |          MaxQVals |            -230 |
# |          MinQVals |            -275 |
# |            LossPi |             253 |
# |             LossQ |           0.639 |
# |              Time |            93.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -371 |
# |          StdEpRet |            7.14 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -382 |
# |  AverageTestEpRet |            -361 |
# |      StdTestEpRet |            24.3 |
# |      MaxTestEpRet |            -310 |
# |      MinTestEpRet |            -383 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.1e+04 |
# |      AverageQVals |            -270 |
# |          StdQVals |             6.1 |
# |          MaxQVals |            -247 |
# |          MinQVals |            -290 |
# |            LossPi |             270 |
# |             LossQ |           0.654 |
# |              Time |             100 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -370 |
# |          StdEpRet |            11.3 |
# |          MaxEpRet |            -348 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -365 |
# |      StdTestEpRet |            18.7 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |            -386 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.25e+04 |
# |      AverageQVals |            -286 |
# |          StdQVals |            6.03 |
# |          MaxQVals |            -262 |
# |          MinQVals |            -305 |
# |            LossPi |             286 |
# |             LossQ |           0.648 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -370 |
# |          StdEpRet |              10 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -358 |
# |      StdTestEpRet |            25.8 |
# |      MaxTestEpRet |            -293 |
# |      MinTestEpRet |            -385 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.4e+04 |
# |      AverageQVals |            -302 |
# |          StdQVals |            5.97 |
# |          MaxQVals |            -278 |
# |          MinQVals |            -322 |
# |            LossPi |             302 |
# |             LossQ |           0.682 |
# |              Time |             115 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -368 |
# |          StdEpRet |              12 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -385 |
# |  AverageTestEpRet |            -368 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |            -338 |
# |      MinTestEpRet |            -382 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.55e+04 |
# |      AverageQVals |            -317 |
# |          StdQVals |            5.88 |
# |          MaxQVals |            -294 |
# |          MinQVals |            -335 |
# |            LossPi |             317 |
# |             LossQ |           0.655 |
# |              Time |             123 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -370 |
# |          StdEpRet |              11 |
# |          MaxEpRet |            -350 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -372 |
# |      StdTestEpRet |              12 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -384 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         2.7e+04 |
# |      AverageQVals |            -331 |
# |          StdQVals |            5.78 |
# |          MaxQVals |            -309 |
# |          MinQVals |            -358 |
# |            LossPi |             331 |
# |             LossQ |           0.721 |
# |              Time |             131 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -368 |
# |          StdEpRet |            9.93 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -369 |
# |      StdTestEpRet |            11.5 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -383 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        2.85e+04 |
# |      AverageQVals |            -345 |
# |          StdQVals |            5.69 |
# |          MaxQVals |            -322 |
# |          MinQVals |            -365 |
# |            LossPi |             345 |
# |             LossQ |           0.707 |
# |              Time |             140 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |            -304 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -357 |
# |      StdTestEpRet |            8.77 |
# |      MaxTestEpRet |            -348 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           3e+04 |
# |      AverageQVals |            -359 |
# |          StdQVals |            5.58 |
# |          MaxQVals |            -336 |
# |          MinQVals |            -378 |
# |            LossPi |             359 |
# |             LossQ |            0.71 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -367 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -332 |
# |          MinEpRet |            -385 |
# |  AverageTestEpRet |            -355 |
# |      StdTestEpRet |            10.9 |
# |      MaxTestEpRet |            -334 |
# |      MinTestEpRet |            -368 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.15e+04 |
# |      AverageQVals |            -372 |
# |          StdQVals |            5.53 |
# |          MaxQVals |            -349 |
# |          MinQVals |            -395 |
# |            LossPi |             371 |
# |             LossQ |            0.73 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -349 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -354 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |            -286 |
# |      MinTestEpRet |            -382 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |            -384 |
# |          StdQVals |            5.49 |
# |          MaxQVals |            -361 |
# |          MinQVals |            -405 |
# |            LossPi |             384 |
# |             LossQ |           0.797 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -364 |
# |          StdEpRet |            12.8 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |            -356 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -374 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.45e+04 |
# |      AverageQVals |            -396 |
# |          StdQVals |            5.47 |
# |          MaxQVals |            -371 |
# |          MinQVals |            -416 |
# |            LossPi |             396 |
# |             LossQ |           0.692 |
# |              Time |             171 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -358 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -337 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -360 |
# |      StdTestEpRet |            15.5 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |            -379 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.6e+04 |
# |      AverageQVals |            -407 |
# |          StdQVals |            5.43 |
# |          MaxQVals |            -383 |
# |          MinQVals |            -428 |
# |            LossPi |             407 |
# |             LossQ |           0.764 |
# |              Time |             179 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |            -331 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -363 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |            -340 |
# |      MinTestEpRet |            -380 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        3.75e+04 |
# |      AverageQVals |            -418 |
# |          StdQVals |            5.46 |
# |          MaxQVals |            -395 |
# |          MinQVals |            -438 |
# |            LossPi |             418 |
# |             LossQ |           0.761 |
# |              Time |             187 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -360 |
# |          StdEpRet |              19 |
# |          MaxEpRet |            -310 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -355 |
# |      StdTestEpRet |            17.7 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |            -383 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         3.9e+04 |
# |      AverageQVals |            -428 |
# |          StdQVals |            5.48 |
# |          MaxQVals |            -406 |
# |          MinQVals |            -448 |
# |            LossPi |             428 |
# |             LossQ |           0.758 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -354 |
# |          StdEpRet |            20.7 |
# |          MaxEpRet |            -306 |
# |          MinEpRet |            -382 |
# |  AverageTestEpRet |            -369 |
# |      StdTestEpRet |            9.62 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.05e+04 |
# |      AverageQVals |            -439 |
# |          StdQVals |            5.51 |
# |          MaxQVals |            -416 |
# |          MinQVals |            -461 |
# |            LossPi |             438 |
# |             LossQ |           0.787 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -359 |
# |          StdEpRet |              11 |
# |          MaxEpRet |            -336 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -354 |
# |      StdTestEpRet |            40.3 |
# |      MaxTestEpRet |            -236 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.2e+04 |
# |      AverageQVals |            -448 |
# |          StdQVals |            5.54 |
# |          MaxQVals |            -426 |
# |          MinQVals |            -472 |
# |            LossPi |             448 |
# |             LossQ |           0.881 |
# |              Time |             211 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -362 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -347 |
# |      StdTestEpRet |            20.3 |
# |      MaxTestEpRet |            -316 |
# |      MinTestEpRet |            -374 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.35e+04 |
# |      AverageQVals |            -458 |
# |          StdQVals |            5.59 |
# |          MaxQVals |            -437 |
# |          MinQVals |            -479 |
# |            LossPi |             457 |
# |             LossQ |           0.808 |
# |              Time |             218 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -356 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -329 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -349 |
# |      StdTestEpRet |            32.1 |
# |      MaxTestEpRet |            -264 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.5e+04 |
# |      AverageQVals |            -466 |
# |          StdQVals |            5.64 |
# |          MaxQVals |            -446 |
# |          MinQVals |            -487 |
# |            LossPi |             466 |
# |             LossQ |           0.882 |
# |              Time |             226 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -349 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |            -293 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -354 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |            -278 |
# |      MinTestEpRet |            -377 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.65e+04 |
# |      AverageQVals |            -475 |
# |          StdQVals |            5.86 |
# |          MaxQVals |            -454 |
# |          MinQVals |            -498 |
# |            LossPi |             475 |
# |             LossQ |           0.901 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -355 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -328 |
# |          MinEpRet |            -380 |
# |  AverageTestEpRet |            -354 |
# |      StdTestEpRet |            26.6 |
# |      MaxTestEpRet |            -303 |
# |      MinTestEpRet |            -378 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |            -483 |
# |          StdQVals |               6 |
# |          MaxQVals |            -462 |
# |          MinQVals |            -506 |
# |            LossPi |             483 |
# |             LossQ |           0.919 |
# |              Time |             242 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -352 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |            -307 |
# |          MinEpRet |            -380 |
# |  AverageTestEpRet |            -346 |
# |      StdTestEpRet |            39.9 |
# |      MaxTestEpRet |            -271 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |            -490 |
# |          StdQVals |            6.13 |
# |          MaxQVals |            -469 |
# |          MinQVals |            -513 |
# |            LossPi |             490 |
# |             LossQ |           0.932 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -341 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |            -255 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -344 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |            -282 |
# |      MinTestEpRet |            -369 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |            -498 |
# |          StdQVals |            6.37 |
# |          MaxQVals |            -476 |
# |          MinQVals |            -521 |
# |            LossPi |             497 |
# |             LossQ |           0.961 |
# |              Time |             258 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            33.7 |
# |          MaxEpRet |            -257 |
# |          MinEpRet |            -359 |
# |  AverageTestEpRet |            -344 |
# |      StdTestEpRet |            37.4 |
# |      MaxTestEpRet |            -249 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |            -504 |
# |          StdQVals |            6.66 |
# |          MaxQVals |            -483 |
# |          MinQVals |            -529 |
# |            LossPi |             504 |
# |             LossQ |            1.01 |
# |              Time |             265 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -334 |
# |          StdEpRet |            34.3 |
# |          MaxEpRet |            -256 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -315 |
# |      StdTestEpRet |            45.2 |
# |      MaxTestEpRet |            -229 |
# |      MinTestEpRet |            -368 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |            -511 |
# |          StdQVals |            6.98 |
# |          MaxQVals |            -490 |
# |          MinQVals |            -535 |
# |            LossPi |             511 |
# |             LossQ |            1.02 |
# |              Time |             273 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -345 |
# |          StdEpRet |            31.5 |
# |          MaxEpRet |            -268 |
# |          MinEpRet |            -380 |
# |  AverageTestEpRet |            -347 |
# |      StdTestEpRet |              21 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |            -377 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |            -517 |
# |          StdQVals |            7.37 |
# |          MaxQVals |            -496 |
# |          MinQVals |            -542 |
# |            LossPi |             517 |
# |             LossQ |            1.09 |
# |              Time |             282 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -341 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |            -266 |
# |          MinEpRet |            -375 |
# |  AverageTestEpRet |            -345 |
# |      StdTestEpRet |            39.4 |
# |      MaxTestEpRet |            -234 |
# |      MinTestEpRet |            -377 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |            -523 |
# |          StdQVals |            7.81 |
# |          MaxQVals |            -500 |
# |          MinQVals |            -550 |
# |            LossPi |             523 |
# |             LossQ |            1.19 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -338 |
# |          StdEpRet |            44.5 |
# |          MaxEpRet |            -241 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -359 |
# |      StdTestEpRet |            19.9 |
# |      MaxTestEpRet |            -309 |
# |      MinTestEpRet |            -379 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |            -528 |
# |          StdQVals |            8.23 |
# |          MaxQVals |            -505 |
# |          MinQVals |            -555 |
# |            LossPi |             528 |
# |             LossQ |            1.25 |
# |              Time |             296 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -339 |
# |          StdEpRet |            34.3 |
# |          MaxEpRet |            -264 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            34.4 |
# |      MaxTestEpRet |            -268 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |            -534 |
# |          StdQVals |            8.71 |
# |          MaxQVals |            -508 |
# |          MinQVals |            -560 |
# |            LossPi |             533 |
# |             LossQ |            1.26 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |              43 |
# |          MaxEpRet |            -222 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -280 |
# |      MinTestEpRet |            -374 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |            -538 |
# |          StdQVals |             9.2 |
# |          MaxQVals |            -512 |
# |          MinQVals |            -568 |
# |            LossPi |             538 |
# |             LossQ |            1.37 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -344 |
# |          StdEpRet |            25.9 |
# |          MaxEpRet |            -292 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -328 |
# |      StdTestEpRet |            48.8 |
# |      MaxTestEpRet |            -239 |
# |      MinTestEpRet |            -380 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |            -543 |
# |          StdQVals |            9.77 |
# |          MaxQVals |            -515 |
# |          MinQVals |            -572 |
# |            LossPi |             543 |
# |             LossQ |            1.34 |
# |              Time |             320 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -337 |
# |          StdEpRet |            43.2 |
# |          MaxEpRet |            -224 |
# |          MinEpRet |            -375 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            20.9 |
# |      MaxTestEpRet |            -294 |
# |      MinTestEpRet |            -374 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |            -547 |
# |          StdQVals |            10.3 |
# |          MaxQVals |            -518 |
# |          MinQVals |            -578 |
# |            LossPi |             547 |
# |             LossQ |            1.32 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -341 |
# |          StdEpRet |              26 |
# |          MaxEpRet |            -278 |
# |          MinEpRet |            -375 |
# |  AverageTestEpRet |            -344 |
# |      StdTestEpRet |            22.5 |
# |      MaxTestEpRet |            -309 |
# |      MinTestEpRet |            -367 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |            -551 |
# |          StdQVals |            10.9 |
# |          MaxQVals |            -520 |
# |          MinQVals |            -586 |
# |            LossPi |             551 |
# |             LossQ |             1.4 |
# |              Time |             334 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |              29 |
# |          MaxEpRet |            -267 |
# |          MinEpRet |            -372 |
# |  AverageTestEpRet |            -343 |
# |      StdTestEpRet |            32.6 |
# |      MaxTestEpRet |            -258 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |            -555 |
# |          StdQVals |            11.4 |
# |          MaxQVals |            -523 |
# |          MinQVals |            -591 |
# |            LossPi |             554 |
# |             LossQ |            1.43 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -338 |
# |          StdEpRet |            22.9 |
# |          MaxEpRet |            -284 |
# |          MinEpRet |            -372 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            22.9 |
# |      MaxTestEpRet |            -304 |
# |      MinTestEpRet |            -375 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |            -558 |
# |          StdQVals |            11.9 |
# |          MaxQVals |            -526 |
# |          MinQVals |            -596 |
# |            LossPi |             557 |
# |             LossQ |            1.42 |
# |              Time |             348 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -339 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |            -292 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -328 |
# |      StdTestEpRet |            38.3 |
# |      MaxTestEpRet |            -252 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |            -561 |
# |          StdQVals |            12.5 |
# |          MaxQVals |            -528 |
# |          MinQVals |            -600 |
# |            LossPi |             561 |
# |             LossQ |            1.42 |
# |              Time |             355 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -327 |
# |          StdEpRet |            36.1 |
# |          MaxEpRet |            -262 |
# |          MinEpRet |            -372 |
# |  AverageTestEpRet |            -342 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |            -277 |
# |      MinTestEpRet |            -377 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |            -564 |
# |          StdQVals |              13 |
# |          MaxQVals |            -530 |
# |          MinQVals |            -605 |
# |            LossPi |             564 |
# |             LossQ |            1.43 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -335 |
# |          StdEpRet |            34.9 |
# |          MaxEpRet |            -275 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -334 |
# |      StdTestEpRet |            41.4 |
# |      MaxTestEpRet |            -252 |
# |      MinTestEpRet |            -378 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |            -567 |
# |          StdQVals |            13.6 |
# |          MaxQVals |            -532 |
# |          MinQVals |            -611 |
# |            LossPi |             567 |
# |             LossQ |            1.46 |
# |              Time |             371 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -333 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |            -269 |
# |          MinEpRet |            -365 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            28.7 |
# |      MaxTestEpRet |            -281 |
# |      MinTestEpRet |            -369 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |            -570 |
# |          StdQVals |            14.1 |
# |          MaxQVals |            -534 |
# |          MinQVals |            -614 |
# |            LossPi |             570 |
# |             LossQ |            1.48 |
# |              Time |             379 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            31.5 |
# |          MaxEpRet |            -255 |
# |          MinEpRet |            -369 |
# |  AverageTestEpRet |            -331 |
# |      StdTestEpRet |            28.9 |
# |      MaxTestEpRet |            -267 |
# |      MinTestEpRet |            -366 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.65e+04 |
# |      AverageQVals |            -572 |
# |          StdQVals |            14.6 |
# |          MaxQVals |            -536 |
# |          MinQVals |            -619 |
# |            LossPi |             572 |
# |             LossQ |            1.56 |
# |              Time |             386 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -342 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -303 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -346 |
# |      StdTestEpRet |            18.6 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |            -375 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.8e+04 |
# |      AverageQVals |            -575 |
# |          StdQVals |            15.1 |
# |          MaxQVals |            -537 |
# |          MinQVals |            -621 |
# |            LossPi |             575 |
# |             LossQ |            1.52 |
# |              Time |             393 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |            -214 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -338 |
# |      StdTestEpRet |            21.4 |
# |      MaxTestEpRet |            -299 |
# |      MinTestEpRet |            -367 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.95e+04 |
# |      AverageQVals |            -577 |
# |          StdQVals |            15.7 |
# |          MaxQVals |            -539 |
# |          MinQVals |            -629 |
# |            LossPi |             577 |
# |             LossQ |            1.46 |
# |              Time |             400 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |            -365 |
# |  AverageTestEpRet |            -329 |
# |      StdTestEpRet |              28 |
# |      MaxTestEpRet |            -265 |
# |      MinTestEpRet |            -370 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         8.1e+04 |
# |      AverageQVals |            -579 |
# |          StdQVals |            16.1 |
# |          MaxQVals |            -540 |
# |          MinQVals |            -633 |
# |            LossPi |             579 |
# |             LossQ |            1.45 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -341 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |            -302 |
# |          MinEpRet |            -380 |
# |  AverageTestEpRet |            -343 |
# |      StdTestEpRet |            22.2 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -367 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |            -581 |
# |          StdQVals |            16.6 |
# |          MaxQVals |            -540 |
# |          MinQVals |            -637 |
# |            LossPi |             581 |
# |             LossQ |            1.44 |
# |              Time |             416 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -265 |
# |          MinEpRet |            -367 |
# ...
# |  AverageTestEpRet |            -339 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |            -242 |
# |      MinTestEpRet |            -385 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.24e+05 |
# |      AverageQVals |            -614 |
# |          StdQVals |              31 |
# |          MaxQVals |            -543 |
# |          MinQVals |            -679 |
# |            LossPi |             613 |
# |             LossQ |             1.7 |
# |              Time |             605 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            45.2 |
# |          MaxEpRet |            -229 |
# |          MinEpRet |            -385 |
# |  AverageTestEpRet |            -319 |
# |      StdTestEpRet |            55.2 |
# |      MaxTestEpRet |            -224 |
# |      MinTestEpRet |            -371 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.26e+05 |
# |      AverageQVals |            -614 |
# |          StdQVals |            31.5 |
# |          MaxQVals |            -542 |
# |          MinQVals |            -680 |
# |            LossPi |             614 |
# |             LossQ |            1.62 |
# |              Time |             611 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -322 |
# |          StdEpRet |            43.1 |
# |          MaxEpRet |            -250 |
# |          MinEpRet |            -388 |
# |  AverageTestEpRet |            -328 |
# |      StdTestEpRet |            26.6 |
# |      MaxTestEpRet |            -275 |
# |      MinTestEpRet |            -369 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.27e+05 |
# |      AverageQVals |            -614 |
# |          StdQVals |            31.7 |
# |          MaxQVals |            -542 |
# |          MinQVals |            -683 |
# |            LossPi |             614 |
# |             LossQ |            1.65 |
# |              Time |             616 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            -331 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |            -278 |
# |          MinEpRet |            -376 |
# |  AverageTestEpRet |            -339 |
# |      StdTestEpRet |            36.9 |
# |      MaxTestEpRet |            -254 |
# |      MinTestEpRet |            -372 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.29e+05 |
# |      AverageQVals |            -615 |
# |          StdQVals |            32.1 |
# |          MaxQVals |            -542 |
# |          MinQVals |            -682 |
# |            LossPi |             614 |
# |             LossQ |            1.69 |
# |              Time |             622 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |            -300 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -344 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -308 |
# |      MinTestEpRet |            -364 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         1.3e+05 |
# |      AverageQVals |            -615 |
# |          StdQVals |            32.4 |
# |          MaxQVals |            -543 |
# |          MinQVals |            -681 |
# |            LossPi |             615 |
# |             LossQ |            1.72 |
# |              Time |             627 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -314 |
# |          StdEpRet |            41.7 |
# |          MaxEpRet |            -212 |
# |          MinEpRet |            -366 |
# |  AverageTestEpRet |            -296 |
# |      StdTestEpRet |            52.1 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |            -376 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.32e+05 |
# |      AverageQVals |            -615 |
# |          StdQVals |            32.7 |
# |          MaxQVals |            -544 |
# |          MinQVals |            -683 |
# |            LossPi |             615 |
# |             LossQ |             1.7 |
# |              Time |             632 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -333 |
# |          StdEpRet |            41.5 |
# |          MaxEpRet |            -214 |
# |          MinEpRet |            -376 |
# |  AverageTestEpRet |            -305 |
# |      StdTestEpRet |            44.4 |
# |      MaxTestEpRet |            -223 |
# |      MinTestEpRet |            -371 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.33e+05 |
# |      AverageQVals |            -615 |
# |          StdQVals |              33 |
# |          MaxQVals |            -544 |
# |          MinQVals |            -683 |
# |            LossPi |             615 |
# |             LossQ |            1.73 |
# |              Time |             638 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            35.3 |
# |          MaxEpRet |            -211 |
# |          MinEpRet |            -352 |
# |  AverageTestEpRet |            -335 |
# |      StdTestEpRet |            41.1 |
# |      MaxTestEpRet |            -254 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            33.2 |
# |          MaxQVals |            -544 |
# |          MinQVals |            -685 |
# |            LossPi |             616 |
# |             LossQ |            1.77 |
# |              Time |             643 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -327 |
# |          StdEpRet |            41.9 |
# |          MaxEpRet |            -243 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -334 |
# |      StdTestEpRet |            43.8 |
# |      MaxTestEpRet |            -241 |
# |      MinTestEpRet |            -374 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.36e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            33.5 |
# |          MaxQVals |            -544 |
# |          MinQVals |            -686 |
# |            LossPi |             616 |
# |             LossQ |            1.74 |
# |              Time |             648 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -333 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |            -259 |
# |          MinEpRet |            -374 |
# |  AverageTestEpRet |            -315 |
# |      StdTestEpRet |            40.7 |
# |      MaxTestEpRet |            -232 |
# |      MinTestEpRet |            -372 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.38e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            33.6 |
# |          MaxQVals |            -544 |
# |          MinQVals |            -689 |
# |            LossPi |             616 |
# |             LossQ |            1.78 |
# |              Time |             653 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -320 |
# |          StdEpRet |            37.8 |
# |          MaxEpRet |            -248 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -332 |
# |      StdTestEpRet |            36.8 |
# |      MaxTestEpRet |            -276 |
# |      MinTestEpRet |            -382 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            33.9 |
# |          MaxQVals |            -543 |
# |          MinQVals |            -690 |
# |            LossPi |             616 |
# |             LossQ |            1.81 |
# |              Time |             659 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -314 |
# |          StdEpRet |            42.9 |
# |          MaxEpRet |            -195 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -315 |
# |      StdTestEpRet |            43.1 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -365 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.41e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            34.1 |
# |          MaxQVals |            -543 |
# |          MinQVals |            -690 |
# |            LossPi |             616 |
# |             LossQ |             1.8 |
# |              Time |             664 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |            -267 |
# |          MinEpRet |            -376 |
# |  AverageTestEpRet |            -305 |
# |      StdTestEpRet |            44.1 |
# |      MaxTestEpRet |            -230 |
# |      MinTestEpRet |            -377 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            34.4 |
# |          MaxQVals |            -542 |
# |          MinQVals |            -691 |
# |            LossPi |             616 |
# |             LossQ |            1.78 |
# |              Time |             670 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |            37.8 |
# |          MaxEpRet |            -257 |
# |          MinEpRet |            -376 |
# |  AverageTestEpRet |            -305 |
# |      StdTestEpRet |            42.8 |
# |      MaxTestEpRet |            -217 |
# |      MinTestEpRet |            -379 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            34.6 |
# |          MaxQVals |            -542 |
# |          MinQVals |            -694 |
# |            LossPi |             616 |
# |             LossQ |            1.82 |
# |              Time |             675 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |            39.5 |
# |          MaxEpRet |            -243 |
# |          MinEpRet |            -370 |
# |  AverageTestEpRet |            -335 |
# |      StdTestEpRet |            40.1 |
# |      MaxTestEpRet |            -256 |
# |      MinTestEpRet |            -373 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            34.9 |
# |          MaxQVals |            -540 |
# |          MinQVals |            -692 |
# |            LossPi |             616 |
# |             LossQ |            1.95 |
# |              Time |             681 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -309 |
# |          StdEpRet |            53.2 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |            -333 |
# |      StdTestEpRet |              33 |
# |      MaxTestEpRet |            -279 |
# |      MinTestEpRet |            -372 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |              35 |
# |          MaxQVals |            -540 |
# |          MinQVals |            -692 |
# |            LossPi |             616 |
# |             LossQ |            1.85 |
# |              Time |             686 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -324 |
# |          StdEpRet |            39.2 |
# |          MaxEpRet |            -222 |
# |          MinEpRet |            -360 |
# |  AverageTestEpRet |            -328 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |            -257 |
# |      MinTestEpRet |            -351 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |            -616 |
# |          StdQVals |            35.1 |
# |          MaxQVals |            -539 |
# |          MinQVals |            -691 |
# |            LossPi |             616 |
# |             LossQ |            1.92 |
# |              Time |             692 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dad473007ccd> in <module>
#      34                     act_noise = 0.1,
#      35                     max_ep_len = 100,
# ---> 36                     logger_kwargs = dict(output_dir='ddpg_compare', exp_name='ddpg_compare')
#      37                     )
#
# ~/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in ddpg(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     281             for _ in range(update_every):
#     282                 batch = replay_buffer.sample_batch(batch_size)
# --> 283                 update(data=batch)
#     284
#     285         # End of epoch handling
#
# ~/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in update(data)
#     206         pi_optimizer.zero_grad()
#     207         loss_pi = compute_loss_pi(data)
# --> 208         loss_pi.backward()
#     209         pi_optimizer.step()
#     210
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:
