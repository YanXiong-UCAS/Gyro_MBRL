# %% [markdown]
# # Gyroscope Model Validation

# %% [markdown]
# ## Import

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import prbs
import torch

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Environment Class and Modules

# %%
# Initialization args
env_name = 'GyroscopeEnv-v1'
state = np.zeros([7])
simu_args = {
    'dt': 0.02,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Normalized'
reward_args = {
    'k': 0.05, 
    'qx2': 0.01, 
    'qx4': 0.01, 
    'pu1': 0.5, 
    'pu2': 0.5
}

# Create env
env = create_env(env_name,simu_args,reward_func,reward_args, state)

# Create another env with friction
simu_args['friction'] = True
env_f = create_env(env_name,simu_args,reward_func,reward_args, state)

# Create another env with optimized friction for red gimbal
env_r = create_env(env_name,simu_args,reward_func,reward_args, state)
env_r.fvr, env_r.fcr = 0.00029031, 0

# Create another env with optimized friction for blue gimbal
env_b = create_env(env_name,simu_args,reward_func,reward_args, state)
env_b.fvb, env_b.fcb = 7.09810586e-05, 3.21620766e-03

# %% [markdown]
# ## Helpful funciton

# %%
u = prbs(10,10)
# np.savetxt('prbs.txt', u, delimiter=',')

# %%
def read_data(filepath):
    
    # count lines
    file = open(filepath, "r")
    count = len(file.readlines(  ))
    data = np.empty([count, 16])
    file.seek(0)
    
    # read each line as a numpy array
    for row, x in enumerate(file):
        data[row] = np.array(x.split('\t')).astype(np.float)
    file.close()
    
    # change time from usec into sec and shift the beginning to 0
    data[:,11] = data[:,11] / 1e6
    data[:,11] -= data[0,11]
    
    return data

# %% [markdown]
# # Red gimbal in virtual env（no friction）

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record = np.empty([len(time), len(x_0)])
reward_record = np.empty([len(time), 1])
action_record = np.empty([len(time), 2])

for i in range(len(time)):
    action = [u[i],0] 
    
    observation, reward, done, info = env.step(action)
    state_record[i] = env.state
    reward_record[i] = reward
    action_record[i] = action

# %%
f, axs = plt.subplots(4,2,figsize=(19,19))

plt.subplot(4,2,1)
plt.title('Red gimbal angle',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\theta$ [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,0],'r-')

plt.subplot(4,2,2)
plt.title('Blue gimbal angle',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\phi$ [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,2],'b-')

plt.subplot(4,2,3)
plt.title('Red gimbal speed',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\dot \theta$ [rad/s]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,1],'r-')

plt.subplot(4,2,4)
plt.title('Blue gimbal speed',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\dot \phi$ [rad/s]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,3],'b-')

plt.subplot(4,2,5)
plt.title('Red gimbal tracking error',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\theta$ error [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,0]-state_record[:,4],'r-')

plt.subplot(4,2,6)
plt.title('Blue gimbal tracking error',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\phi$ error [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,2]-state_record[:,5],'b-')

plt.subplot(4,2,7)
plt.title('Red gimbal input',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel('voltage [V]',fontsize=16)
plt.grid()
plt.plot(time,action_record[:,0]*10,'r-')

plt.subplot(4,2,8)
plt.title('Blue gimbal input',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel('voltage [V]',fontsize=16)
plt.grid()
plt.plot(time,action_record[:,1]*10,'b-')

plt.show()

# %% [markdown]
# # Red gimbal in virtual env（with friction）

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env_f.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record_f = np.empty([len(time), len(x_0)])
reward_record_f = np.empty([len(time), 1])
action_record_f = np.empty([len(time), 2])

for i in range(len(time)):
    action = [u[i],0] 
    
    observation, reward, done, info = env_f.step(action)
    state_record_f[i] = env_f.state
    reward_record_f[i] = reward
    action_record_f[i] = action

# %% [markdown]
# # Red gimbal in virtual env（with optimized friction）

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env_r.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record_r = np.empty([len(time), len(x_0)])
reward_record_r = np.empty([len(time), 1])
action_record_r = np.empty([len(time), 2])

for i in range(len(time)):
    action = [u[i],0] 
    
    observation, reward, done, info = env_r.step(action)
    state_record_r[i] = env_r.state
    reward_record_r[i] = reward
    action_record_r[i] = action

# %% [markdown]
# # Red gimbal in real machine

# %%
data = read_data('data_red.txt')

# %%
# there could be some data loss
t = (data[:,11] / 0.02).astype(int)
# make sure the input PRBS is correct
plt.figure(figsize = (19,5))
plt.grid()
plt.plot([i for i in range(255)], [10*u[i] for i in range(255)])
plt.plot(t[0:255], data[0:255,9])

# %%
f, axs = plt.subplots(2,1,figsize=(16,16))
plt.subplots_adjust(hspace=0.2)

plt.subplot(2,1,1)
plt.title('Red gimbal angle',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\theta$ [rad]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,0])
plt.plot(time,state_record_f[:,0])
plt.plot(time,state_record_r[:,0])
plt.plot(data[:,11], data[:,2]/180*np.pi) # deg to rad
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

plt.subplot(2,1,2)
plt.title('Red gimbal speed',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\dot \theta$ [rad/s]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,1])
plt.plot(time,state_record_f[:,1])
plt.plot(time,state_record_r[:,1])
plt.plot(data[:,11], data[:,3]*2*np.pi/60) # rpm to rad/s
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)
plt.savefig('id_red.png')

# %%
f, axs = plt.subplots(2,1,figsize=(16,16))
plt.subplots_adjust(hspace=0.2)

plt.subplot(2,1,1)
plt.title('Blue gimbal angle',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\phi$ [rad]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,2])
plt.plot(time,state_record_f[:,2])
plt.plot(time,state_record_r[:,2])
plt.plot(data[:,11], data[:,4]/180*np.pi) # deg to rad
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

plt.subplot(2,1,2)
plt.title('Blue gimbal speed',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\dot \phi$ [rad/s]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,3])
plt.plot(time,state_record_f[:,3])
plt.plot(time,state_record_r[:,3])
plt.plot(data[:,11], data[:,5]*2*np.pi/60) # rpm to rad/s
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

# plt.savefig('id_red.png')

# %% [markdown]
# # Blue gimbal in virtual env (no friction)

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record = np.empty([len(time), len(x_0)])
reward_record = np.empty([len(time), 1])
action_record = np.empty([len(time), 2])

for i in range(len(time)):
    action = [0,u[i]] 
    
    observation, reward, done, info = env.step(action)
    state_record[i] = env.state
    reward_record[i] = reward
    action_record[i] = action

# %%
f, axs = plt.subplots(4,2,figsize=(19,19))

plt.subplot(4,2,1)
plt.title('Red gimbal angle',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\theta$ [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,0],'r-')

plt.subplot(4,2,2)
plt.title('Blue gimbal angle',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\phi$ [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,2],'b-')

plt.subplot(4,2,3)
plt.title('Red gimbal speed',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\dot \theta$ [rad/s]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,1],'r-')

plt.subplot(4,2,4)
plt.title('Blue gimbal speed',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\dot \phi$ [rad/s]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,3],'b-')

plt.subplot(4,2,5)
plt.title('Red gimbal tracking error',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\theta$ error [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,0]-state_record[:,4],'r-')

plt.subplot(4,2,6)
plt.title('Blue gimbal tracking error',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\phi$ error [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,2]-state_record[:,5],'b-')

plt.subplot(4,2,7)
plt.title('Red gimbal input',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel('voltage [V]',fontsize=16)
plt.grid()
plt.plot(time,action_record[:,0]*10,'r-')

plt.subplot(4,2,8)
plt.title('Blue gimbal input',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel('voltage [V]',fontsize=16)
plt.grid()
plt.plot(time,action_record[:,1]*10,'b-')

plt.show()

# %% [markdown]
# # Blue gimbal in virtual env (with friction)

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env_f.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record_f = np.empty([len(time), len(x_0)])
reward_record_f = np.empty([len(time), 1])
action_record_f = np.empty([len(time), 2])

for i in range(len(time)):
    action = [0,u[i]] 
    
    observation, reward, done, info = env_f.step(action)
    state_record_f[i] = env_f.state
    reward_record_f[i] = reward
    action_record_f[i] = action

# %% [markdown]
# # Blue gimbal in virtual env (with optimized friction)

# %%
# Initial state
x_0 = [0,0,0,0,0,0,0]
observation = env_b.reset(x_0)

time = np.arange(0, 60, env.dt)
state_record_b = np.empty([len(time), len(x_0)])
reward_record_b = np.empty([len(time), 1])
action_record_b = np.empty([len(time), 2])

for i in range(len(time)):
    action = [0,u[i]] 
    
    observation, reward, done, info = env_b.step(action)
    state_record_b[i] = env_b.state
    reward_record_b[i] = reward
    action_record_b[i] = action

# %% [markdown]
# # Blue gimbal in real machine

# %%
data = read_data('data_blue.txt')

# %%
# there could be some data loss
t = np.around(data[:,11] / 0.02)
# make sure the input PRBS is correct
plt.figure(figsize = (19,5))
plt.grid()
plt.plot([i for i in range(255)], [10*u[i] for i in range(255)])
plt.plot(t[0:255]-1, data[0:255,10])

# %%
f, axs = plt.subplots(2,1,figsize=(16,16))
plt.subplots_adjust(hspace=0.2)

plt.subplot(2,1,1)
plt.title('Blue gimbal angle',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\phi$ [rad]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,2])
plt.plot(time,state_record_f[:,2])
plt.plot(time,state_record_b[:,2])
plt.plot(data[:,11], data[:,4]/180*np.pi) # deg to rad
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

plt.subplot(2,1,2)
plt.title('Blue gimbal speed',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\dot \phi$ [rad/s]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,3])
plt.plot(time,state_record_f[:,3])
plt.plot(time,state_record_b[:,3])
plt.plot(data[:,11], data[:,5]*2*np.pi/60) # rpm to rad/s
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

plt.savefig('id_blue.png')

# %%
f, axs = plt.subplots(2,1,figsize=(16,16))
plt.subplots_adjust(hspace=0.2)

plt.subplot(2,1,1)
plt.title('Red gimbal angle',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\theta$ [rad]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,0])
plt.plot(time,state_record_f[:,0])
plt.plot(time,state_record_b[:,0])
plt.plot(data[:,11], data[:,2]/180*np.pi) # deg to rad
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

plt.subplot(2,1,2)
plt.title('Red gimbal speed',fontsize=24)
plt.xlabel('time [s]',fontsize=20)
plt.ylabel(r'$\dot \theta$ [rad/s]',fontsize=20)
plt.grid()
plt.plot(time,state_record[:,1])
plt.plot(time,state_record_f[:,1])
plt.plot(time,state_record_b[:,1])
plt.plot(data[:,11], data[:,3]*2*np.pi/60) # rpm to rad/s
plt.xlim([0,60])
plt.legend(['Virtual env', 'Virtual env with friction', 
            'Virtual env with optimized friction', 'Real gyro'],fontsize=20)

# plt.savefig('id_blue.png')

# %% [markdown]
# ## Zoom in

# %%
f, axs = plt.subplots(3,1,figsize=(14,10))

t_start = 0
t_end = 20

plt.subplot(3,1,1)
plt.title('Blue gimbal angle',fontsize=20)
plt.xlabel('time [s]',fontsize=16)
plt.ylabel(r'$\phi$ [rad]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,2])
plt.plot(data[:,11], data[:,4]/180*np.pi) # deg to rad
plt.xlim([t_start,t_end])
plt.legend(['Virtual env', 'Real gyro'],fontsize=16)

plt.subplot(3,1,2)
plt.title('Blue gimbal speed',fontsize=20)
plt.xlabel('time (s)',fontsize=16)
plt.ylabel(r'$\dot \phi$ [rad/s]',fontsize=16)
plt.grid()
plt.plot(time,state_record[:,3])
plt.plot(data[:,11], data[:,5]*2*np.pi/60) # rpm to rad/s
plt.xlim([t_start,t_end])
plt.legend(['Virtual env', 'Real gyro'],fontsize=16)

plt.subplot(3,1,3)
plt.title('Input',fontsize=20)
plt.xlabel('time (s)',fontsize=16)
plt.ylabel('voltage (V)',fontsize=16)
plt.grid()
plt.plot(time,u[:len(time)]*10)
plt.plot(data[:,11], data[:,10])
plt.xlim([t_start,t_end])
plt.legend(['Virtual env', 'Real gyro'],fontsize=16)

# %% [markdown]
# ## Acceleration

# %%
plt.figure(figsize = (20,10))

plt.title('Blue gimbal acceleration',fontsize=20)
plt.xlabel('time (s)',fontsize=16)
plt.ylabel(r'$\ddot \phi [rad/s^2] $',fontsize=16)
plt.grid()
b = state_record[:,3] # velocity in rad/s
plt.plot(time[1:], b[1:]-b[:-1]) # acceleration 
r = data[:,5]*2*np.pi/60 # velocity in rad/s
plt.plot(data[1:,11], r[1:]-r[:-1]) # acceleration
plt.xlim([0,60])
plt.legend(['Virtual env', 'Real gyro'],fontsize=16)
