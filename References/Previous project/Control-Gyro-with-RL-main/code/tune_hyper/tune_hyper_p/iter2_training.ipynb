# %% [markdown]
# # DDPG hyperparameter search with p=0.05 reward

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

# %% [markdown]
# ## Baseline

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_base', exp_name='iter2_base'))

# %% [markdown]
# ## Reward tuning

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.075, 
    'qx3': 1, 
    'qx4': 0.075, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_reward01', exp_name='iter2_reward01'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.125, 
    'qx3': 1, 
    'qx4': 0.125, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_reward02', exp_name='iter2_reward02'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.025, 
    'pu2': 0.025,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_reward03', exp_name='iter2_reward03'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.075, 
    'pu2': 0.075,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_reward04', exp_name='iter2_reward04'))

# %% [markdown]
# ## Replay size

# %% [markdown]
# ## Discount factor gamma

# %% [markdown]
# ## Polyak

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.94, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_polyak01', exp_name='iter2_polyak01'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.96, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_polyak02', exp_name='iter2_polyak02'))

# %% [markdown]
# ## Learning rate

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.001,
                    q_lr = 0.001,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_lr01', exp_name='iter2_lr01'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0015,
                    q_lr = 0.0015,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_lr02', exp_name='iter2_lr02'))

# %% [markdown]
# ## Batch size

# %% [markdown]
# ## Start size

# %% [markdown]
# ## Act noise

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.08,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_noise01', exp_name='iter2_noise01'))

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.05, 
    'pu2': 0.05,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 2000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.95, 
                    pi_lr = 0.0012,
                    q_lr = 0.0012,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.12,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_noise02', exp_name='iter2_noise02'))

# %% [markdown]
# ## Final model
# #### But change epochs from 2k to 5k

# %%
# Env function
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'Power'
reward_args = {
    'qx1': 1, 
    'qx2': 0.1, 
    'qx3': 1, 
    'qx4': 0.1, 
    'pu1': 0.075, 
    'pu2': 0.075,
    'p': 0.05
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 5000, 
                    replay_size = 1000000, 
                    gamma = 0.925, 
                    polyak = 0.96, 
                    pi_lr = 0.0015,
                    q_lr = 0.0015,
                    batch_size = 200, 
                    start_steps = 7500,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='iter2_final', exp_name='iter2_final'))
