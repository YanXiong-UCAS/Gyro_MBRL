# %% [markdown]
# # DDPG reward shaping with p=0.1 & e = 40 reward

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path
from scipy.integrate import solve_ivp

import gym_gyroscope_env
import spinup
import torch
from functools import partial

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import create_env
from custom_functions.custom_functions import load_agent
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control
from custom_functions.custom_functions import read_progress

import pickle

# %% [markdown]
# ## Baseline on virtual environment

# %%
env_name = 'GyroscopeEnv-v1'
simu_args = {
    'dt': 0.05,
    'ep_len': 100,
    'seed': 2
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 5000, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 15000,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m0_005', exp_name='m0_005'),
                    save_file = True)

# %% [markdown]
# # Apply m0_005 on real gyro

# %%
pkl_file = open('gyro_data/m0_ep001-010_np.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m0_ep011-020_np.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m0_ep021-030_np.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m0_ep031-040_np.pkl', 'rb')
data4 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m0_ep041-050_np.pkl', 'rb')
data5 = pickle.load(pkl_file)
pkl_file.close()

# %%
data = np.concatenate((data1,data2,data3,data4,data5), axis=0)
data.shape
# Out:
# (750, 111, 9)

# %% [markdown]
# # Continue training on virtual environment

# %%
# env_name = 'GyroscopeEnv-v1'
env_name = 'GyroscopeRealEnv-v0'

# simu_args = {
#     'dt': 0.05,
#     'ep_len': 100,
#     'seed': 2
# }
simu_args = {
    'ep_len': 100,
    'data': data
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

pkl_file = open('m0_005/ac.pkl', 'rb')
trained_ac = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m0_005/ac_targ.pkl', 'rb')
trained_ac_targ = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m0_005/replay_buffer.pkl', 'rb')
trained_bf = pickle.load(pkl_file)
pkl_file.close()

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 50, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 0,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m1_005', exp_name='m1_005'),
                    save_file = True,
                    trained_ac = trained_ac,
                    trained_ac_targ = trained_ac_targ,
                    trained_bf = trained_bf)
# Out:
# Warning: Log dir m1_005 already exists! Storing info there anyway.
# Logging data to m1_005/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ff3dfaf5830>, 'GyroscopeRealEnv-v0', simu_args={'ep_len': 100, 'data': array([[[ 6.81725606e-01,  5.84947064e-01, -6.66017643e-01, ...,\n          1.54524916e+01,  1.52331500e-01, -8.49609000e-02],\n        [ 6.94291976e-01,  3.30520366e-01, -5.56061900e-01, ...,\n          1.53369343e+01,  9.92000000e-01, -3.07617200e-01],\n        [ 7.16283125e-01,  3.48582324e-01, -5.12079603e-01, ...,\n          1.52540596e+01,  9.92000000e-01, -9.27730000e-03],\n        ...,\n        [ 2.39232281e+00, -2.20878238e+00,  8.15243294e-01, ...,\n          1.56201115e+01,  9.92000000e-01, -1.00000000e+00],\n        [ 2.27451308e+00, -2.56167999e+00,  6.29889327e-01, ...,\n          1.60015393e+01,  9.92000000e-01,  1.00000000e+00],\n        [ 2.22267680e+00, -1.50769178e+00,  4.33539786e-01, ...,\n          1.59820699e+01,  4.93698700e-01,  7.58789100e-01]],\n\n       [[ 2.26665910e+00, -8.75980961e-01, -2.57610598e+00, ...,\n          2.52903847e+01,  6.47788100e-01, -1.00000000e+00],\n        [ 2.32477856e+00,  6.88223781e-01, -2.46772103e+00, ...,\n          2.54938397e+01,  8.55927200e-01, -1.00000000e+00],\n        [ 2.39546440e+00,  1.42384550e+00, -2.66092898e+00, ...,\n          2.58154607e+01,  9.92000000e-01,  6.75781200e-01],\n        ...,\n        [-2.00590691e+00,  5.95705239e-01,  1.87867241e+00, ...,\n          2.57068309e+01, -9.50000000e-01, -4.34570300e-01],\n        [-2.05460160e+00, -5.19376999e-01,  1.51738925e+00, ...,\n          2.59123853e+01,  1.52331500e-01,  1.00000000e+00],\n        [-2.10957947e+00, -1.14983286e+00,  1.23935830e+00, ...,\n          2.62915243e+01,  7.33129900e-01,  1.00000000e+00]],\n\n       [[ 2.18340689e+00,  5.28246427e+00,  1.04929195e+00, ...,\n          2.61553401e-01,  1.53105000e-02, -1.00000000e+00],\n        [ 2.44572988e+00,  5.28869761e+00,  8.54513202e-01, ...,\n          4.31150814e-01,  3.21592800e-
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.7000,  -5.6145,  -8.1448,  -6.8575,  -9.7258,  -1.3593,  -3.9322,\n         -8.7503,  -5.3332,  -9.0568,   1.0134,  -5.9357,  -6.4915,  -9.1702,\n         -5.6629,  -3.9901,  -8.2581,  -9.1320,  -2.6525,  -3.4965,  -9.9694,\n         -7.6488,  -5.6218, -12.1366,  -7.3685,  -6.4020,  -1.0246,  -5.4174,\n         -9.1276,  -5.5616,   0.1327,  -5.3302,  -1.8712,  -0.5167,  -6.7604,\n         -6.6102,  -3.0919,  -8.9502,  -2.4533,  -7.3219,  -8.7825,  -4.2341,\n         -9.8537,  -8.4576,  -2.0213,  -5.3700,  -3.9261,  -5.7497,  -7.5263,\n         -9.3468,  -3.4377,  -4.9027,  -6.0455, -10.2410,  -8.2264,  -7.8728,\n         -8.1670,  -7.9874,  -4.1103,  -3.6366,  -9.2454,  -7.1753,  -8.1225,\n         -4.7195,  -6.0973,  -6.1057,  -7.0409,  -5.5381,  -7.2371,  -9.2912,\n         -8.9251,  -4.5113,  -3.2454,  -3.7512,  -3.2950,  -7.7430,  -0.1092,\n        -10.4268,  -7.8825,  -3.4879,  -3.9849,  -5.2815,  -7.6512,  -4.5478,\n          0.5024, -12.3478,  -5.9750,  -1.2653,  -9.0933,  -6.0898,  -6.0991,\n         -2.6548,  -0.2436,  -4.9860,  -2.0310,  -0.8955,  -7.9015,  -3.4654
1.2769e-02,  9.3406e-02,  2.7965e-02, -1.4505e-01,\n         -1.4915e-01,  6.9468e-01],\n        [-1.0968e-01, -2.8201e-01,  1.5724e-01, -1.0918e-01, -3.6051e-03,\n          1.5972e-02,  4.1893e-02,  3.1283e-01,  8.7162e-04, -1.2783e-01,\n          8.1273e-02,  1.6608e-03,  2.9891e-02,  2.2348e-01,  1.6695e-01,\n          9.3786e-03, -7.5460e-02, -1.3314e-01, -1.1518e-01,  1.2713e-01,\n          1.1362e-01, -5.5357e-02,  2.1724e-02,  7.7919e-03,  1.0743e-01,\n          1.7558e-02, -1.8645e-01, -1.3117e-03,  3.4377e-01,  4.2734e-03,\n          3.1521e-03,  1.3893e-02]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.6642e+00,  7.3925e+00,  1.9596e-02, -1.2561e+01,  1.8304e+00,\n        -5.8734e+00, -2.8144e-02, -1.4071e+01, -1.3077e+01,  3.9624e+00,\n        -8.0609e-02, -3.3875e+00,  9.1106e+00,  1.6791e+00, -6.8093e+00,\n        -6.5748e+00, -8.3151e+00, -6.7792e+00, -1.3524e+00, -2.2308e+00,\n        -9.5741e+00, -6.9899e+00,  1.0721e+00, -2.0890e+00, -2.6835e-01,\n        -1.2485e+01,  4.3698e+00,  2.7101e-01,  5.8019e-01, -1.1513e+01,\n         5.3499e-03, -7.2313e+00, -3.5596e+00,  1.0168e-01, -8.2986e-01,\n        -8.9995e+00,  2.1792e+00,  3.1388e+00, -5.6868e-01, -2.7389e+00,\n        -1.0308e+01, -1.2985e-01, -4.1283e+00, -9.1912e+00,  6.3275e-02,\n        -5.6249e+00,  4.4116e+00, -1.3570e+00, -9.9044e+00, -
ires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0544e-02,  6.5698e-02, -8.4443e-03,  ..., -4.2085e-02,\n         -9.9345e-02, -4.1872e-02],\n        [-3.5127e-02, -3.5187e-02, -3.5977e-02,  ..., -4.2726e-02,\n         -3.9361e-02,  2.6798e-02],\n        [ 4.4061e+00,  6.9371e+00, -3.7529e+00,  ...,  5.2457e-02,\n         -5.3947e-01, -2.9986e+00],\n        ...,\n        [ 4.1420e-02, -9.7629e-02, -9.2679e-02,  ..., -1.4161e-02,\n          1.7957e-02, -5.4993e-02],\n        [ 5.9673e+00,  4.0463e+00,  1.4885e+00,  ..., -1.0758e-01,\n          4.2089e+00, -9.1922e+00],\n        [ 1.4138e+01,  1.2891e+00, -2.5477e-01,  ...,  3.1950e-02,\n         -3.4286e-01,  1.8907e+00]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-15.4156], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0582,  0.0168, -0.0848, -0.1314,  0.1131,  0.1038, -0.1767,  0.0582,\n         -0.0034,  0.1523,  0.0558, -0.1186, -0.1255,  0.0573,  0.1260,  0.1286,\n         -0.1766, -0.0309, -0.0583, -0.3673,  0.0461, -0.0855,  0.0355, -0.0415,\n          0.0740, -0.0158, -0.1007, -0.0019,  0.1374,  0.1100, -0.0989, -0.1295]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Identity()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "trained_ac_targ":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.7362,  -5.5917,  -8.1462,  -6.8980,  -9.7615,  -1.3580,  -3.9477,\n         -8.7462,  -5.3117,  -9.0718,   1.0122,  -5.9581,  -6.4830,  -9.1646,\n         -5.6731,  -3.9731,  -8.2792,  -9.1683,  -2.6972,  -3.4981,  -9.9381,\n         -7.6537,  -5.6105, -12.1457,  -7.3586,  -6.4160,  -1.0377,  -5.4241,\n         -9.1428,  -5.6036,   0.1576,  -5.3345,  -1.8493,  -0.5335,  -6.7674,\n         -6.5971,  -3.0663,  -8.9402,  -2.4712,  -7.3459,  -8.8660,  -4.2302,\n         -9.8355,  -8.3984,  -2.0027,  -5.3740,  -3.9205,  -5.7418,  -7.5279,\n         -9.3240,  -3.4478,  -4.8960,  -6.0408, -10.2241,  -8.2238,  -7.8683,\n         -8.1658,  -7.9913,  -4.1143,  -3.6409,  -9.1964,  -7.1446,  -8.0989,\n         -4.7289,  -6.0679,  -6.1513,  -7.0173,  -5.5175,  -7.2109,  -9.3219,\n         -8.9193,  -4.5061,  -3.2186,  -3.7422,  -3.3062,  -7.7465,  -0.1355,\n        -10.4262,  -7.9391,  -3.4843,  -3.9794,  -5.3003,  -7.6363,  -4.5327,\n          0.5126, -12.3663,  -5.9447,  -1.2526,  -9.0847,  -6.0922,  -6.1036,\n         -2.6423,  -0.2711,  -4.9943,  -2.0065,  -0.9053,  -7.8751,  -3.4535,\n         -0.1371,  -4.2682,  -3.1566,  -6.3429,  -3.3981,   1.4854,  -0.7399,\n         -5.1901,  -7.5560,  -4.7341,  -3.2094,  -4.4024,  -1.3153,  -9.3597,\n         -5.0146,  -9.4897,  -8.0503,  -7.5908,  -8.5917,  -4.6713,  -9.4458,\n         -4.1291,  -2.6241, -11.0592,  -8.0107,  -7.9305,  -4.4308,  -3.2595,\n         -6.8755,  -6.1697])",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0651e+00,  3.4813e+00, -2.8532e+00,  ..., -6.2780e+00,\n         -2.2736e-01, -6.3961e-02],\n        [ 4.2712e+00, -7.4029e-01,  4.1870e+00,  ..., -1.0726e+01,\n         -2.6041e-01,  1.5919e+00],\n        [ 6.7274e-01,  5.2950e+00,  3.9418e+00,  ..., -6.9881e+00,\n         -3.8871e-01,  3.1514e+00],\n        ...,\n        [ 2.9665e+00,  3.2770e+00,  3.0129e+00,  ..., -4.8440e+00,\n         -3.2606e-01,  2.0955e+00],\n        [-2.3289e-02,  4.4104e-02,  8.8952e-01,  ..., -6.6429e-02,\n          8.4590e+00, -4.2815e-01],\n        [-9.3306e-03,  1.0405e-01,  4.3718e+00,  ..., -5.9801e-02,\n         -2.2937e+00, -3.8134e+00]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":

#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.6773e+00,  7.3916e+00,  1.5414e-02, -1.2564e+01,  1.8352e+00,\n        -5.8551e+00, -2.8144e-02, -1.4048e+01, -1.3073e+01,  3.9689e+00,\n        -8.0605e-02, -3.3777e+00,  9.1065e+00,  1.6712e+00, -6.7995e+00,\n        -6.5710e+00, -8.2965e+00, -6.7706e+00, -1.3441e+00, -2.2234e+00,\n        -9.5761e+00, -6.9833e+00,  1.0745e+00, -2.0985e+00, -2.6833e-01,\n        -1.2476e+01,  4.3657e+00,  2.8328e-01,  5.7708e-01, -1.1489e+01,\n        -8.1157e-03, -7.2461e+00, -3.5625e+00,  8.7762e-02, -8.2952e-01,\n        -8.9928e+00,  2.1729e+00,  3.1452e+00, -5.8095e-01, -2.7142e+00,\n        -1.0325e+01, -1.2389e-01, -4.1151e+00, -9.1816e+00,  4.9529e-02,\n        -5.6193e+00,  4.4016e+00, -1.3818e+00, -9.8970e+00, -7.0504e+00,\n        -5.1004e+00,  9.3166e-01, -1.2055e+01, -1.2023e+01, -2.2915e-01,\n        -3.6366e+00, -6.5387e+00, -7.9970e+00, -3.5990e+00, -1.1093e+01,\n        -4.6869e+00, -1.4866e+00,  8.4785e-01, -6.5212e-01, -4.1176e+00,\n        -4.7775e+00, -1.7096e+00, -6.7826e+00,  4.4764e-01, -4.2463e+00,\n        -1.3091e+00, -6.1025e-02, -3.8805e+00, -6.7724e+00, -4.8351e+00,\n        -7.3094e+00, -1.0028e+01, -1.1017e+01, -6.1774e+00,  7.3222e+00,\n         1.4900e+00, -5.9515e+00, -1.8647e+00, -7.9071e+00, -3.8402e+00,\n        -4.3907e+00, -1.3948e+01, -7.2511e-01,  5.9376e+00, -4.2876e+00,\n        -6.1192e+00, -5.3708e+00, -7.4314e+00,  4.1273e+00, -1.5046e+00,\n        -2.8917e+00, -5.0896e-01,  8.2603e+00, -1.0367e+00, -1.2285e+00,\n        -6.0651e+00, -4.2384e+00, -2.0320e+00,  7.1363e+00,  1.1697e+00,\n         8.6162e-01, -2.7682e+00,  9.2597e-01, -6.5293e+00, -7.7968e+00,\n         8.4915e-01, -7.5365e-01, -2.6231e+00,  7.6935e+00,  2.4325e+00,\n        -6.6270e-02, -3.2685e-01, -1.3367e+01, -8.9122e+00, -3.7902e-01,\n        -7.2808e+00, -4.5972e+00, -1.5940e+01, -7.9631e+00, -6.4658e+00,\n        -1.2301e-01, -1.8137e+00, -8.5995e+00])",
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            24.7 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -469 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |           -57.3 |
# |          StdQVals |            8.25 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -112 |
# |            LossPi |            57.1 |
# |             LossQ |           0.484 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            -390 |
# |      StdTestEpRet |            21.3 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -435 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.29 |
# |          MaxQVals |           -47.8 |
# |          MinQVals |            -114 |
# |            LossPi |            57.1 |
# |             LossQ |           0.485 |
# |              Time |             318 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -446 |
# |  AverageTestEpRet |            -410 |
# |      StdTestEpRet |            29.9 |
# |      MaxTestEpRet |            -356 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.28 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -112 |
# |            LossPi |            57.1 |
# |             LossQ |           0.476 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            23.4 |
# |      MaxTestEpRet |            -360 |
# |      MinTestEpRet |            -430 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |             8.3 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -112 |
# |            LossPi |            57.1 |
# |             LossQ |           0.483 |
# |              Time |             336 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -463 |
# |  AverageTestEpRet |            -403 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -444 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -57.3 |
# |          StdQVals |            8.28 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -125 |
# |            LossPi |            57.1 |
# |             LossQ |           0.489 |
# |              Time |             346 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            19.6 |
# |          MaxEpRet |            -386 |
# |          MinEpRet |            -446 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -434 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.26 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -110 |
# |            LossPi |            57.1 |
# |             LossQ |           0.472 |
# |              Time |             356 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |            -340 |
# |          MinEpRet |            -440 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            19.9 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.29 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -113 |
# |            LossPi |            57.1 |
# |             LossQ |           0.481 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -417 |
# |          StdEpRet |            31.5 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -486 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            17.1 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |            -423 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.26 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -118 |
# |            LossPi |            57.1 |
# |             LossQ |           0.481 |
# |              Time |             374 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |              27 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            33.4 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -470 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.29 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -115 |
# |            LossPi |            57.2 |
# |             LossQ |           0.501 |
# |              Time |             383 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -434 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -475 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |             8.3 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -112 |
# |            LossPi |            57.2 |
# |             LossQ |           0.503 |
# |              Time |             392 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |            -375 |
# |          MinEpRet |            -437 |
# |  AverageTestEpRet |            -420 |
# |      StdTestEpRet |            38.5 |
# |      MaxTestEpRet |            -374 |
# |      MinTestEpRet |            -486 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.28 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -114 |
# |            LossPi |            57.2 |
# |             LossQ |           0.489 |
# |              Time |             402 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -402 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -436 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            30.7 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.28 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -118 |
# |            LossPi |            57.2 |
# |             LossQ |           0.503 |
# |              Time |             412 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -412 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -422 |
# |      StdTestEpRet |            20.3 |
# |      MaxTestEpRet |            -374 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -57.4 |
# |          StdQVals |            8.29 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -123 |
# |            LossPi |            57.2 |
# |             LossQ |           0.497 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -433 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            23.3 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |            -434 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.38 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -114 |
# |            LossPi |            57.2 |
# |             LossQ |           0.511 |
# |              Time |             430 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -440 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            22.7 |
# |      MaxTestEpRet |            -363 |
# |      MinTestEpRet |            -431 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.35 |
# |          MaxQVals |           -47.9 |
# |          MinQVals |            -111 |
# |            LossPi |            57.2 |
# |             LossQ |            0.51 |
# |              Time |             439 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -416 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.29 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -109 |
# |            LossPi |            57.2 |
# |             LossQ |           0.496 |
# |              Time |             448 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |            20.8 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |            -440 |
# |  AverageTestEpRet |            -411 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -450 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.29 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -112 |
# |            LossPi |            57.2 |
# |             LossQ |           0.502 |
# |              Time |             457 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -418 |
# |      StdTestEpRet |            27.3 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.33 |
# |          MaxQVals |           -47.8 |
# |          MinQVals |            -111 |
# |            LossPi |            57.3 |
# |             LossQ |           0.506 |
# |              Time |             467 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -380 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            19.4 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |           -57.5 |
# |          StdQVals |            8.32 |
# |          MaxQVals |           -47.9 |
# |          MinQVals |            -114 |
# |            LossPi |            57.3 |
# |             LossQ |           0.504 |
# |              Time |             476 |
# ---------------------------------------

# %%
progress = read_progress('m1_005')
np.mean(progress[:,1])
# Out:
# -405.35034060000004

# %% [markdown]
# # Apply m1_005 on real gyro

# %%
pkl_file = open('gyro_data/m1_ep001-010_np.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m1_ep011-020_np.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m1_ep021-030_np.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m1_ep031-040_np.pkl', 'rb')
data4 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m1_ep041-050_np.pkl', 'rb')
data5 = pickle.load(pkl_file)
pkl_file.close()

# %%
data = np.concatenate((data1,data2,data3,data4,data5), axis=0)
data.shape
# Out:
# (750, 111, 9)

# %% [markdown]
# # Continue training on virtual environment

# %%
# env_name = 'GyroscopeEnv-v1'
env_name = 'GyroscopeRealEnv-v0'

# simu_args = {
#     'dt': 0.05,
#     'ep_len': 100,
#     'seed': 2
# }
simu_args = {
    'ep_len': 100,
    'data': data
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

pkl_file = open('m1_005/ac.pkl', 'rb')
trained_ac = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m1_005/ac_targ.pkl', 'rb')
trained_ac_targ = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m1_005/replay_buffer.pkl', 'rb')
trained_bf = pickle.load(pkl_file)
pkl_file.close()

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 50, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 0,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m2_005', exp_name='m2_005'),
                    save_file = True,
                    trained_ac = trained_ac,
                    trained_ac_targ = trained_ac_targ,
                    trained_bf = trained_bf)
# Out:
# Warning: Log dir m2_005 already exists! Storing info there anyway.
# Logging data to m2_005/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ff3dfaf5830>, 'GyroscopeRealEnv-v0', simu_args={'ep_len': 100, 'data': array([[[-1.49225651e-01, -2.75454488e+00,  5.34070751e-02, ...,\n          2.63758726e+01,  1.38700000e-04,  0.00000000e+00],\n        [-1.72787596e-01, -1.12808801e+00, -2.65464579e-01, ...,\n          2.63187603e+01,  1.81252900e-01,  1.00000000e+00],\n        [-1.13097336e-01,  6.97375345e-01, -3.54999970e-01, ...,\n          2.62789337e+01,  9.92000000e-01,  1.00000000e+00],\n        ...,\n        [-6.53451272e-01, -1.90758920e+00,  1.48754412e+00, ...,\n          2.60885500e+01, -6.17641100e-01, -3.26660200e-01],\n        [-8.16814090e-01, -3.17507470e+00,  1.77499985e+00, ...,\n          2.69022117e+01,  9.92000000e-01, -1.00000000e+00],\n        [-9.22057444e-01, -2.50993702e+00,  1.93365028e+00, ...,\n          2.72931662e+01,  9.92000000e-01, -2.15332000e-01]],\n\n       [[ 1.75143790e+00,  2.96481628e-01, -2.21325202e+00, ...,\n         -1.01714301e+01, -7.40912600e-01,  5.86425800e-01],\n        [ 1.66975650e+00, -1.10279746e+00, -1.66661490e+00, ...,\n         -1.04179307e+01, -7.92117700e-01, -6.25488300e-01],\n        [ 1.53152642e+00, -2.38192173e+00, -1.28176980e+00, ...,\n         -1.10127380e+01, -9.50000000e-01, -1.00000000e+00],\n        ...,\n        [ 5.45066325e-01,  2.77984454e-01, -1.67446888e+00, ...,\n         -1.11287709e+01, -7.88324700e-01,  7.81738300e-01],\n        [ 5.10508806e-01, -4.56841293e-01, -1.50482288e+00, ...,\n         -1.14022283e+01, -1.16495100e-01,  1.00000000e+00],\n        [ 4.69668102e-01, -8.11561242e-01, -1.22836273e+00, ...,\n         -1.16623240e+01, -1.58691900e-01, -1.00000000e+00]],\n\n       [[ 1.93050869e+00,  1.79436997e+00, -1.50953527e+00, ...,\n         -6.27843627e+00, -9.50000000e-01, -1.00000000e+00],\n        [ 1.97449098e+00,  1.11399315e+00, -1.24407069e+00, ...,\n         -6.57692202e+00, -6.56519000e-01, -1.78222700e-01],\n        [ 1.97763258e+00,  3.11312145e-01, -1.09798663e+00, ...,\n         -7.16812085e+00, -4.32259800e-01, -1.44531200e-01],\n        ...,\n        [ 1.47183616e+00, -2.61225524e-02,  2.28865025e+00, ...,\n         -8.93418497e+00, -9.50000000e-01, -6.45507800e-01],\n        [ 1.40900431e+00, -9.71034036e-01,  2.39389360e+00, ...,\n         -8.64839292e+00,  9.92000000e-01, -1.00000000e+00],\n        [ 1.36030962e+00, -1.12461425e+00,  2.26194671e+00, ...,\n         -8.43603896e+00,  9.92000000e-01, -4.55566400e-01]],\n\n       ...,\n\n       [[-3.11803071e+00, -4.58668339e-02, -1.97134939e+00, ...,\n          2.51038558e+01,  8.94331100e-01,  1.00000000e+00],\n        [-3.11488912e+00, -8.20102290e-03, -1.98234496e+00, ...,\n          2.50977360e+01,  9.92000000e-01,  1.48437500e-01],\n        [-3.08190239e+00,  4.39167426e-01, -1.89280957e+00, ...,\n          2.51971306e+01,  9.92000000e-01,  1.00000000e+00],\n        ...,\n        [-1.60849544e+00,  2.58112205e-02,  8.78075147e-01, ...,\n          2.50411006e+01, -9.50000000e-01,  1.00000000e+00],\n        [-1.60221225e+00,  1.09475184e-01,  7.50840644e-01, ...,\n          2.51355791e+01,  3.93160000e-03,  1.00000000e+00],\n        [-1.59907066e+00,  9.03310513e-02,  7.80685774e-01, ...,\n          2.51854348e+01, -4.25147900e-01,  1.00000000e+00]],\n\n       [[ 8.32522053e-02,  6.62133105e+00,  1.40272112e+00, ...,\n          6.51515841e+00, -6.26649400e-01,  6.54785200e-01],\n        [ 3.95840674e-01,  6.39152198e+00,  1.46084058e+00, ...,\n          6.64624556e+00, -8.50908700e-01,  1.00000000e+00],\n        [ 6.80154810e-01,  5.84377724e+00,  1.63519898e+00, ...,\n          6.90881160e+00, -7.14536000e-02,  1.00000000e+00],\n        ...,\n        [-2.65464579e+00, -1.52171732e-01, -2.13471221e+00, ...,\n          6.72115673e+00,  9.92000000e-01, -8.54003900e-01],\n        [-2.62165907e+00,  4.33584502e-01, -2.07659274e+00, ...,\n          7.00950383e+00,  2.59482900e-01, -4.77050800e-01],\n        [-2.57296438e+00,  8.96883757e-01, -2.18340689e+00, ..., ...
#     "epochs":	50,
#     "exp_name":	"m2_005",
#     "gamma":	0.96,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7ff349ac98d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"m2_005",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"m2_005",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='m2_005/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"m2_005",
#         "output_dir":	"m2_005"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.002,
#     "polyak":	0.999,
#     "q_lr":	0.002,
#     "replay_size":	8000000,
#     "save_file":	true,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	0,
#     "steps_per_epoch":	1500,
#     "trained_ac":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.5133,  -5.6188,  -8.2932,  -6.9076,  -9.8219,  -1.3206,  -3.9495,\n         -8.8713,  -5.5572,  -9.1489,   0.9832,  -5.9850,  -6.4922,  -9.1592,\n         -5.8048,  -4.0677,  -8.5155,  -9.1551,  -2.5683,  -3.4604,  -9.8725,\n         -7.5411,  -5.6239, -12.1744,  -7.3182,  -6.5037,  -1.1490,  -5.4051,\n         -9.3417,  -5.7261,   0.2777,  -5.2644,  -1.9705,  -0.5163,  -6.6125,\n         -6.4553,  -3.2153,  -9.1358,  -2.4784,  -7.2500,  -8.6977,  -4.1187,\n         -9.7781,  -8.3488,  -1.9684,  -5.4624,  -3.9713,  -5.9159,  -7.5371,\n         -9.2472,  -3.6317,  -4.9659,  -6.1423, -10.3064,  -8.2651,  -7.8759,\n         -8.1921,  -8.0651,  -4.0176,  -3.6051,  -9.2909,  -7.3302,  -8.0307,\n         -4.7406,  -6.0116,  -6.0492,  -6.9970,  -5.4315,  -7.0781,  -9.3205,\n         -9.0235,  -4.4965,  -3.2709,  -3.7901,  -3.3527,  -7.6625,  -0.2096,\n        -10.4268,  -8.0132,  -3.6011,  -4.0454,  -4.9113,  -7.6749,  -4.5434,\n          0.3368, -12.3729,  -5.8784,  -1.0688,  -9.0049,  -6.1594,  -6.1584,\n         -2.6593,  -0.1340,  -4.9838,  -2.1301,  -0.7973,  -7.8230,  -3.6272,\n         -0.2222,  -4.3672,  -3.1517,  -6.4005,  -3.4377,   1.5053,  -0.7862,\n         -5.3688,  -7.7260,  -4.7586,  -3.2248,  -4.4427,  -1.2960,  -9.5036,\n         -4.8758,  -9.5386,  -8.0981,  -7.3807,  -8.5731,  -4.7506,  -9.4425,\n         -4.1491,  -2.5667, -11.3124,  -8.2368,  -7.9773,  -4.4304,  -3.3457,\n         -6.9210,  -6.0796], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor
ires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.7499e+00,  7.5895e+00,  1.4170e-02, -1.2513e+01,  1.9042e+00,\n        -5.8072e+00, -2.8144e-02, -1.4093e+01, -1.2980e+01,  4.0831e+00,\n        -8.0609e-02, -3.4855e+00,  9.1161e+00,  1.6549e+00, -6.9025e+00,\n        -6.2974e+00, -8.4551e+00, -6.8485e+00, -1.4341e+00, -2.2433e+00,\n        -9.8656e+00, -6.8723e+00,  1.2789e+00, -1.8977e+00, -2.6835e-01,\n        -1.2669e+01,  4.1500e+00,  2.5955e-01,  5.2567e-01, -1.1475e+01,\n        -2.4598e-02, -7.3150e+00, -3.5098e+00, -7.6697e-02, -4.7201e-01,\n        -9.0678e+00,  2.3670e+00,  3.1366e+00, -6.3189e-01, -2.7108e+00,\n        -1.0236e+01, -1.5276e-01, -4.2842e+00, -9.4749e+00,  7.3618e-02,\n        -5.5407e+00,  4.4334e+00, -1.0658e+00, -9.9355e+00, -7.1557e+00,\n        -5.1584e+00,  8.0705e-01, -1.2289e+01, -1.1702e+01, -2.8377e-01,\n        -3.4070e+00, -6.6707e+00, -8.0076e+00, -3.2543e+00, -1.1410e+01,\n        -4.6610e+00, -1.4665e+00,  8.3009e-01, -5.9921e-01, -3.9226e+00,\n        -4.7733e+00, -1.6637e+00
ires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0544e-02,  6.5698e-02, -8.4443e-03,  ..., -4.2085e-02,\n         -9.9345e-02, -4.1872e-02],\n        [-3.5127e-02, -3.5187e-02, -3.5977e-02,  ..., -4.2726e-02,\n         -3.9361e-02,  2.6798e-02],\n        [ 4.5647e+00,  6.9086e+00, -4.1577e+00,  ...,  5.2457e-02,\n         -7.4758e-01, -2.6698e+00],\n        ...,\n        [ 4.1420e-02, -9.7629e-02, -9.2679e-02,  ..., -1.4161e-02,\n          1.7957e-02, -5.4993e-02],\n        [ 6.0943e+00,  4.0463e+00,  1.3495e+00,  ..., -1.0758e-01,\n          4.4173e+00, -9.9459e+00],\n        [ 1.4133e+01,  1.2673e+00, -2.5588e-01,  ...,  3.1950e-02,\n         -4.2322e-01,  1.6104e+00]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-15.6025], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0582,  0.0168, -0.1027, -0.1274,  0.1131,  0.1222, -0.1776,  0.0582,\n         -0.0034,  0.1523,  0.0558, -0.0925, -0.1031,  0.0573,  0.1143,  0.0696,\n         -0.1732, -0.0309, -0.0681, -0.3661,  0.0461, -0.0802,  0.0355, -0.0415,\n          0.0740, -0.0158, -0.1106, -0.0019,  0.1520,  0.1100, -0.0918, -0.1315]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Identity()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "trained_ac_targ":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor
":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.7246e+00,  7.5898e+00,  9.3180e-03, -1.2520e+01,  1.8971e+00,\n        -5.8104e+00, -2.8144e-02, -1.4108e+01, -1.2960e+01,  4.0891e+00,\n        -8.0605e-02, -3.4953e+00,  9.1208e+00,  1.6560e+00, -6.8896e+00,\n        -6.3124e+00, -8.4650e+00, -6.8377e+00, -1.4361e+00, -2.2222e+00,\n        -9.8780e+00, -6.8757e+00,  1.2545e+00, -1.8918e+00, -2.6833e-01,\n        -1.2660e+01,  4.1499e+00,  2.6106e-01,  5.2157e-01, -1.1520e+01,\n        -1.3337e-02, -7.3112e+00, -3.5312e+00, -7.8336e-02, -4.8625e-01,\n        -9.0618e+00,  2.3547e+00,  3.1401e+00, -6.5240e-01, -2.7037e+00,\n        -1.0242e+01, -1.5674e-01, -4.2890e+00, -9.4835e+00,  6.9538e-02,\n        -5.5324e+00,  4.4269e+00, -1.0640e+00, -9.9305e+00, -7.1598e+00,\n        -5.1654e+00,  8.3741e-01, -1.2276e+01, -1.1728e+01, -2.8916e-01,\n        -3.4161e+00, -6.6571e+00, -8.0071e+00, -3.2515e+00, -1.1376e+01,\n        -4.6475e+00, -1.4673e+00,  8.3936e-01, -6.1057e-01, -3.9184e+00,\n        -4.7714e+00, -1.6602e+00, -6.8719e+00,  4.8462e-01, -4.2142e+00,\n        -1.2194e+00, -1.4025e-01, -3.8497e+00, -6.7700e+00, -4.9620e+00,\n        -7.1672e+00, -1.0079e+01, -1.1080e+01, -6.3333e+00,  7.3075e+00,\n         1.4121e+00, -6.0231e+00, -1.9130e+00, -7.8680e+00, -3.8405e+00,\n        -4.4485e+00, -1.3989e+01, -6.4011e-01,  5.9778e+00, -4.4347e+00,\n        -6.1882e+00, -5.6185e+00, -7.4989e+00,  4.1977e+00, -1.5157e+00,\n        -2.9745e+00, -4.9737e-01,  8.3719e+00, -1.0923e+00, -1.3236e+00,\n        -6.1390e+00, -3.9211e+00, -2.0961e+00,  7.1948e+00,  1.2375e+00,\n         3.7275e-01, -2.8081e+00,  7.9602e-01, -6.4751e+00, -8.0876e+00,\n         7.5888e-01, -7.5199e-01, -2.5070e+00,  7.6507e+00,  2.4545e+00,\n        -6.6270e-02, -4.0496e-01, -1.3493e+01, -8.9554e+00, -3.7902e-01,\n        -7.1466e+00, -4.4260e+00, -1.6074e+01, -7.9359e+00, -6.4862e+00,\n        -1.2301e-01, -1.6161e+00, -8.6675e+00])",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.5213e-01, -4.2506e-02, -3.9058e-02,  ...,  6.5153e-02,\n          2.6909e-03,  4.0449e-01],\n        [-4.2846e+00, -1.0861e+00,  3.4100e+00,  ...,  9.0047e-03,\n          1.8556e-01,  6.9238e-02],\n        [ 2.7199e-02, -6.4411e-03,  1.6142e+01,  ..., -2.6910e-02,\n          1.2750e+00, -3.1038e-02],\n        ...,\n        [ 1.1620e-02,  2.1487e-03,  4.2147e-04,  ...,  3.1047e-03,\n          2.4454e-02,  4.5736e-03],\n        [ 4.6470e-02, -2.7102e-01,  4.2136e+00,  ..., -3.5510e+00,\n          2.8247e-01,  8.6360e-01],\n        [ 1.0255e-02,  1.8316e-02,  1.0826e+00,  ...,  2.4717e-02,\n          6.1061e-02,  8.2527e-01]])"
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            28.8 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.35 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -114 |
# |            LossPi |            57.4 |
# |             LossQ |           0.571 |
# |              Time |             302 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -441 |
# |  AverageTestEpRet |            -421 |
# |      StdTestEpRet |            27.5 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -481 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.35 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -115 |
# |            LossPi |            57.4 |
# |             LossQ |           0.571 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -421 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -413 |
# |      StdTestEpRet |            20.2 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.39 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -114 |
# |            LossPi |            57.4 |
# |             LossQ |           0.592 |
# |              Time |             323 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            22.1 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.38 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -112 |
# |            LossPi |            57.4 |
# |             LossQ |           0.566 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -418 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -490 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |             8.4 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -131 |
# |            LossPi |            57.4 |
# |             LossQ |           0.581 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -399 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -434 |
# |  AverageTestEpRet |            -403 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |            -374 |
# |      MinTestEpRet |            -432 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |           -57.6 |
# |          StdQVals |            8.35 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -112 |
# |            LossPi |            57.4 |
# |             LossQ |           0.561 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -402 |
# |          StdEpRet |            25.9 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            22.9 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -437 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.41 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -114 |
# |            LossPi |            57.4 |
# |             LossQ |           0.583 |
# |              Time |             359 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            22.8 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -452 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |              21 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -442 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.36 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -122 |
# |            LossPi |            57.4 |
# |             LossQ |           0.578 |
# |              Time |             368 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            20.5 |
# |      MaxTestEpRet |            -374 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.36 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -115 |
# |            LossPi |            57.4 |
# |             LossQ |           0.586 |
# |              Time |             378 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |            -366 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -409 |
# |      StdTestEpRet |            31.2 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -487 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.39 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -114 |
# |            LossPi |            57.4 |
# |             LossQ |           0.589 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |            -357 |
# |      MinTestEpRet |            -454 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |             8.4 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -115 |
# |            LossPi |            57.4 |
# |             LossQ |           0.594 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |            -462 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            30.6 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -467 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.36 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -115 |
# |            LossPi |            57.4 |
# |             LossQ |           0.594 |
# |              Time |             405 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            30.5 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -483 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |            -426 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -57.6 |
# |          StdQVals |            8.33 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -112 |
# |            LossPi |            57.4 |
# |             LossQ |           0.592 |
# |              Time |             414 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            30.2 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |            20.2 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |           -57.8 |
# |          StdQVals |            8.47 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -117 |
# |            LossPi |            57.5 |
# |             LossQ |           0.594 |
# |              Time |             424 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            29.6 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -382 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |            -414 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.45 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -117 |
# |            LossPi |            57.5 |
# |             LossQ |           0.611 |
# |              Time |             433 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            16.5 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            27.5 |
# |      MaxTestEpRet |            -352 |
# |      MinTestEpRet |            -442 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |             8.4 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -113 |
# |            LossPi |            57.5 |
# |             LossQ |           0.597 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -452 |
# |  AverageTestEpRet |            -415 |
# |      StdTestEpRet |              28 |
# |      MaxTestEpRet |            -365 |
# |      MinTestEpRet |            -461 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.38 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -111 |
# |            LossPi |            57.4 |
# |             LossQ |           0.592 |
# |              Time |             452 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |            -372 |
# |          MinEpRet |            -448 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            18.1 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.39 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -118 |
# |            LossPi |            57.5 |
# |             LossQ |           0.601 |
# |              Time |             461 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            -413 |
# |      StdTestEpRet |            26.1 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |           -57.7 |
# |          StdQVals |            8.44 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -112 |
# |            LossPi |            57.5 |
# |             LossQ |           0.597 |
# |              Time |             470 |
# ---------------------------------------

# %%
progress = read_progress('m2_005')
np.mean(progress[:,1])
# Out:
# -403.78617500000007

# %% [markdown]
# # Apply m2_005 on real gyro

# %%
pkl_file = open('gyro_data/m2_ep001-010_np.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m2_ep011-020_np.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m2_ep021-030_np.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m2_ep031-040_np.pkl', 'rb')
data4 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m2_ep041-050_np.pkl', 'rb')
data5 = pickle.load(pkl_file)
pkl_file.close()

# %%
data = np.concatenate((data1,data2,data3,data4,data5), axis=0)
data.shape
# Out:
# (750, 111, 9)

# %% [markdown]
# # Continue training on virtual environment

# %%
# env_name = 'GyroscopeEnv-v1'
env_name = 'GyroscopeRealEnv-v0'

# simu_args = {
#     'dt': 0.05,
#     'ep_len': 100,
#     'seed': 2
# }
simu_args = {
    'ep_len': 100,
    'data': data
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

pkl_file = open('m2_005/ac.pkl', 'rb')
trained_ac = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m2_005/ac_targ.pkl', 'rb')
trained_ac_targ = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m2_005/replay_buffer.pkl', 'rb')
trained_bf = pickle.load(pkl_file)
pkl_file.close()

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 50, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 0,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m3_005', exp_name='m3_005'),
                    save_file = True,
                    trained_ac = trained_ac,
                    trained_ac_targ = trained_ac_targ,
                    trained_bf = trained_bf)
# Out:
# Warning: Log dir m3_005 already exists! Storing info there anyway.
# Logging data to m3_005/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ff3dfaf5830>, 'GyroscopeRealEnv-v0', simu_args={'ep_len': 100, 'data': array([[[-4.71238898e-03,  5.13363048e-01, -1.99176974e+00, ...,\n          2.06086650e+01,  3.07843300e-01,  4.03320300e-01],\n        [ 6.75442421e-02,  1.21217818e+00, -1.67761048e+00, ...,\n          2.09554855e+01,  4.93698700e-01,  1.00000000e+00],\n        [ 1.50796447e-01,  1.63770544e+00, -1.19851760e+00, ...,\n          2.13252274e+01, -7.25266600e-01, -6.00585900e-01],\n        ...,\n        [-1.88495559e-02, -2.03810918e+00, -1.44513262e-01, ...,\n          2.06791573e+01,  6.66278800e-01, -1.00000000e+00],\n        [-7.06858347e-02, -1.52157647e+00, -4.08407045e-01, ...,\n          2.05724475e+01,  9.92000000e-01, -1.00000000e+00],\n        [-1.57079633e-03,  5.61041743e-01, -8.54513202e-01, ...,\n          2.06388702e+01,  9.92000000e-01,  1.00000000e+00]],\n\n       [[ 1.61634942e+00, -3.73555347e+00, -2.57453518e+00, ...,\n          3.10613769e-01,  9.92000000e-01,  8.40820300e-01],\n        [ 1.44984501e+00, -3.44021790e+00, -2.77088472e+00, ...,\n          8.18039625e-01,  5.42059100e-01,  9.77539100e-01],\n        [ 1.30847334e+00, -2.98851154e+00, -2.72690242e+00, ...,\n          1.42700856e+00,  9.92000000e-01,  1.00000000e+00],\n        ...,\n        [ 2.64836261e+00, -9.45051703e-01, -1.35559723e+00, ...,\n          1.71631626e+00,  9.92000000e-01, -4.80957000e-01],\n        [ 2.63108385e+00, -5.82111462e-01, -1.30533175e+00, ...,\n          1.58868969e+00,  9.92000000e-01,  3.12011700e-01],\n        [ 2.64679181e+00
>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"m3_005",
#         "output_dir":	"m3_005"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.002,
#     "polyak":	0.999,
#     "q_lr":	0.002,
#     "replay_size":	8000000,
#     "save_file":	true,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	0,
#     "steps_per_epoch":	1500,
#     "trained_ac":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.4344,  -5.5380,  -8.1407,  -6.9230,  -9.9556,  -1.4806,  -3.9646,\n         -8.9681,  -5.7635,  -9.1023,   0.9582,  -6.0323,  -6.4484,  -9.2994,\n         -5.7720,  -4.0092,  -8.6107,  -9.1097,  -2.2610,  -3.5554,  -9.9075,\n         -7.8330,  -5.6212, -12.2287,  -7.3978,  -6.2638,  -1.1104,  -5.2996,\n         -9.2584,  -5.8012,   0.1999,  -5.5582,  -2.0984,  -0.5022,  -6.5517,\n         -6.2855,  -3.3328,  -9.2565,  -2.5474,  -7.3338,  -9.0176,  -4.0715,\n         -9.5894,  -8.3306,  -2.0691,  -5.5306,  -4.1076,  -5.7684,  -7.4886,\n         -9.4348,  -3.8473,  -5.0075,  -6.2870, -10.3446,  -8.4037,  -7.9890,\n         -8.1820,  -8.1028,  -4.0648,  -3.6177,  -9.3400,  -7.6043,  -7.9388,\n         -4.7741,  -5.9955,  -5.9822,  -7.1257,  -5.4255,  -7.2375,  -9.3628,\n         -9.1226,  -4.3665,  -3.3085,  -3.7648,  -3.3087,  -7.7017,  -0.1735,\n        -10.4268,  -7.9761,  -3.7038,  -4.1915,  -4.6282,  -7.7889,  -4.6166,\n          0.3973, -12.5296,  -5.9667,  -0.9200,  -9.2487,  -6.2287,  -6.2655,\n         -2.6914,  -0.0408,  -4.9883,  -2.2767,  -0.9869,  -7.7025,  -3.7641,\n         -0.2076,  -4.6276,  -3.0992,  -6.4455,  -3.4897,   1.5002,  -0.8952,\n         -5.4055,  -7.9232,  -4.5360,  -3.1350,  -4.4056,  -1.3183,  -9.6121,\n         -4.8508,  -9.5573,  -8.1599,  -7.2728,  -8.4919,  -4.7950,  -9.4331,\n         -4.1782,  -2.7135, -11.0611,  -8.3234,  -8.2067,  -4.4189,  -3.2810,\n         -6.7601,  -5.9392], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.6993e+00,  2.6757e+00, -2.9063e+00,  ..., -6.2835e+00,\n         -9.6200e-02,  1.0267e-01],\n        [ 4.2837e+00, -4.7696e-01,  4.2110e+00,  ..., -1.0728e+01,\n         -2.4696e-01,  1.6041e+00],\n        [ 6.8763e-01,  4.7371e+00,  4.4637e+00,  ..., -7.2715e+00,\n         -6.2248e-01,  3.3631e+00],\n        ...,\n        [ 2.7017e+00,  3.2496e+00,  3.4308e+00,  ..., -5.0435e+00,\n         -1.1803e-01,  2.1693e+00],\n        [ 4.4306e-03,  2.9812e-02,  4.7166e-01,  ..., -1.3412e-01,\n          8.7108e+00, -5.2383e-01],\n        [ 6.8976e-02,  1.2893e-02,  5.2247e+00,  ..., -5.6862e-02,\n         -3.0801e+00, -3.6478e+00]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	9,
#                                                 "out_features":	128,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "1":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "2":	{
#                                             "Linear(in_features=128, out_features=32, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -6.0446, -16.5962,  -7.9836,  -0.7866, -12.5365, -11.9680,  -0.1615,\n          1.1150,   5.5155,   3.5648,  -8.9879, -11.6850,  -0.3228,  -8.8546,\n         -0.2213,   5.6741, -10.1134,  -0.1996,  -2.3945,  -1.2404,  -6.1541,\n         -0.1171, -12.5153,   8.2206,   4.8039, -21.7654,  -2.3881,   5.5763,\n        -13.6833,  -2.6767,   8.3457,  -8.2653], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[  0.1609,   0.3674,  -0.1214,  ...,   0.3018,  -3.5143,  -3.0354],\n        [ -0.3872, -12.7734,  15.9775,  ...,  -7.6768,  -0.1797,  -0.1095],\n        [ -0.4650,   3.3334,  -0.7368,  ...,   3.2590, -29.4526,   5.5388],\n        ...,\n        [  1.4799,   0.0695,  -6.3913,  ...,  -0.1702,  -1.2864,   0.1203],\n        [ -2.3612,  -0.1888,  -5.6155,  ...,  -0.4402,   0.0552,  -7.3471],\n        [ -4.2621,  -0.4340,  -5.7887,  ...,  -0.8196,  -6.5095,   4.7295]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.4626,  0.2646], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-4.4787e-03, -1.9264e-03,  2.8984e-02, -1.3183e-03,  1.2197e-01,\n         -1.4231e+00,  1.1686e-01,  2.5490e-02, -2.5922e-01, -3.5878e-03,\n         -2.6823e-02,  1.2324e-01, -1.1750e-01,  5.9274e-02,  1.2731e-02,\n          2.6030e-01, -3.5831e-02,  1.0261e-02,  3.9625e-02, -6.1218e-03,\n          6.5856e-03, -1.3078e-02,  7.5135e-01, -6.4769e-01, -4.8988e-03,\n         -1.2204e+00,  4.9764e-03,  9.7646e-02,  6.7942e-02, -9.0894e-02,\n         -1.7302e-01,  9.5371e-01],\n        [-1.1930e-01, -1.9305e-01,  2.6402e-01, -1.1631e-01,  2.2260e-03,\n          4.5532e-02,  4.1893e-02,  3.3673e-01, -7.9673e-04, -1.7046e-01,\n          1.1137e-01, -2.1960e-03,  2.9891e-02,  2.0395e-01,  1.6695e-01,\n         -1.1324e-02, -4.6938e-02, -1.3314e-01, -1.0237e-01,  1.3926e-01,\n          1.1055e-01, -5.5357e-02, -1.8403e-03,  2.6906e-03,  1.0847e-01,\n          2.6781e-02, -2.0305e-01, -1.6817e-03,  2.4106e-01,  1.0987e-02,\n         -1.5734e-03, -4.3411e-03]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.7674e+00,  7.6969e+00,  1.2761e-02, -1.2593e+01,  2.0292e+00,\n        -5.9302e+00, -2.8144e-02, -1.4182e+01, -1.2794e+01,  4.2006e+00,\n        -8.0609e-02, -3.4945e+00,  9.1181e+00,  1.6389e+00, -6.9933e+00,\n        -5.9419e+00, -8.4943e+00, -6.9087e+00, -1.5405e+00, -2.2087e+00,\n        -1.0015e+01, -6.9217e+00,  1.3441e+00, -1.8509e+00, -2.6835e-01,\n        -1.2826e+01,  4.0555e+00,  2.7983e-01,  4.3164e-01, -1.1554e+01,\n
bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-9.8573e-02, -1.3937e-01,  2.0398e+00,  3.0679e+00, -7.9359e-02,\n        -1.3589e+01,  4.3284e+00, -3.2680e-02, -5.6332e-02, -4.7576e-02,\n        -1.5050e-01,  3.0303e+00,  1.0939e+00,  3.1040e-02, -1.6035e+01,\n        -2.1969e+01,  3.8807e-02, -1.4026e-01,  2.2205e+00,  6.5472e+00,\n        -8.3115e-02,  2.3593e+00, -3.0902e-02, -1.1642e-01,  1.1372e-03,\n        -1.6033e-01,  5.7710e-02, -1.0711e-01, -1.8341e+01,  2.3355e-02,\n         7.1323e-01,  1.9654e+00], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0544e-02,  6.5698e-02, -8.4443e-03,  ..., -4.2085e-02,\n         -9.9345e-02, -4.1872e-02],\n        [-3.5127e-02, -3.5187e-02, -3.5977e-02,  ..., -4.2726e-02,\n         -3.9361e-02,  2.6798e-02],\n        [ 4.6558e+00,  6.8166e+00, -4.3899e+00,  ...,  5.2457e-02,\n         -7.0831e-01, -2.6442e+00],\n        ...,\n        [ 4.1420e-02, -9.7629e-02, -9.2679e-02,  ..., -1.4161e-02,\n          1.7957e-02, -5.4993e-02],\n        [ 6.1704e+00,  4.1544e+00,  1.3135e+00,  ..., -1.0758e-01,\n          4.7075e+00, -1.0758e+01],\n        [ 1.4136e+01,  1.2054e+00, -9.0406e-02,  ...,  3.1950e-02,\n         -4.7467e-01,  1.3202e+00]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-15.7666], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0582,  0.0168, -0.0973, -0.1199,  0.1131,  0.1154, -0.1740,  0.0582,\n         -0.0034,  0.1523,  0.0558, -0.1027, -0.0930,  0.0573,  0.0966,  0.1062,\n         -0.1777, -0.0309, -0.0665, -0.3676,  0.0461, -0.0881,  0.0355, -0.0415,\n          0.0740, -0.0158, -0.1307, -0.0019,  0.1624,  0.1100, -0.0961, -0.1316]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Identity()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "trained_ac_targ":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.4008,  -5.5830,  -8.1142,  -6.8848,  -9.9299,  -1.4639,  -3.9570,\n         -8.9770,  -5.7594,  -9.1238,   0.9786,  -5.9937,  -6.4580,  -9.2868,\n         -5.7715,  -4.0378,  -8.6217,  -9.1462,  -2.2672,  -3.5481,  -9.8904,\n         -7.8572,  -5.6224, -12.2247,  -7.4154,  -6.2702,  -1.1408,  -5.3014,\n         -9.2688,  -5.8087,   0.1534,  -5.5218,  -2.1383,  -0.4842,  -6.5435,\n         -6.3134,  -3.3262,  -9.2451,  -2.5418,  -7.3286,  -9.0524,  -4.0824,\n         -9.5721,  -8.3046,  -2.0596,  -5.5477,  -4.1098,  -5.8002,  -7.4856,\n         -9.4225,  -3.7858,  -4.9826,  -6.2595, -10.3586,  -8.4285,  -7.9894,\n         -8.1852,  -8.0905,  -4.0680,  -3.6455,  -9.3118,  -7.5852,  -7.9136,\n         -4.7969,  -6.0113,  -5.9842,  -7.0960,  -5.4469,  -7.2455,  -9.3633,\n         -9.1136,  -4.3803,  -3.3173,  -3.7729,  -3.2939,  -7.7182,  -0.1962,\n        -10.4262,  -8.0027,  -3.6992,  -4.1959,  -4.6307,  -7.7840,  -4.6123,\n          0.4040, -12.4824,  -5.9776,  -0.9385,  -9.2565,  -6.2211,  -6.2729,\n         -2.6899,  -0.0421,  -4.9794,  -2.2675,  -0.9760,  -7.7180,  -3.7503,\n         -0.2178,  -4.6447,  -3.1160,  -6.4644,  -3.4998,   1.5031,  -0.8940,\n         -5.3959,  -7.9390,  -4.5595,  -3.1352,  -4.4037,  -1.3275,  -9.6305,\n         -4.8342,  -9.5636,  -8.1684,  -7.2734,  -8.4060,  -4.7777,  -9.4398,\n         -4.1890,  -2.6939, -11.1437,  -8.2899,  -8.1805,  -4.4382,  -3.2937,\n         -6.7797,  -5.9174])",
#                                                     "weight":	"Parameter containing:\ntensor([[ -1.6851,   2.6979,  -2.9729,  ...,  -6.3064,  -0.0722,   0.0979],\n        [  4.2509,  -0.5102,   4.2030,  ..., -10.7018,  -0.2247,   1.5776],\n        [  0.6383,   4.8121,   4.4891,  ...,  -7.3044,  -0.6624,   3.3692],\n        ...,\n        [  2.6728,   3.2205,   3.4182,  ...,  -5.0469,  -0.1189,   2.1366],\n        [  0.0433,   0.0408,   0.4801,  ...,  -0.0973,   8.6879,  -0.4796],\n        [  0.1050,   0.0217,   5.2356,  ...,  -0.1117,  -3.0956,  -3.6679]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":

#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.7537e+00,  7.6974e+00,  4.0616e-03, -1.2590e+01,  2.0317e+00,\n        -5.9385e+00, -2.8144e-02, -1.4191e+01, -1.2784e+01,  4.1879e+00,\n        -8.0605e-02, -3.4976e+00,  9.1194e+00,  1.6398e+00, -6.9927e+00,\n        -5.9356e+00, -8.4706e+00, -6.8961e+00, -1.5391e+00, -2.2149e+00,\n        -1.0007e+01, -6.9209e+00,  1.3313e+00, -1.8348e+00, -2.6833e-01,\n        -1.2828e+01,  4.0637e+00,  2.8040e-01,  4.2898e-01, -1.1575e+01,\n        -1.0046e-02, -7.3140e+00, -3.3801e+00, -2.9229e-01, -1.1669e-01,\n        -9.2007e+00,  2.5184e+00,  3.1993e+00, -6.8917e-01, -2.6579e+00,\n        -1.0227e+01, -2.5571e-01, -4.3594e+00, -9.6804e+00, -1.0498e-01,\n        -5.4371e+00,  4.4388e+00, -9.1484e-01, -9.9950e+00, -7.1836e+00,\n        -5.2546e+00,  6.8185e-01, -1.2311e+01, -1.1536e+01, -1.7375e-01,\n        -3.2490e+00, -6.7615e+00, -8.0498e+00, -2.9729e+00, -1.1655e+01,\n        -4.5676e+00, -1.4230e+00,  8.7217e-01, -6.0683e-01, -3.9415e+00,\n        -4.7486e+00, -1.6298e+00, -6.9593e+00,  5.7452e-01, -4.2258e+00,\n        -1.2572e+00, -1.5095e-01, -3.9358e+00, -6.8643e+00, -5.0176e+00,\n        -7.1320e+00, -1.0074e+01, -1.1163e+01, -6.4169e+00,  7.3359e+00,\n         1.3116e+00, -5.9968e+00, -1.8480e+00, -7.8601e+00, -3.8121e+00,\n        -4.5294e+00, -1.4050e+01, -5.2467e-01,  6.0157e+00, -4.4399e+00,\n        -6.1994e+00, -5.8152e+00, -7.5885e+00,  4.2417e+00, -1.5564e+00,\n        -3.0243e+00, -4.1482e-01,  8.4263e+00, -1.1536e+00, -1.4377e+00,\n        -6.2090e+00, -3.8090e+00, -2.2156e+00,  7.2289e+00,  1.2579e+00,\n         2.8758e-02, -2.8685e+00,  6.1489e-01, -6.4968e+00, -8.3284e+00,\n         6.4593e-01, -7.7601e-01, -2.4176e+00,  7.5612e+00,  2.4461e+00,\n        -6.6270e-02, -5.2767e-01, -1.3614e+01, -8.9856e+00, -3.7902e-01,\n        -7.1371e+00, -4.3537e+00, -1.6050e+01, -7.7234e+00, -6.5845e+00,\n        -1.2301e-01, -1.5146e+00, -8.7335e+00])",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.6992e-01,  3.1129e-02,  1.7451e-01,  ...,  1.1165e-01,\n          3.8809e-02,  4.3328e-01],\n        [-4.2464e+00, -1.2326e+00,  3.4983e+00,  ...,  5.2866e-03,\n          1.6551e-01,  8.3001e-02],\n        [ 2.5679e-02,  1.0157e-02,  1.6716e+01,  ..., -2.8448e-02,\n          1.2241e+00, -3.2961e-02],\n        ...,\n        [ 1.1620e-02,  2.1487e-03,  4.2147e-04,  ...,  3.1047e-03,\n          2.4454e-02,  4.5736e-03],\n        [ 2.8719e-02, -1.8797e-01,  4.1915e+00,  ..., -3.6378e+00,\n          2.6722e-01,  9.2923e-01],\n        [ 7.0404e-03,  1.1357e-02,  1.1459e+00,  ...,  3.5746e-02,\n          9.4304e-02,  8.0975e-01]])"
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -402 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -447 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            28.5 |
# |      MaxTestEpRet |            -360 |
# |      MinTestEpRet |            -449 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.43 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -117 |
# |            LossPi |            57.6 |
# |             LossQ |           0.665 |
# |              Time |             328 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -446 |
# |  AverageTestEpRet |            -382 |
# |      StdTestEpRet |            27.3 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -438 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -57.8 |
# |          StdQVals |            8.39 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -117 |
# |            LossPi |            57.6 |
# |             LossQ |           0.665 |
# |              Time |             338 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            27.3 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -477 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |              23 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.45 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -113 |
# |            LossPi |            57.6 |
# |             LossQ |           0.678 |
# |              Time |             349 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |            -369 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            27.8 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.43 |
# |          MaxQVals |           -48.5 |
# |          MinQVals |            -111 |
# |            LossPi |            57.6 |
# |             LossQ |           0.677 |
# |              Time |             363 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -386 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -334 |
# |          MinEpRet |            -425 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            29.6 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -471 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.47 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -135 |
# |            LossPi |            57.6 |
# |             LossQ |           0.672 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            29.8 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -463 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            19.6 |
# |      MaxTestEpRet |            -377 |
# |      MinTestEpRet |            -437 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.41 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -112 |
# |            LossPi |            57.6 |
# |             LossQ |            0.69 |
# |              Time |             386 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -453 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            30.4 |
# |      MaxTestEpRet |            -360 |
# |      MinTestEpRet |            -473 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |           -57.8 |
# |          StdQVals |            8.42 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -114 |
# |            LossPi |            57.6 |
# |             LossQ |            0.66 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -406 |
# |          StdEpRet |            28.7 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -396 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |            -349 |
# |      MinTestEpRet |            -420 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.45 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -116 |
# |            LossPi |            57.6 |
# |             LossQ |           0.683 |
# |              Time |             406 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            22.1 |
# |          MaxEpRet |            -354 |
# |          MinEpRet |            -435 |
# |  AverageTestEpRet |            -409 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -387 |
# |      MinTestEpRet |            -435 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -57.8 |
# |          StdQVals |            8.39 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -122 |
# |            LossPi |            57.6 |
# |             LossQ |           0.674 |
# |              Time |             417 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -394 |
# |          StdEpRet |            32.5 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |              23 |
# |      MaxTestEpRet |            -378 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.46 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -113 |
# |            LossPi |            57.6 |
# |             LossQ |           0.692 |
# |              Time |             431 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |            36.8 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            24.6 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.44 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -120 |
# |            LossPi |            57.6 |
# |             LossQ |           0.683 |
# |              Time |             442 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -388 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -432 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |            20.9 |
# |      MaxTestEpRet |            -357 |
# |      MinTestEpRet |            -416 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.44 |
# |          MaxQVals |           -48.5 |
# |          MinQVals |            -122 |
# |            LossPi |            57.6 |
# |             LossQ |           0.706 |
# |              Time |             452 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            15.1 |
# |      MaxTestEpRet |            -386 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.41 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -112 |
# |            LossPi |            57.6 |
# |             LossQ |           0.684 |
# |              Time |             462 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            21.8 |
# |          MaxEpRet |            -375 |
# |          MinEpRet |            -448 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.43 |
# |          MaxQVals |           -48.5 |
# |          MinQVals |            -140 |
# |            LossPi |            57.6 |
# |             LossQ |           0.683 |
# |              Time |             472 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |            -354 |
# |          MinEpRet |            -462 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            26.9 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |            -464 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |             8.5 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -114 |
# |            LossPi |            57.7 |
# |             LossQ |           0.699 |
# |              Time |             485 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |            20.2 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -453 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -433 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.46 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -115 |
# |            LossPi |            57.7 |
# |             LossQ |           0.692 |
# |              Time |             496 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            18.4 |
# |          MaxEpRet |            -372 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |            -373 |
# |      MinTestEpRet |            -447 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.42 |
# |          MaxQVals |           -48.5 |
# |          MinQVals |            -110 |
# |            LossPi |            57.7 |
# |             LossQ |           0.689 |
# |              Time |             511 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |            -372 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |           -57.9 |
# |          StdQVals |            8.44 |
# |          MaxQVals |           -48.6 |
# |          MinQVals |            -114 |
# |            LossPi |            57.7 |
# |             LossQ |           0.701 |
# |              Time |             524 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -411 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -360 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            24.5 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -446 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |            8.47 |
# |          MaxQVals |           -48.6 |
# |          MinQVals |            -111 |
# |            LossPi |            57.7 |
# |             LossQ |             0.7 |
# |              Time |             533 |
# ---------------------------------------

# %%
progress = read_progress('m3_005')
np.mean(progress[:,1])
# Out:
# -399.8493876

# %% [markdown]
# # Apply m3_005 on real gyro

# %%
pkl_file = open('gyro_data/m3_ep001-010_np.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m3_ep011-020_np.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m3_ep021-030_np.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m3_ep031-040_np.pkl', 'rb')
data4 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m3_ep041-050_np.pkl', 'rb')
data5 = pickle.load(pkl_file)
pkl_file.close()

# %%
data = np.concatenate((data1,data2,data3,data4,data5), axis=0)
data.shape
# Out:
# (750, 111, 9)

# %% [markdown]
# # Continue training on virtual environment

# %%
# env_name = 'GyroscopeEnv-v1'
env_name = 'GyroscopeRealEnv-v0'

# simu_args = {
#     'dt': 0.05,
#     'ep_len': 100,
#     'seed': 2
# }
simu_args = {
    'ep_len': 100,
    'data': data
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

pkl_file = open('m3_005/ac.pkl', 'rb')
trained_ac = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m3_005/ac_targ.pkl', 'rb')
trained_ac_targ = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m3_005/replay_buffer.pkl', 'rb')
trained_bf = pickle.load(pkl_file)
pkl_file.close()

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 50, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 0,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m4_005', exp_name='m4_005'),
                    save_file = True,
                    trained_ac = trained_ac,
                    trained_ac_targ = trained_ac_targ,
                    trained_bf = trained_bf)
# Out:
# Warning: Log dir m4_005 already exists! Storing info there anyway.
# Logging data to m4_005/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ff3dfaf5830>, 'GyroscopeRealEnv-v0', simu_args={'ep_len': 100, 'data': array([[[ 1.39800873e-01,  1.60723294e+00,  1.97606178e+00, ...,\n         -1.88373755e+01, -6.42295400e-01,  1.00000000e+00],\n        [ 1.61792022e-01,  8.17166053e-01,  2.33577414e+00, ...,\n         -1.85318030e+01,  9.40320800e-01,  1.00000000e+00],\n        [ 1.22522113e-01, -3.98092254e-01,  2.86670330e+00, ...,\n         -1.81354707e+01, -1.23606900e-01,  5.05371100e-01],\n        ...,\n        [-2.91539798e+00, -1.11910651e-01, -1.32732290e+00, ...,\n         -1.86419491e+01,  3.33271000e-02, -1.00000000e+00],\n        [-2.89654843e+00,  9.97226331e-02, -1.13568574e+00, ...,\n         -1.88571507e+01,  5.30680200e-01, -3.33496100e-01],\n        [-2.85256613e+00,  7.39465356e-01, -1.09013265e+00, ...,\n         -1.88015489e+01, -7.71256300e-01, -1.36230500e-01]],\n\n       [[ 1.89123878e+00, -8.94037579e-01,  2.31849538e+00, ...,\n          1.61469642e+01,  1.38700000e-04,  0.00000000e+00],\n        [ 1.81898215e+00, -1.37291924e+00,  2.21325202e+00, ...,\n          1.63673441e+01,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7ff22b8f0550>":	{
#             "epoch_dict":	{},
#             "exp_name":	"m4_005",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"m4_005",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='m4_005/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"m4_005",
#         "output_dir":	"m4_005"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.002,
#     "polyak":	0.999,
#     "q_lr":	0.002,
#     "replay_size":	8000000,
#     "save_file":	true,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	0,
#     "steps_per_epoch":	1500,
#     "trained_ac":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.2533,  -5.5965,  -8.1309,  -6.9213,  -9.6647,  -1.6270,  -3.8898,\n         -9.1275,  -5.6932,  -9.2192,   0.9660,  -6.0431,  -6.4413,  -9.3659,\n         -5.7981,  -3.9703,  -8.5981,  -9.2717,  -1.8997,  -3.6384,  -9.5441,\n         -7.8686,  -5.6819, -12.2608,  -7.4802,  -6.3280,  -1.1523,  -5.0503,\n         -9.2092,  -5.8819,   0.1374,  -5.6431,  -2.2176,  -0.3405,  -6.4813,\n         -6.2144,  -3.4266,  -9.3079
ires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.4731,  0.3443], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.5615e-05,  9.2360e-04,  2.0193e-02,  6.1667e-03,  1.2743e-01,\n         -1.1216e+00,  1.1686e-01,  7.9299e-03, -2.7254e-01,  1.3875e-03,\n         -1.3916e-02,  1.2316e-01, -1.1750e-01, -1.0832e-01,  1.2731e-02,\n          3.2339e-01, -3.3130e-02,  1.0261e-02,  4.5402e-02,  6.6770e-03,\n         -7.9416e-05, -1.3078e-02,  8.3617e-01, -6.5841e-01, -2.2378e-03,\n         -1.1298e+00,  1.1020e-02,  9.5988e-02,  5.1398e-02, -1.2275e-01,\n         -1.7399e-01,  1.0930e+00],\n        [-1.2810e-01, -2.7068e-01,  2.1674e-01, -1.2085e-01,  2.9389e-03,\n          9.3065e-02,  4.1893e-02,  3.0623e-01,  2.1719e-03, -1.8355e-01,\n          7.7928e-02,  5.1332e-03,  2.9891e-02,  3.3593e-01,  1.6695e-01,\n          1.0648e-02, -7.0527e-02, -1.3314e-01, -1.2595e-01,  1.6795e-01,\n          1.3244e-01, -5.5357e-02, -2.4750e-03, -7.4002e-03,  1.0189e-01,\n          8.1105e-03, -2.5249e-01, -1.0278e-03,  2.1794e-01,  8.3080e-03,\n          3.1234e-03,  6.0904e-03]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor
ires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	11,
#                                                 "out_features":	128,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "1":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "2":	{
#                                             "Linear(in_features=128, out_features=32, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-9.8573e-02, -1.3937e-01,  2.0740e+00,  3.0858e+00, -7.9359e-02,\n        -1.3695e+01,  4.2738e+00, -3.2680e-02, -5.6332e-02, -4.7576e-02,\n        -1.5050e-01,  3.0212e+00,  1.0695e+00,  3.1040e-02, -1.6083e+01,\n        -2.1993e+01,  4.8758e-03, -1.4026e-01,  2.2332e+00,  6.5529e+00,\n        -8.3115e-02,  2.3548e+00, -3.0902e-02, -1.1642e-01,  1.1372e-03,\n        -1.6033e-01, -1.9344e-02, -1.0711e-01, -1.8429e+01,  2.3355e-02,\n         7.7294e-01,  1.9422e+00], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0544e-02,  6.5698e-02, -8.4443e-03,  ..., -4.2085e-02,\n         -9.9345e-02, -4.1872e-02],\n        [-3.5127e-02, -3.5187e-02, -3.5977e-02,  ..., -4.2726e-02,\n         -3.9361e-02,  2.6798e-02],\n        [ 4.6045e+00,  6.7358e+00, -4.7158e+00,  ...,  5.2457e-02,\n         -6.7593e-01, -2.6995e+00],\n        ...,\n        [ 4.1420e-02, -9.7629e-02, -9.2679e-02,  ..., -1.4161e-02,\n          1.7957e-02, -5.4993e-02],\n        [ 6.2729e+00,  4.1926e+00,  1.2270e+00,  ..., -1.0758e-01,\n          4.7574e+00, -1.0867e+01],\n        [ 1.4147e+01,  1.1355e+00,  7.5965e-02,  ...,  3.1950e-02,\n         -4.7901e-01,  9.3637e-01]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-15.9346], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0582,  0.0168, -0.0991, -0.1290,  0.1131,  0.1193, -0.1747,  0.0582,\n         -0.0034,  0.1523,  0.0558, -0.1087, -0.0969,  0.0573,  0.1223,  0.1005,\n         -0.1739, -0.0309, -0.0635, -0.3703,  0.0461, -0.0823,  0.0355, -0.0415,\n          0.0740, -0.0158, -0.1224, -0.0019,  0.1670,  0.1100, -0.0953, -0.1215]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Identity()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "trained_ac_targ":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.2478,  -5.5929,  -8.1140,  -6.9468,  -9.6530,  -1.6242,  -3.8891,\n         -9.1294,  -5.6964,  -9.2197,   0.9716,  -6.0123,  -6.4263,  -9.3679,\n         -5.8043,  -3.9768,  -8.5916,  -9.2800,  -1.9377,  -3.6396,  -9.5606,\n         -7.8230,  -5.6640, -12.2701,  -7.4717,  -6.3202,  -1.1418,  -5.0557,\n         -9.2235,  -5.8821,   0.1272,  -5.6396,  -2.1865,  -0.3470,  -6.4835,\n         -6.2078,  -3.4309,  -9.3167,  -2.5765,  -7.3828,  -9.0735,  -4.0929,\n         -9.5852,  -8.2130,  -2.1614,  -5.6497,  -4.0298,  -5.9389,  -7.5023,\n         -9.5485,  -4.0286,  -5.0448,  -6.3208, -10.5024,  -8.4540,  -8.0013,\n         -8.1821,  -8.1541,  -4.1081,  -3.6591,  -9.2433,  -7.5199,  -7.8203,\n         -4.8302,  -6.0080,  -5.8680,  -7.0839,  -5.4695,  -7.3850,  -9.4197,\n         -9.1645,  -4.2377,  -3.4483,  -3.7998,  -3.3368,  -7.7452,  -0.1585,\n        -10.4262,  -7.9147,  -3.7716,  -4.2974,  -4.5954,  -7.8944,  -4.6148,\n          0.3746, -12.5907,  -5.8937,  -0.8420,  -9.4250,  -6.3236,  -6.1544,\n         -2.7392,  -0.0368,  -4.9537,  -2.1931,  -1.0167,  -7.6976,  -3.8263,\n         -0.2331,  -4.6589,  -3.0596,  -6.5534,  -3.3797,   1.5272,  -0.8216,\n         -5.7078,  -8.0266,  -4.6069,  -3.0627,  -4.3481,  -1.3412,  -9.6622,\n         -4.7055,  -9.6095,  -8.2288,  -7.4718,  -8.4142,  -4.8296,  -9.4581,\n         -4.2433,  -2.9365, -11.1754,  -8.3991,  -8.2185,  -4.4436,  -3.0991,\n         -6.8373,  -5.9100])",
#                                                     "weight":	"Parameter containing:\ntensor([[ -1.9304,   2.5952,  -2.6989,  ...,  -6.2422,   0.0175,   0.1536],\n        [  4.2667,  -0.4786,   4.2233,  ..., -10.6974,  -0.2481,   1.3810],\n        [  0.5567,   4.4286,   4.2102,  ...,  -7.3580,  -0.5076,   3.1635],\n        ...,\n        [  2.7081,   3.2799,   3.3231,  ...,  -5.1262,  -0.0422,   2.1532],\n        [  0.0546,   0.0156,   0.4557,  ...,  -0.0607,   8.7817,  -0.3109],\n        [ -0.0573,  -0.0358,   5.2216,  ...,  -0.1066,  -2.9533,  -3.5243]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	9,
#                                                 "out_features":	128,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "1":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "2":	{
#                                             "Linear(in_features=128, out_features=32, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -6.1252, -16.7505,  -8.3332,  -0.8477, -12.5261, -12.0898,  -0.1615,\n          0.7348,   5.4199,   3.6612,  -8.5552, -11.6677,  -0.3228,  -9.4655,\n         -0.2213,   5.8844, -10.1029,  -0.1996,  -2.2613,  -1.4296,  -5.9465,\n         -0.1171, -12.5531,   7.9609,   4.9316, -21.8093,  -2.3590,   5.9335,\n        -13.9367,  -2.8878,   8.2684,  -8.3179])",
#                                                     "weight":	"Parameter containing:\ntensor([[  0.1079,   0.5074,  -0.2072,  ...,   0.3220,  -3.4074,  -3.2069],\n        [ -0.1818, -12.7403,  15.7749,  ...,  -7.4928,   0.3781,   0.4706],\n        [ -0.7953,   3.5674,  -0.9288,  ...,   3.4020, -29.1989,   5.1501],\n        ...,\n        [  1.6218,  -0.1249,  -5.9115,  ...,   0.2491,  -1.4979,   0.5365],\n        [ -2.3720,  -0.0914,  -6.7006,  ...,  -0.3324,   0.1236,  -5.4299],\n        [ -4.3975,  -0.4971,  -5.7898,  ...,  -0.3144,  -6.5755,   5.5721]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.4812,  0.3428])",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.1751e-03, -1.4179e-03,  3.9348e-03, -6.9750e-04,  1.2563e-01,\n         -1.1040e+00,  1.1686e-01,  4.3455e-02, -2.7756e-01,  4.6757e-03,\n         -1.9586e-02,  1.2187e-01, -1.1750e-01, -1.2220e-01,  1.2731e-02,\n          3.3523e-01, -3.5268e-02,  1.0261e-02,  4.9595e-02,  5.0866e-03,\n          1.0597e-02, -1.3079e-02,  8.6475e-01, -6.7921e-01, -3.8460e-04,\n         -1.1252e+00,  4.9604e-03,  9.7150e-02,  7.0267e-02, -1.3414e-01,\n         -1.7372e-01,  1.0201e+00],\n        [-1.2286e-01, -2.6880e-01,  2.0589e-01, -1.2141e-01,  2.5939e-03,\n          3.4757e-02,  4.1897e-02,  3.1806e-01,  2.4696e-04, -1.7765e-01,\n          7.9920e-02,  1.3864e-03,  2.9891e-02,  3.0573e-01,  1.6696e-01,\n          3.2185e-03, -6.6673e-02, -1.3315e-01, -9.5107e-02,  1.6191e-01,\n          1.1760e-01, -5.5360e-02, -1.6070e-03, -2.3453e-03,  9.8102e-02,\n         -2.1215e-03, -2.4244e-01, -2.3744e-03,  1.8918e-01,  1.7456e-03,\n          1.1518e-04,  1.1814e-02]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-6.8670e+00,  7.7614e+00,  1.3155e-02, -1.2685e+01,  2.1002e+00,\n        -5.8894e+00, -2.8144e-02, -1.4273e+01, -1.2573e+01,  4.3439e+00,\n        -8.0605e-02, -3.4111e+00,  9.1015e+00,  1.6306e+00, -7.0911e+00,\n        -5.7407e+00, -8.6008e+00, -6.9305e+00, -1.6231e+00, -2.1646e+00,\n        -1.0132e+01, -6.9919e+00,  1.3951e+00, -1.9423e+00, -2.6833e-01,\n        -1.2967e+01,  3.9937e+00,  3.3015e-01,  2.6968e-01, -1.1417e+01,\n        -7.8315e-03, -7.3095e+00, -3.4240e+00, -4.6305e-01,  4.5598e-02,\n        -9.3438e+00,  2.5693e+00,  3.2298e+00, -6.1493e-01, -2.6522e+00,\n        -1.0284e+01, -2.9851e-01, -4.5226e+00, -9.8991e+00, -1.5549e-01,\n        -5.3657e+00,  4.4533e+00, -7.4627e-01, -1.0118e+01, -7.2269e+00,\n        -5.2202e+00,  5.4347e-01, -1.2464e+01, -1.1547e+01, -7.4618e-02,\n        -3.1183e+00, -6.7110e+00, -8.0818e+00, -2.8200e+00, -1.1091e+01,\n        -4.5482e+00, -1.3438e+00,  9.0393e-01, -5.4913e-01, -3.8894e+00,\n        -4.7458e+00, -1.6021e+00, -6.8972e+00,  7.3492e-01, -4.2112e+00,\n        -1.3086e+00, -5.1923e-02, -4.0163e+00, -6.8358e+00, -5.0870e+00,\n        -7.1263e+00, -1.0044e+01, -1.1255e+01, -6.4269e+00,  7.3879e+00,\n         1.2077e+00, -6.0511e+00, -1.8331e+00, -7.8763e+00, -3.6730e+00,\n        -4.6603e+00, -1.4121e+01, -4.1636e-01,  6.0579e+00, -4.3701e+00,\n        -6.1968e+00, -5.8795e+00, -7.6500e+00,  4.2517e+00, -1.5214e+00,\n        -3.0772e+00, -3.4834e-01,  8.4733e+00, -1.2666e+00, -1.5526e+00,\n        -6.2539e+00, -3.7509e+00, -2.2448e+00,  7.2458e+00,  1.2731e+00,\n         5.5076e-02, -2.8278e+00,  6.0771e-01, -6.6143e+00, -8.5435e+00,\n         5.8133e-01, -7.8606e-01, -2.4340e+00,  7.5029e+00,  2.4776e+00,\n        -6.6270e-02, -6.1653e-01, -1.3794e+01, -8.8378e+00, -3.7902e-01,\n        -7.1215e+00, -4.2983e+00, -1.6164e+01, -7.5496e+00, -6.6098e+00,\n        -1.2301e-01, -1.4075e+00, -8.8115e+00])",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.6719e-01,  7.1751e-02,  4.5165e-01,  ...,  7.0061e-02,\n          9.0593e-02,  3.9611e-01],\n        [-4.2193e+00, -1.3250e+00,  3.4523e+00,  ...,  6.9864e-03,\n          1.4526e-01,  6.4870e-02],\n        [ 3.5692e-02,  1.2677e-02,  1.7327e+01,  ..., -2.5601e-02,\n          1.2257e+00, -2.7171e-02],\n        ...,\n        [ 1.1620e-02,  2.1487e-03,  4.2147e-04,  ...,  3.1047e-03,\n          2.4454e-02,  4.5736e-03],\n        [-2.1740e-02, -9.8366e-02,  4.2944e+00,  ..., -3.6910e+00,\n          2.7382e-01,  9.0435e-01],\n        [ 6.7148e-03,  2.2389e-02,  1.2293e+00,  ...,  3.0197e-02,\n          1.3735e-01,  7.6699e-01]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	11,
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            17.7 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            26.7 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -462 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         4.8e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -115 |
# |            LossPi |            57.8 |
# |             LossQ |           0.768 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -389 |
# |          StdEpRet |              26 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -386 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -363 |
# |      MinTestEpRet |            -431 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -116 |
# |            LossPi |            57.8 |
# |             LossQ |           0.784 |
# |              Time |             316 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            30.8 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            26.4 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -438 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -121 |
# |            LossPi |            57.8 |
# |             LossQ |           0.789 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -402 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -403 |
# |      StdTestEpRet |            23.9 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.54 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -112 |
# |            LossPi |            57.8 |
# |             LossQ |           0.792 |
# |              Time |             334 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -397 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -452 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.53 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -112 |
# |            LossPi |            57.8 |
# |             LossQ |           0.769 |
# |              Time |             343 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |            -423 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |            8.47 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -133 |
# |            LossPi |            57.7 |
# |             LossQ |           0.792 |
# |              Time |             353 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -445 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            29.7 |
# |      MaxTestEpRet |            -363 |
# |      MinTestEpRet |            -449 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |            8.48 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -118 |
# |            LossPi |            57.8 |
# |             LossQ |           0.769 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -351 |
# |          MinEpRet |            -433 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            23.4 |
# |      MaxTestEpRet |            -360 |
# |      MinTestEpRet |            -426 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -111 |
# |            LossPi |            57.8 |
# |             LossQ |           0.787 |
# |              Time |             371 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -414 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |            -377 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |              30 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -456 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -114 |
# |            LossPi |            57.8 |
# |             LossQ |           0.793 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -393 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -448 |
# |  AverageTestEpRet |            -399 |
# |      StdTestEpRet |            33.4 |
# |      MaxTestEpRet |            -351 |
# |      MinTestEpRet |            -459 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |             8.5 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -115 |
# |            LossPi |            57.8 |
# |             LossQ |           0.804 |
# |              Time |             390 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -437 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.55 |
# |          MaxQVals |           -47.9 |
# |          MinQVals |            -117 |
# |            LossPi |            57.8 |
# |             LossQ |           0.802 |
# |              Time |             399 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |            -355 |
# |          MinEpRet |            -466 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |              29 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.53 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -114 |
# |            LossPi |            57.8 |
# |             LossQ |           0.788 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -401 |
# |          StdEpRet |            20.4 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |            -440 |
# |  AverageTestEpRet |            -407 |
# |      StdTestEpRet |            32.2 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -463 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.52 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -117 |
# |            LossPi |            57.8 |
# |             LossQ |           0.806 |
# |              Time |             417 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |              30 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |            -405 |
# |      StdTestEpRet |              24 |
# |      MaxTestEpRet |            -367 |
# |      MinTestEpRet |            -460 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |            8.49 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -111 |
# |            LossPi |            57.8 |
# |             LossQ |           0.784 |
# |              Time |             427 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -403 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -457 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.64 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -133 |
# |            LossPi |            57.9 |
# |             LossQ |            0.81 |
# |              Time |             437 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -434 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -376 |
# |      MinTestEpRet |            -440 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.58 |
# |          MaxQVals |           -47.9 |
# |          MinQVals |            -114 |
# |            LossPi |            57.8 |
# |             LossQ |           0.807 |
# |              Time |             446 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            14.8 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |            -418 |
# |  AverageTestEpRet |            -400 |
# |      StdTestEpRet |            20.6 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.55 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -116 |
# |            LossPi |            57.8 |
# |             LossQ |           0.812 |
# |              Time |             455 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -388 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -384 |
# |      StdTestEpRet |            20.9 |
# |      MaxTestEpRet |            -356 |
# |      MinTestEpRet |            -428 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |             -58 |
# |          StdQVals |            8.48 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -118 |
# |            LossPi |            57.8 |
# |             LossQ |           0.797 |
# |              Time |             464 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -409 |
# |          StdEpRet |              26 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |            -390 |
# |      StdTestEpRet |            27.6 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.55 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -115 |
# |            LossPi |            57.8 |
# |             LossQ |           0.808 |
# |              Time |             475 |
# ---------------------------------------

# %%
progress = read_progress('m4_005')
np.mean(progress[:,1])
# Out:
# -399.66352020000005

# %% [markdown]
# # Apply m4_005 on real gyro

# %%
pkl_file = open('gyro_data/m4_ep001-010_np.pkl', 'rb')
data1 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m4_ep011-020_np.pkl', 'rb')
data2 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m4_ep021-030_np.pkl', 'rb')
data3 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m4_ep031-040_np.pkl', 'rb')
data4 = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('gyro_data/m4_ep041-050_np.pkl', 'rb')
data5 = pickle.load(pkl_file)
pkl_file.close()

# %%
data = np.concatenate((data1,data2,data3,data4,data5), axis=0)
data.shape
# Out:
# (750, 111, 9)

# %% [markdown]
# # Continue training on virtual environment

# %%
# env_name = 'GyroscopeEnv-v1'
env_name = 'GyroscopeRealEnv-v0'

# simu_args = {
#     'dt': 0.05,
#     'ep_len': 100,
#     'seed': 2
# }
simu_args = {
    'ep_len': 100,
    'data': data
}
reward_func = 'PE'
reward_args = {
    'qx1': 1, 
    'qx2': 0.2, 
    'qx3': 1, 
    'qx4': 0.2, 
    'pu1': 0.1, 
    'pu2': 0.1,
    'p': 0.1,
    'e': 40
}
env_fn_ = partial(env_fn, env_name, simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

pkl_file = open('m4_005/ac.pkl', 'rb')
trained_ac = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m4_005/ac_targ.pkl', 'rb')
trained_ac_targ = pickle.load(pkl_file)
pkl_file.close()

pkl_file = open('m4_005/replay_buffer.pkl', 'rb')
trained_bf = pickle.load(pkl_file)
pkl_file.close()

spinup.ddpg_pytorch(env_fn_, 
                    ac_kwargs = dict(hidden_sizes=[128,32], activation=torch.nn.ReLU), 
                    seed = 0, 
                    steps_per_epoch = 1500, 
                    epochs = 50, 
                    replay_size = 8000000, 
                    gamma = 0.96, 
                    polyak = 0.999, 
                    pi_lr = 0.002,
                    q_lr = 0.002,
                    batch_size = 100, 
                    start_steps = 0,
                    act_noise = 0.1,
                    max_ep_len = 100, 
                    logger_kwargs = dict(output_dir='m5_005', exp_name='m5_005'),
                    save_file = True,
                    trained_ac = trained_ac,
                    trained_ac_targ = trained_ac_targ,
                    trained_bf = trained_bf)
# Out:
# Warning: Log dir m5_005 already exists! Storing info there anyway.
# Logging data to m5_005/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             128,
#             32
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7ff3dfaf5830>, 'GyroscopeRealEnv-v0', simu_args={'ep_len': 100, 'data': array([[[-1.77499985e-01, -9.38700136e-01, -2.65150420e+00, ...,\n          6.85860549e+00,  1.38700000e-04,  0.00000000e+00],\n        [-2.18340689e-01, -8.32815792e-01, -2.65464579e+00, ...,\n          6.86982621e+00, -9.50000000e-01,  1.00000000e+00],\n        [-2.76460154e-01, -1.01291450e+00, -2.48185820e+00, ...,\n          6.89572016e+00, -9.50000000e-01,  3.52050800e-01],\n        ...,\n        [ 2.52426970e+00, -6.33611067e-01, -2.70019889e+00, ...,\n          7.23305129e+00,  8.91960400e-01,  6.21582000e-01],\n        [ 2.54940244e+00,  2.16500344e-01, -2.43787590e+00, ...,\n          7.27983840e+00,  9.92000000e-01,  1.52343800e-01],\n        [ 2.62637146e+00,  1.20080572e+00, -2.09544230e+00, ...,\n          7.54344860e+00, -9.50000000e-01, -1.00000000e+00
#     "epochs":	50,
#     "exp_name":	"m5_005",
#     "gamma":	0.96,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7ff34f56eb90>":	{
#             "epoch_dict":	{},
#             "exp_name":	"m5_005",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"m5_005",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='m5_005/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"m5_005",
#         "output_dir":	"m5_005"
#     },
#     "max_ep_len":	100,
#     "num_test_episodes":	10,
#     "pi_lr":	0.002,
#     "polyak":	0.999,
#     "q_lr":	0.002,
#     "replay_size":	8000000,
#     "save_file":	true,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	0,
#     "steps_per_epoch":	1500,
#     "trained_ac":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor
ires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 1.2305e-01,  5.0741e-01, -2.4634e-01,  ...,  3.3369e-01,\n         -3.0619e+00, -3.0675e+00],\n        [-2.9730e-01, -1.2801e+01,  1.5017e+01,  ..., -7.5482e+00,\n          6.0584e-01,  3.6786e-01],\n        [-1.4047e+00,  4.0354e+00, -1.0109e+00,  ...,  3.2513e+00,\n         -2.8116e+01,  4.1064e+00],\n        ...,\n        [ 1.6460e+00, -1.8892e-01, -4.9183e+00,  ...,  5.5295e-03,\n         -1.4489e+00,  2.2853e-01],\n        [-2.3120e+00, -4.4541e-02, -7.2351e+00,  ..., -6.2039e-01,\n          2.2855e-01, -3.9098e+00],\n        [-4.8760e+00, -4.5031e-01, -4.9995e+00,  ..., -1.9046e-01,\n         -6.6770e+00,  5.5924e+00]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.5119,  0.4016], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.0479e-02, -4.6744e-02, -1.7856e-02, -1.6646e-03,  9.2170e-02,\n         -1.1332e+00,  1.1686e-01,  1.0263e-01, -3.2683e-01, -4.5558e-03,\n         -9.7457e-03,  8.8859e-02, -1.1750e-01, -7.1556e-02,  1.2731e-02,\n          3.1100e-01, -2.7975e-02,  1.0261e-02,  2.6715e-02,  2.4555e-04,\n          2.0103e-02, -1.3078e-02,  8.7590e-01, -6.5855e-01, -2.4509e-03,\n         -8.0480e-01,  2.5799e-02,  9.5310e-02,  1.0321e-01, -1.2339e-01,\n         -1.7118e-01,  1.4030e+00],\n        [-1.2142e-01, -2.9797e-01,  2.3766e-01, -1.2417e-01,  6.4727e-03,\n         -6.0355e-02,  4.1893e-02,  2.5331e-01,  9.2051e-03, -1.7950e-01,\n          7.6557e-02, -5.3359e-04,  2.9891e-02,  2.2650e-01,  1.6695e-01,\n         -5.9983e-03, -5.5813e-02, -1.3314e-01, -8.6640e-02,  1.4997e-01,\n          1.2435e-01, -5.5357e-02,  8.8473e-03, -1.0575e-02,  1.0463e-01,\n         -5.0969e-04, -2.7953e-01, -8.2849e-03,  2.8053e-01,  1.7934e-02,\n          1.1415e-03,  7.7317e-03]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
ires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.3005e-01,  1.2524e-01,  6.5079e-01,  ...,  9.5560e-02,\n          1.2860e-01,  4.2578e-01],\n        [-4.2373e+00, -1.3609e+00,  3.5461e+00,  ...,  8.5815e-03,\n          1.5809e-01,  1.0031e-01],\n        [ 2.4284e-02,  4.7450e-03,  1.7967e+01,  ..., -3.9650e-02,\n          1.1997e+00, -7.3748e-02],\n        ...,\n        [ 1.1620e-02,  2.1488e-03,  4.2146e-04,  ...,  3.1048e-03,\n          2.4453e-02,  4.5731e-03],\n        [-8.6765e-02, -9.4777e-02,  4.4492e+00,  ..., -3.5459e+00,\n          4.2291e-01,  8.7642e-01],\n        [ 1.7123e-02,  5.4772e-02,  1.4529e+00,  ...,  2.1840e-02,\n          1.5744e-01,  7.2544e-01]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	11,
#                                                 "out_features":	128,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "1":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "2":	{
#                                             "Linear(in_features=128, out_features=32, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-9.8573e-02, -1.3937e-01,  2.0774e+00,  3.0832e+00, -7.9359e-02,\n        -1.3702e+01,  4.2189e+00, -3.2680e-02, -5.6332e-02, -4.7576e-02,\n        -1.5050e-01,  2.9806e+00,  1.0023e+00,  3.1040e-02, -1.6142e+01,\n        -2.2086e+01, -3.3566e-02, -1.4026e-01,  2.2122e+00,  6.5593e+00,\n        -8.3115e-02,  2.3532e+00, -3.0902e-02, -1.1642e-01,  1.1372e-03,\n        -1.6033e-01, -4.2928e-02, -1.0711e-01, -1.8561e+01,  2.3355e-02,\n         8.0836e-01,  1.9126e+00], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-2.0544e-02,  6.5698e-02, -8.4443e-03,  ..., -4.2085e-02,\n         -9.9345e-02, -4.1872e-02],\n        [-3.5127e-02, -3.5187e-02, -3.5977e-02,  ..., -4.2726e-02,\n         -3.9361e-02,  2.6798e-02],\n        [ 4.5542e+00,  6.6680e+00, -5.4400e+00,  ...,  5.2457e-02,\n         -5.9905e-01, -2.9419e+00],\n        ...,\n        [ 4.1420e-02, -9.7629e-02, -9.2679e-02,  ..., -1.4161e-02,\n          1.7957e-02, -5.4993e-02],\n        [ 6.5011e+00,  4.2687e+00,  1.4150e+00,  ..., -1.0758e-01,\n          4.7888e+00, -1.0639e+01],\n        [ 1.4154e+01,  1.0803e+00,  2.7820e-01,  ...,  3.1950e-02,\n         -3.4596e-01,  4.4454e-01]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-16.1085], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0582,  0.0168, -0.1113, -0.1401,  0.1131,  0.1067, -0.1816,  0.0582,\n         -0.0034,  0.1523,  0.0558, -0.1231, -0.0968,  0.0573,  0.1497,  0.1058,\n         -0.1848, -0.0309, -0.0476, -0.3705,  0.0461, -0.0877,  0.0355, -0.0415,\n          0.0740, -0.0158, -0.1355, -0.0019,  0.1634,  0.1100, -0.0904, -0.1272]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Identity()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "trained_ac_targ":	{
#         "MLPActorCritic(\n  (pi): MLPActor(\n    (pi): Sequential(\n      (0): Linear(in_features=9, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=2, bias=True)\n      (5): Tanh()\n    )\n  )\n  (q): MLPQFunction(\n    (q): Sequential(\n      (0): Linear(in_features=11, out_features=128, bias=True)\n      (1): ReLU()\n      (2): Linear(in_features=128, out_features=32, bias=True)\n      (3): ReLU()\n      (4): Linear(in_features=32, out_features=1, bias=True)\n      (5): Identity()\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "pi":	{
#                     "MLPActor(\n  (pi): Sequential(\n    (0): Linear(in_features=9, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=2, bias=True)\n    (5): Tanh()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "pi":	{
#                                 "Sequential(\n  (0): Linear(in_features=9, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=2, bias=True)\n  (5): Tanh()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=9, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -2.2446,  -5.5868,  -7.9134,  -7.0942,  -9.9440,  -1.6851,  -3.9777,\n         -9.2264,  -5.7813,  -9.3401,   0.9216,  -6.0256,  -6.3594,  -9.4039,\n         -5.7376,  -3.9656,  -8.5998,  -9.1591,  -1.5267,  -3.7656,  -9.7624,\n         -8.0148,  -5.7190, -12.3253,  -7.4294,  -6.2916,  -1.2920,  -4.8436,\n         -9.1410,  -5.8623,   0.1093,  -5.6044,  -2.1201,  -0.3665,  -6.4338,\n         -6.1756,  -3.6969,  -9.4187,  -2.5368,  -7.2524,  -9.3296,  -4.1439,\n         -9.5776,  -8.0711,  -2.1901,  -5.6288,  -3.8941,  -5.8347,  -7.6556,\n         -9.5742,  -4.2884,  -5.1375,  -6.4397, -10.6678,  -8.4831,  -7.9802,\n         -8.1967,  -8.2445,  -4.1413,  -3.6414,  -9.0735,  -7.6705,  -7.7008,\n         -4.8517,  -6.2109,  -5.8003,  -7.1355,  -5.6348,  -7.3752,  -9.4639,\n         -9.2584,  -4.3520,  -3.4963,  -3.7760,  -3.3097,  -7.7828,  -0.0300,\n        -10.4262,  -7.9267,  -3.8696,  -4.3707,  -4.5550,  -7.9939,  -4.7869,\n          0.2634, -12.6538,  -6.0034,  -0.7298,  -9.5990,  -6.3739,  -6.2519,\n         -2.8072,   0.0503,  -4.9916,  -2.1637,  -0.9474,  -7.6876,  -3.9789,\n         -0.2923,  -4.6724,  -2.9227,  -6.5049,  -3.3716,   1.5309,  -0.8406,\n         -5.7691,  -8.0081,  -4.5666,  -2.9881,  -4.2290,  -1.4842,  -9.5218,\n         -4.7552,  -9.5572,  -8.2442,  -7.4875,  -8.3788,  -4.7352,  -9.4990,\n         -4.2460,  -3.0683, -11.0746,  -8.4930,  -8.1399,  -4.4130,  -3.0159,\n         -6.7781,  -5.8024])",
#                                                     "weight":	"Parameter containing:\ntensor([[ -2.0452,   2.4427,  -2.6784,  ...,  -6.1264,   0.0747,   0.2881],\n        [  4.3685,  -0.3371,   4.0559,  ..., -10.7871,  -0.2327,   1.5299],\n        [  0.1317,   4.4160,   4.0254,  ...,  -7.2530,  -0.5371,   3.3501],\n        ...,\n        [  2.6617,   3.2380,   3.2668,  ...,  -5.2282,  -0.0588,   2.2326],\n        [  0.0788,  -0.0351,   0.1651,  ...,  -0.0664,   8.8743,  -0.1146],\n        [  0.0145,   0.1173,   5.1761,  ...,  -0.0481,  -3.3347,  -3.3525]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	9,
#                                                 "out_features":	128,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "1":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "2":	{
#                                             "Linear(in_features=128, out_features=32, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ -6.2012, -16.5823,  -8.6844,  -0.9720, -12.6402, -12.2246,  -0.1615,\n          0.4122,   5.2766,   4.1055,  -8.2450, -11.9409,  -0.3228,  -9.6437,\n         -0.2213,   5.8610, -10.2918,  -0.1996,  -2.2180,  -1.7488,  -5.7636,\n         -0.1171, -12.6135,   7.7612,   5.0435, -22.1092,  -2.3732,   6.3095,\n        -13.7864,  -3.2519,   8.0988,  -8.3703])",
#                                                     "weight":	"Parameter containing:\ntensor([[ 1.3038e-01,  5.3150e-01, -1.9591e-01,  ...,  3.4391e-01,\n         -3.0831e+00, -3.1538e+00],\n        [-3.3395e-01, -1.2827e+01,  1.5005e+01,  ..., -7.5906e+00,\n          5.8485e-01,  3.2418e-01],\n        [-1.4155e+00,  3.9933e+00, -9.5979e-01,  ...,  3.2627e+00,\n         -2.8152e+01,  4.1536e+00],\n        ...,\n        [ 1.5922e+00, -2.3587e-01, -4.9816e+00,  ...,  5.1308e-02,\n         -1.4440e+00,  2.4716e-01],\n        [-2.3118e+00, -2.6673e-02, -7.1741e+00,  ..., -6.3585e-01,\n          1.9917e-01, -3.9575e+00],\n        [-4.9291e+00, -4.4260e-01, -5.0607e+00,  ..., -2.2614e-01,\n         -6.6572e+00,  5.5494e+00]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	128,
#                                                 "out_features":	32,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "3":	{
#                                             "ReLU()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "inplace":	false,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "4":	{
#                                             "Linear(in_features=32, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.5155,  0.4085])",
#                                                     "weight":	"Parameter containing:\ntensor([[-1.4595e-03, -1.1143e-02,  7.4984e-03, -2.8612e-03,  8.9510e-02,\n         -1.0900e+00,  1.1686e-01,  6.3956e-02, -3.2603e-01,  1.1047e-03,\n         -1.5087e-02,  1.0058e-01, -1.1750e-01, -2.9507e-02,  1.2731e-02,\n          2.8573e-01, -4.1596e-02,  1.0261e-02,  4.1224e-02,  3.4987e-03,\n          1.0540e-02, -1.3079e-02,  8.8050e-01, -6.9522e-01, -5.1231e-04,\n         -8.1257e-01,  3.7868e-03,  9.5695e-02,  9.5700e-02, -1.2536e-01,\n         -1.6768e-01,  1.3208e+00],\n        [-1.2669e-01, -2.6445e-01,  2.1198e-01, -1.2238e-01,  8.6852e-04,\n         -7.9909e-02,  4.1897e-02,  2.8029e-01,  4.6426e-04, -1.9684e-01,\n          8.2181e-02,  4.9409e-04,  2.9891e-02,  2.6947e-01,  1.6696e-01,\n          7.9418e-04, -7.1114e-02, -1.3315e-01, -9.7655e-02,  1.6206e-01,\n          1.1553e-01, -5.5360e-02,  1.6334e-03, -2.9248e-03,  9.9464e-02,\n          6.4404e-03, -2.6466e-01, -5.3273e-03,  3.0750e-01,  6.6284e-03,\n          1.6840e-03,  3.0872e-03]])"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	32,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "5":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "act_limit":	"1.0",
#                         "training":	true
#                     }
#                 },
#                 "q":	{
#                     "MLPQFunction(\n  (q): Sequential(\n    (0): Linear(in_features=11, out_features=128, bias=True)\n    (1): ReLU()\n    (2): Linear(in_features=128, out_features=32, bias=True)\n    (3): ReLU()\n    (4): Linear(in_features=32, out_features=1, bias=True)\n    (5): Identity()\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "q":	{
#                                 "Sequential(\n  (0): Linear(in_features=11, out_features=128, bias=True)\n  (1): ReLU()\n  (2): Linear(in_features=128, out_features=32, bias=True)\n  (3): ReLU()\n  (4): Linear(in_features=32, out_features=1, bias=True)\n  (5): Identity()\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "0":	{
#                                             "Linear(in_features=11, out_features=128, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
|
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -387 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -353 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.57 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -121 |
# |            LossPi |            57.9 |
# |             LossQ |           0.906 |
# |              Time |             420 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -399 |
# |          StdEpRet |            24.4 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |            -459 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            17.6 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -421 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.1e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.59 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -115 |
# |            LossPi |            57.9 |
# |             LossQ |           0.897 |
# |              Time |             432 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -352 |
# |          MinEpRet |            -437 |
# |  AverageTestEpRet |            -395 |
# |      StdTestEpRet |            32.9 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |            -448 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.25e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.58 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -118 |
# |            LossPi |            57.9 |
# |             LossQ |           0.906 |
# |              Time |             444 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -394 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -420 |
# |  AverageTestEpRet |            -394 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |            -345 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.4e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.59 |
# |          MaxQVals |           -47.7 |
# |          MinQVals |            -118 |
# |            LossPi |            57.9 |
# |             LossQ |           0.891 |
# |              Time |             456 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -442 |
# |  AverageTestEpRet |            -402 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |            -374 |
# |      MinTestEpRet |            -454 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.55e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |             8.6 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -142 |
# |            LossPi |            57.9 |
# |             LossQ |           0.923 |
# |              Time |             469 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -400 |
# |          StdEpRet |            23.7 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |            -444 |
# |  AverageTestEpRet |            -411 |
# |      StdTestEpRet |            31.1 |
# |      MaxTestEpRet |            -362 |
# |      MinTestEpRet |            -474 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         5.7e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.54 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -118 |
# |            LossPi |            57.9 |
# |             LossQ |           0.881 |
# |              Time |             481 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -404 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            31.9 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -458 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        5.85e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.62 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -109 |
# |            LossPi |            57.9 |
# |             LossQ |           0.924 |
# |              Time |             493 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            25.5 |
# |          MaxEpRet |            -350 |
# |          MinEpRet |            -439 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            32.2 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -489 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |           6e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.57 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -112 |
# |            LossPi |            57.9 |
# |             LossQ |           0.911 |
# |              Time |             505 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -403 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |            -358 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            24.3 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |            -436 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.15e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.56 |
# |          MaxQVals |           -48.3 |
# |          MinQVals |            -109 |
# |            LossPi |            57.9 |
# |             LossQ |           0.928 |
# |              Time |             519 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -354 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -383 |
# |      StdTestEpRet |            18.1 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |            -414 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.3e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.63 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -121 |
# |            LossPi |              58 |
# |             LossQ |           0.913 |
# |              Time |             531 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -408 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -450 |
# |  AverageTestEpRet |            -408 |
# |      StdTestEpRet |            22.7 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |            -443 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.45e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.61 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -111 |
# |            LossPi |            57.9 |
# |             LossQ |           0.919 |
# |              Time |             544 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -391 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |            -430 |
# |  AverageTestEpRet |            -386 |
# |      StdTestEpRet |              26 |
# |      MaxTestEpRet |            -357 |
# |      MinTestEpRet |            -437 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.59 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -119 |
# |            LossPi |            57.9 |
# |             LossQ |           0.917 |
# |              Time |             556 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -397 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -471 |
# |  AverageTestEpRet |            -404 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -379 |
# |      MinTestEpRet |            -426 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        6.75e+04 |
# |      AverageQVals |           -58.1 |
# |          StdQVals |            8.54 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -110 |
# |            LossPi |            57.9 |
# |             LossQ |           0.897 |
# |              Time |             568 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -390 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |            -428 |
# |  AverageTestEpRet |            -423 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -402 |
# |      MinTestEpRet |            -471 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         6.9e+04 |
# |      AverageQVals |           -58.3 |
# |          StdQVals |            8.65 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -132 |
# |            LossPi |              58 |
# |             LossQ |           0.918 |
# |              Time |             580 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -396 |
# |          StdEpRet |            18.1 |
# |          MaxEpRet |            -371 |
# |          MinEpRet |            -441 |
# |  AverageTestEpRet |            -398 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |            -371 |
# |      MinTestEpRet |            -445 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.05e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.66 |
# |          MaxQVals |           -48.1 |
# |          MinQVals |            -122 |
# |            LossPi |              58 |
# |             LossQ |           0.911 |
# |              Time |             592 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -398 |
# |          StdEpRet |            25.5 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -449 |
# |  AverageTestEpRet |            -389 |
# |      StdTestEpRet |            20.6 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |            -421 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.2e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.65 |
# |          MaxQVals |             -48 |
# |          MinQVals |            -115 |
# |            LossPi |              58 |
# |             LossQ |           0.928 |
# |              Time |             605 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -397 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |            -451 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |            26.1 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |            -439 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |        7.35e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.58 |
# |          MaxQVals |           -48.2 |
# |          MinQVals |            -118 |
# |            LossPi |            57.9 |
# |             LossQ |           0.919 |
# |              Time |             618 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -395 |
# |          StdEpRet |            35.2 |
# |          MaxEpRet |            -359 |
# |          MinEpRet |            -480 |
# |  AverageTestEpRet |            -392 |
# |      StdTestEpRet |            19.9 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -442 |
# |             EpLen |             100 |
# |         TestEpLen |             100 |
# | TotalEnvInteracts |         7.5e+04 |
# |      AverageQVals |           -58.2 |
# |          StdQVals |            8.62 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -111 |
# |            LossPi |              58 |
# |             LossQ |           0.911 |
# |              Time |             630 |
# ---------------------------------------

# %%
progress = read_progress('m5_005')
np.mean(progress[:,1])
# Out:
# -397.1045966000001
