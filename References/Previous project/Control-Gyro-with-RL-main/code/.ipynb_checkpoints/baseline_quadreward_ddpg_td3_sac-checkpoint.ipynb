# %% [markdown]
# # DDPG/TD3/SAC training of baseline with quadratic reward (spinup library)
#
# ## Keep only part of code to run some test

# %%
import gym
from gym import spaces
from gym.utils import seeding

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

import gym_gyroscope_env

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from functools import partial

# %% [markdown]
# ## Environment Class and Modules

# %%
simu_args = {
    'dt': 0.05,
    'ep_len': 110,
    'seed': 2
}
reward_func = 'Quadratic'
reward_args = {
    'qx1': 9, 
    'qx2': 0.05, 
    'qx3': 9, 
    'qx4': 0.05, 
    'pu1': 0.1, 
    'pu2': 0.1, 
    # 'bound': 0.1, 
    # 'penalty': 50
}
env_fn = partial(env_fn, env_name = 'GyroscopeEnv-v0', simu_args = simu_args, reward_func = reward_func, reward_args = reward_args)

# %% [markdown]
# ## Training

# %% [markdown]
# #### DDPG

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_b0', exp_name='ddpg_b0')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, 
                    replay_size = repsize_b, gamma = gamma_b, polyak = polyak_b, batch_size = batchsize_b, 
                    start_steps = startsteps_b, max_ep_len = maxeplen_b, logger_kwargs = logger_kwargs, 
                    act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_b0 already exists! Storing info there anyway.
# Logging data to ddpg_b0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fa286d64320>, env_name='GyroscopeEnv-v0', simu_args={'dt': 0.05, 'ep_len': 110, 'seed': 2}, reward_func='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1})",
#     "epochs":	100,
#     "exp_name":	"ddpg_b0",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fa28e30c450>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_b0",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_b0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_b0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_b0",
#         "output_dir":	"ddpg_b0"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -5.47e+03 |
# |          StdEpRet |        1.82e+03 |
# |          MaxEpRet |          -2e+03 |
# |          MinEpRet |       -8.27e+03 |
# |  AverageTestEpRet |       -6.47e+03 |
# |      StdTestEpRet |        2.69e+03 |
# |      MaxTestEpRet |          -3e+03 |
# |      MinTestEpRet |       -1.22e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |           -88.4 |
# |          StdQVals |            54.7 |
# |          MaxQVals |           0.267 |
# |          MinQVals |            -309 |
# |            LossPi |            85.7 |
# |             LossQ |             939 |
# |              Time |            7.75 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |        -6.7e+03 |
# |          StdEpRet |        1.25e+03 |
# |          MaxEpRet |       -5.05e+03 |
# |          MinEpRet |       -9.82e+03 |
# |  AverageTestEpRet |       -5.41e+03 |
# |      StdTestEpRet |        2.88e+03 |
# |      MaxTestEpRet |       -1.42e+03 |
# |      MinTestEpRet |       -1.19e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -321 |
# |          StdQVals |             163 |
# |          MaxQVals |           -39.4 |
# |          MinQVals |            -951 |
# |            LossPi |             310 |
# |             LossQ |        1.02e+03 |
# |              Time |            20.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -7.54e+03 |
# |          StdEpRet |        1.96e+03 |
# |          MaxEpRet |       -3.39e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -4.61e+03 |
# |      StdTestEpRet |         2.3e+03 |
# |      MaxTestEpRet |       -1.52e+03 |
# |      MinTestEpRet |       -8.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -627 |
# |          StdQVals |             234 |
# |          MaxQVals |           -62.4 |
# |          MinQVals |       -1.57e+03 |
# |            LossPi |             606 |
# |             LossQ |        2.06e+03 |
# |              Time |            33.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -7.82e+03 |
# |          StdEpRet |        2.09e+03 |
# |          MaxEpRet |       -5.13e+03 |
# |          MinEpRet |       -1.12e+04 |
# |  AverageTestEpRet |       -2.43e+03 |
# |      StdTestEpRet |        2.03e+03 |
# |      MaxTestEpRet |            -410 |
# |      MinTestEpRet |       -6.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |            -905 |
# |          StdQVals |             308 |
# |          MaxQVals |            -154 |
# |          MinQVals |       -2.07e+03 |
# |            LossPi |             878 |
# |             LossQ |        2.63e+03 |
# |              Time |            46.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -6.46e+03 |
# |          StdEpRet |        2.21e+03 |
# |          MaxEpRet |       -4.02e+03 |
# |          MinEpRet |       -1.18e+04 |
# |  AverageTestEpRet |       -3.51e+03 |
# |      StdTestEpRet |        2.22e+03 |
# |      MaxTestEpRet |       -1.01e+03 |
# |      MinTestEpRet |       -7.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             377 |
# |          MaxQVals |            -276 |
# |          MinQVals |       -2.44e+03 |
# |            LossPi |        1.12e+03 |
# |             LossQ |        3.01e+03 |
# |              Time |            58.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -6.98e+03 |
# |          StdEpRet |        1.88e+03 |
# |          MaxEpRet |       -3.25e+03 |
# |          MinEpRet |       -9.95e+03 |
# |  AverageTestEpRet |       -2.72e+03 |
# |      StdTestEpRet |        2.01e+03 |
# |      MaxTestEpRet |            -481 |
# |      MinTestEpRet |       -7.41e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -1.34e+03 |
# |          StdQVals |             432 |
# |          MaxQVals |            -306 |
# |          MinQVals |       -2.73e+03 |
# |            LossPi |         1.3e+03 |
# |             LossQ |        3.33e+03 |
# |              Time |              73 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -2.49e+03 |
# |          StdEpRet |        2.72e+03 |
# |          MaxEpRet |            -136 |
# |          MinEpRet |          -9e+03 |
# |  AverageTestEpRet |        -2.3e+03 |
# |      StdTestEpRet |         1.2e+03 |
# |      MaxTestEpRet |            -633 |
# |      MinTestEpRet |       -4.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -1.46e+03 |
# |          StdQVals |             495 |
# |          MaxQVals |            -280 |
# |          MinQVals |          -3e+03 |
# |            LossPi |        1.42e+03 |
# |             LossQ |        3.59e+03 |
# |              Time |            87.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -2.51e+03 |
# |          StdEpRet |        1.99e+03 |
# |          MaxEpRet |           -76.3 |
# |          MinEpRet |        -7.8e+03 |
# |  AverageTestEpRet |       -1.83e+03 |
# |      StdTestEpRet |        2.14e+03 |
# |      MaxTestEpRet |            -284 |
# |      MinTestEpRet |       -7.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -1.49e+03 |
# |          StdQVals |             546 |
# |          MaxQVals |            -287 |
# |          MinQVals |       -3.22e+03 |
# |            LossPi |        1.45e+03 |
# |             LossQ |        3.46e+03 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -3.06e+03 |
# |          StdEpRet |        2.78e+03 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |       -8.95e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |        2.15e+03 |
# |      MaxTestEpRet |            -303 |
# |      MinTestEpRet |       -7.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |        -1.5e+03 |
# |          StdQVals |             585 |
# |          MaxQVals |            -300 |
# |          MinQVals |       -3.42e+03 |
# |            LossPi |        1.46e+03 |
# |             LossQ |        3.36e+03 |
# |              Time |             117 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -2.23e+03 |
# |          StdEpRet |        2.02e+03 |
# |          MaxEpRet |            -247 |
# |          MinEpRet |       -6.32e+03 |
# |  AverageTestEpRet |       -2.16e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |            -117 |
# |      MinTestEpRet |       -5.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |        -1.5e+03 |
# |          StdQVals |             609 |
# |          MaxQVals |            -338 |
# |          MinQVals |       -3.61e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |        3.24e+03 |
# |              Time |             130 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -2.12e+03 |
# |          StdEpRet |        1.33e+03 |
# |          MaxEpRet |            -392 |
# |          MinEpRet |       -5.36e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |        1.26e+03 |
# |      MaxTestEpRet |           -53.6 |
# |      MinTestEpRet |       -3.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |        -1.5e+03 |
# |          StdQVals |             630 |
# |          MaxQVals |            -303 |
# |          MinQVals |       -3.78e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |        3.12e+03 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -1.18e+03 |
# |          StdEpRet |             591 |
# |          MaxEpRet |            -562 |
# |          MinEpRet |       -2.36e+03 |
# |  AverageTestEpRet |       -1.06e+03 |
# |      StdTestEpRet |             493 |
# |      MaxTestEpRet |            -246 |
# |      MinTestEpRet |       -1.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |        -1.5e+03 |
# |          StdQVals |             639 |
# |          MaxQVals |            -312 |
# |          MinQVals |       -3.92e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |        3.02e+03 |
# |              Time |             156 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.64e+03 |
# |          StdEpRet |             932 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |        -3.7e+03 |
# |  AverageTestEpRet |       -2.53e+03 |
# |      StdTestEpRet |        2.19e+03 |
# |      MaxTestEpRet |            -360 |
# |      MinTestEpRet |       -7.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.51e+03 |
# |          StdQVals |             644 |
# |          MaxQVals |            -325 |
# |          MinQVals |       -4.04e+03 |
# |            LossPi |        1.48e+03 |
# |             LossQ |        2.87e+03 |
# |              Time |             169 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.77e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |            -419 |
# |          MinEpRet |       -3.65e+03 |
# |  AverageTestEpRet |       -2.88e+03 |
# |      StdTestEpRet |        2.59e+03 |
# |      MaxTestEpRet |            -586 |
# |      MinTestEpRet |       -9.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -1.49e+03 |
# |          StdQVals |             652 |
# |          MaxQVals |            -334 |
# |          MinQVals |       -4.18e+03 |
# |            LossPi |        1.46e+03 |
# |             LossQ |        2.74e+03 |
# |              Time |             182 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.76e+03 |
# |          StdEpRet |        1.14e+03 |
# |          MaxEpRet |            -240 |
# |          MinEpRet |       -5.09e+03 |
# |  AverageTestEpRet |       -1.51e+03 |
# |      StdTestEpRet |             863 |
# |      MaxTestEpRet |            -285 |
# |      MinTestEpRet |       -2.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -1.47e+03 |
# |          StdQVals |             656 |
# |          MaxQVals |            -328 |
# |          MinQVals |       -4.26e+03 |
# |            LossPi |        1.44e+03 |
# |             LossQ |         2.7e+03 |
# |              Time |             196 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.17e+03 |
# |          StdEpRet |             824 |
# |          MaxEpRet |           -60.7 |
# |          MinEpRet |       -3.85e+03 |
# |  AverageTestEpRet |       -1.35e+03 |
# |      StdTestEpRet |             843 |
# |      MaxTestEpRet |            -218 |
# |      MinTestEpRet |        -3.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -1.44e+03 |
# |          StdQVals |             666 |
# |          MaxQVals |            -314 |
# |          MinQVals |       -4.29e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |        2.63e+03 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -1.52e+03 |
# |          StdEpRet |         1.1e+03 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |       -3.83e+03 |
# |  AverageTestEpRet |       -1.82e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |            -491 |
# |      MinTestEpRet |       -4.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |        -1.4e+03 |
# |          StdQVals |             654 |
# |          MaxQVals |            -287 |
# |          MinQVals |       -4.38e+03 |
# |            LossPi |        1.38e+03 |
# |             LossQ |        2.53e+03 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -2.83e+03 |
# |          StdEpRet |        2.19e+03 |
# |          MaxEpRet |            -389 |
# |          MinEpRet |       -8.99e+03 |
# |  AverageTestEpRet |       -1.35e+03 |
# |      StdTestEpRet |             756 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |       -3.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -1.38e+03 |
# |          StdQVals |             653 |
# |          MaxQVals |            -271 |
# |          MinQVals |       -4.47e+03 |
# |            LossPi |        1.36e+03 |
# |             LossQ |        2.43e+03 |
# |              Time |             238 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |        1.05e+03 |
# |          MaxEpRet |            -260 |
# |          MinEpRet |       -4.04e+03 |
# |  AverageTestEpRet |        -1.4e+03 |
# |      StdTestEpRet |             719 |
# |      MaxTestEpRet |            -457 |
# |      MinTestEpRet |       -2.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -1.35e+03 |
# |          StdQVals |             648 |
# |          MaxQVals |            -274 |
# |          MinQVals |       -4.52e+03 |
# |            LossPi |        1.32e+03 |
# |             LossQ |        2.37e+03 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -2.04e+03 |
# |          StdEpRet |        1.92e+03 |
# |          MaxEpRet |            -364 |
# |          MinEpRet |       -8.07e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |        1.01e+03 |
# |      MaxTestEpRet |            -503 |
# |      MinTestEpRet |       -3.76e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -1.32e+03 |
# |          StdQVals |             651 |
# |          MaxQVals |            -255 |
# |          MinQVals |       -4.58e+03 |
# |            LossPi |         1.3e+03 |
# |             LossQ |        2.31e+03 |
# |              Time |             266 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -1.85e+03 |
# |          StdEpRet |        1.44e+03 |
# |          MaxEpRet |            -121 |
# |          MinEpRet |       -4.99e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |           1e+03 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |       -3.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -1.29e+03 |
# |          StdQVals |             656 |
# |          MaxQVals |            -145 |
# |          MinQVals |       -4.65e+03 |
# |            LossPi |        1.27e+03 |
# |             LossQ |        2.26e+03 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        -1.8e+03 |
# |          StdEpRet |        1.64e+03 |
# |          MaxEpRet |            -116 |
# |          MinEpRet |       -6.92e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             761 |
# |      MaxTestEpRet |            -167 |
# |      MinTestEpRet |       -2.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -1.26e+03 |
# |          StdQVals |             645 |
# |          MaxQVals |            -127 |
# |          MinQVals |       -4.66e+03 |
# |            LossPi |        1.23e+03 |
# |             LossQ |        2.21e+03 |
# |              Time |             293 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -2.45e+03 |
# |          StdEpRet |        1.63e+03 |
# |          MaxEpRet |            -529 |
# |          MinEpRet |       -6.71e+03 |
# |  AverageTestEpRet |       -2.23e+03 |
# |      StdTestEpRet |             958 |
# |      MaxTestEpRet |            -733 |
# |      MinTestEpRet |       -4.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -1.23e+03 |
# |          StdQVals |             648 |
# |          MaxQVals |           -98.2 |
# |          MinQVals |       -4.64e+03 |
# |            LossPi |        1.21e+03 |
# |             LossQ |        2.13e+03 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -1.19e+03 |
# |          StdEpRet |             759 |
# |          MaxEpRet |             -92 |
# |          MinEpRet |        -2.9e+03 |
# |  AverageTestEpRet |        -1.8e+03 |
# |      StdTestEpRet |        1.72e+03 |
# |      MaxTestEpRet |            -410 |
# |      MinTestEpRet |       -6.55e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -1.21e+03 |
# |          StdQVals |             651 |
# |          MaxQVals |           -64.1 |
# |          MinQVals |       -4.64e+03 |
# |            LossPi |        1.19e+03 |
# |             LossQ |        2.15e+03 |
# |              Time |             321 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        -1.9e+03 |
# |          StdEpRet |        1.65e+03 |
# |          MaxEpRet |            -272 |
# |          MinEpRet |       -5.73e+03 |
# |  AverageTestEpRet |       -2.12e+03 |
# |      StdTestEpRet |        1.49e+03 |
# |      MaxTestEpRet |            -630 |
# |      MinTestEpRet |       -4.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -1.18e+03 |
# |          StdQVals |             656 |
# |          MaxQVals |             -25 |
# |          MinQVals |       -4.61e+03 |
# |            LossPi |        1.16e+03 |
# |             LossQ |        2.18e+03 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        -1.4e+03 |
# |          StdEpRet |             892 |
# |          MaxEpRet |            -144 |
# |          MinEpRet |        -2.8e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |        1.01e+03 |
# |      MaxTestEpRet |            -175 |
# |      MinTestEpRet |       -3.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             661 |
# |          MaxQVals |            25.8 |
# |          MinQVals |       -4.54e+03 |
# |            LossPi |        1.13e+03 |
# |             LossQ |        2.12e+03 |
# |              Time |             349 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.61e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |            -212 |
# |          MinEpRet |       -4.69e+03 |
# |  AverageTestEpRet |       -2.37e+03 |
# |      StdTestEpRet |        1.86e+03 |
# |      MaxTestEpRet |            -287 |
# |      MinTestEpRet |       -6.61e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.12e+03 |
# |          StdQVals |             669 |
# |          MaxQVals |            68.9 |
# |          MinQVals |       -4.39e+03 |
# |            LossPi |         1.1e+03 |
# |             LossQ |        2.08e+03 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -916 |
# |          StdEpRet |             538 |
# |          MaxEpRet |            -192 |
# |          MinEpRet |       -1.86e+03 |
# |  AverageTestEpRet |       -2.23e+03 |
# |      StdTestEpRet |         2.4e+03 |
# |      MaxTestEpRet |            -242 |
# |      MinTestEpRet |       -8.69e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.08e+03 |
# |          StdQVals |             669 |
# |          MaxQVals |              99 |
# |          MinQVals |       -4.37e+03 |
# |            LossPi |        1.06e+03 |
# |             LossQ |         2.1e+03 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -1.33e+03 |
# |          StdEpRet |             839 |
# |          MaxEpRet |            -211 |
# |          MinEpRet |       -2.95e+03 |
# |  AverageTestEpRet |       -1.86e+03 |
# |      StdTestEpRet |             778 |
# |      MaxTestEpRet |            -454 |
# |      MinTestEpRet |       -3.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.04e+03 |
# |          StdQVals |             676 |
# |          MaxQVals |             129 |
# |          MinQVals |       -4.31e+03 |
# |            LossPi |        1.02e+03 |
# |             LossQ |        2.06e+03 |
# |              Time |             389 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -1.84e+03 |
# |          StdEpRet |        1.36e+03 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |       -4.79e+03 |
# |  AverageTestEpRet |       -1.47e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |            -281 |
# |      MinTestEpRet |       -5.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |          -1e+03 |
# |          StdQVals |             683 |
# |          MaxQVals |             182 |
# |          MinQVals |       -4.24e+03 |
# |            LossPi |             982 |
# |             LossQ |        2.02e+03 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.67e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |            -526 |
# |          MinEpRet |       -3.97e+03 |
# |  AverageTestEpRet |       -1.48e+03 |
# |      StdTestEpRet |        1.12e+03 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |       -4.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |            -969 |
# |          StdQVals |             689 |
# |          MaxQVals |             209 |
# |          MinQVals |       -4.17e+03 |
# |            LossPi |             948 |
# |             LossQ |        1.95e+03 |
# |              Time |             422 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -1.34e+03 |
# |          StdEpRet |             961 |
# |          MaxEpRet |            -126 |
# |          MinEpRet |        -3.4e+03 |
# |  AverageTestEpRet |       -1.16e+03 |
# |      StdTestEpRet |        1.14e+03 |
# |      MaxTestEpRet |            -216 |
# |      MinTestEpRet |       -4.05e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |            -928 |
# |          StdQVals |             687 |
# |          MaxQVals |             231 |
# |          MinQVals |       -4.12e+03 |
# |            LossPi |             907 |
# |             LossQ |        1.93e+03 |
# |              Time |             436 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -1.32e+03 |
# |          StdEpRet |             981 |
# |          MaxEpRet |           -24.9 |
# |          MinEpRet |       -3.47e+03 |
# |  AverageTestEpRet |            -873 |
# |      StdTestEpRet |             402 |
# |      MaxTestEpRet |            -304 |
# |      MinTestEpRet |       -1.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |            -880 |
# |          StdQVals |             688 |
# |          MaxQVals |             267 |
# |          MinQVals |       -4.07e+03 |
# |            LossPi |             859 |
# |             LossQ |        1.88e+03 |
# |              Time |             449 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -949 |
# |          StdEpRet |             810 |
# |          MaxEpRet |           -43.4 |
# |          MinEpRet |       -2.62e+03 |
# |  AverageTestEpRet |       -1.73e+03 |
# |      StdTestEpRet |        1.46e+03 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |       -5.38e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |            -827 |
# |          StdQVals |             690 |
# |          MaxQVals |             322 |
# |          MinQVals |       -4.01e+03 |
# |            LossPi |             805 |
# |             LossQ |        1.86e+03 |
# |              Time |             462 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -1.52e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |       -5.29e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             615 |
# |      MaxTestEpRet |            -441 |
# |      MinTestEpRet |       -2.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |            -764 |
# |          StdQVals |             697 |
# |          MaxQVals |             395 |
# |          MinQVals |       -4.04e+03 |
# |            LossPi |             741 |
# |             LossQ |        1.82e+03 |
# |              Time |             475 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -1.46e+03 |
# |          StdEpRet |             984 |
# |          MaxEpRet |            -252 |
# |          MinEpRet |       -3.17e+03 |
# |  AverageTestEpRet |       -1.07e+03 |
# |      StdTestEpRet |             747 |
# |      MaxTestEpRet |            -262 |
# |      MinTestEpRet |       -2.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |            -704 |
# |          StdQVals |             704 |
# |          MaxQVals |             515 |
# |          MinQVals |       -4.11e+03 |
# |            LossPi |             681 |
# |             LossQ |        1.79e+03 |
# |              Time |             489 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -1.46e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |       -4.39e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |        1.19e+03 |
# |      MaxTestEpRet |            -116 |
# |      MinTestEpRet |       -4.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |            -637 |
# |          StdQVals |             709 |
# |          MaxQVals |             595 |
# |          MinQVals |       -4.07e+03 |
# |            LossPi |             613 |
# |             LossQ |        1.73e+03 |
# |              Time |             502 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -1.13e+03 |
# |          StdEpRet |             796 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |       -3.04e+03 |
# |  AverageTestEpRet |            -821 |
# |      StdTestEpRet |             419 |
# |      MaxTestEpRet |            -301 |
# |      MinTestEpRet |       -1.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |            -562 |
# |          StdQVals |             704 |
# |          MaxQVals |             638 |
# |          MinQVals |       -3.98e+03 |
# |            LossPi |             537 |
# |             LossQ |        1.68e+03 |
# |              Time |             515 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -985 |
# |          StdEpRet |             369 |
# |          MaxEpRet |            -373 |
# |          MinEpRet |       -1.57e+03 |
# |  AverageTestEpRet |       -1.16e+03 |
# |      StdTestEpRet |             848 |
# |      MaxTestEpRet |           -68.2 |
# |      MinTestEpRet |       -3.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |            -492 |
# |          StdQVals |             696 |
# |          MaxQVals |             721 |
# |          MinQVals |       -3.92e+03 |
# |            LossPi |             468 |
# |             LossQ |        1.64e+03 |
# |              Time |             528 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -1.15e+03 |
# |          StdEpRet |             948 |
# |          MaxEpRet |           -37.2 |
# |          MinEpRet |       -3.34e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |             848 |
# |      MaxTestEpRet |            -142 |
# |      MinTestEpRet |       -2.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |            -423 |
# |          StdQVals |             684 |
# |          MaxQVals |             753 |
# |          MinQVals |       -3.92e+03 |
# |            LossPi |             400 |
# |             LossQ |         1.6e+03 |
# |              Time |             542 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -1.35e+03 |
# |          StdEpRet |             797 |
# |          MaxEpRet |            -266 |
# |          MinEpRet |       -3.36e+03 |
# |  AverageTestEpRet |       -1.47e+03 |
# |      StdTestEpRet |        1.23e+03 |
# |      MaxTestEpRet |             -66 |
# |      MinTestEpRet |       -4.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |            -357 |
# |          StdQVals |             673 |
# |          MaxQVals |             805 |
# |          MinQVals |       -3.88e+03 |
# |            LossPi |             333 |
# |             LossQ |        1.53e+03 |
# |              Time |             561 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             472 |
# |          MaxEpRet |            -216 |
# |          MinEpRet |        -2.4e+03 |
# |  AverageTestEpRet |        -1.5e+03 |
# |      StdTestEpRet |        1.03e+03 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |       -3.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |            -293 |
# |          StdQVals |             665 |
# |          MaxQVals |             843 |
# |          MinQVals |       -3.76e+03 |
# |            LossPi |             270 |
# |             LossQ |        1.48e+03 |
# |              Time |             577 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -1.05e+03 |
# |          StdEpRet |             732 |
# |          MaxEpRet |            -141 |
# |          MinEpRet |       -2.46e+03 |
# |  AverageTestEpRet |            -868 |
# |      StdTestEpRet |             548 |
# |      MaxTestEpRet |            -112 |
# |      MinTestEpRet |       -1.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |            -233 |
# |          StdQVals |             663 |
# |          MaxQVals |             895 |
# |          MinQVals |       -3.74e+03 |
# |            LossPi |             210 |
# |             LossQ |        1.44e+03 |
# |              Time |             592 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -1.26e+03 |
# |          StdEpRet |        1.13e+03 |
# |          MaxEpRet |            -210 |
# |          MinEpRet |       -4.57e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |             877 |
# |      MaxTestEpRet |            -238 |
# |      MinTestEpRet |       -3.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |            -175 |
# |          StdQVals |             658 |
# |          MaxQVals |             940 |
# |          MinQVals |       -3.66e+03 |
# |            LossPi |             152 |
# |             LossQ |        1.37e+03 |
# |              Time |             605 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -765 |
# |          StdEpRet |             600 |
# |          MaxEpRet |           -86.2 |
# |          MinEpRet |       -2.02e+03 |
# |  AverageTestEpRet |       -1.06e+03 |
# |      StdTestEpRet |             821 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |       -3.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |            -125 |
# |          StdQVals |             650 |
# |          MaxQVals |             983 |
# |          MinQVals |       -3.61e+03 |
# |            LossPi |             101 |
# |             LossQ |        1.37e+03 |
# |              Time |             620 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -731 |
# |          StdEpRet |             361 |
# |          MaxEpRet |            -195 |
# |          MinEpRet |       -1.43e+03 |
# |  AverageTestEpRet |            -781 |
# |      StdTestEpRet |             621 |
# |      MaxTestEpRet |            -102 |
# |      MinTestEpRet |        -2.2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |           -63.3 |
# |          StdQVals |             641 |
# |          MaxQVals |        1.01e+03 |
# |          MinQVals |       -3.44e+03 |
# |            LossPi |            40.7 |
# |             LossQ |        1.28e+03 |
# |              Time |             634 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.07e+03 |
# |          StdEpRet |             849 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |       -3.03e+03 |
# |  AverageTestEpRet |       -1.08e+03 |
# |      StdTestEpRet |        1.07e+03 |
# |      MaxTestEpRet |            -283 |
# |      MinTestEpRet |       -3.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |           -12.2 |
# |          StdQVals |             638 |
# |          MaxQVals |        1.03e+03 |
# |          MinQVals |       -3.36e+03 |
# |            LossPi |           -10.3 |
# |             LossQ |        1.26e+03 |
# |              Time |             648 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -889 |
# |          StdEpRet |             691 |
# |          MaxEpRet |            -274 |
# |          MinEpRet |       -2.89e+03 |
# |  AverageTestEpRet |            -766 |
# |      StdTestEpRet |             812 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |       -2.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |            28.8 |
# |          StdQVals |             635 |
# |          MaxQVals |        1.05e+03 |
# |          MinQVals |       -3.28e+03 |
# |            LossPi |           -51.3 |
# |             LossQ |        1.23e+03 |
# |              Time |             662 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -950 |
# |          StdEpRet |             604 |
# |          MaxEpRet |            -231 |
# |          MinEpRet |       -2.69e+03 |
# |  AverageTestEpRet |            -996 |
# |      StdTestEpRet |             521 |
# |      MaxTestEpRet |            -223 |
# |      MinTestEpRet |       -2.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |            79.9 |
# |          StdQVals |             629 |
# |          MaxQVals |        1.07e+03 |
# |          MinQVals |       -3.23e+03 |
# |            LossPi |            -102 |
# |             LossQ |        1.22e+03 |
# |              Time |             682 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |             724 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |       -2.73e+03 |
# |  AverageTestEpRet |       -1.39e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |            -243 |
# |      MinTestEpRet |       -4.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |             119 |
# |          StdQVals |             627 |
# |          MaxQVals |         1.1e+03 |
# |          MinQVals |       -3.13e+03 |
# |            LossPi |            -141 |
# |             LossQ |        1.18e+03 |
# |              Time |             696 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -884 |
# |          StdEpRet |             619 |
# |          MaxEpRet |            -140 |
# |          MinEpRet |       -2.01e+03 |
# |  AverageTestEpRet |          -1e+03 |
# |      StdTestEpRet |             381 |
# |      MaxTestEpRet |            -312 |
# |      MinTestEpRet |       -1.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |             165 |
# |          StdQVals |             618 |
# |          MaxQVals |        1.13e+03 |
# |          MinQVals |       -3.09e+03 |
# |            LossPi |            -187 |
# |             LossQ |        1.18e+03 |
# |              Time |             710 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -948 |
# |          StdEpRet |             713 |
# |          MaxEpRet |            -297 |
# |          MinEpRet |          -3e+03 |
# |  AverageTestEpRet |       -1.06e+03 |
# |      StdTestEpRet |             740 |
# |      MaxTestEpRet |            -251 |
# |      MinTestEpRet |       -2.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |             206 |
# |          StdQVals |             609 |
# |          MaxQVals |        1.18e+03 |
# |          MinQVals |          -3e+03 |
# |            LossPi |            -227 |
# |             LossQ |        1.16e+03 |
# |              Time |             723 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -878 |
# |          StdEpRet |             578 |
# |          MaxEpRet |            -115 |
# |          MinEpRet |        -2.2e+03 |
# |  AverageTestEpRet |       -1.11e+03 |
# |      StdTestEpRet |             886 |
# |      MaxTestEpRet |           -44.8 |
# |      MinTestEpRet |       -2.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |             241 |
# |          StdQVals |             610 |
# |          MaxQVals |        1.23e+03 |
# |          MinQVals |       -2.89e+03 |
# |            LossPi |            -261 |
# |             LossQ |        1.12e+03 |
# |              Time |             737 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -937 |
# |          StdEpRet |             818 |
# |          MaxEpRet |            -149 |
# |          MinEpRet |       -2.96e+03 |
# |  AverageTestEpRet |       -1.03e+03 |
# |      StdTestEpRet |             594 |
# |      MaxTestEpRet |            -414 |
# |      MinTestEpRet |       -2.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |             280 |
# |          StdQVals |             601 |
# |          MaxQVals |        1.28e+03 |
# |          MinQVals |       -2.88e+03 |
# |            LossPi |            -300 |
# |             LossQ |        1.05e+03 |
# |              Time |             752 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -915 |
# |          StdEpRet |             557 |
# |          MaxEpRet |            -268 |
# |          MinEpRet |       -2.42e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |             905 |
# |      MaxTestEpRet |            -464 |
# |      MinTestEpRet |       -3.78e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |             308 |
# |          StdQVals |             596 |
# |          MaxQVals |        1.31e+03 |
# |          MinQVals |       -2.84e+03 |
# |            LossPi |            -328 |
# |             LossQ |        1.05e+03 |
# |              Time |             767 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |            -746 |
# |          StdEpRet |             496 |
# |          MaxEpRet |           -84.7 |
# |          MinEpRet |       -1.65e+03 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -852 |
# |          StdEpRet |             502 |
# |          MaxEpRet |            -108 |
# |          MinEpRet |       -1.93e+03 |
# |  AverageTestEpRet |            -643 |
# |      StdTestEpRet |             342 |
# |      MaxTestEpRet |            -107 |
# |      MinTestEpRet |       -1.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |        1.04e+03 |
# |          StdQVals |             509 |
# |          MaxQVals |        2.03e+03 |
# |          MinQVals |       -2.34e+03 |
# |            LossPi |       -1.06e+03 |
# |             LossQ |             918 |
# |              Time |        1.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -940 |
# |          StdEpRet |             770 |
# |          MaxEpRet |            -309 |
# |          MinEpRet |        -2.8e+03 |
# |  AverageTestEpRet |            -879 |
# |      StdTestEpRet |             572 |
# |      MaxTestEpRet |            -107 |
# |      MinTestEpRet |       -2.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |        1.06e+03 |
# |          StdQVals |             505 |
# |          MaxQVals |        2.04e+03 |
# |          MinQVals |       -2.39e+03 |
# |            LossPi |       -1.08e+03 |
# |             LossQ |             907 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -992 |
# |          StdEpRet |             546 |
# |          MaxEpRet |            -332 |
# |          MinEpRet |       -2.15e+03 |
# |  AverageTestEpRet |            -949 |
# |      StdTestEpRet |             873 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |       -3.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |        1.08e+03 |
# |          StdQVals |             499 |
# |          MaxQVals |        2.05e+03 |
# |          MinQVals |       -2.38e+03 |
# |            LossPi |        -1.1e+03 |
# |             LossQ |             912 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -758 |
# |          StdEpRet |             418 |
# |          MaxEpRet |           -90.2 |
# |          MinEpRet |       -1.42e+03 |
# |  AverageTestEpRet |            -943 |
# |      StdTestEpRet |             745 |
# |      MaxTestEpRet |            -319 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |        1.09e+03 |
# |          StdQVals |             493 |
# |          MaxQVals |        2.05e+03 |
# |          MinQVals |       -2.42e+03 |
# |            LossPi |       -1.11e+03 |
# |             LossQ |             919 |
# |              Time |         1.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |       -1.09e+03 |
# |          StdEpRet |        1.13e+03 |
# |          MaxEpRet |            -423 |
# |          MinEpRet |       -5.18e+03 |
# |  AverageTestEpRet |            -877 |
# |      StdTestEpRet |             540 |
# |      MaxTestEpRet |            -109 |
# |      MinTestEpRet |       -1.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |        1.11e+03 |
# |          StdQVals |             487 |
# |          MaxQVals |        2.05e+03 |
# |          MinQVals |        -2.4e+03 |
# |            LossPi |       -1.13e+03 |
# |             LossQ |             911 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -829 |
# |          StdEpRet |             472 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |       -1.75e+03 |
# |  AverageTestEpRet |            -880 |
# |      StdTestEpRet |             387 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |        -1.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |        1.12e+03 |
# |          StdQVals |             482 |
# |          MaxQVals |        2.07e+03 |
# |          MinQVals |        -2.4e+03 |
# |            LossPi |       -1.14e+03 |
# |             LossQ |             897 |
# |              Time |        1.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -936 |
# |          StdEpRet |             435 |
# |          MaxEpRet |            -104 |
# |          MinEpRet |       -1.74e+03 |
# |  AverageTestEpRet |       -1.11e+03 |
# |      StdTestEpRet |        1.33e+03 |
# |      MaxTestEpRet |           -50.4 |
# |      MinTestEpRet |       -4.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |        1.14e+03 |
# |          StdQVals |             479 |
# |          MaxQVals |        2.09e+03 |
# |          MinQVals |       -2.29e+03 |
# |            LossPi |       -1.16e+03 |
# |             LossQ |             884 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             901 |
# |          MaxEpRet |            -311 |
# |          MinEpRet |       -3.79e+03 |
# |  AverageTestEpRet |            -764 |
# |      StdTestEpRet |             353 |
# |      MaxTestEpRet |            -319 |
# |      MinTestEpRet |       -1.51e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |        1.15e+03 |
# |          StdQVals |             478 |
# |          MaxQVals |        2.09e+03 |
# |          MinQVals |       -2.32e+03 |
# |            LossPi |       -1.17e+03 |
# |             LossQ |             882 |
# |              Time |        1.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             734 |
# |          MaxEpRet |           -67.4 |
# |          MinEpRet |       -2.55e+03 |
# |  AverageTestEpRet |       -1.15e+03 |
# |      StdTestEpRet |             757 |
# |      MaxTestEpRet |            -258 |
# |      MinTestEpRet |       -2.61e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |        1.16e+03 |
# |          StdQVals |             473 |
# |          MaxQVals |        2.08e+03 |
# |          MinQVals |       -2.28e+03 |
# |            LossPi |       -1.18e+03 |
# |             LossQ |             866 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -734 |
# |          StdEpRet |             456 |
# |          MaxEpRet |            -129 |
# |          MinEpRet |       -1.63e+03 |
# |  AverageTestEpRet |            -958 |
# |      StdTestEpRet |             988 |
# |      MaxTestEpRet |            -137 |
# |      MinTestEpRet |       -3.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |        1.18e+03 |
# |          StdQVals |             472 |
# |          MaxQVals |         2.1e+03 |
# |          MinQVals |       -2.24e+03 |
# |            LossPi |       -1.19e+03 |
# |             LossQ |             877 |
# |              Time |        1.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -856 |
# |          StdEpRet |             507 |
# |          MaxEpRet |            -119 |
# |          MinEpRet |       -2.07e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |             610 |
# |      MaxTestEpRet |            -266 |
# |      MinTestEpRet |       -2.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |        1.19e+03 |
# |          StdQVals |             467 |
# |          MaxQVals |        2.12e+03 |
# |          MinQVals |       -2.23e+03 |
# |            LossPi |       -1.21e+03 |
# |             LossQ |             890 |
# |              Time |        1.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -945 |
# |          StdEpRet |             489 |
# |          MaxEpRet |           -22.4 |
# |          MinEpRet |       -1.83e+03 |
# |  AverageTestEpRet |       -1.16e+03 |
# |      StdTestEpRet |             735 |
# |      MaxTestEpRet |            -501 |
# |      MinTestEpRet |          -3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |        1.21e+03 |
# |          StdQVals |             464 |
# |          MaxQVals |        2.13e+03 |
# |          MinQVals |       -2.12e+03 |
# |            LossPi |       -1.22e+03 |
# |             LossQ |             896 |
# |              Time |        1.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |       -1.06e+03 |
# |          StdEpRet |             553 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |       -2.48e+03 |
# |  AverageTestEpRet |            -822 |
# |      StdTestEpRet |             434 |
# |      MaxTestEpRet |            -310 |
# |      MinTestEpRet |       -1.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |        1.22e+03 |
# |          StdQVals |             458 |
# |          MaxQVals |        2.14e+03 |
# |          MinQVals |       -2.03e+03 |
# |            LossPi |       -1.24e+03 |
# |             LossQ |             892 |
# |              Time |        1.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -596 |
# |          StdEpRet |             187 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -855 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |        1.11e+03 |
# |      MaxTestEpRet |           -98.1 |
# |      MinTestEpRet |       -3.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |        1.23e+03 |
# |          StdQVals |             458 |
# |          MaxQVals |        2.17e+03 |
# |          MinQVals |          -2e+03 |
# |            LossPi |       -1.25e+03 |
# |             LossQ |             902 |
# |              Time |        1.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -931 |
# |          StdEpRet |             580 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |       -2.09e+03 |
# |  AverageTestEpRet |            -911 |
# |      StdTestEpRet |             695 |
# |      MaxTestEpRet |           -96.1 |
# |      MinTestEpRet |       -2.61e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |        1.24e+03 |
# |          StdQVals |             455 |
# |          MaxQVals |        2.19e+03 |
# |          MinQVals |       -2.02e+03 |
# |            LossPi |       -1.26e+03 |
# |             LossQ |             886 |
# |              Time |        1.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -804 |
# |          StdEpRet |             520 |
# |          MaxEpRet |            -220 |
# |          MinEpRet |       -1.87e+03 |
# |  AverageTestEpRet |            -648 |
# |      StdTestEpRet |             373 |
# |      MaxTestEpRet |           -96.4 |
# |      MinTestEpRet |       -1.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |        1.26e+03 |
# |          StdQVals |             452 |
# |          MaxQVals |         2.2e+03 |
# |          MinQVals |       -1.88e+03 |
# |            LossPi |       -1.27e+03 |
# |             LossQ |             890 |
# |              Time |        1.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |       -1.05e+03 |
# |          StdEpRet |             737 |
# |          MaxEpRet |            -188 |
# |          MinEpRet |       -2.78e+03 |
# |  AverageTestEpRet |            -791 |
# |      StdTestEpRet |             562 |
# |      MaxTestEpRet |            -123 |
# |      MinTestEpRet |       -2.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |        1.27e+03 |
# |          StdQVals |             451 |
# |          MaxQVals |        2.23e+03 |
# |          MinQVals |       -1.81e+03 |
# |            LossPi |       -1.28e+03 |
# |             LossQ |             906 |
# |              Time |        1.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -694 |
# |          StdEpRet |             415 |
# |          MaxEpRet |           -56.3 |
# |          MinEpRet |       -1.54e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |             529 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |       -1.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |        1.28e+03 |
# |          StdQVals |             447 |
# |          MaxQVals |        2.25e+03 |
# |          MinQVals |       -1.84e+03 |
# |            LossPi |        -1.3e+03 |
# |             LossQ |             876 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -995 |
# |          StdEpRet |             618 |
# |          MaxEpRet |            -139 |
# |          MinEpRet |       -2.18e+03 |
# |  AverageTestEpRet |       -1.07e+03 |
# |      StdTestEpRet |             372 |
# |      MaxTestEpRet |            -616 |
# |      MinTestEpRet |       -1.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |        1.29e+03 |
# |          StdQVals |             446 |
# |          MaxQVals |        2.25e+03 |
# |          MinQVals |       -1.77e+03 |
# |            LossPi |       -1.31e+03 |
# |             LossQ |             880 |
# |              Time |        1.43e+03 |
# ---------------------------------------

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'GyroscopeEnv-v0'
agent_path = 'ddpg_b0'
# init_state = [1,1,2,1,2,1,20]
init_state = [0,0,0,0,2,2,0]
t_end = 100 * 0.05

# Perform testing
score, state_record, obs_record, action_record, reward_record = \
    test_agent(env_name, simu_args, reward_func, reward_args, agent_path, init_state, t_end)
# Out:
# Total cumulative reward: -679.9170723706239

# %% [markdown]
# ## Plot

# %%
plot_test(state_record ,action_record, t_end)

# %% [markdown]
# ## Evaluate control performance

# %%
# Single evaluation
env_name = 'GyroscopeEnv-v0'
agent_path = 'ddpg_b0'
ss_bound = 0.3
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d5e09e78a091> in <module>
#       3 agent_path = 'ddpg_b0'
#       4 ss_bound = 0.3
# ----> 5 metrics = evaluate_control(env_name,agent_path,ss_bound)
#       6 metrics
#
# ~/Desktop/Thesis/SP code/code/custom_functions/custom_functions/custom_functions.py in evaluate_control(env_name, agent_path, ss_bound)
#     200     env = gym.make(env_name) # default env
#     201     env.seed(seed)
# --> 202     dt,eval_per_dt,maxVoltage = env.access_members()
#     203     ep_len = 110
#     204     t_end = dt*ep_len
#
# AttributeError: 'GyroscopeEnv' object has no attribute 'access_members'

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['ddpg_b0','ddpg_b1','ddpg_b2','td3_b0','td3_b1','td3_b2','sac_b0','sac_b1','sac_b2',]
ss_bound = 0.3

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)

# Show
metrics

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man

# %%
# To LaTex
print(metrics_man.to_latex(escape=False))
